# %% [markdown]
# ### 001_ top  <a id="title_page"></a

# %% [markdown]
# ### 001_ pacakges  <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
parameter_w_seas=14
parameter_h_seas=13
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %%
country_database = "CANADA"

# %% [markdown]
# ### 001_ macromomentum   <a id="title_page"></a

# %%
# canada
# paye data
country_database = "CANADA"
horizon_00=120
# monthly
cai_m_tickers1 = ["vr449483", "v6j01210", 
                  "v4c90914",
                  "v1m85715", "cfo3",
                  "cfaa",
                  "ipmsi", "v1996452",
                  "v1996458",
                  "v1996473", "v2062816"]
hv_tb_ca_000_001_m = Haver.data(cai_m_tickers1, "CANADA", dates=True)
#print(hv_tb_ca_000_001_m)
# quarterly
cai_m_tickers2 = ["v6e05752", "v6e05724"]
hv_tb_ca_000_002_m = Haver.data(cai_m_tickers2, "CANADA", dates=True)
#print(hv_tb_ca_000_002_m)

hv_tb_ca_000_001_m = pd.concat([hv_tb_ca_000_001_m, hv_tb_ca_000_002_m], axis=1, join="outer")
ca_m_tickers = cai_m_tickers1 + cai_m_tickers2

#print(hv_tb_ca_000_001_m)
hv_tb_ca_000_001_m.rename(columns={"v6e05752": "Real: GDP"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v6e05724": "Real: Household Consumption"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"vr449483": "Real: Retail Trade"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v6j01210": "Real: IP"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v4c90914": "Price: CPI All Groups"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v1m85715": "Price: CPI Trimmed"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"cfo3": "Cycle: Business Barometer Short"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"cfaa": "Cycle: Business Barometer Long"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"ipmsi": "Cycle: IVEY PMI"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v1996452": "Employment: Wage Goods"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v1996458": "Employment: Wage Services"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v1996473": "Employment: Compensation Employees"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v2062816": "Employment: Participation Rate"}, inplace=True)
hv_tb_ca_000_001_m = hv_tb_ca_000_001_m.fillna(method="bfill")
hv_tb_ca_000_001_m = hv_tb_ca_000_001_m.fillna(method='ffill')
# hv_tb_ca_000_001_m.drop(hv_tb_au_000_001_m.tail(1).index, inplace=True)
# view all data in levels, see if transformation makes sense/FFILL FORWARD
hv_tb_ca_000_001_m.sort_index(ascending=False, axis=1, inplace=True)
#hv_tb_ca_000_001_m.to_clipboard()

# %%
cai_m_tickers=hv_tb_ca_000_001_m.columns
for x in range(len(cai_m_tickers)):
    #print(x)
    variable=str(cai_m_tickers[x])
    #print(variable)
    #print(hv_tb_ca_000_001_m[variable])
    hv_tb_ca_000_001_m[(str(variable)+str("_yy"))] = hv_tb_ca_000_001_m[variable].pct_change(12).multiply(100).round(3)
    hv_tb_ca_000_001_m[(str(variable)+str("_qq"))]= hv_tb_ca_000_001_m[variable].pct_change(4).multiply(100).round(3)
    hv_tb_ca_000_001_m[(str(variable)+str("_mm"))]= hv_tb_ca_000_001_m[variable].pct_change(1).multiply(100).round(3)

window_zl0=[12,24,36,60,100]
window_zl=window_zl0

cai_m_tickers=hv_tb_ca_000_001_m.columns
for x in range(len(cai_m_tickers)):
    #print(x)
    variable=str(cai_m_tickers[x])
    #print(variable)
    for y in range(len(window_zl)):
        #print(y)
        window_z=(window_zl[y])
        hv_tb_ca_000_001_m[(str(variable)+str("_zscore")+str(window_z))]=(zscore(hv_tb_ca_000_001_m[variable], window_z)).round(2)
        hv_tb_ca_000_001_m[(str(variable)+str("_zavg")+str(window_z))]=(zscore_avg(hv_tb_ca_000_001_m[variable], window_z)).round(2)

# %%
window_zl=window_zl0
for x in range(len(window_zl)):
    window_z=window_zl[x]
    window_z_1=str("zscore"+str(window_z))
    #print(window_z)
    cai_m_tickers=["Real: GDP_yy_zscore"+str(window_z),
                   "Real: Household Consumption_yy_zscore"+str(window_z),
                   "Real: Retail Trade_yy_zscore"+str(window_z),
                   "Real: IP_yy_zscore"+str(window_z),
                   "Employment: Wage Goods_yy_zscore"+str(window_z),
                   "Employment: Wage Services_yy_zscore"+str(window_z),
                   "Employment: Compensation Employees_yy_zscore"+str(window_z),
                   "Employment: Participation Rate_yy_zscore"+str(window_z),
                   "Price: CPI All Groups_yy_zscore"+str(window_z),
                   "Price: CPI Trimmed_yy_zscore"+str(window_z),
                   "Cycle: Business Barometer Short_zscore"+str(window_z),
                   "Cycle: Business Barometer Long_zscore"+str(window_z),
                   "Cycle: IVEY PMI_zscore"+str(window_z)]
    print("tickers updated")
    #print(cai_m_tickers)
    hv_tb_ca_000_002_m=hv_tb_ca_000_001_m[cai_m_tickers]
    hv_tb_ca_000_002_m.sort_index(ascending=False, axis=1, inplace=True)
    hv_tb_ca_000_002_m = hv_tb_ca_000_002_m.tail(24)
    hv_tb_ca_000_002_m = hv_tb_ca_000_002_m.transpose()
    hv_tb_ca_000_002_m.index.names = ['Variable']
    #path_display = 'dashboard_eco\table_ca_000_002z'
    #path_display=str(path_display)+str(window_z)+".csv"
    #print(path_display)
    #hv_tb_ca_000_002_m.to_csv (path_display, index=True, header=True)
    #print(hv_tb_ca_000_002_m)

    #####STACKED BARCHART
    hv_tb_ca_000_003_m=hv_tb_ca_000_001_m[cai_m_tickers]
    div=len(cai_m_tickers)
    div=div+0
    print(div)
    hv_tb_ca_000_003_m= (hv_tb_ca_000_003_m/div)
    hv_tb_ca_000_003_m=hv_tb_ca_000_003_m.tail(120)
    print(hv_tb_ca_000_003_m)
    
    ########## bar chart
    df1=hv_tb_ca_000_003_m.copy()
    
    h1=df1.copy()
    fig, ax = plt.subplots(figsize=(parameter3_s, parameter4_s))
    
    #ax= df.plot(kind='bar', stacked=True, figsize=(10, 6))
    colors = ["orange", "orange", "orange", "orange",
    "blue", "blue","blue", "blue",
    "green", "green",
    "yellow", "yellow", "yellow"]
    h1.plot(kind='bar', stacked=True, ax=ax, color=colors)
    title_r=str('CA_MacroMomentum_z'+str(window_z))
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.title(str(title_r), size=parameter5)
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(title_r), size=parameter3)
    plt.legend(title='labels', bbox_to_anchor=(1.0, 1), loc='upper left')
    plt.grid(axis='both', alpha=.3)
    ax2=ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    #loc= plticker.MultipleLocator(base=4) # this Locator puts ticks at regular intervals
    #a.xaxis.set_major_Locator (Loc)
    #date_form = DateFormatter("%m-%Y")
    #ax.xaxis.set_major_formatter(date_form)
    #ax.xaxis.set_major_Locator (mdates.YearLocator())
    #half_year_Locator = mdates.MonthLocator (interval=1)
    #ax.xaxis.set_major_Locator(half_year_Locator)
    #ax.xaxis.set_major_formatter(mdates. DateFormatter("%Y"))
    plt.savefig(str('CA_MacroMomentum_bar_z'+str(window_z)+".png"), bbox_inches="tight")
    plt.close()
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del h1
    del df1
    del fig
    del ax
    del ax2





    ########timeseries
    hv_tb_ca_000_003_m[str("CA_MacroMomentum_z"+str(window_z))] = hv_tb_ca_000_003_m[cai_m_tickers].mean(axis=1)
    hv_tb_ca_000_004_m=hv_tb_ca_000_003_m[str('CA_MacroMomentum_z'+str(window_z))]
    df1=hv_tb_ca_000_004_m.copy()
    g1=df1.copy()
    title_r=str('CA_MacroMomentum_z'+str(window_z))
    fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=[str('CA_MacroMomentum_z'+str(window_z))], color="darkorange",
    linewidth= l1, linestyle='-',  marker='s',markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')    
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('CA_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('CA_MacroMomentum_z'+str(window_z)+".png"), bbox_inches='tight')
    
    del g1
    del df1
    del fig
    del ax
    del ax2
    df1=hv_tb_ca_000_004_m.tail(24)
    g1=df1
    title_r=str('CA_MacroMomentum_z'+str(window_z))
    fig,ax=plt.subplots (figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=[str('CA_MacroMomentum_z'+str(window_z))], color="darkorange",
            linewidth= l1, linestyle='-',marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1,linestyle ='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('CA_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2= ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('CA_MacroMomentum_z'+str(window_z)+"z.png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    del fig
    del ax
    del ax2
    del hv_tb_ca_000_002_m
    del hv_tb_ca_000_003_m
    del hv_tb_ca_000_004_m
# Out:
# tickers updated
# 13
#             Real: GDP_yy_zscore12  Real: Household Consumption_yy_zscore12  \
# 2015-04-30              -0.190000                                -0.227692
# 2015-05-31              -0.141538                                -0.158462
# 2015-06-30              -0.113846                                -0.123846
# 2015-07-31              -0.129231                                -0.096923
# 2015-08-31              -0.106923                                -0.081538
# ...                           ...                                      ...
# 2024-11-30               0.115385                                 0.143077
# 2024-12-31               0.096154                                 0.114615
# 2025-01-31               0.033077                                 0.022308
# 2025-02-28               0.023846                                 0.014615
# 2025-03-31               0.011538                                 0.006154
#
# ...

# %%
#######Maacro momentum 
#######Maacro momentum 
#######Maacro momentum 
#######Maacro momentum

# %% [markdown]
# ### 001_ BOC Core Inflation  <a id="title_page"></a

# %%
horizon_tb_cad_m = 24
# Loading tickers
horizon_1 = 24
country_database = "CANADA"
ca_m_tickers = ['v1m85715', 'v1m85714', 'v1m85713']
hv_tb_cad_002_001_m = Haver.data(ca_m_tickers, country_database, dates=True)
#print(hv_tb_cad_002_001_m)
#hv_tb_cad_002_001_m[variable] = hv_tb_cad_002_001_m[variable].pct_change(12).multiply(100).round(2)
hv_tb_cad_002_001_m.rename(columns={"v1m85715": "CA BOC Core Inflation CPI Trim Y/Y"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v1m85714": "CA BOC Core Inflation CPI Median Y/Y"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v1m85713": "CA BOC Core Inflation CPI Common Y/Y"}, inplace=True)
#hv_tb_cad_002_001_m_g_001 = hv_tb_cad_002_001_m.copy()
#hv_tb_cad_002_001_m = hv_tb_cad_002_001_m.tail(horizon_1)
#hv_tb_cad_002_001_m = hv_tb_cad_002_001_m.transpose()
#hv_tb_cad_002_001_m.index.names = ['Variable']
#print(hv_tb_cad_002_001_m)



hv_tb_cad_002_001_m_g = hv_tb_cad_002_001_m.copy()
hv_tb_cad_002_001_m_g_001 = hv_tb_cad_002_001_m.copy()

hv_tb_cad_002_001_m.index=hv_tb_cad_002_001_m.index.date
hv_tb_cad_002_001_m = hv_tb_cad_002_001_m.tail(horizon_tb)
hv_tb_cad_002_001_t1=hv_tb_cad_002_001_m.tail(horizon_tb)

hv_tb_cad_002_001_m_t = hv_tb_cad_002_001_m.transpose()
hv_tb_cad_002_001_m_t.index.names = ['Variable']

hv_tb_cad_002_001_t1_t = hv_tb_cad_002_001_t1.transpose()
hv_tb_cad_002_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_ BOC Core Inflation table

# %%
############################################################
######Table 1

#####here*******
title_table="cad_boc_core_inflation_table"
df =hv_tb_cad_002_001_t1.copy()
df_transposed = hv_tb_cad_002_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_002_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_002_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_002_001_m_t_002.png')

# %% [markdown]
# ### 001_ BOC Core Inflation graphs

# %%
title_r="BOC Core Inflation"
y_label="Index %"
x_label=title_r
list_c=["CA BOC Core Inflation CPI Trim Y/Y",
        "CA BOC Core Inflation CPI Median Y/Y",
        "CA BOC Core Inflation CPI Common Y/Y"]
df1=hv_tb_cad_002_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA BOC Core Inflation CPI Trim Y/Y"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA BOC Core Inflation CPI Median Y/Y"], color="darkblue", linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA BOC Core Inflation CPI Common Y/Y"], color="darkred", linewidth= l1, linestyle='-',
        marker='X',markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle'-',
#marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="BOC Core Inflation"
y_label="Index %"
x_label=title_r
list_c=["CA BOC Core Inflation CPI Trim Y/Y",
        "CA BOC Core Inflation CPI Median Y/Y",
        "CA BOC Core Inflation CPI Common Y/Y"]
df1=hv_tb_cad_002_001_m_g_001[list_c]
df1=df1.tail(74)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA BOC Core Inflation CPI Trim Y/Y"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA BOC Core Inflation CPI Median Y/Y"], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA BOC Core Inflation CPI Common Y/Y"], color="darkred", linewidth= l1, linestyle='-',
        marker='X',markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle'-',
#marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %% [markdown]
# ### 001_  CANADA Inflation  <a id="title_page"></a

# %%
#Loading tickers
horizon_1 = 24
country_database = "CANADA"
ca_m_tickers = ['v4c90914', 'v4c90923', 'v4c90924', 
                'v4c90915', 'v4c90916', 'v4c90917', 
                'v4c90918', 'v4c90919', 'v4c90920',
                'v4c90921', 'v4c90922']
hv_tb_cad_002_002_m = Haver.data(ca_m_tickers, country_database, dates=True)
print(hv_tb_cad_002_002_m)
for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_002_002_m[variable] = hv_tb_cad_002_002_m[variable].pct_change(12).multiply(100).round(3)

hv_tb_cad_002_002_m.rename(columns={"v4c90914": "CA CPI All items SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90923": "CA CPI Excl Food SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90924": "CA CPI Excl Food & Energy SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90915": "CA CPI Food SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90916": "CA CPI Shelter SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90917": "CA CPI HH Operations SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90918": "CA CPI Clothing SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90919": "CA CPI Transportation SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90920": "CA CPI Health SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90921": "CA CPI Recreation Education SA Y/Y"}, inplace=True)
hv_tb_cad_002_002_m.rename(columns={"v4c90922": "CA CPI Alcohol SA Y/Y"}, inplace=True)
#hv_tb_cad_002_002_m_g_001 = hv_tb_cad_002_002_m.copy()
#hv_tb_cad_002_002_m = hv_tb_cad_002_002_m.tail(horizon_1)
#hv_tb_cad_002_002_m = hv_tb_cad_002_002_m.transpose()
#hv_tb_cad_002_002_m.index.names = ['Variable']

hv_tb_cad_002_002_m_g = hv_tb_cad_002_002_m.copy()
hv_tb_cad_002_002_m_g_001 = hv_tb_cad_002_002_m.copy()

hv_tb_cad_002_002_m.index=hv_tb_cad_002_002_m.index.date
hv_tb_cad_002_002_m = hv_tb_cad_002_002_m.tail(horizon_tb)
hv_tb_cad_002_002_t1=hv_tb_cad_002_002_m.tail(horizon_tb)

hv_tb_cad_002_002_m_t = hv_tb_cad_002_002_m.transpose()
hv_tb_cad_002_002_m_t.index.names = ['Variable']

hv_tb_cad_002_002_t1_t = hv_tb_cad_002_002_t1.transpose()
hv_tb_cad_002_002_t1_t.index.names = ['Variable']
# Out:
#             v4c90914  v4c90923  v4c90924  v4c90915  v4c90916  v4c90917  \
# 1992-01-31      83.1      83.3      84.2      82.0      87.6      87.7
# 1992-02-29      83.2      83.5      84.4      82.2      87.6      87.7
# 1992-03-31      83.6      83.7      84.8      82.9      87.5      87.6
# 1992-04-30      83.7      83.9      84.9      83.0      87.4      87.6
# 1992-05-31      83.9      84.1      85.2      82.8      87.6      87.7
# ...              ...       ...       ...       ...       ...       ...
# 2024-10-31     161.7     156.4     152.1     191.2     184.8     130.9
# 2024-11-30     162.0     156.6     152.2     191.5     185.3     130.2
# 2024-12-31     162.3     157.4     152.7     188.5     185.8     129.7
# 2025-01-31     162.6     157.9     153.1     186.3     186.4     130.9
# 2025-02-28     163.7     158.7     153.9     190.1     186.7     131.5
#
#             v4c90918  v4c90919  v4c90920  v4c90921  v4c90922
# ...

# %% [markdown]
# ### 001_  CANADA Inflation table

# %%
############################################################
######Table 1

#####here*******
title_table="cad_inflation_table"
df =hv_tb_cad_002_002_t1.copy()
df_transposed = hv_tb_cad_002_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_002_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_002_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_002_002_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA Inflation graphs

# %%
title_r="Canada Inflation"
y_label="Index %"
x_label=title_r
list_c=["CA CPI All items SA Y/Y",
        "CA CPI Excl Food SA Y/Y",
        "CA CPI Excl Food & Energy SA Y/Y"]
df1=hv_tb_cad_002_002_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI All items SA Y/Y"], color="darkgreen", linewidth= l1, linestyle='',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA CPI Excl Food SA Y/Y"], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA CPI Excl Food & Energy SA Y/Y"], color="darkred", linewidth= l1, linestyle="-",
        marker="X", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth= 11, linestyle="marker's', markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

# %%
title_r="Canada Inflation Food"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Food SA Y/Y"]
df1=hv_tb_cad_002_002_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Food SA Y/Y"], color="darkblue", linewidth= 11, linestyle="-",
        marker="D", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle="-",
#marker's', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r = "Canada Inflation Shelter"
y_label = "Index %"
x_label = title_r
list_c = ["CA CPI Shelter SA Y/Y"]
df1 = hv_tb_cad_002_002_m_g_001[list_c]
df1 = df1.tail(48)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA CPI Shelter SA Y/Y"], color="darkblue", 
        linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, linestyle='-',
#        marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r = "Canada Inflation Transportation"
y_label = "Index %"
x_label = title_r
list_c = ["CA CPI Transportation SA Y/Y"]
df1 = hv_tb_cad_002_002_m_g_001[list_c]
df1 = df1.tail(48)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA CPI Transportation SA Y/Y"], 
        color="darkblue", linewidth=11, linestyle='-',
        marker='D', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, linestyle='-',
#        marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Health"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Health SA Y/Y"]
df1=hv_tb_cad_002_002_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["CA CPI Health SA Y/Y"], 
        color="darkblue", linewidth=11, linestyle="-",
        marker="D", markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth=11, Linestyle='-',marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_005.png",
            bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Health"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Health SA Y/Y"]
df1=hv_tb_cad_002_002_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Health SA Y/Y"], 
        color="darkblue", linewidth= l1, linestyle="",
        marker='D', markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth=11, Linestyle-'-',marker='s', markersize=s2)
#
plt.axhline(0, color="black", lw=1,linestyle ="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_005.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Recreation Education"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Recreation Education SA Y/Y"]
df1=hv_tb_cad_002_002_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Recreation Education SA Y/Y"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-',marker's', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_002_m_g_006.png",
            bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %% [markdown]
# ### 001_  CANADA Inflation  QQ <a id="title_page"></a

# %%
#q/q
horizon_tb_cad_m = 24
#Loading tickers
horizon_1 = 24
country_database = "CANADA"
ca_m_tickers = ['v4c90914', 'v4c90923', 'v4c90924',
                'v4c90915', 'v4c90916', 'v4c90917', 
                'v4c90918', 'v4c90919', 'v4c90920',
                'v4c90921', 'v4c90922']
hv_tb_cad_002_003_m = Haver.data(ca_m_tickers, 
                                 country_database, dates=True)

for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_002_003_m[variable] = hv_tb_cad_002_003_m[variable].pct_change(4).multiply(100).round(3)

hv_tb_cad_002_003_m.rename(columns={"v4c90914": "CA CPI All items SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90923": "CA CPI Excl Food SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90924": "CA CPI Excl Food & Energy SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90915": "CA CPI Food SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90916": "CA CPI Shelter SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90917": "CA CPI HH Operations SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90918": "CA CPI Clothing SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90919": "CA CPI Transportation SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90920": "CA CPI Health SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90921": "CA CPI Recreation Education SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m.rename(columns={"v4c90922": "CA CPI Alcohol SA Q/Q"}, inplace=True)
hv_tb_cad_002_003_m = hv_tb_cad_002_003_m.tail(horizon_1)
hv_tb_cad_002_003_m = hv_tb_cad_002_003_m.transpose()
hv_tb_cad_002_003_m.index.names = ['Variable']
#dashboard.to_clipboard()

# %% [markdown]
# ### 001_  CANADA Inflation sa  QQ  table <a id="title_page"></a

# %% [markdown]
# ### 001_  CANADA Inflation  sa QQ graphs <a id="title_page"></a

# %% [markdown]
# ### 001_  CANADA Inflation  sa mm <a id="title_page"></a

# %%
horizon_1 = 24
country_database = "CANADA"
ca_m_tickers = ['v4c90914', 'v4c90923', 'v4c90924', 
                'v4c90915', 'v4c90916', 'v4c90917', 
                'v4c90918', 'v4c90919', 'v4c90920',
                'v4c90921', 'v4c90922']
hv_tb_cad_002_004_m = Haver.data(ca_m_tickers, country_database, dates=True)
print(hv_tb_cad_002_004_m)
for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_002_004_m[variable] = hv_tb_cad_002_004_m[variable].pct_change(1).multiply(100).round(3)

hv_tb_cad_002_004_m.rename(columns={"v4c90914": "CA CPI All items SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90923": "CA CPI Excl Food SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90924": "CA CPI Excl Food & Energy SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90915": "CA CPI Food SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90916": "CA CPI Shelter SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90917": "CA CPI HH Operations SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90918": "CA CPI Clothing SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90919": "CA CPI Transportation SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90920": "CA CPI Health SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90921": "CA CPI Recreation Education SA M/M"}, inplace=True)
hv_tb_cad_002_004_m.rename(columns={"v4c90922": "CA CPI Alcohol SA M/M"}, inplace=True)
#hv_tb_cad_002_002_m_g_001 = hv_tb_cad_002_002_m.copy()
#hv_tb_cad_002_002_m = hv_tb_cad_002_002_m.tail(horizon_1)
#hv_tb_cad_002_002_m = hv_tb_cad_002_002_m.transpose()
#hv_tb_cad_002_002_m.index.names = ['Variable']

hv_tb_cad_002_004_m_g = hv_tb_cad_002_004_m.copy()
hv_tb_cad_002_004_m_g_001 = hv_tb_cad_002_004_m.copy()

hv_tb_cad_002_004_m.index=hv_tb_cad_002_004_m.index.date
hv_tb_cad_002_004_m = hv_tb_cad_002_004_m.tail(horizon_tb)
hv_tb_cad_002_004_t1=hv_tb_cad_002_004_m.tail(horizon_tb)

hv_tb_cad_002_004_m_t = hv_tb_cad_002_004_m.transpose()
hv_tb_cad_002_004_m_t.index.names = ['Variable']

hv_tb_cad_002_004_t1_t = hv_tb_cad_002_004_t1.transpose()
hv_tb_cad_002_004_t1_t.index.names = ['Variable']
# Out:
#             v4c90914  v4c90923  v4c90924  v4c90915  v4c90916  v4c90917  \
# 1992-01-31      83.1      83.3      84.2      82.0      87.6      87.7
# 1992-02-29      83.2      83.5      84.4      82.2      87.6      87.7
# 1992-03-31      83.6      83.7      84.8      82.9      87.5      87.6
# 1992-04-30      83.7      83.9      84.9      83.0      87.4      87.6
# 1992-05-31      83.9      84.1      85.2      82.8      87.6      87.7
# ...              ...       ...       ...       ...       ...       ...
# 2024-10-31     161.7     156.4     152.1     191.2     184.8     130.9
# 2024-11-30     162.0     156.6     152.2     191.5     185.3     130.2
# 2024-12-31     162.3     157.4     152.7     188.5     185.8     129.7
# 2025-01-31     162.6     157.9     153.1     186.3     186.4     130.9
# 2025-02-28     163.7     158.7     153.9     190.1     186.7     131.5
#
#             v4c90918  v4c90919  v4c90920  v4c90921  v4c90922
# ...

# %%
# title_r="Canada Inflation"
# y_label="Index %"

# x_label=title_r
list_c=["CA CPI All items SA M/M",
        "CA CPI Excl Food SA M/M",
        "CA CPI Excl Food & Energy SA M/M"]
df1=hv_tb_cad_002_004_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI All items SA M/M"], color="darkgreen", linewidth= 11, linestyle='',
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA CPI Excl Food SA M/M"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA CPI Excl Food & Energy SA M/M"], color="darkred", linewidth= 11, linestyle='-',
        marker='X',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_004_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Food"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Food SA M/M"]
df1=hv_tb_cad_002_004_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Food SA M/M"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-',
#marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_004_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r="Canada Inflation Shelter"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Shelter SA M/M"]
df1=hv_tb_cad_002_004_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Shelter SA M/M"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_004_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Transportation"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Transportation SA M/M"]
df1=hv_tb_cad_002_004_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line',ax=ax,y=["CA CPI Transportation SA M/M"], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')    
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)

plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_004_m_g_004.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Health"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Health SA M/M"]
df1=hv_tb_cad_002_004_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Health SA M/M"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)

plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_004_m_g_005.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="Canada Inflation Recreation Education"
y_label="Index %"
x_label=title_r
list_c=["CA CPI Recreation Education SA M/M"]
df1=hv_tb_cad_002_004_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA CPI Recreation Education SA M/M"], color="darkblue",
        linewidth= l1, linestyle='-',
        marker='D', markersize=s2)

plt.axhline(0, color="black", lw=1,linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_002_004_m_g_006.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

# %% [markdown]
# ### 001_  CANADA CA CPI All items NSA Y/Y <a id="title_page"></a

# %%
#Goods services

#Loading tickers
country_database = "CANADA"
ca_m_tickers = ['v4c90973', 'v4c91222',
                'v4c91223', 'v4c91224', 
                'v4c91225', 'v4c91229', 
                'v4c91230', 'v4c93229',
                'v4c93216']
hv_tb_cad_002_005_m = Haver.data(ca_m_tickers, country_database, dates=True)
for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_002_005_m[variable] = hv_tb_cad_002_005_m[variable].pct_change(12).multiply(100).round(3)

hv_tb_cad_002_005_m.rename(columns={"v4c90973": "CA CPI All items NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c91222": "CA CPI Goods NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c91223": "CA CPI Durable Goods NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c91224": "CA CPI Semi Durable Goods SA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c91225": "CA CPI Non Durable Goods NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c91229": "CA CPI Goods excl Food NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c91230": "CA CPI Services NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c93229": "CA CPI Financial Services NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m.rename(columns={"v4c93216": "CA CPI Internet Access Services NSA Y/Y"}, inplace=True)
hv_tb_cad_002_005_m = hv_tb_cad_002_005_m.tail(horizon_1)
hv_tb_cad_002_005_m = hv_tb_cad_002_005_m.transpose()
hv_tb_cad_002_005_m.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA CPI All items NSA Y/Y  table

# %% [markdown]
# ### 001_  CANADA CA CPI All items NSA Y/Y  graphs

# %% [markdown]
# ### 001_  CANADA CA GDP  Y/Y

# %%
ca_m_tickers = ['v6e05752', 'v6e05723',
                'v6e05724', 'v6e05725', 
                'v6e05729', 'v6e05731',
                'v6e05745', 'v6e05748']

hv_tb_cad_003_001_m = Haver.data(ca_m_tickers, country_database, dates=True)

for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_003_001_m[variable] = hv_tb_cad_003_001_m[variable].pct_change(periods=4, fill_method='bfill').multiply(100).round(3)

hv_tb_cad_003_001_m.rename(columns={"v6e05752": "CA GDP SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05723": "GDP Final Consumption SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05724": "GDP Household Consumption SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05725": "GDP Household Goods SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05729": "GDP Household Services SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05731": "GDP Govt Consumption SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05732": "GDP Gross Fixed Capital Formation SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05745": "GDP Exports G&S SAAR Y/Y"}, inplace=True)
hv_tb_cad_003_001_m.rename(columns={"v6e05748": "GDP Imports G&S SAAR Y/Y"}, inplace=True)
#hv_tb_cad_003_001_m_g_001 = hv_tb_cad_003_001_m.copy()
#hv_tb_cad_003_001_m = hv_tb_cad_003_001_m.tail(horizon_1)
#hv_tb_cad_003_001_m = hv_tb_cad_003_001_m.transpose()
#hv_tb_cad_003_001_m.index.names = ['Variable']
# dashboard.to_clipboard()


hv_tb_cad_003_001_m_g = hv_tb_cad_003_001_m.copy()
hv_tb_cad_003_001_m_g_001 = hv_tb_cad_003_001_m.copy()

hv_tb_cad_003_001_m.index=hv_tb_cad_003_001_m.index.date
hv_tb_cad_003_001_m = hv_tb_cad_003_001_m.tail(horizon_tb)
hv_tb_cad_003_001_t1=hv_tb_cad_003_001_m.tail(horizon_tb)

hv_tb_cad_003_001_m_t = hv_tb_cad_003_001_m.transpose()
hv_tb_cad_003_001_m_t.index.names = ['Variable']

hv_tb_cad_003_001_t1_t = hv_tb_cad_003_001_t1.transpose()
hv_tb_cad_003_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA GDP  Y/Y  TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_gdp_yy_table"
df =hv_tb_cad_003_001_t1.copy()
df_transposed = hv_tb_cad_003_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_002_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_003_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_003_001_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA GDP  Y/Y  graphs

# %%
title_r="CA GDP SAAR Y/Y"
y_label="Index %"
x_label=title_r
#List_c=["CA GDP Flash MM NSA"]
df1=hv_tb_cad_003_001_m_g_001
list_c=df1.columns.tolist()
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[0], color="darkred", 
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
for x,y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label, # this is the text
        (x,y), # these are the coordinates to position the label                              
        textcoords="offset points", # how to position the text
        xytext=(0,18), # distance from text to points (x,y)
        size=6,
        ha='center')

plt.axhline(0, color="black", lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_003_001_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()

# %% [markdown]
# ### 001_  CANADA CA GDP SAAR Q/Q <a id="title_page"></a

# %%
ca_m_tickers = ['v6e05752', 'v6e05723', 
                'v6e05724', 'v6e05725', 
                'v6e05729', 'v6e05731',
                'v6e05745', 'v6e05748']
hv_tb_cad_003_002_m = Haver.data(ca_m_tickers,
                                 country_database, dates=True)
for x in range(len(ca_m_tickers)):
  variable = str(ca_m_tickers[x])
  hv_tb_cad_003_002_m[variable] = hv_tb_cad_003_002_m[variable].pct_change(4).multiply(100).round(3)

hv_tb_cad_003_002_m.rename(columns={'v6e05752': 'CA GDP SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05723': 'GDP Final Consumption SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05724': 'GDP Household Consumption SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05725': 'GDP Household Goods SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05729': 'GDP Household Services SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05731': 'GDP Govt Consumption SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05732': 'GDP Gross Fixed Capital Formation SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05745': 'GDP Exports G&S SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m.rename(columns={'v6e05748': 'GDP Imports G&S SAAR Q/Q'}, inplace=True)
hv_tb_cad_003_002_m = hv_tb_cad_003_002_m.tail(horizon_1)
hv_tb_cad_003_002_m = hv_tb_cad_003_002_m.transpose()
hv_tb_cad_003_002_m.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA GDP   FLASH

# %%
ca_m_tickers = ['s156mgpp']
hv_tb_cad_003_003_m=Haver.data(ca_m_tickers, country_database, dates=True)
hv_tb_cad_003_003_m.rename(columns={"s156mgpp": "CA GDP Flash MM NSA"}, inplace=True)
#hv_tb_cad_003_003_m_g_001=hv_tb_cad_003_003_m.copy()
#hv_tb_cad_003_003_m=hv_tb_cad_003_003_m.tail(horizon_1)
#hv_tb_cad_003_003_m = hv_tb_cad_003_003_m.transpose()
#hv_tb_cad_003_003_m.index.names = ['Variable']



hv_tb_cad_003_003_m_g = hv_tb_cad_003_003_m.copy()
hv_tb_cad_003_003_m_g_001 = hv_tb_cad_003_003_m.copy()

hv_tb_cad_003_003_m.index=hv_tb_cad_003_003_m.index.date
hv_tb_cad_003_003_m = hv_tb_cad_003_003_m.tail(horizon_tb)
hv_tb_cad_003_003_t1=hv_tb_cad_003_003_m.tail(horizon_tb)

hv_tb_cad_003_003_m_t = hv_tb_cad_003_003_m.transpose()
hv_tb_cad_003_003_m_t.index.names = ['Variable']

hv_tb_cad_003_003_t1_t = hv_tb_cad_003_003_t1.transpose()
hv_tb_cad_003_003_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA GDP   FLASH  table

# %%
############################################################
######Table 1

#####here*******
title_table="cad_gdo_flash_table"
df =hv_tb_cad_003_003_t1.copy()
df_transposed = hv_tb_cad_003_003_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_002_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_003_003_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_003_003_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA GDP   FLASH  GRAPH

# %%
title_r="Canada Flash GDP MM NSA"
y_label="Index %"
x_label=title_r
#List_c=["CA GDP Flash MM NSA"]
df1=hv_tb_cad_003_003_m_g_001
list_c=df1.columns.tolist()
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[0], color="darkred", linewidth=l1, linestyle="-")
for x,y in zip(g1.index,g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label, # this is the text
        (x,y), #these are the coordinates to position the Label                                               
        textcoords="offset points", #how to position the text
        xytext=(0,18), #distance from text to points (x,y)
        size=6,
        ha='center')
plt.axhline(0, color='black', lw=1, linestyle ="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
pit.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
pit.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_003_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()

# %% [markdown]
# ### 001_  CANADA CA Unemployment 15+ % SA <a id="title_page"></a

# %%
ca_m_tickers = ['v2062815', 'v2062816']
hv_tb_cad_004_001_m = Haver.data(ca_m_tickers, country_database, dates=True)
hv_tb_cad_004_001_m.rename(columns={"v2062815": "CA Unemployment 15+ % SA"}, inplace=True)
hv_tb_cad_004_001_m.rename(columns={"v2062816": "CA Participation % SA"}, inplace=True)
#hv_tb_cad_004_001_m_g_001 = hv_tb_cad_004_001_m.copy()
#hv_tb_cad_004_001_m = hv_tb_cad_004_001_m.tail(horizon_1)
#hv_tb_cad_004_001_m = hv_tb_cad_004_001_m.transpose()
#hv_tb_cad_004_001_m.index.names = ['Variable']

hv_tb_cad_004_001_m_g = hv_tb_cad_004_001_m.copy()
hv_tb_cad_004_001_m_g_001 = hv_tb_cad_004_001_m.copy()

hv_tb_cad_004_001_m.index=hv_tb_cad_004_001_m.index.date
hv_tb_cad_004_001_m = hv_tb_cad_004_001_m.tail(horizon_tb)
hv_tb_cad_004_001_t1=hv_tb_cad_004_001_m.tail(horizon_tb)

hv_tb_cad_004_001_m_t = hv_tb_cad_004_001_m.transpose()
hv_tb_cad_004_001_m_t.index.names = ['Variable']

hv_tb_cad_004_001_t1_t = hv_tb_cad_004_001_t1.transpose()
hv_tb_cad_004_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA Unemployment   TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_employment_table"
df =hv_tb_cad_004_001_t1.copy()
df_transposed = hv_tb_cad_004_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_004_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_004_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_004_001_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA Unemployment   GRAPH

# %%
title_r="CA Unemployment 15+ % SA"
y_label="Index %"
x_label=title_r
list_c=["CA Unemployment 15+ % SA"]
df1=hv_tb_cad_004_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Unemployment 15+ % SA"], 
        color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_004_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="CA Unemployment 15+ % SA"
y_label="Index %"
x_label=title_r
list_c=["CA Unemployment 15+ % SA"]
df1=hv_tb_cad_004_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["CA Unemployment 15+ % SA"], color="darkblue", 
        linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle'-',marker's", markersize=s2)
#pLt.axhline(0, color='black', lw=1, Linestyle = 'dashed", alpha=0.75)
for x,y in zip(g1.index,g1 ["CA Unemployment 15+ % SA"]):
    label = "(:.1f)".format(y)
    plt.annotate(label, # this is the text
    (x,y), # these are the coordinates to position the label  
    textcoords="offset points", # how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_004_001_m_g_001z.png", bbox_inches="tight")
plt.close()

# %%
title_r="CA Participation % SA"
y_label="Index %"
x_label=title_r
list_c=["CA Participation % SA"]
df1=hv_tb_cad_004_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Participation % SA"], 
        color="darkblue", linewidth= l1, 
        linestyle="-",
        marker="D", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle-'-',
#marker's', markersize=s2)
#plt.axhline(0, color="black", lw=1, linestyle 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_004_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

# %%
title_r="CA Participation % SA"
y_label="Index %"
x_label=title_r
list_c=["CA Participation % SA"]
df1=hv_tb_cad_004_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line",ax=ax,y=["CA Participation % SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker ="D", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle="-",arker's', markersize=s2)
for x,y in zip(g1.index,g1 ["CA Participation % SA"]):
    label = "(:.1f)".format(y)
    plt.annotate(label, # this is the text
    (x,y), # these are the coordinates to position the label  
    textcoords="offset points", # how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_004_001_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()

# %% [markdown]
# ### 001_  CANADA CA cOMPESANTION

# %%
ca_m_tickers = ['v1996473', 'v1996471',
                'v1996452', 'v1996458']
hv_tb_cad_005_001_m = Haver.data(ca_m_tickers, country_database, dates=True)

for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_005_001_m[variable] = hv_tb_cad_005_001_m[variable].pct_change(12).multiply(100).round(3)

hv_tb_cad_005_001_m.rename(columns={"v1996473": "CA Compensation SA Y/Y"}, inplace=True)
hv_tb_cad_005_001_m.rename(columns={"v1996471": "CA Wage SA Y/Y"}, inplace=True)
hv_tb_cad_005_001_m.rename(columns={"v1996452": "CA Wage Goods SA Y/Y"}, inplace=True)
hv_tb_cad_005_001_m.rename(columns={"v1996458": "CA Wage Services SA Y/Y"}, inplace=True)
#hv_tb_cad_005_001_m_g_001 = hv_tb_cad_005_001_m.copy()
#hv_tb_cad_005_001_m = hv_tb_cad_005_001_m.tail(horizon_1)
#hv_tb_cad_005_001_m = hv_tb_cad_005_001_m.transpose()
#hv_tb_cad_005_001_m.index.names = ['Variable']


hv_tb_cad_005_001_m_g = hv_tb_cad_005_001_m.copy()
hv_tb_cad_005_001_m_g_001 = hv_tb_cad_005_001_m.copy()

hv_tb_cad_005_001_m.index=hv_tb_cad_005_001_m.index.date
hv_tb_cad_005_001_m = hv_tb_cad_005_001_m.tail(horizon_tb)
hv_tb_cad_005_001_t1=hv_tb_cad_005_001_m.tail(horizon_tb)

hv_tb_cad_005_001_m_t = hv_tb_cad_005_001_m.transpose()
hv_tb_cad_005_001_m_t.index.names = ['Variable']

hv_tb_cad_005_001_t1_t = hv_tb_cad_005_001_t1.transpose()
hv_tb_cad_005_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA cOMPESANTION  TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_compensation_table"
df =hv_tb_cad_005_001_t1.copy()
df_transposed = hv_tb_cad_005_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_005_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_005_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_005_001_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA cOMPESANTION  GRAPH

# %%
title_r="CA Compensation SA Y/Y"
y_label="Index %"
x_label=title_r
list_c=["CA Compensation SA Y/Y",
        "CA Wage SA Y/Y",
        "CA Wage Goods SA Y/Y",
        "CA Wage Services SA Y/Y"]
df1=hv_tb_cad_005_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Compensation SA Y/Y"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA Wage SA Y/Y"], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["CA Wage Goods SA Y/Y"], color="darkred",
        linewidth= l1, linestyle='-',
        marker = 'X',markersize=s2)
g1.plot(kind="line", ax=ax, y=["CA Wage Services SA Y/Y"], color="darkred", 
        linewidth= l1, linestyle='-',
        marker='s',markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_005_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r="CA Compensation SA Y/Y"
y_label="Index %"
x_label=title_r
list_c=["CA Compensation SA Y/Y",
        "CA Wage SA Y/Y",
        "CA Wage Goods SA Y/Y",
        "CA Wage Services SA Y/Y"]
df1=hv_tb_cad_005_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Compensation SA Y/Y"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Wage SA Y/Y"], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["CA Wage Goods SA Y/Y"], color="darkred",
        linewidth= l1, linestyle='-',
        marker="X", markersize=s2)
g1.plot(kind="line", ax=ax,y=["CA Wage Services SA Y/Y"], color="darkred", 
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_005_001_m_g_001z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %% [markdown]
# ### 001_  CANADA CA cOMPESANTION MM

# %%
ca_m_tickers = ['v1996473', 'v1996471', 'v1996452', 'v1996458']
hv_tb_cad_005_002_m = Haver.data(ca_m_tickers, country_database, dates=True)

for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_005_002_m[variable] = hv_tb_cad_005_002_m[variable].pct_change(1).multiply(100).round(3)

hv_tb_cad_005_002_m.rename(columns={"v1996473": "CA Compensation SA M/M"}, inplace=True)
hv_tb_cad_005_002_m.rename(columns={"v1996471": "CA Wage SA M/M"}, inplace=True)
hv_tb_cad_005_002_m.rename(columns={"v1996452": "CA Wage Goods SA M/M"}, inplace=True)
hv_tb_cad_005_002_m.rename(columns={"v1996458": "CA Wage Services SA M/M"}, inplace=True)
#hv_tb_cad_005_002_m_g_001 = hv_tb_cad_005_002_m.copy()
#hv_tb_cad_005_002_m = hv_tb_cad_005_002_m.tail(horizon_1)
#hv_tb_cad_005_002_m = hv_tb_cad_005_002_m.transpose()
#hv_tb_cad_005_002_m.index.names = ['Variable']



hv_tb_cad_005_002_m_g = hv_tb_cad_005_002_m.copy()
hv_tb_cad_005_002_m_g_001 = hv_tb_cad_005_002_m.copy()

hv_tb_cad_005_002_m.index=hv_tb_cad_005_002_m.index.date
hv_tb_cad_005_002_m = hv_tb_cad_005_002_m.tail(horizon_tb)
hv_tb_cad_005_002_t1=hv_tb_cad_005_002_m.tail(horizon_tb)

hv_tb_cad_005_002_m_t = hv_tb_cad_005_002_m.transpose()
hv_tb_cad_005_002_m_t.index.names = ['Variable']

hv_tb_cad_005_002_t1_t = hv_tb_cad_005_002_t1.transpose()
hv_tb_cad_005_002_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA cOMPESANTION MM TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_compensation_yy_table"
df =hv_tb_cad_005_002_t1.copy()
df_transposed = hv_tb_cad_005_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_005_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_005_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_005_002_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA cOMPESANTION MM GRAPH

# %%
title_r="CA Compensation SA M/M"
y_label="Index %"

x_label=title_r
list_c=["CA Compensation SA M/M", "CA Wage SA M/M", 
        "CA Wage Goods SA M/M","CA Wage Services SA M/M"]
df1=hv_tb_cad_005_002_m_g_001[list_c]                
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["CA Compensation SA M/M"],
        color="darkgreen", linewidth= l1, linestyle='-',marker='P',markersize=s2)
g1.plot(kind="line", ax=ax, y=["CA Wage SA M/M"], 
        color="darkblue", linewidth= l1, linestyle='-',marker='D',markersize=s2)
g1.plot(kind="line", ax=ax,y=["CA Wage Goods SA M/M"],
        color="darkred", linewidth= 11, linestyle='-',marker="X",markersize=s2)
g1.plot(kind="line",ax=ax,y=["CA Wage Services SA M/M"],
        color="purple", linewidth= 11, linestyle="-",marker='s',markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle ="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_005_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax

# %%
title_r = "CA Compensation SA M/M"
y_label = "Index %"
list_c = ["CA Compensation SA M/M",
          "CA Wage SA M/M",
          "CA Wage Goods SA M/M",
          "CA Wage Services SA M/M"]
df1 = hv_tb_cad_005_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA Compensation SA M/M"], color="darkgreen", linewidth=l1, 
        linestyle='',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Wage SA M/M"], color="darkblue", linewidth=l1, 
        linestyle='',
        marker="D", markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Wage Goods SA M/M"], color="darkred", linewidth=l1,
        linestyle='-',
        marker='X', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Wage Services SA M/M"], color="darkred", linewidth=l1,
        linestyle='-',
        marker='s', markersize=s2)
plt.axhline(0,
            color='black', 
            lw=1, 
            linestyle='dashed',
            alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_005_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %% [markdown]
# ### 001_  CANADA CA Hours Worked SA <a id="title_page"></a

# %%
ca_m_tickers = ['v4391505', 
                'v4391507', 
                'v4391519']
hv_tb_cad_006_001_m = Haver.data(ca_m_tickers, country_database, dates=True)
for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_006_001_m[variable] = hv_tb_cad_006_001_m[variable].pct_change(12).multiply(100).round(3)

hv_tb_cad_006_001_m.rename(columns={"v4391505": "CA Hours Worked SA Y/Y"}, inplace=True)
hv_tb_cad_006_001_m.rename(columns={"v4391507": "CA Hours Worked Goods SA Y/Y"}, inplace=True)
hv_tb_cad_006_001_m.rename(columns={"v4391519": "CA Hours Worked Services SA Y/Y"}, inplace=True)
#hv_tb_cad_006_001_m_g_001 = hv_tb_cad_006_001_m.copy()
#hv_tb_cad_006_001_m = hv_tb_cad_006_001_m.tail(horizon_1)
#hv_tb_cad_006_001_m = hv_tb_cad_006_001_m.transpose()
#hv_tb_cad_006_001_m.index.names = ['Variable']




hv_tb_cad_006_001_m_g = hv_tb_cad_006_001_m.copy()
hv_tb_cad_006_001_m_g_001 = hv_tb_cad_006_001_m.copy()

hv_tb_cad_006_001_m.index=hv_tb_cad_006_001_m.index.date
hv_tb_cad_006_001_m = hv_tb_cad_006_001_m.tail(horizon_tb)
hv_tb_cad_006_001_t1=hv_tb_cad_006_001_m.tail(horizon_tb)

hv_tb_cad_006_001_m_t = hv_tb_cad_006_001_m.transpose()
hv_tb_cad_006_001_m_t.index.names = ['Variable']

hv_tb_cad_006_001_t1_t = hv_tb_cad_006_001_t1.transpose()
hv_tb_cad_006_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA CA Hours Worked SA  TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_hours_yy_table"
df =hv_tb_cad_006_001_t1.copy()
df_transposed = hv_tb_cad_006_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_006_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_006_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_006_001_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA Hours Worked SA GRAPH

# %%
title_r="CA Hours Worked SA Y/Y"
y_label="Index %"
x_label=title_r
list_c=[ "CA Hours Worked SA Y/Y",
         "CA Hours Worked Goods SA Y/Y",
         "CA Hours Worked Services SA Y/Y"]
df1=hv_tb_cad_006_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA Hours Worked SA Y/Y"], color="darkgreen", linewidth=11, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA Hours Worked Goods SA Y/Y"], color="darkblue", linewidth=11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Hours Worked Services SA Y/Y"], color="darkred", linewidth=11, linestyle='-',
        marker="X", markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

# %%
title_r="CA Hours Worked SA Y/Y"
y_label="Index %"
x_label=title_r
list_c=[ "CA Hours Worked SA Y/Y",
        "CA Hours Worked Goods SA Y/Y",
        "CA Hours Worked Services SA Y/Y"]
df1=hv_tb_cad_006_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Hours Worked SA Y/Y"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker="P",markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA Hours Worked Goods SA Y/Y"], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind="line", ax=ax,y=["CA Hours Worked Services SA Y/Y"], color="darkred", 
        linewidth= l1, linestyle='-',
        marker="X", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %% [markdown]
# ### 001_  CANADA CA Hours Worked SA M/M <a id="title_page"></a

# %%
ca_m_tickers = ['v4391505', 
                'v4391507',
                'v4391519']
hv_tb_cad_006_002_m = Haver.data(ca_m_tickers, country_database, dates=True)
print(hv_tb_cad_006_002_m)
for x in range(len(ca_m_tickers)):
    variable = str(ca_m_tickers[x])
    hv_tb_cad_006_002_m[variable] = hv_tb_cad_006_002_m[variable].pct_change(periods=1, fill_method='bfill').multiply(100).round(3)


hv_tb_cad_006_002_m.rename(columns={"v4391505": "CA Hours Worked SA M/M"}, inplace=True)
hv_tb_cad_006_002_m.rename(columns={"v4391507": "CA Hours Worked Goods SA M/M"}, inplace=True)
hv_tb_cad_006_002_m.rename(columns={"v4391519": "CA Hours Worked Services SA M/M"}, inplace=True)
#hv_tb_cad_006_002_m_g_001 = hv_tb_cad_006_002_m.copy()
#hv_tb_cad_006_002_m = hv_tb_cad_006_002_m.tail(horizon_1)
#hv_tb_cad_006_002_m = hv_tb_cad_006_002_m.transpose()
#hv_tb_cad_006_002_m.index.names = ['Variable']
## dashboard.to_clipboard()


hv_tb_cad_006_002_m_g = hv_tb_cad_006_002_m.copy()
hv_tb_cad_006_002_m_g_001 = hv_tb_cad_006_002_m.copy()

hv_tb_cad_006_002_m.index=hv_tb_cad_006_002_m.index.date
hv_tb_cad_006_002_m = hv_tb_cad_006_002_m.tail(horizon_tb)
hv_tb_cad_006_002_t1=hv_tb_cad_006_002_m.tail(horizon_tb)

hv_tb_cad_006_002_m_t = hv_tb_cad_006_002_m.transpose()
hv_tb_cad_006_002_m_t.index.names = ['Variable']

hv_tb_cad_006_002_t1_t = hv_tb_cad_006_002_t1.transpose()
hv_tb_cad_006_002_t1_t.index.names = ['Variable']
# Out:
#             v4391505  v4391507  v4391519
# 1976-01-31  349438.4       NaN       NaN
# 1976-02-29  347387.9       NaN       NaN
# 1976-03-31  348572.0       NaN       NaN
# 1976-04-30  350861.8       NaN       NaN
# 1976-05-31  351030.8       NaN       NaN
# ...              ...       ...       ...
# 2024-10-31  673174.3  155360.5  517813.8
# 2024-11-30  672496.8  155627.6  516869.2
# 2024-12-31  676962.0  157642.8  519319.2
# 2025-01-31  682747.1  159306.7  523440.4
# 2025-02-28  673569.8  154785.7  518784.1
#
# [590 rows x 3 columns]

# %% [markdown]
# ### 001_  CANADA CA Hours Worked SA M/M  TABE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_hours_mm_table"
df =hv_tb_cad_006_002_t1.copy()
df_transposed = hv_tb_cad_006_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_006_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_006_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_006_002_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA Hours Worked SA M/M  GRAPHS

# %%
title_r = "CA Hours Worked SA M/M"
y_label = "Index %"
x_label = title_r
list_c = [
    "CA Hours Worked SA M/M",
    "CA Hours Worked Goods SA M/M",
    "CA Hours Worked Services SA M/M"]

df1 = hv_tb_cad_006_002_m_g_001[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax, y=["CA Hours Worked SA M/M"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Hours Worked Goods SA M/M"], color="darkblue", linewidth=11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Hours Worked Services SA M/M"], color="darkred", linewidth=11, linestyle='-',
        marker='X', markersize=s2)
plt.axhline(0, color="black", linewidth=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r = "CA Hours Worked SA M/M"
y_label = "Index %"

x_label = title_r
list_c = [
    "CA Hours Worked SA M/M",
    "CA Hours Worked Goods SA M/M",
    "CA Hours Worked Services SA M/M"]

df1 = hv_tb_cad_006_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(
    kind='line', ax=ax, y=["CA Hours Worked SA M/M"], color="darkgreen", linewidth=11, linestyle='-',
    marker='o', markersize=s2)
g1.plot(
    kind='line', ax=ax, y=["CA Hours Worked Goods SA M/M"], color="darkblue", linewidth=11, linestyle='-',
    marker='D', markersize=s2)
g1.plot(
    kind='line', ax=ax, y=["CA Hours Worked Services SA M/M"], color="darkred", linewidth=11, linestyle='-',
    marker='X', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %% [markdown]
# ### 001_  CANADA eMPLOYMENT

# %%
ca_m_tickers = ['v2062811', 'v2062812', 'v2062813']

hv_tb_cad_006_003_m = Haver.data(ca_m_tickers, country_database, dates=True)
for x in range(len(ca_m_tickers)):
    variable=str(ca_m_tickers[x])
    hv_tb_cad_006_003_m[variable] = hv_tb_cad_006_003_m[variable].diff(periods=1).round(0)

hv_tb_cad_006_003_m.rename(columns={"v2062811":"CA Employment SA"}, inplace=True)
hv_tb_cad_006_003_m.rename(columns={"v2062812": "CA Employment FT SA"}, inplace=True)
hv_tb_cad_006_003_m.rename(columns={"v2062813": "CA Employment PT SA"}, inplace=True)

#hv_tb_cad_006_003_m_g_001=hv_tb_cad_006_003_m.copy()
#hv_tb_cad_006_003_m=hv_tb_cad_006_003_m.tail(horizon_1)
#hv_tb_cad_006_003_m = hv_tb_cad_006_003_m.transpose()
#hv_tb_cad_006_003_m.index.names = ['Variable']



hv_tb_cad_006_003_m_g = hv_tb_cad_006_003_m.copy()
hv_tb_cad_006_003_m_g_001 = hv_tb_cad_006_003_m.copy()

hv_tb_cad_006_003_m.index=hv_tb_cad_006_003_m.index.date
hv_tb_cad_006_003_m = hv_tb_cad_006_003_m.tail(horizon_tb)
hv_tb_cad_006_003_t1=hv_tb_cad_006_003_m.tail(horizon_tb)

hv_tb_cad_006_003_m_t = hv_tb_cad_006_003_m.transpose()
hv_tb_cad_006_003_m_t.index.names = ['Variable']

hv_tb_cad_006_003_t1_t = hv_tb_cad_006_003_t1.transpose()
hv_tb_cad_006_003_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_  CANADA eMPLOYMENT  TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_employment_table"
df =hv_tb_cad_006_003_t1.copy()
df_transposed = hv_tb_cad_006_003_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_006_003_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_006_003_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_006_003_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA eMPLOYMENT GRAPH

# %%
title_r="CA Employment SA"
y_label="Index %"
x_label=title_r
list_c=["CA Employment SA",
        "CA Employment FT SA",
        "CA Employment PT SA"]

df1=hv_tb_cad_006_003_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Employment SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind="line", ax=ax,y=["CA Employment FT SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA Employment PT SA"], color="darkred", linewidth= l1, linestyle='-',
        marker="X", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r="CA Employment SA"
y_label="Index %"
x_label=title_r
list_c=["CA Employment SA",
        "CA Employment FT SA",
        "CA Employment PT SA"]
df1=hv_tb_cad_006_003_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Employment SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA Employment FT SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker ='D',markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Employment PT SA"], color="darkred", linewidth= l1, linestyle='-',
        marker='X', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_003_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r="CA Employment SA"
y_label="Index %"
x_label=title_r
list_c=["CA Employment SA"]
df1=hv_tb_cad_006_003_m_g_001[list_c]
df1=df1.tail(18)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Employment SA"], color="darkgreen", 
        linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
for x,y in zip(g1.index,g1["CA Employment SA"]):
    label = "(:.1f)".format(y)
    plt.annotate(label, # this is the text
    (x,y), # these are the coordinates to position the label  
    textcoords="offset points", # how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha='center')
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_003_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del df1

# %%
title_r="CA Employment SA"
y_label="Index %"
x_label=title_r
list_c=["CA Employment FT SA",
        "CA Employment PT SA"]
df1=hv_tb_cad_006_003_m_g_001[list_c]
df1=df1.tail(18)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA Employment FT SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CA Employment PT SA"], color="darkred", linewidth= l1, linestyle='-',
        marker='X', markersize=s2)
for x,y in zip(g1.index,g1 ["CA Employment FT SA"]):
    label = "(:.1f)".format(y)
    plt.annotate(label, # this is the text
    (x,y), # these are the coordinates to position the label  
    textcoords="offset points", # how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha='center')

for x,y in zip(g1.index,g1["CA Employment PT SA"]):
    label = "(:.1f)".format(y)
    plt.annotate(label, # this is the text
    (x,y), # these are the coordinates to position the label  
    textcoords="offset points", # how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha='center')
plt.axhline(0, color="black", lw=1,linestyle = "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_003_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

# %% [markdown]
# ### Canada employment seasonality

# %%
#hv_tb_cad_006_003_m.rename(columns={"v2091072":"CA Employment NSA"}, inplace=True)
#hv_tb_cad_006_003_m.rename(columns={"v2091093": "CA Employment FT NSA"}, inplace=True)
#hv_tb_cad_006_003_m.rename(columns={"v2091114": "CA Employment PT NSA"}, inplace=True)

#hv_tb_cad_006_003_m.rename(columns={"v2062811":"CA Employment SA"}, inplace=True)
#hv_tb_cad_006_003_m.rename(columns={"v2062812": "CA Employment FT SA"}, inplace=True)
#hv_tb_cad_006_003_m.rename(columns={"v2062813": "CA Employment PT SA"}, inplace=True)

# %%
##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['v2091072', 'v2062811', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()


hv_tb_se_001_001_m.rename(columns={"v2091072": "employment_lfs_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"v2062811": "employment_lfs_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_cad_006_003_m_g_004.png')
# Out:
#             v2091072  v2062811
# 1966-01-31       NaN    7130.0
# 1966-02-28       NaN    7168.0
# 1966-03-31       NaN    7182.0
# 1966-04-30       NaN    7221.0
# 1966-05-31       NaN    7193.0
# ...              ...       ...
# 2024-10-31   20861.8   20782.6
# 2024-11-30   20828.6   20826.4
# 2024-12-31   20843.6   20917.4
# 2025-01-31   20670.1   20993.4
# 2025-02-28   20768.6   20994.5
#
# [710 rows x 2 columns]
# Index(['v2091072', 'v2062811'], dtype='object')

# %%
list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['v2091093', 'v2062812', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"v2091093": "employment_ft_lfs_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"v2062812": "employment_ft_lfs_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index



df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_cad_006_003_m_g_005.png')
# Out:
#             v2091093  v2062812
# 1976-01-31    8007.4    8431.0
# 1976-02-29    8073.6    8467.5
# 1976-03-31    8162.1    8509.4
# 1976-04-30    8238.0    8540.1
# 1976-05-31    8531.0    8529.6
# ...              ...       ...
# 2024-10-31   17048.3   17038.7
# 2024-11-30   16997.6   17091.6
# 2024-12-31   16962.9   17150.7
# 2025-01-31   16756.4   17185.9
# 2025-02-28   16786.7   17166.2
#
# [590 rows x 2 columns]
# Index(['v2091093', 'v2062812'], dtype='object')

# %%
list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['v2091114', 'v2062813', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"v2091114": "employment_pt_lfs_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"v2062813": "employment_pt_lfs_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index



df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_cad_006_003_m_g_006.png')
# Out:
#             v2091114  v2062813
# 1976-01-31    1264.0    1205.6
# 1976-02-29    1250.9    1192.3
# 1976-03-31    1266.2    1194.8
# 1976-04-30    1265.0    1198.1
# 1976-05-31    1235.4    1196.4
# ...              ...       ...
# 2024-10-31    3813.6    3743.9
# 2024-11-30    3831.0    3734.8
# 2024-12-31    3880.7    3766.6
# 2025-01-31    3913.7    3807.5
# 2025-02-28    3981.9    3828.3
#
# [590 rows x 2 columns]
# Index(['v2091114', 'v2062813'], dtype='object')

# %% [markdown]
# ### 001_  CANADA CA Business Baromete <a id="title_page"></a

# %%
ca_m_tickers = ['cfo3', 'cfaa']
hv_tb_cad_006_004_m=Haver.data(ca_m_tickers, country_database, dates=True)
print(hv_tb_cad_006_004_m)
hv_tb_cad_006_004_m.rename(columns={"cfo3": "CA Business Barometer Short"}, inplace=True)
hv_tb_cad_006_004_m.rename(columns={"cfaa": "CA Business Barometer Long"}, inplace=True)
#hv_tb_cad_006_004_m_g_001=hv_tb_cad_006_004_m.copy()
#hv_tb_cad_006_004_m=hv_tb_cad_006_004_m.tail(horizon_1)
#hv_tb_cad_006_004_m=hv_tb_cad_006_004_m.transpose()
#hv_tb_cad_006_004_m.index.names = ['Variable']

hv_tb_cad_006_004_m_g = hv_tb_cad_006_004_m.copy()
hv_tb_cad_006_004_m_g_001 = hv_tb_cad_006_004_m.copy()

hv_tb_cad_006_004_m.index=hv_tb_cad_006_004_m.index.date
hv_tb_cad_006_004_m = hv_tb_cad_006_004_m.tail(horizon_tb)
hv_tb_cad_006_004_t1=hv_tb_cad_006_004_m.tail(horizon_tb)

hv_tb_cad_006_004_m_t = hv_tb_cad_006_004_m.transpose()
hv_tb_cad_006_004_m_t.index.names = ['Variable']

hv_tb_cad_006_004_t1_t = hv_tb_cad_006_004_t1.transpose()
hv_tb_cad_006_004_t1_t.index.names = ['Variable']
# Out:
#             cfo3  cfaa
# 2000-10-31   NaN  72.1
# 2000-11-30   NaN   NaN
# 2000-12-31   NaN   NaN
# 2001-01-31   NaN   NaN
# 2001-02-28   NaN  64.1
# ...          ...   ...
# 2024-11-30  51.3  59.8
# 2024-12-31  46.5  56.5
# 2025-01-31  48.8  54.5
# 2025-02-28  47.2  49.8
# 2025-03-31  31.2  25.0
#
# [294 rows x 2 columns]

# %% [markdown]
# ### 001_  CANADA CA Business Baromete TABLE

# %%
############################################################
######Table 1

#####here*******
title_table="cad_barometer"
df =hv_tb_cad_006_004_t1.copy()
df_transposed = hv_tb_cad_006_004_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_cad_006_004_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_cad_006_004_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_cad_006_004_m_t_002.png')

# %% [markdown]
# ### 001_  CANADA CA Business Baromete GRAPH

# %%
title_r="CA Business Barometer"
y_label="Index %"
x_label=title_r
list_c=["CA Business Barometer Short",
        "CA Business Barometer Long"]
df1=hv_tb_cad_006_004_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Business Barometer Short"],
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)

g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_004_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r="CA Business Barometer"
y_label="Index %"
x_label=title_r
list_c=["CA Business Barometer Short",
"CA Business Barometer Long"]
df1=hv_tb_cad_006_004_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Business Barometer Short"],
        color="darkgreen", linewidth= l1,
        linestyle='-',  marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"],
        color="darkblue", linewidth= l1, 
        linestyle='-',   marker='D', markersize=s2)
#pit.axhline(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_004_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

# %%
title_r = "CA Business Barometer"
y_label = "Index %"
x_label = title_r
list_c = ["CA Business Barometer Short"]
df1 = hv_tb_cad_006_004_m_g_001[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA Business Barometer Short"], color="darkgreen", 
        linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
for x, y in zip(g1.index, g1["CA Business Barometer Short"]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_004_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

# %%
title_r = "CA Business Barometer"
y_label = "Index %"
x_label = title_r
list_c = ["CA Business Barometer Short"]
df1 = hv_tb_cad_006_004_m_g_001[list_c]
df1 = df1.tail(18)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CA Business Barometer Short"], color="darkgreen", 
        linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
for x, y in zip(g1.index, g1["CA Business Barometer Short"]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_004_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

# %%
title_r="CA Business Barometer"
y_label="Index %"
x_label=title_r
list_c=["CA Business Barometer Long"]
df1=hv_tb_cad_006_004_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Business Barometer Long"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#pit.axhline(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
for x,y in zip(g1.index,g1["CA Business Barometer Long"]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_004_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1

# %%
title_r="CA Business Barometer"
y_label="Index %"
x_label=title_r
list_c=["CA Business Barometer Long"]
df1=hv_tb_cad_006_004_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CA Business Barometer Long"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#pit.axhline(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
for x,y in zip(g1.index,g1["CA Business Barometer Long"]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_006_004_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1

# %% [markdown]
# ### 001_  CANADA CURVEe <a id="title_page"></a

# %%
#hv_tb_cad_007_001_m_g_001
#v2151027
#v2151003
#v2151003

cai_m_tickers = ['v215l003','v215l027']
#V1J73014 QUATERLY VACNACY RATE nsa
hv_tb_cad_007_001_m = Haver.data(cai_m_tickers, "CANADA", dates=True)
print(hv_tb_cad_007_001_m)
hv_tb_cad_007_001_m['unemployment'] = (hv_tb_cad_007_001_m['v215l027'] / hv_tb_cad_007_001_m['v215l003'])
hv_tb_cad_007_001_m = hv_tb_cad_007_001_m.drop(['v215l003', 'v215l027'], axis=1)
hv_tb_cad_007_001_m.index = hv_tb_cad_007_001_m.index.floor('D')

cai_m_tickers = ['v1j73014']
hv_tb_cad_007_001_m1 = Haver.data(cai_m_tickers, "CANADA", dates=True)
hv_tb_cad_007_001_m1.index = hv_tb_cad_007_001_m1.index.floor('D')
hv_tb_cad_007_001_m = pd.merge(hv_tb_cad_007_001_m, hv_tb_cad_007_001_m1, how="outer", left_index=True, right_index=True)
#hv_tb_cad_007_001_m.rename(columns={"v2062815":"unemployment"}, inplace=True)
#hv_tb_cad_007_001_m.rename(columns={"uknelur":"unemployment_"}, inplace=True)
hv_tb_cad_007_001_m.rename(columns={"v1j73014":"vacancy"}, inplace=True)
hv_tb_cad_007_001_m["vacancy"] = hv_tb_cad_007_001_m["vacancy"].fillna(method='ffill')
hv_tb_cad_007_001_m["year"] = hv_tb_cad_007_001_m.index.year
hv_tb_cad_007_001_m = hv_tb_cad_007_001_m.tail(240)
# figure
# data
x = hv_tb_cad_007_001_m['unemployment']
y = hv_tb_cad_007_001_m['vacancy']
t = hv_tb_cad_007_001_m['year']
y_label = "vacancy"
x_label = "unemployment"
print(len(x))
print(len(y))
title_r = "CANADA BEVERIDGE CURVE"
df1 = hv_tb_cad_007_001_m.copy()
df1.index = df1.index.date
#df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(10, 10))
plt.scatter(g1.unemployment, g1.vacancy, c=g1.year, cmap="brg", zorder=2)
plt.plot(g1.unemployment,g1.vacancy, zorder=1)

# add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1.unemployment.iloc[line], g1.vacancy.iloc[line]),
        va='top',ha='right',size = 8)

x0 = x.iloc[range (len(x)-1)].values
x1 = x.iloc[range (1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range (1,len(y))].values
xpos = (x0+x1)/2
ypos= (y0+y1)/2
xdir= x1-x0
ydir= y1-y0

# plot arrow on each line:
for X, Y, dX, dY in zip(xpos, ypos, xdir, ydir):
    ax.annotate("", xytext=(X,Y), xy=(X+0.001*dX, Y+0.001*dY),
    arrowprops=dict(arrowstyle="->", color="b"), size = 11)

plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
plt.savefig("hv_tb_cad_007_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# Out:
#             v215l003  v215l027
# 1976-01-31   10185.0     719.4
# 1976-02-29   10199.3     707.1
# 1976-03-31   10185.5     652.3
# 1976-04-30   10268.3     695.7
# 1976-05-31   10276.8     708.9
# ...              ...       ...
# 2024-10-31   21130.9    1411.3
# 2024-11-30   21223.0    1476.2
# 2024-12-31   21232.0    1434.9
# 2025-01-31   21357.1    1473.4
# 2025-02-28   21305.5    1437.7
#
# [590 rows x 2 columns]
# 240
# 240

# %% [markdown]
# ### 001_  CANADA Phillips curve <a id="title_page"></a

# %%
###### Phillips curve


print("Philips Curve")
### cORE PCE VS UNEMPLTOEMTN
cai_m_tickers = ['v1m85715','v2062815']
hv_tb_cad_007_001_m = Haver.data(cai_m_tickers, "CANADA", dates=True)
#hv_tb_us_002_006_m.index = hv_tb_us_002_006_m.index.floor('D')


    
hv_tb_cad_007_001_m.rename(columns={'v1m85715': 'CA CPI Trim yy sa Monthly'}, inplace=True)
hv_tb_cad_007_001_m.rename(columns={'v2062815': 'CA Unemployment Rate Monthly'}, inplace=True)
hv_tb_cad_007_001_m['year'] = hv_tb_cad_007_001_m.index.year
hv_tb_cad_007_001_m = hv_tb_cad_007_001_m.tail(90)

list_pc=hv_tb_cad_007_001_m.columns.tolist()
print(hv_tb_cad_007_001_m.tail(5))
x = hv_tb_cad_007_001_m[list_pc[1]]
y = hv_tb_cad_007_001_m[list_pc[0]]
t = hv_tb_cad_007_001_m['year']
y_label = list_pc[0]
x_label = list_pc[1]
print(len(x))
print(len(y))


title_r="PHILLIPS CURVE CORE VS UNEMPLOYMENT"
df1=hv_tb_cad_007_001_m.copy()
df1.index= df1.index.date

#df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[list_pc[1]],
            g1[list_pc[0]], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1[list_pc[1]],
         g1[list_pc[0]], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1[list_pc[1]].iloc[line], 
         g1[list_pc[0]].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_007_002_m_g_001.jpg", bbox_inches='tight')
plt.savefig("hv_tb_cad_007_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# Out:
# Philips Curve
#             CA CPI Trim yy sa Monthly  CA Unemployment Rate Monthly  year
# 2024-10-31                        2.7                           6.6  2024
# 2024-11-30                        2.7                           6.9  2024
# 2024-12-31                        2.5                           6.7  2024
# 2025-01-31                        2.7                           6.6  2025
# 2025-02-28                        2.9                           6.6  2025
# 90
# 90

# %%
print("Philips Curve")
### cORE PCE VS UNEMPLTOEMTN
cai_m_tickers = ['v1996473','v2062815']
hv_tb_cad_007_001_m = Haver.data(cai_m_tickers, "CANADA", dates=True)
#hv_tb_us_002_006_m.index = hv_tb_us_002_006_m.index.floor('D')

cai_m_tickers = ['v1996473']
for x in range(len(cai_m_tickers)):
    variable = str(cai_m_tickers[x])
    hv_tb_cad_007_001_m[variable] = hv_tb_cad_007_001_m[variable].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(3)
    
hv_tb_cad_007_001_m.rename(columns={'v1996473': 'CA Compensation yy sa Monthly'}, inplace=True)
hv_tb_cad_007_001_m.rename(columns={'v2062815': 'CA Unemployment Rate Monthly'}, inplace=True)
hv_tb_cad_007_001_m['year'] = hv_tb_cad_007_001_m.index.year
hv_tb_cad_007_001_m = hv_tb_cad_007_001_m.tail(90)

list_pc=hv_tb_cad_007_001_m.columns.tolist()
print(hv_tb_cad_007_001_m.tail(5))
x = hv_tb_cad_007_001_m[list_pc[1]]
y = hv_tb_cad_007_001_m[list_pc[0]]
t = hv_tb_cad_007_001_m['year']
y_label = list_pc[0]
x_label = list_pc[1]
print(len(x))
print(len(y))


title_r="PHILLIPS CURVE WAGE VS UNEMPLOYMENT"
df1=hv_tb_cad_007_001_m.copy()
df1.index= df1.index.date

#df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[list_pc[1]],
            g1[list_pc[0]], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1[list_pc[1]],
         g1[list_pc[0]], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1[list_pc[1]].iloc[line], 
         g1[list_pc[0]].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_007_003_m_g_001.jpg", bbox_inches='tight')
plt.savefig("hv_tb_cad_007_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# Out:
# Philips Curve
#             CA Compensation yy sa Monthly  CA Unemployment Rate Monthly  year
# 2024-10-31                          6.058                           6.6  2024
# 2024-11-30                          5.774                           6.9  2024
# 2024-12-31                          6.883                           6.7  2024
# 2025-01-31                            NaN                           6.6  2025
# 2025-02-28                            NaN                           6.6  2025
# 90
# 90

# %% [markdown]
# ### 001_  CANADA heatmap <a id="title_page"></a

# %%
#### heatmap
#### heatmap
#### heatmap
#### heatmap

#print(hv_tb_cad_003_001_m)

from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns

###paye data
country_database = "CANADA"

horizon_00=120
#montthy

cai_m_tickers1 = ['v4c90916', 'v4c90915', 'v4c90924', 'v5e26612', 'v5e26326', 's156mgpp', 'v6j01211', 'v6j01212', 'v2062815', 'vr449483',
                 'v6j01210', 'v4c90914', 'v1m85715', 'v1m85714', 'v1m85713', 'cfo3', 'cfaa',
                 'ipmsi', 'v1996452', 'v1996458', 'v1996473',
                 'v2062816', 'v3075014', 'v2062812', 'v2062813', 'v415b796', 'r156mae', 'rceerb']

hv_tb_ca_000_001_m = Haver.data(cai_m_tickers1, "CANADA", dates=True)
#print(hv_tb_ca_000_001_m)

#qaurterly
cai_m_tickers2 = ['v6e05752', 'v6e05724', 'vw275440', 've696813']
hv_tb_ca_000_002_m = Haver.data(cai_m_tickers2, "CANADA", dates=True)
#print(hv_tb_ca_000_002_m)

hv_tb_ca_000_001_m = pd.concat([hv_tb_ca_000_001_m, hv_tb_ca_000_002_m], axis=1, join="outer")
ca_m_tickers = cai_m_tickers1 + cai_m_tickers2
#print(hv_tb_ca_000_001_m)
hv_tb_ca_000_001_m = hv_tb_ca_000_001_m.fillna(method='bfill')
#hv_tb_ca_000_001_m.rename(columns={"s156rsic": "Real: Retail Sales Volume SA YY"}, inplace=True)
#hv_tb_ca_000_001_m.rename(columns={"s156rsi": "Real: Retail Sales Volume SA YY"}, inplace=True)

##v_tb_hh_000_001_m["Real: Monthly GDP Production SA YY%"]= hv_tb_hh_000_001_m["ecy44"].pct_change(periods=12,fill_method="bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m["Real: Monthly GDP Services SA YY%"]= hv_tb_hh_000_001_m["ecyc4"].pct_change(periods=12,fill_method="bfill').multiply(100).round(1)




hv_tb_ca_000_001_m.rename(columns={"s156mgpp": "Real: Monthly Flash GDP mm sa"}, inplace=True)

hv_tb_ca_000_001_m["v6j01211"]= hv_tb_ca_000_001_m["v6j01211"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v6j01211": "Real: Monthly GDP Goods YY SAAR"}, inplace=True)

hv_tb_ca_000_001_m["v6j01212"]= hv_tb_ca_000_001_m["v6j01212"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v6j01212": "Real: Monthly GDP Services YY SAAR"}, inplace=True)

hv_tb_ca_000_001_m.rename(columns={"s156elpi": "Real: Canada Productivity"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v6e05752": "Real: GDP"}, inplace=True)

hv_tb_ca_000_001_m["Real: GDP"]= hv_tb_ca_000_001_m["Real: GDP"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_ca_000_001_m.rename(columns={"v6e05724": "Real: Household Consumption"}, inplace=True)
hv_tb_ca_000_001_m["Real: Household Consumption"]= hv_tb_ca_000_001_m["Real: Household Consumption"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_ca_000_001_m.rename(columns={"vr449483": "Real: Retail Trade"}, inplace=True)
hv_tb_ca_000_001_m["Real: Retail Trade"]= hv_tb_ca_000_001_m["Real: Retail Trade"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)



hv_tb_ca_000_001_m.rename(columns={"v6j01210": "Real: IP"}, inplace=True)
hv_tb_ca_000_001_m["Real: IP"]= hv_tb_ca_000_001_m["Real: IP"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

# %%
hv_tb_ca_000_001_m.rename(columns={"h156hg": "Real: Housing Prices New Houses SA YY"}, inplace=True)

hv_tb_ca_000_001_m["v4c90924"] = hv_tb_ca_000_001_m["v4c90924"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v4c90924": "Price: CPI Excl Food & Energy SA Y/Y"}, inplace=True)

hv_tb_ca_000_001_m["v4c90915"]= hv_tb_ca_000_001_m["v4c90915"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v4c90915": "Price: CPI Food SA Y/Y"}, inplace=True)



hv_tb_ca_000_001_m.rename(columns={"v4c90915": "Price: CPI Food SA Y/Y"}, inplace=True)
hv_tb_ca_000_001_m["v4c90916"] = hv_tb_ca_000_001_m["v4c90916"].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v4c90916": "Price: CPI Shelter SA Y/Y"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v4c90914": "Price: CPI All Groups"}, inplace=True)
hv_tb_ca_000_001_m["Price: CPI All Groups"] = hv_tb_ca_000_001_m["Price: CPI All Groups"].pct_change(periods=12,
                                                                                                     fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v1m85715": "Price: CPI Trimmed"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v1m85714": "Price: CPI Median"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v1m85713": "Price: CPI Common"}, inplace=True)
hv_tb_ca_000_001_m["v2062816"] = hv_tb_ca_000_001_m["v2062816"].round(0)
hv_tb_ca_000_001_m.rename(columns={"v2062816": "Employment: Participation Rate"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"v2062815": "Employment: Unemployment Rate Sa"}, inplace=True)
hv_tb_ca_000_001_m["v2062812"] = hv_tb_ca_000_001_m["v2062812"].diff()
hv_tb_ca_000_001_m.rename(columns={"v2062812": "Employment: Full time employment"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Full time employment"] = hv_tb_ca_000_001_m["Employment: Full time employment"] / 1
hv_tb_ca_000_001_m["Employment: Full time employment"] = hv_tb_ca_000_001_m["Employment: Full time employment"].round(0)
hv_tb_ca_000_001_m["v2062813"] = hv_tb_ca_000_001_m["v2062813"].diff()
hv_tb_ca_000_001_m.rename(columns={"v2062813": "Employment: Part time employment"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Part time employment"] = hv_tb_ca_000_001_m["Employment: Part time employment"] / 1
hv_tb_ca_000_001_m["Employment: Part time employment"] = hv_tb_ca_000_001_m["Employment: Part time employment"].round(0)



hv_tb_ca_000_001_m["v5e26612"] = hv_tb_ca_000_001_m["v5e26612"].diff()
hv_tb_ca_000_001_m.rename(columns={"v5e26612": "Employment: Services employment"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Services employment"] = hv_tb_ca_000_001_m["Employment: Services employment"]/1000
hv_tb_ca_000_001_m["Employment: Services employment"] = hv_tb_ca_000_001_m["Employment: Services employment"].round(0)
hv_tb_ca_000_001_m["v5e26326"] = hv_tb_ca_000_001_m["v5e26326"].diff()
hv_tb_ca_000_001_m.rename(columns={"v5e26326": "Employment: Goods employment"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Goods employment"] = hv_tb_ca_000_001_m["Employment: Goods employment"]/1000
hv_tb_ca_000_001_m["Employment: Goods employment"] = hv_tb_ca_000_001_m["Employment: Goods employment"].round(0)
hv_tb_ca_000_001_m.rename(columns={"v1996452": "Employment: Wage Goods"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Wage Goods"] = hv_tb_ca_000_001_m["Employment: Wage Goods"].pct_change(
    periods=12,fill_method='bfill').multiply(100).round(1)                                                                                                                                                               
hv_tb_ca_000_001_m.rename(columns={"v1996458": "Employment: Wage Services"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Wage Services"] = hv_tb_ca_000_001_m["Employment: Wage Services"].pct_change(
    periods=12,fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v1996473": "Employment: Compensation Employees"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Compensation Employees"] = hv_tb_ca_000_001_m["Employment: Compensation Employees"].pct_change(periods=12,
                                                                                                                               fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v3075014": "Employment: Avg Hourly Rate NSA YY"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Avg Hourly Rate NSA YY"] = hv_tb_ca_000_001_m["Employment: Avg Hourly Rate NSA YY"].pct_change(periods=12,
                                                                                                                               fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"cfo3": "Cycle: Business Barometer Short"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"cfaa": "Cycle: Business Barometer Long"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"ipmsi": "Cycle: IVEY PMI"}, inplace=True)

# %%
hv_tb_ca_000_001_m.rename(columns={"v3075014": "Employment: Avg Hourly Rate NSA YY"}, inplace=True)
hv_tb_ca_000_001_m["Employment: Avg Hourly Rate NSA YY"] = hv_tb_ca_000_001_m["Employment: Avg Hourly Rate NSA YY"].pct_change(periods=12,
                                                                                                    fill_method='bfill').multiply(100).round(1)

hv_tb_ca_000_001_m.rename(columns={"cfo3": "Cycle: Business Barometer Short"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"cfaa": "Cycle: Business Barometer Long"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"ipmsi": "Cycle: IVEY PMI"}, inplace=True)
hv_tb_ca_000_001_m["Cycle: Business Barometer Short"] = hv_tb_ca_000_001_m["Cycle: Business Barometer Short"].round(0)
hv_tb_ca_000_001_m["Cycle: Business Barometer Long"] = hv_tb_ca_000_001_m["Cycle: Business Barometer Long"].round(0)
hv_tb_ca_000_001_m["Cycle: IVEY PMI"] = hv_tb_ca_000_001_m["Cycle: IVEY PMI"].round(0)
hv_tb_ca_000_001_m.rename(columns={"rceerb": "Financial: REER FX CAD"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"r156mae": "Financial: 10Y Treasury Bond mid yield"}, inplace=True)
hv_tb_ca_000_001_m["v415b796"] = hv_tb_ca_000_001_m["v415b796"].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(1)
hv_tb_ca_000_001_m.rename(columns={"v415b796": "Financial: m2 yy sa"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"ve696813": "Financial: debt service ratio quarterly"}, inplace=True)
hv_tb_ca_000_001_m.rename(columns={"vw275440": "Financial: debt to disposable income ratio quarterly"}, inplace=True)

# hv_tb_ca_000_001_m
# hv_tb_ca_000_001_m hv_th_ca_000_001_m.fillna(method='ffill')
# hv_tb_ca_000_001_m.drop(hv_tb_au_000_001_m.tail(1).
#hv_tb_ca_000_001_m.fillna(method="bfill", inplace=True)
#index, inplace=True)
# view alll data in elvels, see if trasnformation amkes sensFFIL FORWARD
# hv_tb_ca_000_001_m.sort_index(ascending=False, axis=1, inplace=True)
# hv_tb_ca_000_001_m.to_clipboard()

#KeyError: "['Employment: Unemployment Rate Sa', 'Employment: Hage Goods', 'Financial: debt to disposable income ratio quarterly'] not in index"


hv_tb_hh_000_001_m = hv_tb_ca_000_001_m.copy()
# gpd motnhs

# ip
# retail sales

# Headlines
# Trummed

# median
# Command

# Goods
# UnemLpLoyment

#Employment FT
#Employment PT
#UK CONSUMERS CREDITS
hv_tb_hh_000_001_m.index = hv_tb_hh_000_001_m.index.date

# %%
list_c = [
    "Real: Monthly Flash GDP mm sa",
    "Real: Monthly GDP Goods YY SAAR",
    "Real: Monthly GDP Services YY SAAR",
    "Real: GDP",
    "Real: Household Consumption",
    "Real: Retail Trade",
    "Real: IP",
    "Price: CPI All Groups",
    "Price: CPI Trimmed",
    "Price: CPI Median",
    "Price: CPI Common",
    "Price: CPI Excl Food & Energy SA Y/Y",
    "Price: CPI Food SA Y/Y",
    "Price: CPI Shelter SA Y/Y",
    "Employment: Participation Rate",
    "Employment: Unemployment Rate Sa",
    "Employment: Full time employment",
    "Employment: Part time employment",
    "Employment: Goods employment",
    "Employment: Services employment",
    "Employment: Wage Goods",
    "Employment: Wage Services",
    "Employment: Compensation Employees",
    "Employment: Avg Hourly Rate NSA YY",
    "Cycle: Business Barometer Short",
    "Cycle: Business Barometer Long",
    "Cycle: IVEY PMI",
    "Financial: REER FX CAD",
    "Financial: 10Y Treasury Bond mid yield",
    "Financial: m2 yy sa",
    "Financial: debt service ratio quarterly",
    "Financial: debt to disposable income ratio quarterly"]

hv_tb_hh_000_001_m = hv_tb_hh_000_001_m[list_c]
hv_tb_hh_000_001_m_c = hv_tb_hh_000_001_m.copy()
hv_tb_hh_000_001_m_c = hv_tb_hh_000_001_m_c.tail(120)
hv_tb_hh_000_001_m = hv_tb_hh_000_001_m.tail(60)

# %% [markdown]
# ### 001_  CANADA heatmap  graph <a id="title_page"></a

# %%
n_time=50
size1=30
size2=20
font_size_h=11
number_vbs=32
x_sizel=15
x2_sizel=x_sizel-2
xlabel_size=15
title_s=25
hspace_n=-1
df1 = hv_tb_hh_000_001_m.copy()
df1 = df1.tail(n_time)
df1 = df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]

for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    #print(x)
    locals()[str(str("vmin_")+str(x))] = hv_tb_hh_000_001_m_c.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = hv_tb_hh_000_001_m_c.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)
#data = np.random.random((10,12))
#df = pd.DataFrame(data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1,
                                  size2),
                         sharex=True,)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels (ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels (ax.get_xticklabels(), rotation=90)
    n=(n+1)

#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])

axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels (axis="x", which="both", Length=0, Labelrotation=45)
#.set_xticks([])
fig.suptitle("Canada Economic Dashboard", fontsize=title_s)
plt.figtext(0.5,0.01, "Canada Economic Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=hspace_n)
plt.tight_layout(rect=[0,0.03,1,0.971])
plt.savefig('canada_heatmap_001.png', bbox_inches='tight', dpi=600)
plt.savefig('canada_heatmap_001_test.png', bbox_inches='tight', dpi=600)
#plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()
print("Complete")
# Out:
# -11.0
# 5.0
# Complete

# %%
df1.to_clipboard()

# %% [markdown]
# ### 001_  CANADA BOC FORECASTS <a id="title_page"></a

# %%
################\\\\\ BOC FORECASTS
################\\\\\ BOC FORECASTS
################\\\\\ BOC FORECASTS

# %%
country_database = "CANADA"
#@'b156pcpi',
cai_m_tickers1 = [
                 'caqgp','caqgx','caqpc',]
hv_tb_ca_000_001_m = Haver.data(cai_m_tickers1, country_database, dates=True)
table_F=hv_tb_ca_000_001_m.copy()

table_F.rename(columns={"b156pcpi": "BOC: CPI YY"}, inplace=True)
table_F.rename(columns={"caqgp": "BOC-F: Real GDP QQ"}, inplace=True)
table_F.rename(columns={"caqgx": "BOC-F: Real GDP YY"}, inplace=True)
table_F.rename(columns={"caqpc": "BOC-F: CPI YY"}, inplace=True)

df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=300,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_ca_forecast_001.png')

# %%
#######################
#########diffusion 
#########diffusion 
#########diffusion 
#########diffusion 
#########diffusion

# %% [markdown]
# ### 001_  CANADA diffusion  <a id="title_page"></a

# %%
m_tickers=["v4c90978","v4c90979", "v4c90980","v4c90982", "v4c90983",
"vb665855","v4c90986","v4c90989","v4c90990","v4c90991","v4c90994",
"v4c90995", "v4c90996","v4c90997", "v4c90998",
"v4c90999","v4c91002", "v4c91003", "v4c91004",

"v4c91006", "v4c91007", "v4c91008", "v4c91009",
"v4c91012", "v4c91013", "v4c91014", "v4c91017", "v4c91018","v4c91019",
"v4c91022", "v4c91023", "v4c91024","v4c91025","v4c91031","v4c91032",
"v4c91034", "v4c91035", "v4c91037", "v4c91038", "v4c91041","v4c91042",
"v4c91043", "v4c91044", "v4c91045", "v4c91047", "v4c91048", "v4c91049",
"v4c91052", "v4c91053", "v4c91054", "v4c91056",
"v4c91057", "v4c91058", "v4c91059","v4c91060",

"v4c91061",
"v4c91063","v4c91064", "v4c91065", "v4c91066",
"v4c91070", "v4c91071","v4c93216", "v53c6596","v4c91073", "v4c91074",
"v4c91076","v4c91077", "v4c91079", "v4c91080",
"v4c91082", "v4c91083", "v4c91084",
"v4c91085", "v4c91086", "v4c93229",
"v4c91090", "v4c91091", "v4c91092", "v4c91094", "v4c91095",
"v4c91099", "v4c91100", "v4c91101", "v4c91102",
"v4c91103", "v4c91105", "v4c91106", "v4c91107",
"v4c91110", "v4c91111","v4c91112", "v4c91114",
"v4c91115","v4c91116", "v4c91117", "v4c91120",
"v4c91121","v4c91123",
"v4c91132", "v4c91133", "v4c91134",
"v4c91136", "v4c91137", "v4c91139", "v4c91141","v4c91142","v4c91143", "v4c91144", "v4c91145",
"v4c91148", "v4c91149", "v4c91151", "v4c91152",
"v4c91157", "v4c91158",                                                                       
             #"v1p24071",
"v41c3381", "v4c91159", "v4c93244", "v4c91161",
"v4c91162","v4c91165", "v4c91166", "v4c91167", "v4c91168", "v4c91169",
"v4c91173", "v41c3382", "v53c6597", "v53c6598",
"v41c3384", "v4c91178","v41c3386", "v4c91180","v4c91181",
"v4c91182","v4c91183",
             
"v4c91185", "v4c91186", "v41c3388", "v41c3390", "v4c91189",
"v4c91191", "v4c91192",
"v4c91194", "v4c91195", "v4c91196", "v4c91196",
"v4c91199", "v4c91200", "v4c91201",
"v4c91203", "v4c91204", "v4c91205", "v4c91205",
"v4c91209", "v4c91210", "v4c91211", "v4c91213", "v4c91214",
"v4c91215", "v4c91217", "v4c91218", "v1p24072",]
#"v4c91187", "v4c91188"

print("getting from api")
print("Historical data")

table_h = Haver.data(m_tickers, "canada", dates=True)
#print(table_h)
# Out:
# getting from api
# Historical data

# %%
##############################################################
table_h.rename(columns={"v4c90978":"fresh_frozen_beef"}, inplace=True)
table_h.rename(columns={"v4c90979":"fresh_frozen_pork"}, inplace=True)
table_h.rename(columns={"v4c90980": "other_fresh_frozen_meat"}, inplace=True)
table_h.rename(columns={"v4c90982":"fresh_frozen_chicken"}, inplace=True)
table_h.rename(columns={"v4c90983": "other_fresh_frozen_poultry_meat"}, inplace=True)
table_h.rename(columns={"vb665855":"food_ham_bacon"}, inplace=True)
table_h.rename(columns={"v4c90986": "food_other_processed_meat"}, inplace=True)
table_h.rename(columns={"v4c90989":"food_fresh_frozen_fish"}, inplace=True)
table_h.rename(columns={"v4c90990":"food_canned_preserved_fish"}, inplace=True)
table_h.rename(columns={"v4c90991":"food_seafood_other_marine"}, inplace=True)
##############################################################
table_h.rename(columns={"v4c90994":"food_fresh_milk"}, inplace=True)
table_h.rename(columns={"v4c90995":"food_butter"}, inplace=True)
table_h.rename(columns={"v4c90996":"food_cheese"}, inplace=True)
table_h.rename(columns={"v4c90997":"food_ice_cream"}, inplace=True)
table_h.rename(columns={"v4c90998":"food_other_diary"}, inplace=True)
table_h.rename(columns={"v4c90999":"food_eggs"}, inplace=True)
table_h.rename(columns={"v4c91002":"food_bread_rolls_buns"}, inplace=True)
table_h.rename(columns={"v4c91003":"food_cookies_crackers"}, inplace=True)
table_h.rename(columns={"v4c91004":"food_other_bakery"}, inplace=True)
table_h.rename(columns={"v4c91006":"food_rice"}, inplace=True)
table_h.rename(columns={"v4c91007":"food_breakfast_cereal"}, inplace=True)
table_h.rename(columns={"v4c91008":"food_pasta"}, inplace=True)
table_h.rename(columns={"v4c91009":"food_flour"}, inplace=True)
table_h.rename(columns={"v4c91012":"food_apples"}, inplace=True)
table_h.rename(columns={"v4c91013":"food_oranges"}, inplace=True)
table_h.rename(columns={"v4c91014":"food_bananas"}, inplace=True)
table_h.rename(columns={"v4c91017":"food_fruit_juices"}, inplace=True)
table_h.rename(columns={"v4c91018":"food_other_preserved_fruit"}, inplace=True)
table_h.rename(columns={"v4c91019":"food_nuts"}, inplace=True)
##############################################################
table_h.rename(columns={"v4c91019": "food_nuts"}, inplace=True)
table_h.rename(columns={"v4c91022": "food_potatoes"}, inplace=True)
table_h.rename(columns={"v4c91023": "food_tomatoes"}, inplace=True)
table_h.rename(columns={"v4c91024": "food_lettuce"}, inplace=True)
table_h.rename(columns={"v4c91025": "food_other_fresh_vegetables"}, inplace=True)
table_h.rename(columns={"v4c91031": "food_sugar_syrup"}, inplace=True)
table_h.rename(columns={"v4c91032": "food_confectionery"}, inplace=True)
table_h.rename(columns={"v4c91034": "food_margarine"}, inplace=True)
table_h.rename(columns={"v4c91035": "food_other_edible_fats_oils"}, inplace=True)
table_h.rename(columns={"v4c91037": "food_coffee"}, inplace=True)
table_h.rename(columns={"v4c91038": "food_tea"}, inplace=True)
table_h.rename(columns={"v4c91041": "food_soup"}, inplace=True)
table_h.rename(columns={"v4c91042": "food_baby_food"}, inplace=True)
table_h.rename(columns={"v4c91043": "food_precooked_frozen_food_preparation"}, inplace=True)
table_h.rename(columns={"v4c91044": "food_all_other_preparation"}, inplace=True)
table_h.rename(columns={"v4c91045": "food_nonalcohollic_beverage"}, inplace=True)
table_h.rename(columns={"v4c91047": "food_purchased_table_service_restaurant"}, inplace=True)
table_h.rename(columns={"v4c91048": "food_purchased_take_out_restaurant"}, inplace=True)
table_h.rename(columns={"v4c91049": "food_purchased_cafeteria"}, inplace=True)

##############################################################
table_h.rename(columns={"v4c91052": "shelter_rent"}, inplace=True)
table_h.rename(columns={"v4c91053": "shelter_shelter_tenant_insurance"}, inplace=True)
table_h.rename(columns={"v4c91054": "shelter_tenant_maintenance"}, inplace=True)
table_h.rename(columns={"v4c91056": "shelter_mortgage_interest_cost"}, inplace=True)
table_h.rename(columns={"v4c91057": "shelter_homeowner_replacement_cost"}, inplace=True)
table_h.rename(columns={"v4c91058": "shelter_property_tax"}, inplace=True)
table_h.rename(columns={"v4c91059": "shelter_homeowner_mortgage_insurance"}, inplace=True)
table_h.rename(columns={"v4c91060": "shelter_homeowner_maintenance"}, inplace=True)
table_h.rename(columns={"v4c91061": "shelter_other_owned_accommodation_exp"}, inplace=True)
##############################################################
table_h.rename(columns={"v4c91063": "electricity"}, inplace=True)
table_h.rename(columns={"v4c91064": "water"}, inplace=True)
table_h.rename(columns={"v4c91065": "natural_gas"}, inplace=True)
table_h.rename(columns={"v4c91066": "fuel_oil"}, inplace=True)
##############################################################
table_h.rename(columns={"v4c91070": "household_operations_telephone_service"}, inplace=True)
table_h.rename(columns={"v4c91071": "household_operations_postal"}, inplace=True)
table_h.rename(columns={"v4c93216": "household_operations_internet"}, inplace=True)
table_h.rename(columns={"v53c6596": "household_operations_telephone_equip"}, inplace=True)
table_h.rename(columns={"v4c91073": "household_operations_childcare_services"}, inplace=True)
table_h.rename(columns={"v4c91074": "household_operations_housekeeping_services"}, inplace=True)

##############################################################
table_h.rename(columns={"v4c91070": "household_operations_telephone_service"}, inplace=True)
table_h.rename(columns={"v4c91071": "household_operations_postal"}, inplace=True)
table_h.rename(columns={"v4c93216": "household_operations_internet"}, inplace=True)
table_h.rename(columns={"v53c6596": "household_operations_telephone_equip"}, inplace=True)
table_h.rename(columns={"v4c91073": "household_operations_childcare_services"}, inplace=True)
table_h.rename(columns={"v4c91074": "household_operations_housekeeping_services"}, inplace=True)
table_h.rename(columns={"v4c91076": "household_operations_detergents_soap"}, inplace=True)
table_h.rename(columns={"v4c91077": "household_operations_other_household_cleaning"}, inplace=True)
table_h.rename(columns={"v4c91079": "household_operations_paper_stationery"}, inplace=True)
table_h.rename(columns={"v4c91080": "household_operations_plastic"}, inplace=True)
table_h.rename(columns={"v4c91082": "household_operations_other_petfood"}, inplace=True)
table_h.rename(columns={"v4c91083": "household_operations_other_seeds"}, inplace=True)
table_h.rename(columns={"v4c91084": "household_operations_other_horticultural"}, inplace=True)
table_h.rename(columns={"v4c91085": "household_operations_other_supplies"}, inplace=True)
table_h.rename(columns={"v4c91086": "household_operations_other_services"}, inplace=True)
table_h.rename(columns={"v4c93229": "household_operations_other_financial_services"}, inplace=True)
table_h.rename(columns={"v4c91090": "household_furnishing_upholstered_furniture"}, inplace=True)
table_h.rename(columns={"v4c91091": "household_furnishing_wooden_furniture"}, inplace=True)
table_h.rename(columns={"v4c91092": "household_furnishing_other_furniture"}, inplace=True)
table_h.rename(columns={"v4c91094": "household_furnishing_window_coverings"}, inplace=True)
table_h.rename(columns={"v4c91095": "household_furnishing_beddings"}, inplace=True)
table_h.rename(columns={"v4c91099": "household_equipment_cooking_appliances"}, inplace=True)
table_h.rename(columns={"v4c91100": "household_equipment_refrigerators_freezers"}, inplace=True)
table_h.rename(columns={"v4c91101": "household_equipment_laundry_dishwashing"}, inplace=True)
table_h.rename(columns={"v4c91102": "household_equipment_other_appliances"}, inplace=True)
table_h.rename(columns={"v4c91103": "household_equipment_nonelectric_kitchen"}, inplace=True)
table_h.rename(columns={"v4c91105": "household_equipment_hh_tools"}, inplace=True)
table_h.rename(columns={"v4c91106": "household_equipment_other_hh_equip"}, inplace=True)
table_h.rename(columns={"v4c91107": "household_services_related_hh_furnishings"}, inplace=True)
table_h.rename(columns={"cwgo": "household_furnishing_equipment_nec"}, inplace=True)
##############################################################


table_h.rename(columns={"v4c91103": "household_equipment_nonelectric_kitchen"}, inplace=True)
table_h.rename(columns={"v4c91105": "household_equipment_hh_tools"}, inplace=True)
table_h.rename(columns={"v4c91106": "household_equipment_other_hh_equip"}, inplace=True)
table_h.rename(columns={"v4c91107": "household_services_related_hh_furnishings"}, inplace=True)
#table_h.rename(columns={"cwgo": "household_furninshing_equipment_nec"}, inplace=True

table_h.rename(columns={"v4c91110": "clothing_women_clothing"}, inplace=True)
table_h.rename(columns={"v4c91111": "clothing_men_clothing"}, inplace=True)
table_h.rename(columns={"v4c91112": "clothing_children_clothing"}, inplace=True)
table_h.rename(columns={"v4c91114": "clothing_women_footwear"}, inplace=True)
table_h.rename(columns={"v4c91115": "clothing_men_footwear"}, inplace=True)
table_h.rename(columns={"v4c91116": "clothing_children_footwear"}, inplace=True)
table_h.rename(columns={"v4c91117": "clothing_athletic_footwear"}, inplace=True)
table_h.rename(columns={"v4c91120": "clothing_watches"}, inplace=True)
table_h.rename(columns={"v4c91121": "clothing_jewelry"}, inplace=True)
table_h.rename(columns={"v4c91123": "clothing_material_notions_services"}, inplace=True)

#["v4c91110", "v4c91111", "v4c91112", "v4c91114", "v4c91115", "v4c91116", "v4c91117", "v4c91120", "v4c91121", "v4c91123"]
##############################################################
table_h.rename(columns={"v4c91132": "transport_private_purchase_passenger_vehicles"}, inplace=True)
table_h.rename(columns={"v4c91133": "transport_private_purchase_leasing_passenger_vehicles"}, inplace=True)
table_h.rename(columns={"v4c91134": "transport_private_rental"}, inplace=True)
table_h.rename(columns={"v4c91136": "transport_private_operation_gasoline"}, inplace=True)
table_h.rename(columns={"v4c91137": "transport_private_operation_vehicle_parts_accessories"}, inplace=True)
table_h.rename(columns={"v4c91139": "transport_private_operation_maintenance_repair_services"}, inplace=True)
table_h.rename(columns={"v4c91141": "transport_private_operation_insurance_premiums"}, inplace=True)
table_h.rename(columns={"v4c91142": "transport_private_operation_registration_fees"}, inplace=True)
table_h.rename(columns={"v4c91143": "transport_private_operation_driver_license"}, inplace=True)
table_h.rename(columns={"v4c91144": "transport_private_operation_parking_fees"}, inplace=True)
table_h.rename(columns={"v4c91145": "transport_private_operation_passenger_vehicle_operating_expense"}, inplace=True)

##############################################################

table_h.rename(columns={"v4c91148": "transport_public_local_citybus_subway"}, inplace=True)
table_h.rename(columns={"v4c91149": "transport_public_local_taxi"}, inplace=True)
table_h.rename(columns={"v4c91151": "transport_public_air_transportation"}, inplace=True)
table_h.rename(columns={"v4c91152": "transport_public_rail_highway"}, inplace=True)
#table_h.rename(columns={"cwtto": "transport_public_other_public"}, inplace=True)
table_h.rename(columns={"v4c91157": "healthcare_goods_prescribed_medicines"}, inplace=True)
table_h.rename(columns={"v4c91158": "healthcare_goods_nonprescribed_medicines"}, inplace=True)
#table_h.rename(columns={"v1p24071": "healthcare_goods_medicinal_cannabis"}, inplace=True)
table_h.rename(columns={"v41c3381": "healthcare_goods_eyecare_goods"}, inplace=True)
table_h.rename(columns={"v4c91159": "other_healthcare_goods"}, inplace=True)
table_h.rename(columns={"v4c93244": "healthcare_services_eyecare_services"}, inplace=True)
table_h.rename(columns={"v4c91161": "healthcare_services_dentalcare_services"}, inplace=True)
table_h.rename(columns={"v4c91162": "healthcare_services_other_healthcare_services"}, inplace=True)
table_h.rename(columns={"v4c91165": "personal_care_personal_soap"}, inplace=True)
table_h.rename(columns={"v4c91166": "personal_care_toiletry_items"}, inplace=True)
table_h.rename(columns={"v4c91167": "personal_care_oral_products"}, inplace=True)
table_h.rename(columns={"v4c91168": "personal_care_other_personalcare_supplies"}, inplace=True)
table_h.rename(columns={"v4c91169": "personal_care_services"}, inplace=True)
table_h.rename(columns={"v4c91173": "recreation_equipment_sporting_exercise_equipment"}, inplace=True)
table_h.rename(columns={"v41c3382": "recreation_equipment_toys_games"}, inplace=True)
table_h.rename(columns={"v53c6597": "recreation_equipment_digital_computer_equipment_software"}, inplace=True)
table_h.rename(columns={"v53c6598": "recreation_equipment_digital_multipurpose_digital_devices"}, inplace=True)
table_h.rename(columns={"v41c3384": "recreation_equipment_photographic_equipment"}, inplace=True)
table_h.rename(columns={"v4c91178": "recreation_equipment_other_recreational"}, inplace=True)
table_h.rename(columns={"v41c3386": "recreation_equipment_recreational_services"}, inplace=True)
table_h.rename(columns={"v4c91180": "recreation_recreational_purchase_recreational_vehicles"}, inplace=True)
table_h.rename(columns={"v4c91181": "recreation_recreational_operation_recreational_vehicles"}, inplace=True)
table_h.rename(columns={"v4c91182": "recreation_recreational_vehicles_fuel"}, inplace=True)
table_h.rename(columns={"v4c91183": "recreation_recreational_vehicles_insurance_license"}, inplace=True)

##############################################################

table_h.rename(columns={"v4c91185": "recreation_recreational_audio_equipment"}, inplace=True)
table_h.rename(columns={"v4c91186": "recreation_recreational_video_equipment"}, inplace=True)

table_h.rename(columns={"v41c3388": "recreation_recreational_rental_digital_media"}, inplace=True)
table_h.rename(columns={"v41c3390": "recreation_recreational_purchase_digital_media"}, inplace=True)
table_h.rename(columns={"v4c91189": "recreation_recreational_other_entertainment"}, inplace=True)

table_h.rename(columns={"v4c91191": "recreation_recreational_traveler_accommodation"}, inplace=True)
table_h.rename(columns={"v4c91192": "recreation_recreational_travel_tours"}, inplace=True)

table_h.rename(columns={"v4c91194": "recreation_recreational_spectator_entertainment"}, inplace=True)
table_h.rename(columns={"v4c91195": "recreation_recreational_cablevision_subscription"}, inplace=True)
table_h.rename(columns={"v4c91196": "recreation_recreational_use_recreational_facilities"}, inplace=True)

#table_h.rename(columns={"v4c91196":"recreation_recreational_cultural_recreational_services"}, inplace=True)

##############################################################
table_h.rename(columns={"v4c91199": "education_tuitionfees"}, inplace=True)
table_h.rename(columns={"v4c91200": "education_textbooks_supplies"}, inplace=True)
table_h.rename(columns={"v4c91201": "education_otherlessons_courses"}, inplace=True)

table_h.rename(columns={"v4c91203": "reading_newspapers"}, inplace=True)
table_h.rename(columns={"v4c91204": "reading_magazines"}, inplace=True)

table_h.rename(columns={"v4c91205": "reading_book"}, inplace=True)
#table_h.rename(columns={"v4c91205": "reading_other_reading_material"}, inplace=True)


table_h.rename(columns={"v4c91199":"education_tuitionfees"}, inplace=True)
table_h.rename(columns={"v4c91200":"education_textbooks_supplies"}, inplace=True)
table_h.rename(columns={"v4c91201":"education_otherlessons_courses"}, inplace=True)

table_h.rename(columns={"v4c91203":"reading_newspapers"}, inplace=True)
table_h.rename(columns={"v4c91204":"reading_magazines"}, inplace=True)
table_h.rename(columns={"v4c91205":"reading_book"}, inplace=True)
#table_h.rename(columns={"v4c91205":"reading_other_reading_material"}, inplace=True)

table_h.rename(columns={"v4c91209":"alcohol_beer_licensed"}, inplace=True)
table_h.rename(columns={"v4c91210":"alcohol_wine_licensed"}, inplace=True)
table_h.rename(columns={"v4c91211":"alcohol_liquor_licensed"}, inplace=True)
table_h.rename(columns={"v4c91213":"alcohol_beer_store"}, inplace=True)
table_h.rename(columns={"v4c91214":"alcohol_wine_store"}, inplace=True)
table_h.rename(columns={"v4c91215":"alcohol_liquor_purchased_store"}, inplace=True)
table_h.rename(columns={"v4c91217":"alcohol_tobacco_cigarettes"}, inplace=True)
table_h.rename(columns={"v4c91218":"alcohol_tobacco_other_tobacco"}, inplace=True)
table_h.rename(columns={"v1p24072":"alcohol_recreational_cannabis"}, inplace=True)
##############################################################
table_h0=table_h.copy()
table_h_mc=table_h.copy()

# %%
list_m = [
"CWF1", "CWF2", "CWF3", "CWF5", "CWFTO", "CWFTPH", "CWFTPO", "CWFAF",
    "CWFAC", "CWCS", "CWFI", "CWBU", "CWFH", "CWFD", "CWFEO", "CWFG",
    "CWFKB", "CWFKK", "CWFKO", "CWFCR", "CWFCB", "CWFCP", "CWFCF", "CWFRA",
    "CWFRR", "CWFRB", "CWF7F", "CWF7O", "CWFN", "CWFVP", "CWFVT", "CWFVL",
    "CWFVO", "CWFJS", "CWFJC", "CWFOM", "CWFOO", "CWBCC", "CWBCT", "CWFPOS",
    "CWFPOB", "CWFPOP", "CWFPOA", "CWBB", "CWFURT", "CWFURF", "CWFURC", "cwhn", 
    "cwhti", "cwhtm", "cwhwm", "cwhwr", "cwhwx", "cwhwr", "cwhwr", "cwhwr",
    "cwhwr", "cwpe", "cwww", "cwng", "cwpl", "cwct", "cwci", "cwce", "cwcx", 
    "cwccdc", "cwccdh", "cwchd", "cwcho", "cwpps", "cwppp", "cwre", "cwrfw",
    "cwhcg", "cwhhs", "cwhhv", "cwof", "cwghu", "cwghw", "cwgho", "cwgtw", "cwgtb",
    "cwgac", "cwgar", "cwgal", "cwgao", "cwgu", "cwgmh", "cwgmo", "cwgs", 
    #"cwgo",
    "cwav", "cwaj", "cwak", "cwafw", "cwafm", "cwafc", "cwafa", "cwaaw", "cwaaj", 
    "cwas", "cwtulu", "cwtull", "cwtr", "cwpg", "cwtgp", "cwtgm", "cwti", "cwtf", 
    "cwtl", "cwtp", "cwtvo", "cwtu2", "cwtu3", "cwtu5", "cwtu6", 
    #"cwtto", 
    "cwhg2", 
    "cwhg3", "cwhg4", "cwhg4", "cwhg5", "cwhse", "cwhsd", "cwhso", "cwpss", "cwpst",
    "cwpsh", "cwpso", "cwpv", "cwrss", "cwrst", "cwrsdc", "cwrsdm", "cwrsp", "cwrso",
    "cwrsr", "cwrup", "cwruo", "cwruf", "cwrui", "cwrha", "cwrhv", "cwrhr", "cwrhp", 
    "cwrho", "cwva", "cwvt", "cwse", "cwcv", "cwrf", 
    #"cwrc1",
    "cwet", "cwes", "cweo", 
    "cwemn", "cwemm", "cwemb",
    #"ciwemo", 
    "cwba1b", "cwba1w", "cwba1l", "cwbe", "cwbw",
    "cwbs", "cwtbc", "cwtbo", "cwbc", "cwhw1", "cwhw2", "cwhwo"]


#'codesnotfound': ['canada:owfeo', 'canada:cwf70', 'canada:cwt1', 'canada:ciwemo', 'canada:cwbalb', 'canada:cwbalw', 'canada:cwball']

print("getting from api")
print("Historical data")

table_h=Haver.data(list_m, "CANADA", dates=True)
print(table_h)
# Out:
# getting from api
# Historical data
#             cwf1  cwf2  cwf3  cwf5  cwfto  cwftph  cwftpo  cwfaf  cwfac  cwcs  \
# 1989-01-31   NaN  0.35   NaN   NaN    NaN     0.2     NaN    NaN    NaN   NaN
# 1989-02-28   NaN  0.35   NaN   NaN    NaN     0.2     NaN    NaN    NaN   NaN
# 1989-03-31   NaN  0.35   NaN   NaN    NaN     0.2     NaN    NaN    NaN   NaN
# 1989-04-30   NaN  0.35   NaN   NaN    NaN     0.2     NaN    NaN    NaN   NaN
# 1989-05-31   NaN  0.35   NaN   NaN    NaN     0.2     NaN    NaN    NaN   NaN
# ...          ...   ...   ...   ...    ...     ...     ...    ...    ...   ...
# 2024-10-31  0.48  0.19  0.07   0.4   0.07     0.1    0.64    0.2   0.07  0.09
# 2024-11-30  0.48  0.19  0.07   0.4   0.07     0.1    0.64    0.2   0.07  0.09
# 2024-12-31  0.48  0.19  0.07   0.4   0.07     0.1    0.64    0.2   0.07  0.09
# 2025-01-31  0.48  0.19  0.07   0.4   0.07     0.1    0.64    0.2   0.07  0.09
# 2025-02-28  0.48  0.19  0.07   0.4   0.07     0.1    0.64    0.2   0.07  0.09
# ...

# %%
table_h.rename(columns={"cwf1":"fresh_frozen_beef"}, inplace=True)
table_h.rename(columns={"cwf2":"fresh_frozen_pork"}, inplace=True)
table_h.rename(columns={"cwf3":"other_fresh_frozen_meat"}, inplace=True)
table_h.rename(columns={"cwf5":"fresh_frozen_chicken"}, inplace=True)
table_h.rename(columns={"cwfto":"other_fresh_frozen_poultry_meat"}, inplace=True)
table_h.rename(columns={"cwftph":"food_ham_bacon"}, inplace=True)
table_h.rename(columns={"cwftpo":"food_other_processed_meat"}, inplace=True)
table_h.rename(columns={"cwfaf":"food_fresh_frozen_fish"}, inplace=True)
table_h.rename(columns={"cwfac":"food_canned_preserved_fish"}, inplace=True)
table_h.rename(columns={"cwcs":"food_seafood_other_marine"}, inplace=True)
table_h.rename(columns={"cwfi":"food_fresh_milk"}, inplace=True)
table_h.rename(columns={"cwbu":"food_butter"}, inplace=True)
table_h.rename(columns={"cwfh":"food_cheese"}, inplace=True)
table_h.rename(columns={"cwfd":"food_ice_cream"}, inplace=True)
table_h.rename(columns={"cwfeo":"food_other_diary"}, inplace=True)
table_h.rename(columns={"cwfg":"food_eggs"}, inplace=True)
table_h.rename(columns={"cwfkb":"food_bread_rolls_buns"}, inplace=True)
table_h.rename(columns={"cwfkk":"food_cookies_crackers"}, inplace=True)
table_h.rename(columns={"cwfko":"food_other_bakery"}, inplace=True)
#######################################################################################################

table_h.rename(columns={"cwfcr":"food_rice"}, inplace=True)
table_h.rename(columns={"cwfcb":"food_breakfast_cereal"}, inplace=True)
table_h.rename(columns={"cwfcp":"food_pasta"}, inplace=True)
table_h.rename(columns={"cwfcf":"food_flour"}, inplace=True)
table_h.rename(columns={"cwfra":"food_apples"}, inplace=True)
table_h.rename(columns={"cwfrr":"food_oranges"}, inplace=True)
table_h.rename(columns={"cwfrb":"food_bananas"}, inplace=True)
table_h.rename(columns={"cwf7f":"food_fruit_juices"}, inplace=True)
table_h.rename(columns={"cwf7o":"food_other_preserved_fruit"}, inplace=True)
table_h.rename(columns={"cwfn":"food_nuts"}, inplace=True)
table_h.rename(columns={"cwfvp":"food_potatoes"}, inplace=True)
table_h.rename(columns={"cwfvt":"food_tomatoes"}, inplace=True)
table_h.rename(columns={"cwfvl":"food_lettuce"}, inplace=True)
table_h.rename(columns={"cwfvo":"food_other_fresh_vegetables"}, inplace=True)
table_h.rename(columns={"cwfjs":"food_sugar_syrup"}, inplace=True)
table_h.rename(columns={"cwfjc":"food_confectionery"}, inplace=True)
table_h.rename(columns={"cwfom":"food_margarine"}, inplace=True)
table_h.rename(columns={"cwfoo":"food_other_edible_fats_oils"}, inplace=True)
table_h.rename(columns={"cwbcc":"food_coffee"}, inplace=True)
table_h.rename(columns={"cwbct":"food_tea"}, inplace=True)
table_h.rename(columns={"cwfpos":"food_soup"}, inplace=True)
table_h.rename(columns={"cwfpob":"food_baby_food"}, inplace=True)
table_h.rename(columns={"cwfpop":"food_precooked_frozen_food_preparation"}, inplace=True)
table_h.rename(columns={"cwfpoa":"food_all_other_preparation"}, inplace=True)
table_h.rename(columns={"cwbb":"food_nonalcohollic_beverage"}, inplace=True)
table_h.rename(columns={"cwfurt":"food_purchased_table_service_restaurant"}, inplace=True)
table_h.rename(columns={"cwfurf":"food_purchased_take_out_restaurant"}, inplace=True)
table_h.rename(columns={"cwfurc":"food_purchased_cafeteria"}, inplace=True)
#######################################################################################################

table_h.rename(columns={"cwfurt":"food_purchased_table_service_restaurant"}, inplace=True)
table_h.rename(columns={"cwfurf":"food_purchased_take_out_restaurant"}, inplace=True)
table_h.rename(columns={"cwfurc":"food_purchased_cafeteria"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwhn":"shelter_rent"}, inplace=True)
table_h.rename(columns={"cwhti":"shelter_shelter_tenant_insurance"}, inplace=True)
table_h.rename(columns={"cwhtm":"shelter_tenant_maintenance"}, inplace=True)
table_h.rename(columns={"cwhwm":"shelter_mortgage_interest_cost"}, inplace=True)
table_h.rename(columns={"cwhwr":"shelter_homeowner_replacement_cost"}, inplace=True)
table_h.rename(columns={"cwhwx":"shelter_property_tax"}, inplace=True)
table_h.rename(columns={"cwhw1":"shelter_homeowner_mortgage_insurance"}, inplace=True)
table_h.rename(columns={"cwhw2":"shelter_homeowner_maintenance"}, inplace=True)
table_h.rename(columns={"cwhwo":"shelter_other_owned_accommodation_exp"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwpe":"electricity"}, inplace=True)
table_h.rename(columns={"cwww":"water"}, inplace=True)
table_h.rename(columns={"cwng":"natural_gas"}, inplace=True)
table_h.rename(columns={"cwpl":"fuel_oil"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwct":"household_operations_telephone_service"}, inplace=True)
table_h.rename(columns={"cwci":"household_operations_postal"}, inplace=True)
table_h.rename(columns={"cwce":"household_operations_internet"}, inplace=True)
table_h.rename(columns={"cwcx":"household_operations_telephone_equip"}, inplace=True)
table_h.rename(columns={"cwccdc":"household_operations_childcare_services"}, inplace=True)
table_h.rename(columns={"cwccdh":"household_operations_housekeeping_services"}, inplace=True)
table_h.rename(columns={"cwchd":"household_operations_detergents_soap"}, inplace=True)
table_h.rename(columns={"cwcho":"household_operations_other_household_cleaning"}, inplace=True)
table_h.rename(columns={"cwpps":"household_operations_paper_stationery"}, inplace=True)
table_h.rename(columns={"cwppp":"household_operations_plastic"}, inplace=True)
#######################################################################################################

table_h.rename(columns={"cwfurt":"food_purchased_table_service_restaurant"}, inplace=True)
table_h.rename(columns={"cwfurf":"food_purchased_take_out_restaurant"}, inplace=True)
table_h.rename(columns={"cwfurc":"food_purchased_cafeteria"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwhn":"shelter_rent"}, inplace=True)
table_h.rename(columns={"cwhti":"shelter_shelter_tenant_insurance"}, inplace=True)
table_h.rename(columns={"cwhtm":"shelter_tenant_maintenance"}, inplace=True)
table_h.rename(columns={"cwhwm":"shelter_mortgage_interest_cost"}, inplace=True)
table_h.rename(columns={"cwhwr":"shelter_homeowner_replacement_cost"}, inplace=True)
table_h.rename(columns={"cwhwx":"shelter_property_tax"}, inplace=True)
table_h.rename(columns={"cwhw1":"shelter_homeowner_mortgage_insurance"}, inplace=True)
table_h.rename(columns={"cwhw2":"shelter_homeowner_maintenance"}, inplace=True)
table_h.rename(columns={"cwhwo":"shelter_other_owned_accommodation_exp"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwpe":"electricity"}, inplace=True)
table_h.rename(columns={"cwww":"water"}, inplace=True)
table_h.rename(columns={"cwng":"natural_gas"}, inplace=True)
table_h.rename(columns={"cwpl":"fuel_oil"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwct":"household_operations_telephone_service"}, inplace=True)
table_h.rename(columns={"cwci":"household_operations_postal"}, inplace=True)
table_h.rename(columns={"cwce":"household_operations_internet"}, inplace=True)
table_h.rename(columns={"cwcx":"household_operations_telephone_equip"}, inplace=True)
table_h.rename(columns={"cwccdc":"household_operations_childcare_services"}, inplace=True)
table_h.rename(columns={"cwccdh":"household_operations_housekeeping_services"}, inplace=True)
table_h.rename(columns={"cwchd":"household_operations_detergents_soap"}, inplace=True)
table_h.rename(columns={"cwcho":"household_operations_other_household_cleaning"}, inplace=True)
table_h.rename(columns={"cwpps":"household_operations_paper_stationery"}, inplace=True)
table_h.rename(columns={"cwppp":"household_operations_plastic"}, inplace=True)
#######################################################################################################


table_h.rename(columns={"cwchd": "household_operations_detergents_soap"}, inplace=True)
table_h.rename(columns={"cwcho": "household_operations_other_household_cleaning"}, inplace=True)
table_h.rename(columns={"cwpps": "household_operations_paper_stationery"}, inplace=True)
table_h.rename(columns={"cwppp": "household_operations_plastic"}, inplace=True)
table_h.rename(columns={"cwre": "household_operations_other_petfood"}, inplace=True)
table_h.rename(columns={"cwrfw": "household_operations_other_seeds"}, inplace=True)
table_h.rename(columns={"cwhcg": "household_operations_other_horticultural"}, inplace=True)
table_h.rename(columns={"cwhhs": "household_operations_other_supplies"}, inplace=True)
table_h.rename(columns={"cwhhv": "household_operations_other_services"}, inplace=True)
table_h.rename(columns={"cwof": "household_operations_other_financial_services"}, inplace=True)
table_h.rename(columns={"cwghu": "household_furnishing_upholstered_furniture"}, inplace=True)
table_h.rename(columns={"cwghw": "household_furnishing_wooden_furniture"}, inplace=True)
table_h.rename(columns={"cwgho": "household_furnishing_other_furniture"}, inplace=True)
table_h.rename(columns={"cwgtw": "household_furnishing_window_coverings"}, inplace=True)
table_h.rename(columns={"cwgtb": "household_furnishing_beddings"}, inplace=True)
table_h.rename(columns={"cwgac": "household_equipment_cooking_appliances"}, inplace=True)
table_h.rename(columns={"cwgar": "household_equipment_refrigerators_freezers"}, inplace=True)
table_h.rename(columns={"cwgal": "household_equipment_laundry_dishwashing"}, inplace=True)
table_h.rename(columns={"cwgao": "household_equipment_other_appliances"}, inplace=True)
table_h.rename(columns={"cwgu": "household_equipment_nonelectric_kitchen"}, inplace=True)
table_h.rename(columns={"cwgmh": "household_equipment_hh_tools"}, inplace=True)
table_h.rename(columns={"cwgmo": "household_equipment_other_hh_equip"}, inplace=True)
table_h.rename(columns={"cwgs": "household_services_related_hh_furnishings"}, inplace=True)

#table_h.rename(columns={"cwgo": "household_furninshing_equipment_nec"}, inplace=True)
table_h.rename(columns={"cwav": "clothing_women_clothing"}, inplace=True)
table_h.rename(columns={"cwaj": "clothing_men_clothing"}, inplace=True)
table_h.rename(columns={"cwak": "clothing_children_clothing"}, inplace=True)
table_h.rename(columns={"cwafw": "clothing_women_footwear"}, inplace=True)
table_h.rename(columns={"cwafm": "clothing_men_footwear"}, inplace=True)
table_h.rename(columns={"cwafc": "clothing_children_footwear"}, inplace=True)
table_h.rename(columns={"cwafa": "clothing_athletic_footwear"}, inplace=True)















###########################################################################################

table_h.rename(columns={"cwav": "clothing_women_clothing"}, inplace=True)
table_h.rename(columns={"cwaj": "clothing_men_clothing"}, inplace=True)
table_h.rename(columns={"cwak": "clothing_children_clothing"}, inplace=True)
table_h.rename(columns={"cwafw": "clothing_women_footwear"}, inplace=True)
table_h.rename(columns={"cwafm": "clothing_men_footwear"}, inplace=True)
table_h.rename(columns={"cwafc": "clothing_children_footwear"}, inplace=True)
table_h.rename(columns={"cwafa":"clothing_athletic_footwear"}, inplace=True)
table_h.rename(columns={"cwaaw": "clothing_watches"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwaaj": "clothing_jewelry"}, inplace=True)
table_h.rename(columns={"cwas": "clothing_material_notions_services"}, inplace=True)
table_h.rename(columns={"cwtulu": "transport_private_purchase_passenger_vehicles"}, inplace=True)
table_h.rename(columns={"cwtull": "transport_private_purchase_leasing_passenger_vehicles"}, inplace=True)
table_h.rename(columns={"cwtr": "transport_private_rental"}, inplace=True)
table_h.rename(columns={"cwpg": "transport_private_operation_gasoline"}, inplace=True)
table_h.rename(columns={"cwtgp": "transport_private_operation_vehicle_parts_accessories"}, inplace=True)
table_h.rename(columns={"cwtgm":"transport_private_operation_maintenance_repair_services"}, inplace=True)
table_h.rename(columns={"cwti": "transport_private_operation_insurance_premiums"}, inplace=True)
table_h.rename(columns={"cwtf": "transport_private_operation_registration_fees"},inplace=True)
#######################################################################################################
table_h.rename(columns={"cwtl":"transport_private_operation_driver_license"}, inplace=True)
table_h.rename(columns={"cwtp": "transport_private_operation_parking_fees"},inplace=True)
table_h.rename(columns={"cwtvo": "transport_private_operation_passenger_vehicle_operating_expense"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwtu2": "transport_public_local_citybus_subway"}, inplace=True)
table_h.rename(columns={"cwtu3": "transport_public_local_taxi"}, inplace=True)
table_h.rename(columns={"cwtu5": "transport_public_air_transportation"}, inplace=True)
table_h.rename(columns={"cwtu6": "transport_public_rail_highway"}, inplace=True)
#table_h.rename(columns=("cwtto": "transport_public_other_public"], inplace=True)
table_h.rename(columns={"cwhg2": "healthcare_goods_prescribed_medicines"}, inplace=True)
table_h.rename(columns={"cwhg3": "healthcare_goods_nonprescribed_medicines"}, inplace=True)
######table_h.rename(columns=["cwhg4": "healthcare_goods_medicinal_cannabis"), inplace=True)
table_h.rename(columns={"cwhg4": "healthcare_goods_eyecare_goods"}, inplace=True)
table_h.rename(columns={"cwhg5":"other_healthcare_goods"}, inplace=True)
table_h.rename(columns={"cwhse": "healthcare_services_eyecare_services"}, inplace=True)
table_h.rename(columns={"cwhsd":"healthcare_services_dentalcare_services"}, inplace=True)
table_h.rename(columns={"cwhso": "healthcare_services_other_healthcare_services"}, inplace=True)
#######################################################################################################

table_h.rename(columns={"cwtu2": "transport_public_local_citybus_subway"}, inplace=True)
table_h.rename(columns={"cwtu3": "transport_public_local_taxi"}, inplace=True)
table_h.rename(columns={"cwtu5": "transport_public_air_transportation"}, inplace=True)
table_h.rename(columns={"cwtu6": "transport_public_rail_highway"}, inplace=True)
#table_h.rename(columns={"cwtto": "transport_public_other_public"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwhg2": "healthcare_goods_prescribed_medicines"}, inplace=True)
table_h.rename(columns={"cwhg3": "healthcare_goods_nonprescribed_medicines"}, inplace=True)
#table_h.rename(columns={"cwhg4":"healthcare_goods_medicinal_cannabis"}, inplace=True)
table_h.rename(columns={"cwhg4": "healthcare_goods_eyecare_goods"}, inplace=True)
table_h.rename(columns={"cwhg5":"other_healthcare_goods"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwhse": "healthcare_services_eyecare_services"}, inplace=True)
table_h.rename(columns={"cwhsd": "healthcare_services_dentalcare_services"}, inplace=True)
table_h.rename(columns={"cwhso": "healthcare_services_other_healthcare_services"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwpss": "personal_care_personal_soap"}, inplace=True)
table_h.rename(columns={"cwpst": "personal_care_toiletry_items"}, inplace=True)
table_h.rename(columns={"cwpsh": "personal_care_oral_products"}, inplace=True)
table_h.rename(columns={"cwpso": "personal_care_other_personalcare_supplies"}, inplace=True)
table_h.rename(columns={"cwpv": "personal_care_services"}, inplace=True)
#######################################################################################################
table_h.rename(columns={"cwrss": "recreation_equipment_sporting_exercise_equipment"}, inplace=True)
table_h.rename(columns={"cwrst": "recreation_equipment_toys_games"}, inplace=True)
table_h.rename(columns={"cwrsdc": "recreation_equipment_digital_computer_equipment_software"}, inplace=True)
table_h.rename(columns={"cwrsdm": "recreation_equipment_digital_multipurpose_digital_devices"}, inplace=True)
table_h.rename(columns={"cwrsp": "recreation_equipment_photographic_equipment"}, inplace=True)
table_h.rename(columns={"cwrso": "recreation_equipment_other_recreational"}, inplace=True)
table_h.rename(columns={"cwrsr": "recreation_equipment_recreational_services"}, inplace=True)
table_h.rename(columns={"cwrup": "recreation_recreational_purchase_recreational_vehicles"}, inplace=True)
table_h.rename(columns={"cwruo": "recreation_recreational_operation_recreational_vehicles"}, inplace=True)
table_h.rename(columns={"cwruf": "recreation_recreational_vehicles_fuel"}, inplace=True)
table_h.rename(columns={"cwrui": "recreation_recreational_vehicles_insurance_license"}, inplace=True)
#######################################################################################################


table_h.rename(columns={"cwrst": "recreation_equipment_toys_games"}, inplace=True)
table_h.rename(columns={"cwrsdc":"recreation_equipment_digital_computer_equipment_software"}, inplace=True)
table_h.rename(columns={"cwrsdm": "recreation_equipment_digital_multipurpose_digital_devices"}, inplace=True)
table_h.rename(columns={"cwrsp":"recreation_equipment_photographic_equipment"}, inplace=True)
table_h.rename(columns={"cwrso":"recreation_equipment_other_recreational"}, inplace=True)
table_h.rename(columns={"cwrsr":"recreation_equipment_recreational_services"}, inplace=True)
table_h.rename(columns={"cwrup":"recreation_recreational_purchase_recreational_vehicles"}, inplace=True)
table_h.rename(columns={"cwruo":"recreation_recreational_operation_recreational_vehicles"}, inplace=True)
table_h.rename(columns={"cwruf": "recreation_recreational_vehicles_fuel"}, inplace=True)
table_h.rename(columns={"cwrui":"recreation_recreational_vehicles_insurance_license"}, inplace=True)
table_h.rename(columns={"cwrha": "recreation_recreational_audio_equipment"}, inplace=True)
table_h.rename(columns={"cwrhv":"recreation_recreational_video_equipment"}, inplace=True)
table_h.rename(columns={"cwrhr":"recreation_recreational_rental_digital_media"}, inplace=True)
table_h.rename(columns={"cwrhp": "recreation_recreational_purchase_digital_media"}, inplace=True)
table_h.rename(columns={"cwrho": "recreation_recreational_other_entertainment"}, inplace=True)
table_h.rename(columns={"cwva": "recreation_recreational_traveler_accommodation"}, inplace=True)
table_h.rename(columns={"cwvt": "recreation_recreational_travel_tours"}, inplace=True)
table_h.rename(columns={"cwse": "recreation_recreational_spectator_entertainment"}, inplace=True)
table_h.rename(columns={"cwcv": "recreation_recreational_cablevision_subscription"}, inplace=True)
table_h.rename(columns={"cwrf": "recreation_recreational_use_recreational_facilities"}, inplace=True)

#table_h.rename(columns={"cwrc1": "recreation_recreational_cultural_recreational_services"}, inplace=True)
table_h.rename(columns={"cwet": "education_tuitionfees"}, inplace=True)
table_h.rename(columns={"cwes":"education_textbooks_supplies"}, inplace=True)
table_h.rename(columns={"cweo": "education_otherlessons_courses"}, inplace=True)
table_h.rename(columns={"cwemn":"reading_newspapers"}, inplace=True)
table_h.rename(columns={"cwemm":"reading_magazines"}, inplace=True)
table_h.rename(columns={"cwemb":"reading_book"}, inplace=True)
#table_h.rename(columns={"cwemo"; "reading_other_reading_material"}, inplace=True)
table_h.rename(columns={"cwba1b": "alcohol_beer_licensed"}, inplace=True)
table_h.rename(columns={"cwba1w":"alcohol_wine_licensed"}, inplace=True)
table_h.rename(columns={"cwba1l":"alcohol_liquor_licensed"}, inplace=True)
table_h.rename(columns={"cwbe":"alcohol_beer_store"}, inplace=True)
table_h.rename(columns={"cwbw":"alcohol_wine_store"}, inplace=True)
table_h.rename(columns={"cwbs":"alcohol_liquor_purchased_store"}, inplace=True)
table_h.rename(columns={"cwtbc":"alcohol_tobacco_cigarettes"}, inplace=True)
table_h.rename(columns={"cwtbo": "alcohol_tobacco_other_tobacco"}, inplace=True)
table_h.rename(columns={"cwbc":"alcohol_recreational_cannabis"}, inplace=True)
table_w=table_h.copy()
table_w_mc = table_h.copy()
#######################################################################################################

# %%
table_h = table_h0.sort_index(axis=1)
table_w = table_w.sort_index(axis=1)

num_columns_h = len(table_h.columns)
num_columns_w = len(table_w.columns)

print(num_columns_h)
print(num_columns_w)

# Convert column names to sets for comparison
columns_df1 = set(table_w.columns)
columns_df2 = set(table_h.columns)

# Check if both DataFrames have the same column names
if columns_df1 == columns_df2:
    print("Both DataFrames have the same column names.")
else:
    # Identify the differences
    not_in_df2 = columns_df1 - columns_df2
    not_in_df1 = columns_df2 - columns_df1

    if not_in_df2:
        print(f"Columns in DataFrame 1 but not in DataFrame 2: {not_in_df2}")

    if not_in_df1:
        print(f"Columns in DataFrame 2 but not in DataFrame 1: {not_in_df1}")

# 'reading_other_reading_material',
# 'transport_public_other_public',

# Columns in DataFrame 1 but not in DataFrame 2: {'cwemo', 'household_furninshing_equipment_nec'}
# Columns in DataFrame 2 but not in DataFrame 1: {'healthcare_goods_medicinal_cannabis'}
# Out:
# 162
# 162
# Both DataFrames have the same column names.

# %%
#reading_other_reading_material',
#transport_public_other_public",
#Columns in DataFrame 1 but not in DataFrame 2: ['cwemo', 'household_furnishing_equipment_nec']
#Columns in DataFrame 2 but not in DataFrame 1: ['healthcare_goods_medicinal_cannabis']

table_h1=table_h.copy()
m_tickers=table_h1.columns.tolist()
for x in range(len(table_h1.columns.tolist())):
                          variable=str(m_tickers[x])
                          table_h1[(str(variable))]= table_h1 [variable].pct_change(periods=12,  fill_method="bfill").multiply(100).round(3)
####################################################
table_h1_3m=table_h.copy()
m_tickers=table_h1_3m.columns.tolist()
for x in range(len(table_h1_3m.columns.tolist())):
                          variable=str(m_tickers[x])
                          table_h1_3m[(str(variable))] = table_h1_3m[(str(variable))].pct_change(periods=3, fill_method='bfill')+1
                          table_h1_3m[(str(variable))] = table_h1_3m[(str(variable))].apply(lambda x: x**4)
                          table_h1_3m[(str(variable))] = table_h1_3m[(str(variable))]-1
                          table_h1_3m[(str(variable))] = table_h1_3m[(str(variable))].multiply(100).round(3)
####################################################
table_h1_6m=table_h.copy()
m_tickers=table_h1_6m.columns.tolist()

for x in range(len(table_h1_6m.columns.tolist())):
                          variable=str(m_tickers[x])
                          table_h1_6m[(str(variable))]= table_h1_6m[(str(variable))].pct_change(periods=6, fill_method='bfill')+1
                          table_h1_6m[(str(variable))]= table_h1_6m[(str(variable))].apply(lambda x: x**2)
                          table_h1_6m[(str(variable))]= table_h1_6m[(str(variable))]-1
                          table_h1_6m[(str(variable))]= table_h1_6m[(str(variable))].multiply(100).round(3)

# %%
#print(table_h1.tail(5))
table_h2=table_h1.copy()
table_h2_3m=table_h1_3m.copy()
table_h2_6m=table_h1_6m.copy()

def adjust_values(val):
    if val > 6:
        return "f"
    if 5 < val <= 6:
        return "e"
    if 4 < val <= 5:
        return "d"
    if 3 < val <= 4:
        return "c"
    elif 2 < val <= 3:
        return "b"
    else:
        return "a"

# Create a new DataFrame by applying the rule
table_h3 = table_h2.applymap(adjust_values)
table_h3_3m = table_h2_3m.applymap(adjust_values)
table_h3_6m = table_h2_6m.applymap(adjust_values)

#print(table_h3.tail(5))

# Assuming df_categories is your first DataFrame with categories and df_weights is your second DataFrame with weights
# For demonstration, let's create sample DataFrames

# %%
#print(table_h3.tail(5))

#Assuming df_categories is your first DataFrame with categories and df_weights is your second DataFrame with weights
#For demonstration, let's create sample DataFrames
#np.random.seed (0) # For reproducible results
df_categories = table_h3.copy()
df_weights = table_w.copy()
print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
df_categories=df_categories.tail(150)
df_categories.index =pd.to_datetime(df_categories.index)
df_categories.index=df_categories.index.date
df_weights.index =pd.to_datetime(df_weights.index)
df_weights.index=df_weights.index.date
#df_weights = df_weights. Loc[df_weights.index. intersection(df_categories.index)]
mask= df_weights.index.isin(df_categories.index)
df_weights= df_weights [mask]
print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
#df_categories = df_categories.reset_index(drop=True)
#df_weights=df_weights.reset_index(drop=True)
#df_categories.index = df_categories.index.to_period("M')
#df_categories.index = pd.to_datetime(df_categories.index)
#df_categories.index=df_categories.index.date
#df_weights.index = df_weights.index.to_period("M")
#df_weights.index = pd.to_datetime(df_weights.index)
#df_weights.index=df_weights.index.date
# Initialize an empty DataFrame for the aggregated weights
#df_aggregated_weights = pd. DataFrame (0, index=df_categories.index, columns=['a', 'b', 'c'])
df_aggregated_weights = pd.DataFrame(0, index=df_categories.index, columns=['a', 'b', 'c', 'd', 'e', 'f'])
#df_aggregated = pd. DataFrame(index=df_categories.index, columns=['a', 'b', 'c']).fillna(8)
#print(df_aggregated)



#df_aggregated = pd.DataFrame(index=df_categories.index, columns=['a', 'b', 'c']).fillna(0)
#print(df_aggregated)

# Aggregate weights by category for each row
for index, row in df_categories.iterrows():

    # Find columns that match the current category
    for category in df_aggregated_weights.columns:
        matching_columns = row == category
        # Sum the weights for these columns from df_weights
        aggregated_weight = df_weights.loc[index, matching_columns].sum()
        # Assign the aggregated weight to the corresponding cell in the result DataFrame
        df_aggregated_weights.at[index, category] = aggregated_weight

# Result
print(df_aggregated_weights)
df_aggregated_weights.columns = ["Below 2%",
                                 "Between 2%-3%",
                                 "Between 3%-4%", 
                                 "Between 4%-5%",
                                 "Between 5%-6%", 
                                 "Above 6%"]

fig, ax = plt.subplots(figsize=(10,5))
df1 = df_aggregated_weights.copy()
#df1.set_index('date')
df1.plot(kind='area', ax=ax, stacked=True, color=['green', 
                                                  'blue', 
                                                  'red', 
                                                  'black',
                                                  'purple', 
                                                  'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("CANADA Inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left")
plt.title(str("CANADA CPI YY Inflation Diffusion: green <2%, blue [2%:3%], red[3%:4%], black [4%:5%], purple [5%:6%), yellow>6%"), size=12)
plt.savefig('canada_diffusion_001.png', bbox_inches='tight',dpi=200)
plt.show()
# Out:
# 1949-01-31 00:00:00
# 2025-02-28 00:00:00
# 1989-01-31 00:00:00
# 2025-02-28 00:00:00
# 2012-09-30
# 2025-02-28
# 2012-09-30
# 2025-02-28
#                 a      b     c     d      e      f
# 2012-09-30  57.48  18.86  7.58  9.18   1.46   4.51
# 2012-10-31  56.53  21.06  8.04  7.65   4.18   1.61
# 2012-11-30  64.79  20.59  5.28  3.68   2.96   1.77
# 2012-12-31  65.44  20.68  4.89  2.88   3.19   1.99
# 2013-01-31  64.88  22.16  4.14  3.52   3.34   1.03
# ...           ...    ...   ...   ...    ...    ...
# 2024-10-31  48.70   9.77  8.91  6.04   2.55  22.05
# 2024-11-30  50.57  11.37  6.68  4.16   2.30  22.94
# 2024-12-31  52.39   9.69  7.48  2.53   5.90  20.03
# 2025-01-31  49.47   7.26  4.94  6.41   4.13  25.81
# 2025-02-28  48.77   6.37  4.94  7.80  14.66  15.48
#
# [150 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
df1 = df_aggregated_weights.copy()
df1 = df1.tail(60)
df1.plot(kind='area', ax=ax, stacked=True, color=['green', 
                                                  'blue', 
                                                  'red', 
                                                  'black',
                                                  'purple', 
                                                  'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("CANADA inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left", fontsize=16)
plt.title(str("CANADA CPI YY inflation Diffusion: green <2%, blue [2%:3%], red [3%:4%], black [4%:5%], purple[5%:6%], yellow>6%"), size=12)
plt.savefig('canada_diffusion_002.png',
            bbox_inches='tight',dpi=200)
plt.show()

# %%
df_categories = table_h3_3m.copy()
df_weights = table_w.copy()
print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
df_categories = df_categories.tail(150)
df_categories.index = pd.to_datetime(df_categories.index)
df_categories.index = df_categories.index.date
df_weights.index = pd.to_datetime(df_weights.index)
df_weights.index = df_weights.index.date
# df_weights = df_weights.loc[df_weights.index.intersection(df_categories.index)]
mask = df_weights.index.isin(df_categories.index)
df_weights = df_weights[mask]

print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
#df_caegories = df_categories.reset_index(drop=True)
#df_weights=df_weights.reset_index(drop=True)
#df_categories. index = df_categories.index.to_period('M')
#df_categories. index = pd.to_datetime(df_categories.index)
#df_categories.index=df_categories.index.date
#df_weights.index = df_weights.index.to_period('M')
#df_weights.index = pd. to_datetime(df_weights. index)
#df_weights.index=df_weights.index.date
#Initialize an empty DataFrame for the aggregated weights
#df_aggregated_weights = pd. DataFrame (0, index=df_categories.index, columns=['a', 'b', 'c'])
df_aggregated_weights = pd.DataFrame(0, index=df_categories.index, columns=['a', 'b', 
                                                                            'c', 'd',
                                                                            'e', 'f'])
#df_aggregated = pd. DataFrame(index=df_categories.index, columns=['a', 'b', 'c']).filina(0)
#print(df_aggregated)
#df_aggregated = pd. DataFrame(index=df_categories, index, columns=['a', 'b', 'c']).fillna (0)
#print(df_aggregated)

# Aggregate weights by category for each row
for index, row in df_categories.iterrows():
    # Find columns that match the current category
    for category in df_aggregated_weights.columns:
        matching_columns = row == category
        # Sum the weights for these columns from df_weights
        aggregated_weight = df_weights.loc[index, matching_columns].sum()
        # Assign the aggregated weight to the corresponding cell in the result DataFrame
        df_aggregated_weights.at[index, category] = aggregated_weight
        
# Result
print(df_aggregated_weights)
df_aggregated_weights.columns = ["below 2%",
                                 "between 2%-3%",
                                 "between 3%-4%",
                                 "between 4%-5%",
                                 "between 5%-6%",
                                 "above 6%"]
fig, ax = plt.subplots(figsize=(10,5))
df1 = df_aggregated_weights.copy()
#df1g.set_index('date')
df1.plot(kind='area', ax=ax, 
         stacked=True, 
         color=['green', 'blue', 'red', 
                'black', 'purple', 'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("CANADA inflation 3m ann Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left")
plt.title(str("CANADA inflation 3m ann Diffusion: green <2%, blue [2%:3%], red [3%:4%], black [4%:5%], purple [5%:6%], yellow>6%"), size=12)
plt.savefig('canada_diffusion_003.png', bbox_inches='tight', dpi=200)
plt.show()
# Out:
# 1949-01-31 00:00:00
# 2025-02-28 00:00:00
# 1989-01-31 00:00:00
# 2025-02-28 00:00:00
# 2012-09-30
# 2025-02-28
# 2012-09-30
# 2025-02-28
#                 a      b     c     d      e      f
# 2012-09-30  59.23  15.45  4.28  0.36   0.98  18.77
# 2012-10-31  51.84  13.78  2.65  0.00   2.17  28.63
# 2012-11-30  59.26   9.30  2.20  2.77   2.25  23.29
# 2012-12-31  60.94  11.94  4.99  2.53   1.61  17.06
# 2013-01-31  67.93   7.22  2.59  3.27   2.03  16.03
# ...           ...    ...   ...   ...    ...    ...
# 2024-10-31  52.26   7.66  3.87  2.60   4.38  27.25
# 2024-11-30  53.19   5.00  2.32  5.82   0.92  30.77
# 2024-12-31  58.17   1.51  0.80  4.93   7.02  25.59
# 2025-01-31  53.39   0.90  8.37  1.29  12.15  21.92
# 2025-02-28  41.69  13.27  8.23  3.34   3.50  27.99
#
# [150 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 5))
df1 = df_aggregated_weights.copy()
df1 = df1.tail(60)
df1.plot(kind='area', ax=ax, stacked=True, color=['green', 'blue', 'red', 'black', 'purple', 'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("CANADA Inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left", fontsize=16)
plt.title(str("CANADA CPI 3m ann Inflation Diffusion: green <2%, blue [2%:3%], red[3%:4%], black[4%:5%], purple[5%:6%], yellow>6%"), size=12)
plt.savefig('canada_diffusion_004.png', bbox_inches='tight', dpi=200)
plt.show()

# %%
df_categories = table_h3_6m.copy()
df_weights = table_w.copy()
print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
df_categories = df_categories.tail(150)
df_categories.index = pd.to_datetime(df_categories.index)
df_categories.index = df_categories.index.date
df_weights.index = pd.to_datetime(df_weights.index)
df_weights.index = df_weights.index.date
# df_weights = df_weights.loc[df_weights.index.intersection(df_categories.index)]
mask = df_weights.index.isin(df_categories.index)
df_weights = df_weights[mask]

print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
#df_categories = df_categories.reset_index(drop=True)
#df_weights=df_weights.reset_index(drop=True)
#df_categories.index = df_categories.index.to_period("M")
#df_categories. index = pd.to_datetime(df_categories.index)
#df_categories.index=df_categories.index.date
#df_weights.index = df_weights.index.to_period("M")
#df_weights.index = pd.to_datetime(df_weights.index)
#df_weights.index=df_weights.index.date
#Initialize an empty DataFrame for the aggregated weights
#df_aggregated_weights = pd. DataFrame (0, index-df_categories, index, columns=['a', 'b', 'c'])

df_aggregated_weights = pd.DataFrame(0, index=df_categories.index, columns=['a', 'b', 
                                                                            'c', 'd',
                                                                            'e', 'f'])
#df_aggregated = pd.DataFrame(index=df_categories.index, columns=['a', 'b', 'c']).fillna(2)
#print(df_aggregated)

# Aggregate weights by category for each row
for index, row in df_categories.iterrows():
    # Find columns that match the current category
    for category in df_aggregated_weights.columns:
        matching_columns = row == category
        # Sum the weights for these columns from df_weights
        aggregated_weight = df_weights.loc[index, matching_columns].sum()
        # Assign the aggregated weight to the corresponding cell in the result DataFrame
        df_aggregated_weights.at[index, category] = aggregated_weight

# Result
print(df_aggregated_weights)
df_aggregated_weights.columns=["below 2%",
                               "between 2%-3%",
                               "between 3%-4%",
                               "between 4%-5%",
                               "between 5%-6%", 
                               "above 6%"]
fig, ax = plt.subplots(figsize=(10,5))
df1=df_aggregated_weights.copy()
#df1g.set_index('date')
df1.plot(kind='area', ax=ax, stacked=True, 
         color=['green', 'blue', 'red', 'black', 'purple', 'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("CANADA inflation 6m ann Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left")
plt.title(str("CANADA inflation 6m ann Diffusion: green <2%, blue [2%:3%], red [3%:4%], black [4%:5%], purple[5%:6%), yellow>6%"), size=12)
plt.savefig('canada_diffusion_005.png', bbox_inches='tight',dpi=200)
plt.show()
# Out:
# 1949-01-31 00:00:00
# 2025-02-28 00:00:00
# 1989-01-31 00:00:00
# 2025-02-28 00:00:00
# 2012-09-30
# 2025-02-28
# 2012-09-30
# 2025-02-28
#                 a      b      c     d     e      f
# 2012-09-30  66.22  11.70   6.03  3.59  1.01  10.52
# 2012-10-31  68.40   8.26   2.99  3.89  6.74   8.79
# 2012-11-30  73.24  12.97   0.92  1.64  5.35   4.95
# 2012-12-31  75.88  11.04   1.13  2.06  4.31   4.65
# 2013-01-31  70.97   6.28   2.99  1.64  3.68  13.51
# ...           ...    ...    ...   ...   ...    ...
# 2024-10-31  49.79   5.64   7.85  7.85  2.01  24.88
# 2024-11-30  54.71  10.40   6.79  4.28  7.69  14.15
# 2024-12-31  63.90   7.42   3.81  1.74  0.74  20.41
# 2025-01-31  54.72   3.02   8.37  8.24  7.40  16.27
# 2025-02-28  47.47   4.81  16.12  5.46  6.84  17.32
#
# [150 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
df1=df_aggregated_weights.copy()
df1=df1.tail(60)
df1.plot(kind='area', ax=ax, stacked=True,
         color=['green', 'blue', 'red', 'black', 'purple', 'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("CANADA inflation Diffusion"), size=12)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left", fontsize=16)
plt.title(str("CANADA CPI 6m ann inflation Diffusion: green <2%, blue [2%:3%), red [3%;4%], black[4%:5%], purple [5%:6%), yellow>6%"), size=12)
plt.savefig('canada_diffusion_006.png', bbox_inches='tight',dpi=200)
plt.show()
print("complete")
#r#edo duffission with 3 motnh aanualszied
# Out:
# complete

# %%
### 001_  CANADA diffusion  <a id="title_page"></a

# %%
print(table_w_mc.shape[0])
print(table_h_mc.shape[0])
print(table_w_mc.shape[1])
print(table_h_mc.shape[1])
table_h_mc_filtered =table_h_mc [table_h_mc.index.year >= 2010]
table_w_mc_filtered=table_w_mc [table_w_mc.index.year >= 2010]
table_h_mc_filtered_index=table_h_mc_filtered.copy()
table_w_mc_filtered_index=table_w_mc_filtered.copy()
print(table_w_mc_filtered.shape[0])
print(table_h_mc_filtered.shape[0])
print(table_w_mc_filtered.shape[1])
print(table_h_mc_filtered.shape[1])
print(table_h_mc_filtered.tail(2))
# Out:
# 434
# 914
# 162
# 162
# 182
# 182
# 162
# 162
#             fresh_frozen_beef  fresh_frozen_pork  other_fresh_frozen_meat  \
# 2025-01-31              264.7              169.4                    195.6
# 2025-02-28              268.6              168.2                    194.6
#
#             fresh_frozen_chicken  other_fresh_frozen_poultry_meat  \
# 2025-01-31                 221.4                            161.4
# 2025-02-28                 211.0                            159.5
#
#             food_ham_bacon  food_other_processed_meat  food_fresh_frozen_fish  \
# 2025-01-31           162.7                      202.0                   177.3
# 2025-02-28           158.0                      205.1                   177.6
#
#             food_canned_preserved_fish  food_seafood_other_marine  ...  \
# 2025-01-31                       188.9                      123.1  ...
# 2025-02-28                       188.6                      121.1  ...
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
table_mc=table_h_mc_filtered.copy()
m_tickers=table_mc.columns.tolist()

for x in range(len(m_tickers)):                                                                                             
    variable=str(m_tickers[x])
    table_mc[(str(variable))]= table_mc [variable].pct_change(periods=1, fill_method='bfill')

#.multiply(100).round(6)
#seasonally adjsut the time series
#doa Loop that grabs the numners and calcutes the new index,
#calcualte the index Looking forward 1 year
#multipy by wietrh and save the resutis as a model, grab the median
#then grab all the restuls
#grab ranodmnmbers of a recent distributions. (macx menad nad mediant percentiles)
#create a
#print(table_mc.tail(5))


table_mc_distribution=table_mc.tail(6)

#print(table_mc_distribution)
#User
#there is a dataframe "A" that is a dataframe with 10 index series corresponding to each component of an inflation basket.
#There is a dataframe "b" that is the month on month change of the time series in dataframe "A".
#dataframe "b" has the same name of columns as dataframe "A".
#There is a dataframe "C" that is the time series weigth of each infaltion basket component from dataframe "A".
#dataframe "c" has the same name of columns as dataframe "A".
#each rows adds up to 100% in dataframe "C".
#Dataframe "D" is the Last 6 rows of dataframe "B"
#Create a Loop does the following: for each column compnent
#of simulate the t+1,+2,+3, t+4, t+5 and t+6 index by considering
#a random row value from dataframe "D" considering the same column name
#Create a Loop does the following: for each column component
#of simulate the t+1,t+2, +3, +4, t+5 and t+6 index by considering
#a random row value from dataframe "D" considering the same column name
#After calculating the new index, grab another random month on month value
#from DtaFrame "D" to calcualte the subsequent index value. Do the same, 6 times for each column name
#elabtorafor each column component in dataframe "A" simulate the index value for the next 6 index values (next 6 end of the month) by multu
dataframe_A=table_h_mc_filtered.copy()
dataframe_B=table_mc.copy()
dataframe_C=table_w_mc_filtered.copy()
dataframe_D=table_mc_distribution.copy()
A=dataframe_A.copy()
B=dataframe_B.copy()
C=dataframe_C.copy()
D=dataframe_D.copy()
#B = A.pct_change()
max_index_graph=dataframe_A.index.max()
#Simulation of next 6 index values for each component in A
new_indices = pd.date_range(start=A.index[-1] + pd.offsets.MonthEnd(1), periods=6, freq='M')
simulated_A = pd.DataFrame(index=new_indices, columns=A.columns)
#print(simulated_A)
print(simulated_A.index.min())
print(simulated_A.index.max())


n=1
for i in range(500):
    ##### create random sample
    data_E = {col: D[col].sample(6, replace=True).values for col in D.columns}
    df_E = pd.DataFrame(data_E).reset_index(drop=True)
    #df_E.to_clipboard()
    ##### grab Last value of inded datafram
    last_values = A.iloc[-1]
    ### creates copy
    a_copy = A.copy()
    #Empty Dataframe to store simulated values
    simulated = pd.DataFrame(index=df_E.index, columns=A.columns)

    # Loop to simulate the next 6 months
    for i in range(len(df_E)):
        if i == 0:
            simulated.iloc[i] = last_values * (1 + df_E.iloc[i])
        else:
            simulated.iloc[i] = simulated.iloc[i - 1] * (1 + df_E.iloc[i])

    new_index = pd.date_range(start=a_copy.index[-1] + pd.offsets.MonthEnd(1), periods=6, freq='M')
    simulated.index = new_index
    #print(simulated)
    #### ocnatenate vertically
    result_df = pd.concat([a_copy, simulated], axis=0)
    ##### create the yy change rates
    result_df_yy = result_df.copy()
    result_df_yy = result_df_yy.pct_change(periods=12, 
                                           fill_method='bfill')
    #print(result_df_yy.tail(8))
    #print(result_df_yy.index.min())
    #print(result_df_yy.index.max())

    ####weights dataframe
    dataframe_C_copy = dataframe_C.copy()
    dataframe_C_copy = dataframe_C_copy.reindex(result_df_yy.index)
    ###froward fill weigths atafrmae
    dataframe_C_copy = dataframe_C_copy.fillna(method='ffill')
    #print(dataframe_C_copy.index.min())
    #print(dataframe_C_copy.index.max())
    #print(dataframe_C_copy.tail(8))
    #print(dataframe_C_copy.index.min())
    #print(dataframe_C_copy.index.max())
    #print(dataframe_C_copy.tail(8))
    #create headline inde
    aggregate_index = (result_df_yy * dataframe_C_copy).sum(axis=1)
    #print(aggregate_index)
    aggregate_index_0 = pd.DataFrame(aggregate_index)
    aggregate_index_0.columns = [str("sim_" + str(n))]

    if n == 1:
        aggregate_index_df = aggregate_index_0.copy()
    else:
        aggregate_index_df = pd.concat([aggregate_index_df, aggregate_index_0], axis=1)
    
    del aggregate_index_0
    del aggregate_index
    del dataframe_C_copy
    del result_df_yy
    del simulated
    del data_E
    del df_E
    n = n + 1
# Out:
# 2025-03-31 00:00:00
# 2025-08-31 00:00:00

# %%
#aggregate_index_df.to_clipboard()
aggregate_index_df_g = aggregate_index_df.apply(lambda x: pd.Series([
    np.percentile(x, 90),
    np.percentile(x, 10),
    np.median(x)], index=['90p', '10p', 'Median']), axis=1)
    
print(aggregate_index_df_g)
aggregate_index_df_g = aggregate_index_df_g.tail(36)
# Out:
#                  90p       10p    Median
# 2010-01-31  0.000000  0.000000  0.000000
# 2010-02-28  0.000000  0.000000  0.000000
# 2010-03-31  0.000000  0.000000  0.000000
# 2010-04-30  0.000000  0.000000  0.000000
# 2010-05-31  0.000000  0.000000  0.000000
# ...              ...       ...       ...
# 2025-04-30  2.432798  1.381452  1.855022
# 2025-05-31  2.139012  0.901158  1.495779
# 2025-06-30  2.626728  1.136324  1.884083
# 2025-07-31  2.526790  0.890068  1.656064
# 2025-08-31  3.095648  1.171165  2.081704
#
# [188 rows x 3 columns]

# %%
import matplotlib.dates as mdates

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(15,5))
ax.plot(aggregate_index_df_g.index, aggregate_index_df_g['90p'], label='90th Percentile', color='blue', marker='', linewidth=1)
ax.plot(aggregate_index_df_g.index, aggregate_index_df_g['10p'], label='10th Percentile', color='blue', marker='', linewidth=1)
ax.plot(aggregate_index_df_g.index, aggregate_index_df_g['Median'], label='Median', color='black', marker='', linewidth=4)
ax.fill_between(aggregate_index_df_g.index, aggregate_index_df_g['90p'], aggregate_index_df_g['10p'], color='gray', alpha=0.3)
ax.grid(axis='y', alpha=0.3)
#ax.set_yticks(np.arange(min(aggregate_index_df_g.min()), max(aggregate_index_df_g.max()) + 0.5, 0.5))
plt.axvline(max_index_graph, color="black", lw=1, linestyle='dashed', alpha=0.75)
#plt.ylabel(str("Inflation Basket Weight"), size=20)
#plt.xlabel(str("CANADA inflation"), size=12)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
#Optional: Set a Locator if you want to control the density of the ticks
ax.xaxis.set_major_locator(mdates.MonthLocator())
for date, value in zip(aggregate_index_df_g.index, aggregate_index_df_g['Median']):
    ax.annotate(f'{value:.2f}', xy=(date, value), textcoords="offset points", xytext=(0,40), ha='center', fontsize=8)
#ax.xaxis.set_major_locator(plt.MaxNLocator(len(aggregate_index_df_g.index)))
plt.xticks(rotation=45)
plt.tick_params(axis='x', which='major', labelsize=6)
plt.legend(loc="lower left")
plt.title(str("CANADA Montecarlo headline simulation"), size=12)
plt.savefig('mc_sim_canada_001.png', bbox_inches='tight',dpi=200)

plt.show()
#multiply by

# %% [markdown]
# ### 001_  CANADA INFLAITON SIMULATIN   <a id="title_page"></a

# %%
#Loading tickers
horizon_1 = 24

country_database = "CANADA"
ca_m_tickers = ['v4c90973', 'v4c90914', 'v4c90974', 
                'v4c90915', 'v1485116', 
                'v1485115', 'v4c91233', 'v4c90924',
                'v1j93702', 'v1j93705', 
                'v4c91222', 'v4c91230']

#'v4c90915', 'v4c90916', 'v4c90917', 'v4c90918', 'v4c90919', 'v4c90920', 'v4c90921', 'v4c90922']
hv_tb_cad_002_001_m = Haver.data(ca_m_tickers, country_database, dates=True)

#print(hv_tb_cad_002_001_m)
#ad_002_001_m[variable].pct_change(12).multiply(100).round(3)

#print(hv_tb_cad_002_002_m)
#for x in range(Len(ca_m_tickers)):
## variable=str(ca_m_tickers[x])
# print(variable)
# hv_tb_cad_002_002_m[variable]= hv_tb_cad_002_002_m[variable].pct_change(12).multiply(100).round(3)
# print(hv_tb_cad_002_002_m[variable])#

hv_tb_cad_002_001_m.rename(columns={"v4c90973":"canada_cpi_headline_nsa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c90914":"canada_cpi_headline_sa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c90974":"canada_cpi_food_nsa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c90915":"canada_cpi_food_sa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v1485116":"canada_boc_core_trim_sa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v1485115":"canada_boc_core_median_sa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c91233":"canada_cpi_ex_food_energy_nsa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c90924":"canada_cpi_ex_food_energy_sa"}, inplace=True)

hv_tb_cad_002_001_m.rename(columns={"v1j93702":"canada_cpix_nsa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v1j93705":"canada_cpix_sa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c91222":"canada_cpi_goods_nsa"}, inplace=True)
hv_tb_cad_002_001_m.rename(columns={"v4c91230":"canada_cpi_services_nsa"}, inplace=True)

#print(x)
#####

# %%
df1=hv_tb_cad_002_001_m.copy()
df1=df1.tail(120)
usi_m_tickers=df1.columns.tolist()
#print(df1)
parameter1_o=12
parameter2_o=8
mks=3
n=0

#print(hv_tb_eu_000_001_m)
for x in range(len(usi_m_tickers)):
    variable=str(usi_m_tickers[x])
    df2=pd.DataFrame(df1[variable])
    df2.index=df2.index.date
    print(variable)
    df2[(str(variable)+"_yy")]= df2[variable].pct_change(periods=12, fill_method='bfill')+1
    df2[(str(variable)+"_yy")]= df2[(str(variable)+"_yy")]-1
    df2[(str(variable)+"_yy")]= df2[(str(variable)+"_yy")].multiply(100).round(3)
    df2[(str(variable)+"_3m_ann")]= df2[variable]
    df2[(str(variable)+"_3m_ann")]= df2[(str(variable)+"_3m_ann")].pct_change(periods=3, fill_method='bfill')+1
    df2[(str(variable)+"_3m_ann")]= df2[(str(variable)+"_3m_ann")].apply(lambda x: x**4)
    df2[(str(variable)+"_3m_ann")]= df2[(str(variable)+"_3m_ann")]-1
    df2[(str(variable)+"_3m_ann")]= df2[(str(variable)+"_3m_ann")].multiply(100).round(3)
    df2[(str(variable)+"_6m_ann")]= df2[variable]
    df2[(str(variable)+"_6m_ann")]= df2[(str(variable)+"_6m_ann")].pct_change(periods=6, fill_method='bfill')+1
    df2[(str(variable)+"_6m_ann")]= df2[(str(variable)+"_6m_ann")].apply(lambda x: x**2)
    df2[(str(variable)+"_6m_ann")]= df2[(str(variable)+"_6m_ann")]-1
    df2[(str(variable)+"_6m_ann")]= df2[(str(variable)+"_6m_ann")].multiply(100).round(3)


    # Create a copy of the DataFrame
    g1 = df2.copy()
    # Get a list of column names
    list_c = g1.columns.tolist()
    # Get the last 48 rows of the DataFrame
    g1 = g1.tail(48)
    # Create a figure and axis objects
    fig, ax = plt.subplots(figsize=(parameter1_o, parameter2_o))
    # Plot the first column as a black line with markers
    g1.plot(kind='line', ax=ax, y=list_c[1], color="black", linewidth=5, linestyle='-', marker='o', markersize=mks)
    # Plot the second column as a red dashed line with markers
    g1.plot(kind='line', ax=ax, y=list_c[2], color="red", linewidth=3, linestyle='--', marker='>', markersize=mks)
    # Plot the third column as a blue dashed line with markers
    g1.plot(kind='line', ax=ax, y=list_c[3], color="blue", linewidth=3, linestyle='--', marker='P', markersize=mks)
    # Annotate the y-values of the last data point for each line
    for line, name in zip(ax.lines, g1.columns):
        y = line.get_ydata()[-1]
        ax.annotate(y, xy=(1, y), xytext=(12, 3), textcoords="offset points",
                    color=line.get_color(), xycoords=ax.get_yaxis_transform(), size=25, va="center")
    # Add a horizontal line at y=0
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    # Set the default style
    plt.style.use('default')
    # Set the y-label and x-label
    # plt.ylabel(str(y_Label), size=parameter3)
    # plt.xlabel(str(x_Label), size=parameter3)
    # Set the tick label size
    plt.tick_params(labelsize=parameter4+2)
    plt.title(str(variable), size=15)
    plt.grid(axis='both', alpha=.3)
    y_label="%"
    x_label=str(variable)
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size= parameter3+1)
    ax.legend(fontsize=15) # You can adjust the number for a larger or smaller font size
    ax.set_xticks(g1.index)
    ax.set_xticklabels (g1.index, rotation=45)
    plt.tick_params(labelsize=8)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    x_position = 0.5 # Adjust this value
    y_position= 0.5 # Adjust this value to place the text inside the plot
    plt.text(0.05, 0.95, '[Canada]', fontsize=12, transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.5)) # Adding the text box
    plt.text(0.5, 0.5, 'BOC', fontsize=40, color="gray", alpha=0.5,
             ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    formatted_number = "{:02}".format(n)
    plt.savefig(str("hv_tb_cad_009_001_m_g_0"+str(formatted_number)+".png"), bbox_inches="tight")
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del fig
    del ax
    del ax2
    n=n+1
# Out:
# canada_cpi_headline_nsa
# canada_cpi_headline_sa
# canada_cpi_food_nsa
# canada_cpi_food_sa
# canada_boc_core_trim_sa
# canada_boc_core_median_sa
# canada_cpi_ex_food_energy_nsa
# canada_cpi_ex_food_energy_sa
# canada_cpix_nsa
# canada_cpix_sa
# canada_cpi_goods_nsa
# canada_cpi_services_nsa

# %% [markdown]
# ### 001_  CANADA IFinancial data  <a id="title_page"></a

# %% [markdown]
# ### 001_  CANADA CORRA  <a id="title_page"></a

# %%
#############################
### Financial data

# %%
#Bank of Canada Monetary and Markets Statistics
#This notebook provides examples of some of the monetary policy and financial market statistics provided by the Bank of Canada. It pulls the data into dataframes that can be used for further data transformation and analysis.

#The notebook uses the data available as CSV files from the Bank of Canada website and can be further enhanced by integrating with the Bank of Canada APIs (https://www.bankofcanada.ca/valet/docs#valet_api) and other data providers such as Bloomberg Professional Services.

#The notebook is using the following CSV files from the BoC website:

#Canadian Overnight Repo Rate Average (CORRA): CORRA.csv - updated every day at 9:00 am at https://www.bankofcanada.ca/rates/interest-rates/corra/
#Securities Repo Operations: Sec_Repo.csv - updated every day at 10:15 am at https://www.bankofcanada.ca/markets/market-operations-liquidity-provision/market-operations-programs-and-facilities/securities-repo-operations/
#Money Market Yields: money_market.csv - updated daily at https://www.bankofcanada.ca/rates/interest-rates/money-market-yields/
#Selected Bond Yields: bond_yields_all.csv - updated daily at https://www.bankofcanada.ca/rates/interest-rates/canadian-bonds/
#Daily Exchange Rates: FX_RATES_DAILY-sd-2017-01-03.csv - updated daily at https://www.bankofcanada.ca/rates/exchange/daily-exchange-rates/
#For this notebook to work, the above files must be downloaded and saved as CSV (Comma delimited) (*.csv) files in the same folder as this notebook.



#Canadian overnight repo rate average (CORRA)
#Dollar trading volume of all trades eligible for CORRA
#Trimmed dollar volume of trades eligible for CORRA
#Number of unique data submitters for CORRA
#Rate at which daily CORRA trading volume is trimmed

#Rate at 5th percentile of the trimmed trading volume
#Rate at 25th percentile of the trimmed trading volume
#Rate at 75th percentile of the trimmed trading volume
#Rate at 95th percentile of the trimmed trading volume

horizon_f=500                                             
ca_m_tickers = ['r156rr',
                'r156rrv',
               'r156rrt',
                'r156rrs',
                'r156rrm',
                'r156r5r',
                'r156rqr',
                'r156rhr',
                'r156r9r'
               ]
hv_tb_cad_020_001_m=Haver.data(ca_m_tickers, "INTDAILY", dates=True)
#print(hv_tb_cad_020_001_m)
hv_tb_cad_020_001_m.rename(columns={"r156rr": "CORRA Canadian overnight repo rate average"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156rrv": "CORRA Dollar trading volume"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156rrt": "CORRA Trimmed dollar volume"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156rrs": "CORRA number unique submitters"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156rrm": "CORRA rate daily trading volume is trimmed"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156r5r": "CORRA rate 5th percentile of the trimmed trading volume"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156rqr": "CORRA rate 25th percentile of the trimmed trading volume"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156rhr": "CORRA rate 75th percentile of the trimmed trading volume"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156r9r": "CORRA rate 95th percentile of the trimmed trading volume"}, inplace=True)


#corra['Corra']=corra_df['AVG.INTWO']
#corra['Total Volume']=corra_df['CORRA_TOTAL_VOLUME']
#corra['Trimmed Volume']=corra_df['CORRA_TRIMMED_VOLUME']
#corra['Number of Submitters']=corra_df['CORRA_NUMBER_OF_SUBMITTERS']
#corra['Rate at Trim']=corra_df['CORRA_RATE_AT_TRIM']
#corra['Rate at 5% Perc']=corra_df['CORRA_RATE_AT_PERCENTILE_5']
#corra['Rate at 25% Perc']=corra_df['CORRA_RATE_AT_PERCENTILE_25']
#corra['Rate at 75% Perc']=corra_df['CORRA_RATE_AT_PERCENTILE_75']
#corra['Rate at 95% Perc']=corra_df['CORRA_RATE_AT_PERCENTILE_95']



hv_tb_cad_020_001_m_g_001=hv_tb_cad_020_001_m.copy()
hv_tb_cad_020_001_m=hv_tb_cad_020_001_m.tail(horizon_f)
hv_tb_cad_020_001_m=hv_tb_cad_020_001_m.transpose()
hv_tb_cad_020_001_m.index.names = ['Variable']
list_corra= hv_tb_cad_020_001_m_g_001.columns.tolist()
print(list_corra[0])
# Out:
#   Any 7-daily series in the DLX Direct query are treated as 5-daily.
# CORRA Canadian overnight repo rate average

# %%
##### Corra 
###hv_tb_cad_020_001_m_g_004

title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001[list_corra[0]]
df1=df1.tail(5000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="darkred", linewidth= l1, linestyle='-',)
#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001[list_corra[0]]
df1=df1.tail(1000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="darkred", linewidth= l1, linestyle='-',)
#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001[list_corra[0]]
df1=df1.tail(500)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="darkred", linewidth= l1, linestyle='-',)
#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001[list_corra[0]]
df1=df1.tail(200)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="darkred", linewidth= l1, linestyle='-',)
#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_001_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %%
#CORRA and Rates at Different Percentiles
#hv_tb_cad_020_002_m_g_002
#hv_tb_cad_020_001_m.rename(columns={"r156rr": "CORRA Canadian overnight repo rate average"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156rrv": "CORRA Dollar trading volume"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156rrt": "CORRA Trimmed dollar volume"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156rrs": "CORRA number unique submitters"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156rrm": "CORRA rate daily trading volume is trimmed"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156r5r": "CORRA rate 5th percentile of the trimmed trading volume"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156rqr": "CORRA rate 25th percentile of the trimmed trading volume"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156rhr": "CORRA rate 75th percentile of the trimmed trading volume"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156r9r": "CORRA rate 95th percentile of the trimmed trading volume"}, inplace=True)


title_r="CORRA and Rates at Different Percentiles"
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkblue", linewidth= l1, linestyle='-',)

#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax




title_r="CORRA and Rates at Different Percentiles"
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(50)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkblue", linewidth= l1, linestyle='-',)

#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_002_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r="CORRA and Rates at Different Percentiles"
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(25)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkblue", linewidth= l1, linestyle='-',)

#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_002_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax




title_r="CORRA and Rates at Different Percentiles"
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(10)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkblue", linewidth= l1, linestyle='-',)

#        marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CA Business Barometer Long"], 
#        color="darkblue", linewidth= l1, linestyle='-',
#        marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_002_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %%
#corra_volume=corra.drop(columns=['Corra','Number of Submitters','Rate at Trim','Rate at 5% Perc','Rate at 25% Perc','Rate at 75% Perc',
#                                 'Rate at 95% Perc'])
#corra_volume.tail()
#CORRA Total and Trimmed Volumes
#hv_tb_cad_020_003_m_g_001
title_r0="CORRA Total and Trimmed Volumes"
title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="black", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkred", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del fig
del ax

title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(50)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="black", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkred", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_003_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(25)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="black", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkred", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_003_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(10)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="black", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkred", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_003_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %%
#corra_n_sub=corra['Number of Submitters']


title_r0="CORRA Number of Submitters"
title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="black", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_004_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del fig
del ax

title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(50)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="black", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_004_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(25)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="black", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_004_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(10)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="black", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_004_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %% [markdown]
# ### 001_  CANADA CORRA Canadian overnight repo rate average  <a id="title_page"></a

# %%
#3. Money Market Yields
#mm=money_market_df.drop(columns=['CL.CDN.MOST.1DL'])
#mm=mm.rename(columns={'AVG.INTWO': 'Corra', 'TB.CDN.30D.MID': '1M T-Bills', 
#                      'TB.CDN.60D.MID': '2M T-Bills','TB.CDN.90D.MID': '3M T-Bills',
#                      'TB.CDN.180D.MID': '6M T-Bills','TB.CDN.1Y.MID': '1Y T-Bills'})



horizon_f=500                                             
ca_m_tickers = ['r156rr',
                'r156g1m',
                'r156g2m',
               'r156g3m',
                'r156g6m',
                'r156g1',
                'r156g2',
                'r156g3',
                'r156g5',
                'r156g7',
                'r156ga'
               ]
hv_tb_cad_020_001_m=Haver.data(ca_m_tickers, "INTDAILY", dates=True)
print(hv_tb_cad_020_001_m)
hv_tb_cad_020_001_m.rename(columns={"r156rr": "CORRA Canadian overnight repo rate average"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g1m": "CA Treasury Bill 1m"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g2m": "CA Treasury Bill 2m"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g3m": "CA Treasury Bill 3m"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g6m": "CA Treasury Bill 6m"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g1": "CA Treasury Bill 1y"}, inplace=True)


hv_tb_cad_020_001_m.rename(columns={"r156g2": "CA benchmark bond yield 2y"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g3":  "CA benchmark bond yield 3y"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g5":  "CA benchmark bond yield 5y"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156g7":  "CA benchmark bond yield 7y"}, inplace=True)
hv_tb_cad_020_001_m.rename(columns={"r156ga":  "CA benchmark bond yield 10y"}, inplace=True)


### Spreads
hv_tb_cad_020_001_m["CA benchmark bond yield spread 2y-10y"]=hv_tb_cad_020_001_m["CA benchmark bond yield 10y"]-hv_tb_cad_020_001_m["CA benchmark bond yield 2y"]
hv_tb_cad_020_001_m["CA benchmark bond yield spread 2y-5y"]=hv_tb_cad_020_001_m["CA benchmark bond yield 5y"]-hv_tb_cad_020_001_m["CA benchmark bond yield 2y"]
hv_tb_cad_020_001_m["CA benchmark bond yield spread 5y-10y"]=hv_tb_cad_020_001_m["CA benchmark bond yield 10y"]-hv_tb_cad_020_001_m["CA benchmark bond yield 5y"]

#curve['2Y-10Y'] = by['10Y'] - by['2Y']
#curve['2Y-5Y'] = by['5Y'] - by['2Y']
#curve['5Y-10Y'] = by['10Y'] - by['5Y']




hv_tb_cad_020_001_m_g_001=hv_tb_cad_020_001_m.copy()
hv_tb_cad_020_001_m=hv_tb_cad_020_001_m.tail(horizon_f)
hv_tb_cad_020_001_m=hv_tb_cad_020_001_m.transpose()
hv_tb_cad_020_001_m.index.names = ['Variable']
list_corra= hv_tb_cad_020_001_m_g_001.columns.tolist()
print(list_corra[0])
# Out:
#   Any 7-daily series in the DLX Direct query are treated as 5-daily.
#             r156rr  r156g1m  r156g2m  r156g3m  r156g6m  r156g1  r156g2  \
# 1962-01-02     NaN     2.75     2.90     3.04     3.15     NaN     NaN
# 1962-01-03     NaN     2.75     2.90     3.03     3.15     NaN     NaN
# 1962-01-04     NaN     2.83     2.96     3.08     3.15     NaN     NaN
# 1962-01-05     NaN     2.83     2.96     3.07     3.23     NaN     NaN
# 1962-01-08     NaN     2.83     2.95     3.07     3.20     NaN     NaN
# ...            ...      ...      ...      ...      ...     ...     ...
# 2025-03-14    2.77     2.69     2.65     2.63     2.64    2.59    2.57
# 2025-03-17    2.78     2.66     2.65     2.63     2.62    2.58    2.55
# 2025-03-18    2.77     2.67     2.65     2.64     2.64    2.61    2.54
# 2025-03-19    2.76     2.66     2.65     2.64     2.64    2.59    2.51
# 2025-03-20    2.76     2.66     2.65     2.64     2.63    2.59    2.53
#
#             r156g3  r156g5  r156g7  r156ga
# ...

# %%
##### Corra 
###hv_tb_cad_020_001_m_g_004

title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(5000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[4]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="orange", linewidth= l1, linestyle='-',)

#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_005_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(1000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[4]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="orange", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_005_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(500)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[4]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="orange", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_005_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r=list_corra[0]
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(200)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[0]],
        color="black", linewidth= l1, linestyle='-',)

g1.plot(kind='line', ax=ax,y=[list_corra[1]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[2]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[3]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[4]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[5]],
        color="orange", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_005_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %%
#4. Goverment of Canada Bond Yields
#by=bond_yields_df.drop(columns=['CDN.AVG.1YTO3Y.AVG','CDN.AVG.3YTO5Y.AVG', 'CDN.AVG.5YTO10Y.AVG',
#                                'CDN.AVG.OVER.10.AVG', 'BD.CDN.LONG.DQ.YLD', 'BD.CDN.RRB.DQ.YLD'])

#by=by.rename(columns={'BD.CDN.2YR.DQ.YLD': '2Y', 'BD.CDN.3YR.DQ.YLD': '3Y', 
#                      'BD.CDN.5YR.DQ.YLD': '5Y','BD.CDN.7YR.DQ.YLD': '7Y',
#                      'BD.CDN.10YR.DQ.YLD': '10Y'})



#hv_tb_cad_020_001_m.rename(columns={"r156g2": "CA benchmark bond yield 2y"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156g3":  "CA benchmark bond yield 3y"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156g5":  "CA benchmark bond yield 5y"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156g7":  "CA benchmark bond yield 7y"}, inplace=True)
#hv_tb_cad_020_001_m.rename(columns={"r156ga":  "CA benchmark bond yield 10y"}, inplace=True)


#hv_tb_cad_020_007_m_g_004


title_r0="Goverment of Canada Bond Yields"
title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(5000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[9]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[10]],
        color="orange", linewidth= l1, linestyle='-',)

#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_006_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(1000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[9]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[10]],
        color="orange", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_006_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(500)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[9]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[10]],
        color="orange", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_006_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(200)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[6]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[7]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[8]],
        color="darkgreen", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[9]],
        color="darkblue", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[10]],
        color="orange", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_006_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %%
### Spreads
#curve = pd.DataFrame()
#curve['2Y-10Y'] = by['10Y'] - by['2Y']
#curve['2Y-5Y'] = by['5Y'] - by['2Y']
#curve['5Y-10Y'] = by['10Y'] - by['5Y']
#curve.tail()

title_r0="Goverment of Canada Bond Yields Spread"
title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(5000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[11]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[12]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[13]],
        color="darkgreen", linewidth= l1, linestyle='-',)
#plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_007_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(1000)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[11]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[12]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[13]],
        color="darkgreen", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_007_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(500)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[11]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[12]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[13]],
        color="darkgreen", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_007_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax



title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_cad_020_001_m_g_001.copy()
df1=df1.tail(200)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_corra[11]],
        color="darkred", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[12]],
        color="darkorange", linewidth= l1, linestyle='-',)
g1.plot(kind='line', ax=ax,y=[list_corra[13]],
        color="darkgreen", linewidth= l1, linestyle='-',)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_cad_020_007_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_ca_000_001_m
# Deleting DataFrame: hv_tb_cad_002_001_m
# Deleting DataFrame: hv_tb_cad_002_001_m_g
# Deleting DataFrame: hv_tb_cad_002_001_m_g_001
# Deleting DataFrame: hv_tb_cad_002_001_t1
# Deleting DataFrame: hv_tb_cad_002_001_m_t
# Deleting DataFrame: hv_tb_cad_002_001_t1_t
# Deleting DataFrame: df
# Deleting DataFrame: df_transposed
# Deleting DataFrame: hv_tb_cad_002_002_m
# Deleting DataFrame: hv_tb_cad_002_002_m_g
# Deleting DataFrame: hv_tb_cad_002_002_m_g_001
# Deleting DataFrame: hv_tb_cad_002_002_t1
# Deleting DataFrame: hv_tb_cad_002_002_m_t
# Deleting DataFrame: hv_tb_cad_002_002_t1_t
# Deleting DataFrame: hv_tb_cad_002_003_m
# Deleting DataFrame: hv_tb_cad_002_004_m
# Deleting DataFrame: hv_tb_cad_002_004_m_g
# Deleting DataFrame: hv_tb_cad_002_004_m_g_001
# Deleting DataFrame: hv_tb_cad_002_004_t1
# Deleting DataFrame: hv_tb_cad_002_004_m_t
# Deleting DataFrame: hv_tb_cad_002_004_t1_t
# Deleting DataFrame: hv_tb_cad_002_005_m
# ...

# %%
print("Compelte")
# Out:
# Compelte

# %% [markdown]
# ### 001_  BOTTOM   <a id="title_page"></a
