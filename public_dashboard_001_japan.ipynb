# %% [markdown]
# ### 000 top  <a id="title_page"></a

# %% [markdown]
# ### 000 packages  <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image


parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %% [markdown]
# ### 001 japan inflation    sa <a id="title_page"></a

# %%
country_database = ['JAPAN']

# %%
country_database = ['JAPAN']
#jpc3ijf1
jap_m_tickers = ["jpc3ij", "jpc3ijf", "jpc3ijh", 
                 "jpc3ijfl", "jpc3ijfh", "jpc3ijmc",
                 "jpc3ijtr", "jpc3ijed", "jpc3ijre", "jpc3ijmi", 
                 "jpc3ije", "jpc3jef", "jpc3jhir", "jpc3isjc", 
                 "jpc3sjeg", "jpc3isjs", "jpc3sjse"]

hv_tb_jap_001_001_m = Haver.data(jap_m_tickers, country_database, dates=True)
#print(hv_tb_jap_001_001_m)

for x in range(len(jap_m_tickers)):
    variable = str(jap_m_tickers[x])
    hv_tb_jap_001_001_m[variable] = hv_tb_jap_001_001_m[variable].pct_change(12).multiply(100).round(1)


hv_tb_jap_001_001_m.rename(columns={"jpc3ij": "cpi headline nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijf": "cpi food beverage nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijh": "cpi housing nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijfl": "cpi fuel light water nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijfh": "cpi furniture sa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijcl": "cpi clothes sa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijmc": "cpi medical care sa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijtr": "cpi transportation communication nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijed": "cpi education nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijre": "cpi culture recreation nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ijmi": "cpi miscellaneous nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3ije":"cpi ex fresh food nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3jef": "cpi ex food energy nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3jhir":"cpi housing ex inmputed rent nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3isjc": "cpi goods nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3sjeg": "cpi electricity gas water nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3isjs": "cpi services nsa"}, inplace=True)
hv_tb_jap_001_001_m.rename(columns={"jpc3sjse": "cpi services ex imputed rent nsa"}, inplace=True)

# %% [markdown]
# ### 001 japan inflation    sa table

# %%
hv_tb_jap_001_001_m_g = hv_tb_jap_001_001_m.copy()
hv_tb_jap_001_001_m_g_001 = hv_tb_jap_001_001_m.copy()

hv_tb_jap_001_001_m.index=hv_tb_jap_001_001_m.index.date
hv_tb_jap_001_001_m = hv_tb_jap_001_001_m.tail(horizon_tb)
hv_tb_jap_001_001_t1=hv_tb_jap_001_001_m.tail(horizon_tb)

hv_tb_jap_001_001_m_t = hv_tb_jap_001_001_m.transpose()
hv_tb_jap_001_001_m_t.index.names = ['Variable']

hv_tb_jap_001_001_t1_t = hv_tb_jap_001_001_t1.transpose()
hv_tb_jap_001_001_t1_t.index.names = ['Variable']
############################################################
######Table 1

#####here*******
title_table="jap_inflation_table"
df =hv_tb_jap_001_001_t1.copy()
df_transposed = hv_tb_jap_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_jap_001_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_jap_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_jap_001_001_m_t_002.png')

# %% [markdown]
# ### 001 japan inflation    sa graph

# %%
hv_tb_jap_001_001_m=hv_tb_jap_001_001_m.tail(240)
df1=hv_tb_jap_001_001_m.copy()
df1=df1.tail(48)

for i in range(len(hv_tb_jap_001_001_m.columns.tolist())):
    print(i)
    ai = f"{i:02}"
    print(ai)
    g1=df1.copy()
    list_c=g1.columns.tolist()
    title_r=str(list_c[i])
    y_label="%"
    x_label=title_r
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=list_c[i], color="darkred", linewidth= l1, linestyle='-',
            marker='D',markersize=(s3-1))
    #g1.plot(kind='Line', ax=ax,y=list_c[1], color="darkgreen", Linewidth= 11, Linestyle="-",
    #                                                          marker="P", markersize=s2)
    #g1.plot(kind="Line", ax=ax,y=list_c[2], color="darkblue", Linewidth= L1, Linestyle*-',
    #marker="D", markersize=s2)
    #
    for x,y in zip(g1.index,g1[list_c[i]]):
        label = "{:.1f}".format(y)
        plt.annotate(label, # this is the text
                      (x,y), # these are the coordinates to position the Label
                      textcoords="offset points", # how to position the text
                      xytext=(0,15), # distance from text to points (x,y)
                      size=7,
                      ha='center',
                      weight='bold')

#Last_y_value = gl[series_name][-1]
#                            #print(Last_y_value)
#                            plt.annotate(f'(series_name} \n {last_y_value}',
#                                             xy=(g1.index.max(), last_y_value),
#                                             xytext=(20, -25),
#                                             textcoords="offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))
    
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    x_position= 0.5  # Adjust this value
    y_position= 0.5  # Adjust this value to place the text inside the plot
    plt.text(0.05, 0.5, '[BOJ]',
             fontsize=12, transform=plt.gca().transAxes,
             bbox=dict(facecolor='white',
                       alpha=0.5))  # Adding the text box
    
    plt.text(0.15, 0.15, str(owner), fontsize=15, color="gray", alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    plt.savefig(str("hv_tb_jap_001_001_m_g_0"+str(ai)+".png"), bbox_inches='tight')
    plt.close()
    
    plt.close('all')
    plt.clf()
    
    plt.cla()
    #del gl
    #del df1
    del list_c
    del fig
    del ax
    del ax2
# Out:
# 0
# 00
# 1
# 01
# 2
# 02
# 3
# 03
# 4
# 04
# 5
# 05
# 6
# 06
# 7
# 07
# 8
# 08
# 9
# 09
# 10
# 10
# 11
# 11
# 12
# 12
# 13
# 13
# 14
# 14
# 15
# 15
# 16
# 16

# %% [markdown]
# ### 001 japan inflation  heatmap  sa <a id="title_page"></a

# %%
n_time=45#size figure
#wide
size1=32
#height
size2=size1/1.5
##heatmaps inside
font_size_h=13
number_vbs=17
#x size Label axis
x_sizel=18
x1_sizel=18
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Laet sie dates
axes_1label=12
title_s=32
#hv_tb_jap_001_001_m.index=hv_tb_jap_001_001_m.index.date
df1=hv_tb_jap_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals() [str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    #print(x)
    locals() [str(str("vmin_")+str(x))] = df1.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = df1.iloc[:,x].max()

print(vmin_0)
print(vmax_0)
# data = np.random.random((10, 12))
# df = pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
# sns.color_palette("coolwarm", as_cmap=True)
fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})


sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})


n = 0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x1_sizel, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=8, va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n = (n + 1)

#axes[0].set_xticks([])
#axes[1].set_xticks([])
#axes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=8, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels(axis="x", which="both", length=0, labelrotation=45)
#.set_xticks([])

fig.suptitle("Japan Inflation Economic Dashboard Monthly", fontsize=title_s)
plt.figtext(0.5, 0.01, "Japan Inflation Economic Dashboard Monthly", fontsize=title_s, ha="center")

plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])

plt.savefig('japan_heatmap_001.png', bbox_inches="tight", dpi=300)
plt.show()

plt.close()
# Out:
# 0.5
# 18.6

# %% [markdown]
# ### 001 japan birdeye   sa <a id="title_page"></a

# %%
parameter1_o=6
parameter2_o=4
mks=3
n=0

linew=2
print(" ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,, ojo aveojo ave")

list_c=hv_tb_jap_001_001_m.columns.tolist()
n=1
for y in list_c:
    print(y)
    #print("filtering time horizon")
    df1=hv_tb_jap_001_001_m.copy()
    df1=pd.DataFrame(df1[str(y)])
    #List_c=df1.columns.tolist()
    df1=df1.tail(90)
    g1=df1.copy()
    fig, ax = plt.subplots(figsize=((parameter1_o-1), (parameter2_o)))
    
    g1.plot(kind='line', ax=ax, y=str(y), 
         color="orange",
         linestyle='-', 
         linewidth= (linew+1),
         markersize=mks)
    
    x_last = df1.index[-1]  # Assuming the DataFrame index is date or sequential
    y_last = df1[str(y)].iloc[-1]
    
    # Annotate the last value on the right of the plot (line)
    ax.annotate(f"({y_last:.2f})",
                xy=(x_last, y_last),
                xytext=(10, 0),
                textcoords="offset points",
                ha='left',
                va="center",
                color="orange",
                size=17,
                weight="bold")
    
    # For line, name in zip(ax.lines, str(y)):
    #   yy = line.get_ydata()[-1]
    #   ax.annotate(yy, xy=(1, yy), xytext=(6, 6), color=line.get_color(),
    #               xycoords=ax.get_yaxis_transform(), textcoords="offset points",
    #               size=15, va="center")
    
    plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
    plt.style.use('default')
    #plt.ylabel(str(y_label), size=parameter3)
    #plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("hv_tb_jap_ov"+str(n)+".png"), bbox_inches="tight")
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    # del List_c
    del fig
    del ax
    del ax2
    n = n+1
# Out:
#  ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,, ojo aveojo ave
# cpi headline nsa
# cpi food beverage nsa
# cpi housing nsa
# cpi fuel light water nsa
# cpi furniture sa
# cpi medical care sa
# cpi transportation communication nsa
# cpi education nsa
# cpi culture recreation nsa
# cpi miscellaneous nsa
# cpi ex fresh food nsa
# cpi ex food energy nsa
# cpi housing ex inmputed rent nsa
# cpi goods nsa
# cpi electricity gas water nsa
# cpi services nsa
# cpi services ex imputed rent nsa

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_jap_001_001_m
# Deleting DataFrame: hv_tb_jap_001_001_m_g
# Deleting DataFrame: hv_tb_jap_001_001_m_g_001
# Deleting DataFrame: hv_tb_jap_001_001_t1
# Deleting DataFrame: hv_tb_jap_001_001_m_t
# Deleting DataFrame: hv_tb_jap_001_001_t1_t
# Deleting DataFrame: df
# Deleting DataFrame: df_transposed
# Deleting DataFrame: data_r0
# Deleting DataFrame: data_r1
# Deleting DataFrame: data_r2
# Deleting DataFrame: data_r3
# Deleting DataFrame: data_r4
# Deleting DataFrame: data_r5
# Deleting DataFrame: data_r6
# Deleting DataFrame: data_r7
# Deleting DataFrame: data_r8
# Deleting DataFrame: data_r9
# Deleting DataFrame: data_r10
# Deleting DataFrame: data_r11
# Deleting DataFrame: data_r12
# Deleting DataFrame: data_r13
# Deleting DataFrame: data_r14
# Deleting DataFrame: data_r15
# Deleting DataFrame: data_r16
# Environment cleaned!

# %%
print("Compelte")
# Out:
# Compelte

# %% [markdown]
# ### bottom
