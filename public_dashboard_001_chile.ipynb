# %% [markdown]
# ### 000 top  <a id="title_page"></a

# %% [markdown]
# ### 000 packages  <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

import kaleido
from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image


parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %% [markdown]
# ### 001 heatmpa vpi table <a id="title_page"></a

# %%
country_database=['EMERGELA']
chil_m_tickers=[ "h228pc", "h228pcxr", "h228pcvf", "h228pclt", "h228pcln",
                "n228pc","n228pcxr", "n228pcvf", "n228pclt", "n228pcln",
                "h228pcfn", "h228pcb", "h228pca", "h228pch",
               "h228pcfn", "h228pcm", "h228pct", "h228pcc",
                "h228pcr", "h228pce", "h228pcd","h228pco",
                "h228pce", "n228pcfn", "n228pcb", "n228pca", "n228pch",
               "n228pcfn", "n228pcm","n228pct", "n228pcc",
                "n228pcr", "n228pce", "n228pcd", "n228pco",
                "n228pce", "n228pcxv", "h228pp", "n228pp",]
hv_tb_chil_001_001_m=Haver.data(chil_m_tickers, country_database, dates=True)
#print(hv_tb_chil_001_001_m)
#print(hv_tb_ch_001_001_m)
#print(chf_m_tickers.columns)
for x in range(len(chil_m_tickers)):
         #print(x)
         variable=str(chil_m_tickers[x])
         #print(variable)
         hv_tb_chil_001_001_m[variable] = hv_tb_chil_001_001_m[variable].pct_change (12).multiply(100).round(1)
         #print(chf_m_tickers[variable])

hv_tb_chil_001_001_m.rename(columns={"h228pc": "cpi sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcxr": "cpi core sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcvf": "cpi perishable sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pclt": "cpi tradables sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pc1n": "cpi nontradables sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pc": "cpi nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcxr": "cpi core nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcvf": "cpi perishable nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pclt": "cpi tradables nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcln": "cpi nontradables nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcfn": "cpi food sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcb": "cpi alcohol sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pca": "cpi clothing sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pch": "cpi housing sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcfn": "cpi household sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcm": "cpi health sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pct": "cpi transportation sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcc": "cpi communication sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcr": "cpi recreation sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pce": "cpi education sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pce": "cpi education sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcd": "cpi hotel restaurant sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pco": "cpi other gs sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcfn": "cpi food nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcb": "cpi alcohol nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pca": "cpi clothing nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pch": "cpi housing nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcfn":"cpi household nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcm": "cpi health nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pct": "cpi transportation nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcc":"cpi communication nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcr":"cpi recreation nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pce": "cpi education nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcd":"cpi hotel restaurant nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pco": "cpi other gs nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcxv":"cpi ex volatiles nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pp": "ppi sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pp": "ppi nsa"}, inplace=True)

# %%
hv_tb_chil_001_001_m=hv_tb_chil_001_001_m.tail(240)
df1=hv_tb_chil_001_001_m.copy()
df1=df1.tail(48)
print(df1.shape[0])
print(df1.shape[1])
for i in range(len(hv_tb_chil_001_001_m.columns.tolist())):
    print(i)
    ai=f"{i:02}"
    print(ai)
    g1=df1.copy()
    list_c=g1.columns.tolist()
    title_r=str(list_c[i])
    y_label="%"
    x_label=title_r
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=list_c[i], color="darkred", linewidth= l1, linestyle='',
            marker='D', markersize=(s3-1))
    #g1.plot(kind='Line', ax=ax, y=list_c[1], color="darkgreen", Linewidth= 11, Linestyle-'-'
    #marker='P', markersize=s2)
    #g1.plot(kind="Line", ax=ax,y=list_c[2], color="darkblue", Linewidth= L1, Linestyle='-',
    #marker='D', markersize=s2)
    #

    for x,y in zip(g1.index,g1[list_c[i]]):
        label = "{:.1f}".format(y)
        plt.annotate(label, # this is the text
                      (x,y), #these are the coordinates to position the Label
                      textcoords="offset points", # how to position the text
                      xytext=(0,15), # distance from text to points (x,y)
                      size=7,
                      ha='center',
                      weight="bold")

        
    for series_name in list_c[i:(i+1)]:
        last_y_value = g1[series_name][-1]
        #print(last_y_value)
        plt.annotate(f' {series_name} \n {last_y_value}',
                     xy=(g1.index.max(), last_y_value),
                     xytext=(20, -25),
                     textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
        
    plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    x_position = 0.5  # Adjust this value
    y_position = 0.5  # Adjust this value to place the text inside the plot
    
    plt.text(0.05, 0.5, '[BCCH]',
             fontsize=12, transform=plt.gca().transAxes,
             bbox=dict(facecolor="white", alpha=0.5)) # Adding the text box
    
    plt.text(0.5, 0.5, 'CHILE',
         fontsize=40,
         color='gray',
         alpha=0.5,
         ha='center',
         va='center',
         rotation=30,
         transform=plt.gca().transAxes)

    plt.text(0.15, 0.15, str(owner),
             fontsize=15,
             color='gray',
             alpha=0.5,
             ha='center',
             va='center',
             rotation=30,
             transform=plt.gca().transAxes)

    plt.savefig(str("hv_tb_chil_001_001_m_g_0"+str(ai)+".png"), bbox_inches='tight')
    plt.savefig(str("hv_tb_chil_001_001_m_g_0"+str(ai)+".jpg"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    #det gi
    #det df1
    del list_c
    del fig
    del ax
    del ax2

#os.chdirdashboard_eco*)
#print(os.getcwd())
# Out:
# 48
# 35
# 0
# 00
# 1
# 01
# 2
# 02
# 3
# 03
# 4
# 04
# 5
# 05
# 6
# 06
# 7
# 07
# 8
# 08
# 9
# 09
# 10
# 10
# 11
# 11
# 12
# 12
# 13
# 13
# 14
# 14
# 15
# 15
# 16
# 16
# 17
# 17
# 18
# 18
# 19
# 19
# 20
# 20
# 21
# 21
# 22
# 22
# 23
# 23
# 24
# 24
# 25
# 25
# 26
# 26
# 27
# 27
# 28
# 28
# 29
# 29
# 30
# 30
# 31
# 31
# 32
# 32
# 33
# 33
# 34
# 34

# %%
print(g1)
# Out:
#             cpi sa  cpi core sa  cpi perishable sa  cpi tradables sa  \
# 2021-02-28     2.8          2.4               15.0               3.8
# 2021-03-31     2.9          2.6               11.7               3.8
# 2021-04-30     3.3          2.8               10.3               4.4
# 2021-05-31     3.7          3.1                8.3               4.8
# 2021-06-30     3.8          3.1                8.5               5.0
# 2021-07-31     4.6          3.6                6.5               5.9
# 2021-08-31     4.8          3.8                6.2               5.9
# 2021-09-30     5.3          4.4                4.5               6.4
# 2021-10-31     6.0          5.1                4.6               6.9
# 2021-11-30     6.7          5.8                2.7               8.3
# 2021-12-31     7.2          6.5                1.0               8.6
# 2022-01-31     7.7          7.2               -2.0               8.9
# 2022-02-28     7.8          6.7                2.3               9.2
# ...

# %%
#os.chdir(dashboard_eco')
#print(os.getcwd())

n_time=45
#size figure
#wide
size1=32
#height
size2=size1/1.3
##heatmaps inside
font_size_h=13
number_vbs=26
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Lael sie dates
axes_1label=12
title_s=32
hv_tb_chil_001_001_m.index=hv_tb_chil_001_001_m.index.date
df1=hv_tb_chil_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    #print(x)
    locals()[str(str("vmin_")+str(x))] = hv_tb_chil_001_001_m.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = hv_tb_chil_001_001_m.iloc[:,x].max()
    #print("end Loop")

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)      
sns.heatmap(data_r0,cmap=red_to_blue, annot =True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1,cmap=red_to_blue, annot =True, ax=axes [1], cbar=False, vmin=vmin_1, vmax=vmax_1,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2,cmap=red_to_blue, annot =True, ax=axes [2], cbar=False, vmin=vmin_2, vmax=vmax_2,fmt='g',
           annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3,cmap=red_to_blue, annot= True, ax=axes [3], cbar=False, vmin=vmin_3, vmax=vmax_3,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4,cmap=red_to_blue, annot=True, ax=axes [4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5,cmap=red_to_blue, annot=True, ax=axes [5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6,cmap=red_to_blue, annot=True, ax=axes [6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7,cmap=red_to_blue, annot=True, ax=axes [7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8,cmap=red_to_blue, annot=True, ax=axes [8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9,cmap=red_to_blue, annot=True, ax=axes [9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10,cmap=red_to_blue, annot=True, ax=axes [10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11,cmap=red_to_blue, annot=True, ax=axes [11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12,cmap=red_to_blue, annot=True, ax=axes [12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13,cmap=red_to_blue, annot=True, ax=axes [13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14,cmap=red_to_blue, annot=True, ax=axes [14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15,cmap=red_to_blue, annot=True, ax=axes [15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16,cmap=red_to_blue, annot=True, ax=axes [16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=reversed_red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=reversed_red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=reversed_red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=reversed_red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=reversed_red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=reversed_red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})                     
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels(ax.get_xtickLabels(), rotation=90)
    n=(n+1)
    
#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels (axis="x", which="both", length=0, Labelrotation=45)
#.set_xticks([])
fig.suptitle("Chile Economic Dashboard ", fontsize=title_s)
plt.figtext(0.5,0.01, "Chile Economic Dashboard ", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout (rect=[0,0.03,1,0.97])
plt.savefig('chile_heatmap_001.png', bbox_inches='tight',dpi=300)
plt.show()
plt.close()


#n=(n+1)

# %%
horizon_00=120

print("quarterly")
chil_m_tickers1 = ["h228elpi", "s228ndtq", "s228ncq", "s228nfq", 
                   "s228nxq","s228nmq", "n228fdng", "n228pftt"]
hv_tb_chil_000_001_m=Haver.data(chil_m_tickers1, "EMERGELA", dates=True)
print(hv_tb_chil_000_001_m)
print("monthly")
chil_m_tickers2 = ["h228pc", "h228pcxr", "h228pcvf", "h228pclt", "h228pcln",
                   "n228pc", "n228pcxr", "n228pcvf", "n228pclt", "n228pcln",
                   "h228pcfn", "h228pcb", "h228pca", "h228pch", "h228pcg",
                   "h228pcm","h228pct", "h228pcc",
                   "h228pcr", "h228pce", "h228pcd", "h228pco",                   
                   "n228pcfn", "n228pcb", "n228pca", "n228pch", "n228pcg",
                   "n228pcm","n228pct", "n228pcc",
                   "n228pcr", "n228pce", "n228pcd", "n228pco",
                   "n228pcxv", "h228pp", "n228pp", "n228pqc",
                   "h228elur", "h228elpr", "s228eja", "c228eja","s228e6",
                   "s228e7", "s228nvfc", "s228nqc", "s228ndc",
                   "s228gvi", "h228fvb",
                   "h228is", "n228is", "n228vec", "n228vce", "n228oncu", "c228rd"]

#
hv_tb_chil_000_002_m=Haver.data(chil_m_tickers2, "EMERGELA", dates=True)
print(hv_tb_chil_000_002_m)
hv_tb_chil_001_001_m=pd.concat([hv_tb_chil_000_001_m, hv_tb_chil_000_002_m], axis=1, join="outer")
chil_m_tickers=chil_m_tickers1+chil_m_tickers2
hv_tb_chil_001_001_m = hv_tb_chil_001_001_m.fillna (method='bfill')


print("round")
#round
yy_m_tickers = ["s228ndtq", "s228ncq", "s228nfq", 
                "s228nxq", "s228nmq", "n228pqc", "h228elur", "h228elpr"]
for x in range(len(yy_m_tickers)):
    variable = str(yy_m_tickers[x])
    hv_tb_chil_001_001_m[variable] = hv_tb_chil_001_001_m[variable].round(1)
print("yy ")
yy_m_tickers = ["s228nvfc", "s228nqc", "h228pc", "h228pcxr", "h228pcvf", "h228pclt", "h228pcln",
                "n228pc", "n228pcxr", "n228pcvf", "n228pclt", "n228pcln", "h228pcb", "h228pca",
                "h228pch", "h228pcfn", "h228pcg", "h228pcm", "h228pct", "h228pcc", "h228pcr",
                "h228pce", "n228pcfn", "n228pcb", "n228pca", "n228pch", "n228pcfn", "n228pcg", 
                "n228pcm", "n228pct", "n228pcc", "n228pcr", "n228pce", "n228pce", "n228pcxv",
                "h228pp", "n228pp", "n228oncu", "h228is", "n228is", "s228e6", "s228e7", "s228gvi",
                "n228pcd", "n228pco", "h228pcd", "h228pco", "s228ndc", "h228elpi"]
for x in range(len(yy_m_tickers)):
    variable = str(yy_m_tickers[x])
    hv_tb_chil_001_001_m[variable] = hv_tb_chil_001_001_m[variable].pct_change(12).multiply(100).round(1)
    
####quarterly
yy_m_tickers = ["n228pqc", "h228elpr"]
for x in range(len(yy_m_tickers)):
    variable = str(yy_m_tickers[x])
    hv_tb_chil_001_001_m[variable] = hv_tb_chil_001_001_m[variable].pct_change(3).multiply(100).round(1)
# Out:
# quarterly
#             h228elpi  s228ndtq  s228ncq  s228nfq  s228nxq  s228nmq  n228fdng  \
# 1986-03-31     51.77       NaN      NaN      NaN      NaN      NaN       NaN
# 1986-06-30     52.91       NaN      NaN      NaN      NaN      NaN       NaN
# 1986-09-30     53.46       NaN      NaN      NaN      NaN      NaN       NaN
# 1986-12-31     54.24       NaN      NaN      NaN      NaN      NaN       NaN
# 1987-03-31     54.10       NaN      NaN      NaN      NaN      NaN       NaN
# ...              ...       ...      ...      ...      ...      ...       ...
# 2023-09-30    113.13   -1.2397  -0.3484  -0.4299   0.7519  -0.9876      23.9
# 2023-12-31    111.50   -0.3587   0.1916  -0.7210  -0.1058  -0.6602      20.8
# 2024-03-31    113.45    1.9796   1.4350  -0.0342   0.6977   0.6358      20.1
# 2024-06-30    111.18   -1.4695  -0.4801   0.3714   0.7572  -0.1196      20.0
# 2024-09-30    112.90    0.6514   0.1883   0.2720   0.5476   0.5371      23.0
#
#             n228pftt
# ...

# %%
#Quarterly
hv_tb_chil_001_001_m.rename(columns={"h228elpi": "real: output per employed person"}, inplace=True)
#Level
hv_tb_chil_001_001_m.rename(columns={"s228ndtq": "real: gdp domestic demand qq sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228ncq": "real: gdp final consumption expenditure qq sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228nfq": "real: gdp gross fixed capital formation qq sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228nxq": "real: gdp exports qq sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228nmq": "real: gdp imports qq sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228nvfc": "real: gdp gva factor cost sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228nqc": "real: gdp mining sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228ndc": "real: gdp manufacturing sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228gvi": "real: monthly economic activity sa"}, inplace=True)
hv_tb_chil_001_001_m["n228fdng"] = hv_tb_chil_001_001_m["n228fdng"].round(0)
hv_tb_chil_001_001_m.rename(columns={"n228fdng": "real: net govt debt consolidated q"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228oncu": "real: copper production"}, inplace=True)
hv_tb_chil_001_001_m["n228pftt"] = hv_tb_chil_001_001_m["n228pftt"].round(0)
hv_tb_chil_001_001_m.rename(columns={"n228pftt": "real: terms of trade nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228elur": "employment: unemployment rate"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228elpr": "employment: participation rate"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228eja": "employment: job vacancy index sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"c228eja": "employment: job vacancy index nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228e6": "employment: hourly nominal remuneration index sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"s228e7": "employment: hourly real remuneration index sa"}, inplace=True)

hv_tb_chil_001_001_m.rename(columns={"h228pc":"prices: cpi sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcxr":"prices: cpi core sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcvf":"prices: cpi perishable sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pclt":"prices: cpi tradables sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcln":"prices: cpi nontradables sa"}, inplace=True)



hv_tb_chil_001_001_m.rename(columns={"n228pc":"prices: cpi nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcxr":"prices: cpi core nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcvf":"prices: cpi perishable nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pclt":"prices: cpi tradables nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcln":"prices: cpi nontradables nsa"}, inplace=True)

hv_tb_chil_001_001_m.rename(columns={"h228pcfn": "prices: cpi food sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcb":"prices: cpi alcohol sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pca":"prices: cpi clothing sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pch":"prices: cpi housing sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcg":"prices: cpi household sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcm":"prices: cpi health sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pct": "prices: cpi transportation sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcc":"prices: cpi communication sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcr": "prices: cpi recreation sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pce":"prices: cpi education sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pcd":"prices: cpi hotel restaurant sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pco":"prices: cpi other gs sa"}, inplace=True)

hv_tb_chil_001_001_m.rename(columns={"n228pcfn":"prices: cpi food nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcb":"prices: cpi alcohol nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pca":"prices: cpi clothing nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pch":"prices: cpi housing nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcg":"prices: cpi household nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcm":"prices: cpi health nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pct": "prices: cpi transportation nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcc":"prices: cpi communication nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcr":"prices: cpi recreation nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pce":"prices: cpi education nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pcd":"prices: cpi hotel restaurant nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pco":"prices: cpi other gs nsa"}, inplace=True)

hv_tb_chil_001_001_m.rename(columns={"n228pcxv":"prices: cpi ex volatiles nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228pp":"prices: ppi sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pp":"prices: ppi nsa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228pqc":"prices: copper price monthly"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228vec":"prices: monthly inflation expectations"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"c228rd": "financial: monetary policy rate eop"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228fvb": "financial: monetary base sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"h228is":"real: industrial production sofofa sa"}, inplace=True)
hv_tb_chil_001_001_m.rename(columns={"n228is":"real: industrial production sofofa nsa"}, inplace=True)
hv_tb_chil_001_001_m["n228vce"]= hv_tb_chil_001_001_m["n228vce"].round(0)
hv_tb_chil_001_001_m.rename(columns={"n228vce":"cycle: economic perception index ipec"}, inplace=True)

#KeyError: "['real: gdp mining sa', 'prices: cpi nsa',
#'prices: cpi core nsa', 'prices: cpi perishable nsa',
#'prices: cpi tradables nsa', 'prices: cpi nontradables nsa', 
#'prices: cpi recreation nsa', 'prices: cpi education nsa'] not in index"

print(len(hv_tb_chil_001_001_m.columns.tolist()))
print(hv_tb_chil_001_001_m.shape[0])
print(hv_tb_chil_001_001_m.shape[1])
#hv_tb_mex_001_001_m.to_clipboard()
hv_tb_chil_001_001_m=hv_tb_chil_001_001_m.tail(200)


list_c=["real: gdp domestic demand qq sa",  
        "real: gdp final consumption expenditure qq sa",
        "real: gdp exports qq sa",
        "real: gdp imports qq sa",
        "real: gdp gva factor cost sa",
        "real: gdp mining sa",
        "real: gdp manufacturing sa",
        "real: monthly economic activity sa",
        "real: industrial production sofofa sa",
        "real: industrial production sofofa nsa",
        "real: output per employed person",
        "real: net govt debt consolidated q",
        "real: terms of trade nsa",
        "real: copper production",
        "employment: unemployment rate",
        "employment: participation rate",
        "employment: job vacancy index sa",
        "employment: job vacancy index nsa",
        "employment: hourly nominal remuneration index sa",
        "employment: hourly real remuneration index sa",
        "prices: cpi sa",
        "prices: cpi core sa",
        "prices: cpi perishable sa",
        "prices: cpi tradables sa",
        "prices: cpi nontradables sa",
        "prices: cpi nsa",
        "prices: cpi core nsa",
        "prices: cpi perishable nsa",
        "prices: cpi tradables nsa",
        "prices: cpi nontradables nsa",
        "prices: cpi food sa",
        "prices: cpi alcohol sa",
        "prices: cpi clothing sa",
        "prices: cpi housing sa",
        "prices: cpi household sa",
        "prices: cpi health sa",
        "prices: cpi transportation sa",
        "prices: cpi communication sa",
        "prices: cpi recreation sa",
        "prices: cpi education sa",
        "prices: cpi hotel restaurant sa",
        "prices: cpi other gs sa",
        "prices: cpi food nsa",
        "prices: cpi alcohol nsa",
        "prices: cpi clothing nsa",
        "prices: cpi perishable nsa",
        "prices: cpi tradables nsa",
        "prices: cpi nontradables nsa",
        "prices: cpi food sa",
        "prices: cpi alcohol sa",
        "prices: cpi clothing sa",
        "prices: cpi housing sa",
        "prices: cpi household sa",
        "prices: cpi health sa",
        "prices: cpi transportation sa",
        "prices: cpi communication sa",
        "prices: cpi recreation sa",
        "prices: cpi education sa",
        "prices: cpi hotel restaurant sa",
        "prices: cpi other gs sa",
        "prices: cpi food nsa",
        "prices: cpi alcohol nsa",
        "prices: cpi clothing nsa",
        "prices: cpi housing nsa",
        "prices: cpi household nsa",
        "prices: cpi health nsa",
        "prices: cpi transportation nsa",
        "prices: cpi communication nsa",
        "prices: cpi recreation nsa",
        "prices: cpi education nsa",
        "prices: cpi hotel restaurant nsa",
        "prices: cpi other gs nsa",
        "prices: cpi ex volatiles nsa",
        "prices: ppi sa",
        "prices: ppi nsa",
        "prices: monthly inflation expectations",
        "prices: copper price monthly",
        "financial: monetary policy rate eop",
        "financial: monetary base sa",
        "cycle: economic perception index ipec"]
hv_tb_chil_001_001_m=hv_tb_chil_001_001_m[list_c]
hv_tb_chil_001_001_m.index=hv_tb_chil_001_001_m.index.date
print(hv_tb_chil_001_001_m.shape[0])
print(hv_tb_chil_001_001_m.shape[1])
# Out:
# 63
# 806
# 63
# 200
# 80

# %%
n_time=45
#size figure
#wide
size1=32
#height
size2=size1/0.80
##heatmaps inside
font_size_h=12
number_vbs=63
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_chil_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names=['Variable']

num_rows = df1.shape[0]
print(num_rows)

for x in range(num_rows):
    #print(x)
    locals() [str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    #print(x)
    locals()[str(str("vmin_")+str(x))] = hv_tb_chil_001_001_m.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = hv_tb_chil_001_001_m.iloc[:,x].max()
    #print("end Loop")

#print(vmin_0)
#print(vmax_0)

#print(vmin_0)
#print(vmax_0)

#data = np.random.random((10,12))
#df=pd.DataFrame(data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))

#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1, 
                         figsize=(size1, size2), 
                         sharex=True)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False,
            vmin=vmin_0, vmax=vmax_0, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False,
            vmin=vmin_1, vmax=vmax_1, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False,
            vmin=vmin_2, vmax=vmax_2, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False,
            vmin=vmin_3, vmax=vmax_3, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False,
            vmin=vmin_4, vmax=vmax_4, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False,
            vmin=vmin_5, vmax=vmax_5, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, 
            vmin=vmin_6, vmax=vmax_6, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False,
            vmin=vmin_7, vmax=vmax_7, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False,
            vmin=vmin_8, vmax=vmax_8, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, 
            vmin=vmin_9, vmax=vmax_9, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False,
            vmin=vmin_10, vmax=vmax_10, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, 
            vmin=vmin_11, vmax=vmax_11, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False,
            vmin=vmin_12, vmax=vmax_12, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, 
            vmin=vmin_13, vmax=vmax_13, fmt='g', annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r38, cmap=red_to_blue, annot=True, ax=axes[38], cbar=False, vmin=vmin_38, vmax=vmax_38, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r39, cmap=red_to_blue, annot=True, ax=axes[39], cbar=False, vmin=vmin_39, vmax=vmax_39, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r40, cmap=red_to_blue, annot=True, ax=axes[40], cbar=False, vmin=vmin_40, vmax=vmax_40, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r41, cmap=red_to_blue, annot=True, ax=axes[41], cbar=False, vmin=vmin_41, vmax=vmax_41, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r42, cmap=red_to_blue, annot=True, ax=axes[42], cbar=False, vmin=vmin_42, vmax=vmax_42, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r43, cmap=red_to_blue, annot=True, ax=axes[43], cbar=False, vmin=vmin_43, vmax=vmax_43, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r44, cmap=red_to_blue, annot=True, ax=axes[44], cbar=False, vmin=vmin_44, vmax=vmax_44, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r45, cmap=red_to_blue, annot=True, ax=axes[45], cbar=False, vmin=vmin_45, vmax=vmax_45, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r46, cmap=red_to_blue, annot=True, ax=axes[46], cbar=False, vmin=vmin_46, vmax=vmax_46, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r47, cmap=red_to_blue, annot=True, ax=axes[47], cbar=False, vmin=vmin_47, vmax=vmax_47, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r48, cmap=red_to_blue, annot=True, ax=axes[48], cbar=False, vmin=vmin_48, vmax=vmax_48, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r49, cmap=red_to_blue, annot=True, ax=axes[49], cbar=False, vmin=vmin_49, vmax=vmax_49, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r50,cmap=red_to_blue, annot=True, ax=axes[50], cbar=False, vmin=vmin_50,vmax=vmax_50, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r51,cmap=red_to_blue, annot=True, ax=axes[51], cbar=False, vmin=vmin_51, vmax=vmax_51, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r52, cmap=red_to_blue, annot=True, ax=axes[52], cbar=False, vmin=vmin_52, vmax=vmax_52, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r53, cmap=red_to_blue, annot=True, ax=axes[53], cbar=False, vmin=vmin_53, vmax=vmax_53, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r54, cmap=red_to_blue, annot=True, ax=axes[54], cbar=False, vmin=vmin_54, vmax=vmax_54, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r55,cmap=red_to_blue, annot=True, ax=axes[55], cbar=False, vmin=vmin_55, vmax=vmax_55, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r56,cmap=red_to_blue, annot=True, ax=axes[56], cbar=False, vmin=vmin_56, vmax=vmax_56, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r57,cmap=red_to_blue, annot=True, ax=axes[57], cbar=False, vmin=vmin_57, vmax=vmax_57, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r58, cmap=red_to_blue, annot=True, ax=axes[58], cbar=False, vmin=vmin_58, vmax=vmax_58, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r59, cmap=red_to_blue, annot=True, ax=axes[59], cbar=False, vmin=vmin_59, vmax=vmax_59, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r60, cmap=red_to_blue, annot=True, ax=axes[60], cbar=False, vmin=vmin_60, vmax=vmax_60, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r61, cmap=red_to_blue, annot=True, ax=axes[61], cbar=False, vmin=vmin_61, vmax=vmax_61, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r62, cmap=red_to_blue, annot=True, ax=axes[62], cbar=False, vmin=vmin_62, vmax=vmax_62, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n = 0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    # ax.set_xticklabels(ax.get_xtickLabels(), rotation=90)
    n = (n + 1)

# axes[0].set_xticks([])
# axes[1].set_xticks([])
# axes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
# .set_xticks([])

fig.suptitle("Chile Economic Dashboard ", fontsize=title_s)
plt.figtext(0.5, 0.01, "Chile Economic Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-0.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('chile_heatmap_002.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()
# Out:
# 80

# %% [markdown]
# ### 001 bird eye  <a id="title_page"></a

# %%
parameter1_0=6
parameter2_0=4
mks=3
n=0
linew=2
print(" ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave")
list_c=hv_tb_chil_001_001_m.columns.tolist()

n=1
for y in list_c:
    print(y)
    #print("filtering time horizon")
    df1=hv_tb_chil_001_001_m.copy()
    df1=pd.DataFrame(df1[str(y)])
    #List_c=df1.columns.tolist()
    df1=df1.tail(90)
    g1=df1.copy()
    print("shape")
    print(g1.shape[0])
    print(g1.shape[1])
    fig, ax = plt.subplots(figsize=((parameter1_0-1), (parameter2_0)))
    g1.plot(kind='line', ax=ax,y=str(y), 
            color="orange",
            linestyle='-',
            linewidth= (linew+1),
            marker='o',
            markersize=mks)
    x_last = g1.index[-1] # Assuming the DataFrame index is date or sequential
    y_last = g1[str(y)].iloc[-1]

    #Annotate the Last value on the right of the plot Line
    #ax.annotate(f'{y_last:.2f}',
    #         xy=(x_last, y_last),
    #         xytext=(10, 0),
    #         textcoords="offset points",
    #         ha="left",
    #         va="center",
    #         color="orange",
    #         size=17,
    #         weight="bold")    
    #for line, name in zip(ax.lines, str(y)):
    #    yy = line.get_ydata()[-1]
    #
    #    ax.annotate(yy, xy=(1,yy), xytext=(6,6), color=line.get_color(),
    #                xycoords=ax.get_yaxis_transform(), textcoords="offset points",  size=15, va="center")
    #
    #plt.axhline(0, color="black", lw=1, linestyle = 'dashed', alpha=0.75)
    plt.style.use('default')
    #plt.ylabel(str(y_Label), size=parameter3)
    #plt.xlabel(str(x_Label), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("hv_tb_chil_ov"+str(n+0)+".png"), bbox_inches='tight')
    plt.savefig(str("hv_tb_chil_ov"+str(n+0)+".jpg"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    #del List_c
    del fig
    del ax
    del ax2
    n=n+1
    print(n)
# Out:
#  ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave
# real: gdp domestic demand qq sa
# shape
# 90
# 1
# 2
# real: gdp final consumption expenditure qq sa
# shape
# 90
# 1
# 3
# real: gdp exports qq sa
# shape
# 90
# 1
# 4
# real: gdp imports qq sa
# shape
# 90
# 1
# 5
# real: gdp gva factor cost sa
# shape
# 90
# 1
# 6
# real: gdp mining sa
# shape
# 90
# 1
# 7
# real: gdp manufacturing sa
# shape
# 90
# 1
# 8
# real: monthly economic activity sa
# shape
# 90
# 1
# 9
# real: industrial production sofofa sa
# shape
# 90
# 1
# 10
# real: industrial production sofofa nsa
# shape
# 90
# 1
# 11
# real: output per employed person
# shape
# 90
# 1
# 12
# real: net govt debt consolidated q
# shape
# 90
# 1
# 13
# real: terms of trade nsa
# shape
# 90
# 1
# 14
# real: copper production
# shape
# 90
# 1
# 15
# employment: unemployment rate
# shape
# 90
# 1
# 16
# employment: participation rate
# shape
# 90
# 1
# 17
# employment: job vacancy index sa
# shape
# 90
# 1
# ...

# %%
#print(g1)

# %%
print("Complete")
from dateutil.relativedelta import relativedelta
import seaborn as sns
import plotly.graph_objects as go

us_m_tickers = ['h228pcxr']
country_database=["EMERGELA"]

hv_tb_usa_009_009_m=Haver.data(us_m_tickers, country_database, dates=True)
#hv_tb_usa_009_009_m.rename(columns={"pcu": "CPI Headline"}, inplace=True)
#hv_tb_usa_009_009_m.rename(columns={"pcuslfe":"CPI Core"}, inplace=True)
#hv_tb_usa_009_009_m.rename(columns={"pcuslfe": "CPI Core"}, inplace=True)
#hv_tb_usa_009_009_m.rename(columns={"jcbm": "PCE Headline"}, inplace=True)
hv_tb_usa_009_009_m.rename(columns={"h228pcxr": "Core CPI SA"}, inplace=True)
#hv_tb_usa_009_009_m.rename(columns={"jcsxehm":"PCE Core SxH"}, inplace=True)

#hv_tb_us_000_001_m.rename(columns={"pculfet": "US Core CPI 3M3M rolling Annualized"), inplace=True)

usi_m_tickers=hv_tb_usa_009_009_m.columns.tolist()
hv_tb_us_000_001_m=hv_tb_usa_009_009_m.copy()

max_index0=hv_tb_us_000_001_m.index.max()
print(max_index0)

hv_tb_us_000_001_m["Core CPI SA diff"]= hv_tb_us_000_001_m["Core CPI SA"].diff()
variable="Core CPI SA diff"

hv_tb_us_000_001_m[str(variable)+"_1mean"] = hv_tb_us_000_001_m[variable].rolling(window=1).mean()
hv_tb_us_000_001_m[str(variable)+"_2mean"] = hv_tb_us_000_001_m[variable].rolling(window=2).mean()
hv_tb_us_000_001_m[str(variable)+"_3mean"] = hv_tb_us_000_001_m[variable].rolling(window=3).mean()
hv_tb_us_000_001_m[str(variable)+"_4mean"] = hv_tb_us_000_001_m[variable].rolling(window=4).mean()
hv_tb_us_000_001_m[str(variable)+"_5mean"] = hv_tb_us_000_001_m[variable].rolling(window=5).mean()
hv_tb_us_000_001_m[str(variable)+"_6mean"] = hv_tb_us_000_001_m[variable].rolling(window=6).mean()

delta_input = 18
hv_tb_us_000_001_m = (hv_tb_us_000_001_m.reindex(pd.date_range(hv_tb_us_000_001_m.index.min(),
                                                               hv_tb_us_000_001_m.index.max() + relativedelta(months=delta_input), 
                                                               freq='M'), method='ffill'))

hv_tb_us_000_001_m["Core CPI SAO"] = hv_tb_us_000_001_m["Core CPI SA"]
hv_tb_us_000_001_m = hv_tb_us_000_001_m.tail(48)

hv_tb_us_000_001_m["Core CPI SA"] = np.where(hv_tb_us_000_001_m.index > max_index0, np.nan, hv_tb_us_000_001_m["Core CPI SA"])
hv_tb_us_000_001_m["Core CPI SA"] = hv_tb_us_000_001_m["Core CPI SA"].fillna(method='ffill', limit=1)
hv_tb_us_000_001_m["Core CPI SA"] = hv_tb_us_000_001_m["Core CPI SA"].fillna(0)
hv_tb_us_000_001_m["Core CPI SAO"] = np.where(hv_tb_us_000_001_m.index > max_index0, 0, hv_tb_us_000_001_m["Core CPI SAO"])
hv_tb_us_000_001_m["Core CPI SA yy"] = hv_tb_us_000_001_m["Core CPI SAO"].pct_change(periods=12, fill_method='bfill').multiply(100).round(2)
hv_tb_us_000_001_m["Core CPI SA yy"] = np.where(hv_tb_us_000_001_m.index > max_index0, 0, hv_tb_us_000_001_m["Core CPI SA yy"])

hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = hv_tb_us_000_001_m[str("Core CPI SA")] + hv_tb_us_000_001_m[str(variable)+"_1mean"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_1mean_s"])
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_1mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] + hv_tb_us_000_001_m["Core CPI SAO"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"].pct_change(
    periods=12, fill_method="bfill").multiply(100)

hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = hv_tb_us_000_001_m[str("Core CPI SA")] + hv_tb_us_000_001_m[str(variable)+"_2mean"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_2mean_s"])
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_2mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] + hv_tb_us_000_001_m["Core CPI SAO"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"].pct_change(
    periods=12, fill_method="bfill").multiply(100)

hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = hv_tb_us_000_001_m[str("Core CPI SA")] + hv_tb_us_000_001_m[str(variable)+"_3mean"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_3mean_s"])
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_3mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] + hv_tb_us_000_001_m["Core CPI SAO"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"].pct_change(
    periods=12, fill_method="bfill").multiply(100)

hv_tb_us_000_001_m[str(variable)+"_4mean_s"]=hv_tb_us_000_001_m[str("Core CPI SA")]+hv_tb_us_000_001_m[str(variable)+"_4mean"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0,0,hv_tb_us_000_001_m[str(variable)+"_4mean_s"])
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_4mean_s"].cumsum()


hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"]+hv_tb_us_000_001_m["Core CPI SAO"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"].pct_change(
    periods=12, fill_method='bfill').multiply(100)

hv_tb_us_000_001_m[str(variable)+"_5mean_s"]=hv_tb_us_000_001_m[str("Core CPI SA")]+hv_tb_us_000_001_m[str(variable)+"_5mean"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s"] =np.where(hv_tb_us_000_001_m.index <= max_index0,0,hv_tb_us_000_001_m[str(variable)+"_5mean_s"])
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_5mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]+hv_tb_us_000_001_m["Core CPI SAO"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"].pct_change(
    periods=12, fill_method='bfill').multiply(100)

hv_tb_us_000_001_m[str(variable)+"_6mean_s"]=hv_tb_us_000_001_m[str("Core CPI SA")]+hv_tb_us_000_001_m[str(variable)+"_6mean"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0,0,hv_tb_us_000_001_m[str(variable)+"_6mean_s"])
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]+hv_tb_us_000_001_m["Core CPI SAO"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"].pct_change(
    periods=12, fill_method='bfill').multiply(100)

#hv_tb_us_000_001_m["Cum_sum"]=np.where(hv_tb_us_000_001_m.index>=max_indexe, hv_tb_us_000_001_m["Cum_sum"], 0)
#hv_tb_us_000_001_m["PCE Core"]=hv_tb_us_000_001_m["PCE Core").cumsum()
# Out:
# Complete
# 2025-01-31 00:00:00

# %%
hv_tb_us_000_001_m=hv_tb_us_000_001_m[['Core CPI SA yy',
                                       'Core CPI SA diff_1mean_s_yy',
                                       'Core CPI SA diff_2mean_s_yy',
                                       'Core CPI SA diff_3mean_s_yy',
                                       'Core CPI SA diff_4mean_s_yy',
                                       'Core CPI SA diff_5mean_s_yy',
                                       'Core CPI SA diff_6mean_s_yy']]

hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(24)
hv_tb_us_000_001_m.insert(0, 'Index', hv_tb_us_000_001_m.index)
#hv_tb_us_000_001_m.to_clipboard()
#print(hv_tb_us_000_001_m)
df=hv_tb_us_000_001_m.copy()
fig=go.Figure(data=[go.Table(header=dict(values=list(df.columns)),
                             cells=dict(values=df.transpose().values.tolist()))])

fig.update_layout(autosize=False,  width=1600, height=750,)
fig.write_image('chile_core_table.png')




title_r=" CORE Simulation YY"
y_label="Index %"
x_label=title_r
list_c=['Core CPI SA yy',
         'Core CPI SA diff_1mean_s_yy',
         'Core CPI SA diff_2mean_s_yy',
         'Core CPI SA diff_3mean_s_yy',
         'Core CPI SA diff_4mean_s_yy',
         'Core CPI SA diff_5mean_s_yy',
         'Core CPI SA diff_6mean_s_yy']

df1=hv_tb_us_000_001_m[list_c]
#print(df1.head(5))
#df1=df1.tail (48)
#df1=df1.multiply(100).round(2)
g1=df1.copy()
g1["Core CPI SA yy"]= np.where(g1.index > max_index0, np. nan, g1 ["Core CPI SA yy"])

fig, ax = plt.subplots(figsize= (parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=str(list_c[0]), color="black", linewidth= 10, linestyle='-')
g1.plot(kind='line', ax=ax,y=str(list_c[1]), color="blue", linewidth= 11, linestyle='--',marker="D", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[2]), color="green", linewidth= 11, linestyle='-',marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=str(list_c[3]), color="orange", linewidth=11, linestyle='--', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=str(list_c[4]), color="red", linewidth=11, linestyle='-', marker='<', markersize=s2)
g1.plot(kind='line', ax=ax, y=str(list_c[5]), color="yellow", linewidth=11, linestyle='--', marker='x', markersize=s2)
g1.plot(kind='line', ax=ax, y=str(list_c[6]), color="brown", linewidth=11, linestyle='--', marker='<', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.axvline(max_index0, color='black', lw=1, linestyle='dashed', alpha=0.75)
for x, y in zip(g1.index, g1[str(list_c[0])]):
    label = "{:.2f}".format(y)
    # Label =f"({x}, {y})"
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 17),  # distance from text to points (x,y)
                 ha='center',
                 fontsize=11)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("chile_core_simulation_yy.png", bbox_inches='tight')
plt.savefig("chile_core_simulation_yy.jpg", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()
plt.cla()

del g1
del df1

# %% [markdown]
# ### 001 phillips curve   <a id="title_page"></a

# %%
#### Phillips curve with Core adn wage growth and
#pc ur infaltion/wage inflaiton
uki_m_tickers = ['h228pcxr', 'h228elur']
hv_tb_uk_0013_001_m=Haver.data(uki_m_tickers, "EMERGELA", dates=True)
hv_tb_uk_0013_001_m.index= hv_tb_uk_0013_001_m.index.floor('D')
#hv_tb_uk_002_005_m.rename(columns={"kai9":"AWE Nominal pay SA No Bonus"}, inplace=True)
uki_m_tickers0 = ['h228pcxr',]
for x in range(len(uki_m_tickers0)):
    variable=str(uki_m_tickers0 [x])
    hv_tb_uk_0013_001_m[variable]= hv_tb_uk_0013_001_m[variable].pct_change(periods=12, fill_method="bfill").multiply(100).round(3)
    print(hv_tb_uk_0013_001_m[variable])

hv_tb_uk_0013_001_m.rename(columns={"h228pcxr":"core"}, inplace=True)
#hv_tb_uk_0013_001_m.rename(columns=["":"wage_nominal_growth"), inplace=True)
hv_tb_uk_0013_001_m.rename(columns={"h228elur": "unemployment"}, inplace=True)
#hv_tb_uk_0013_001_m.rename(columns={"ukne Lur"; "unemployment"}, inplace=True)
#hv_tb_uk_0013_001_m.rename(columns={"ap2y": "vacancy"}, inplace=True)
hv_tb_uk_0013_001_m[ "year"]=hv_tb_uk_0013_001_m.index.year
hv_tb_uk_0013_001_m=hv_tb_uk_0013_001_m.tail(240)
#print(by th uk 0013 001 m.tail(5))

# Figure
# Data

x = hv_tb_uk_0013_001_m['core']
y = hv_tb_uk_0013_001_m['unemployment']
t = hv_tb_uk_0013_001_m['year']
y_label = "core"
x_label = "unemployment"
print(len(x))
print(len(y))
title_r = "Chile PHILLIPS CURVE CORE VS UNEMPLOYMENT"
df1 = hv_tb_uk_0013_001_m.copy()
df1.index = df1.index.date
# df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(10, 10))
plt.scatter(g1.unemployment, g1.core, c=g1.year, cmap="brg", zorder=2)
plt.plot(g1.unemployment, g1.core, zorder=1)

# add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1.unemployment.iloc[line], g1.core.iloc[line]),
        va='top',
        ha='right',
        size=8    )

x0 = x.iloc[range(len(x) - 1)].values
x1 = x.iloc[range(1, len(x))].values
y0 = y.iloc[range(len(y) - 1)].values
y1 = y.iloc[range(1, len(y))].values
xpos = (x0 + x1) / 2
ypos = (y0 + y1) / 2
xdir = x1 - x0
ydir = y1 - y0

# plot arrow on each line:
for X, Y, dX, dy in zip(xpos, ypos, xdir, ydir):
    ax.annotate("", xytext=(X,Y), xy=(X+0.001*dX, Y+0.001*dy),
    arrowprops=dict(arrowstyle="->", color='b'), size=11)

# g1.plot(kind='Line', ax=ax, x=g1.unemployment, y=g1.vacancy, color="darkblue", linewidth=2, linestyle='-')
# marker='D', markersize=2)

plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("chile_pcurve001.png", bbox_inches='tight')
plt.savefig("chile_pcurve001.jpg", bbox_inches='tight')
# plt.savefig("chile_pcurve001.png", bbox_inches='tight')
# plt.show()
# plt.close()
# plt.close('all')
# plt.clf()
# plt.cla()
print("Come[lte")
# Out:
# 2009-01-31      NaN
# 2009-02-28      NaN
# 2009-03-31      NaN
# 2009-04-30      NaN
# 2009-05-31      NaN
#               ...
# 2024-09-30    3.463
# 2024-10-31    3.883
# 2024-11-30    3.694
# 2024-12-31    4.070
# 2025-01-31    4.139
# Name: h228pcxr, Length: 193, dtype: float64
# 193
# 193
# Come[lte

# %% [markdown]
# ### 001 phillips curve   <a id="title_page"></a

# %%
uki_m_tickers = ['h228pcxr', 's228e6']
hv_tb_uk_0013_001_m = Haver.data(uki_m_tickers, "EMERGELA", dates=True)
hv_tb_uk_0013_001_m.index = hv_tb_uk_0013_001_m.index.floor('D')
# hv_tb_uk_002_005_m.rename(columns={"kai9":"AWE Nominal pay SA No Bonus"}, inplace=True)
uki_m_tickers = ['h228pcxr', 's228e6']

for x in range(len(uki_m_tickers)):
    #print(x)
    variable = str(uki_m_tickers[x])
    #print(variable)
    hv_tb_uk_0013_001_m[variable] = hv_tb_uk_0013_001_m[variable].pct_change(periods=12,
                                                                             fill_method="bfill").multiply(100).round(3)
    #print(hv_tb_uk_0013_001_m[variable])

hv_tb_uk_0013_001_m.rename(columns={"h228pcxr":"core"}, inplace=True)
hv_tb_uk_0013_001_m.rename(columns={"s228e6":"wage_nominal_growth"}, inplace=True)
hv_tb_uk_0013_001_m.rename(columns={"h228elur":"unemployment"}, inplace=True)
# hv_tb_uk_0013_001_m.rename(columns={"uknelur":"unemployment"}, inplace=True)
# hv_tb_uk_0013_001_m.rename(columns=("ap2y":"vacancy"), inplace=True)

hv_tb_uk_0013_001_m["year"]=hv_tb_uk_0013_001_m.index.year

hv_tb_uk_0013_001_m=hv_tb_uk_0013_001_m.tail(100)
print(hv_tb_uk_0013_001_m.tail(5))
# figure
# data
x = hv_tb_uk_0013_001_m['wage_nominal_growth']
y = hv_tb_uk_0013_001_m["core"]
t = hv_tb_uk_0013_001_m['year']
y_label = "core"
x_label = "wage_nominal_growth"
print(len(x))
print(len(y))

title_r = "Chile PHILLIPS CURVE CORE VS wage nominal growth"

df1 = hv_tb_uk_0013_001_m
df1.index = df1.index.date
# df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(10, 10))
plt.scatter(g1.wage_nominal_growth, g1.core, c=g1.year, cmap="brg", zorder=2)
plt.plot(g1.wage_nominal_growth, g1.core, zorder=1)

# add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 6):
    plt.annotate(
        g1.index[line],
        (g1.wage_nominal_growth.iloc[line], g1.core.iloc[line]),
        va='top',
        ha='right',
        size=8
    )

x0 = x.iloc[range(len(x) - 1)].values
x1 = x.iloc[range(1, len(x))].values
y0 = y.iloc[range(len(y) - 1)].values
y1 = y.iloc[range(1, len(y))].values
xpos = (x0 + x1) / 2
ypos = (y0 + y1) / 2
xdir = x1 - x0
ydir = y1 - y0

# plot arrow on each Line:
for X, Y, dX, dy in zip(xpos, ypos, xdir, ydir):
    ax.annotate("", xytext=(X, Y), xy=(X + 0.001 * dX, Y + 0.001 * dy),
                arrowprops=dict(arrowstyle="->", color='b'), size=11)

# g1.plot(kind='line', ax=ax, x=g1.unemployment, y=g1.vacancy, color="darkblue", linewidth=2, linestyle='-')
# marker="D", markersize=2)

plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("chile_pcurve002.jpg", bbox_inches="tight")
plt.savefig("chile_pcurve002.png", bbox_inches='tight')
plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()
print("complete")
# Out:
#              core  wage_nominal_growth  year
# 2024-09-30  3.463                7.957  2024
# 2024-10-31  3.883                7.794  2024
# 2024-11-30  3.694                7.902  2024
# 2024-12-31  4.070                7.712  2024
# 2025-01-31  4.139                  NaN  2025
# 100
# 100
# complete

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_chil_001_001_m
# Deleting DataFrame: data_r0
# Deleting DataFrame: data_r1
# Deleting DataFrame: data_r2
# Deleting DataFrame: data_r3
# Deleting DataFrame: data_r4
# Deleting DataFrame: data_r5
# Deleting DataFrame: data_r6
# Deleting DataFrame: data_r7
# Deleting DataFrame: data_r8
# Deleting DataFrame: data_r9
# Deleting DataFrame: data_r10
# Deleting DataFrame: data_r11
# Deleting DataFrame: data_r12
# Deleting DataFrame: data_r13
# Deleting DataFrame: data_r14
# Deleting DataFrame: data_r15
# Deleting DataFrame: data_r16
# Deleting DataFrame: data_r17
# Deleting DataFrame: data_r18
# Deleting DataFrame: data_r19
# Deleting DataFrame: data_r20
# Deleting DataFrame: data_r21
# Deleting DataFrame: data_r22
# Deleting DataFrame: data_r23
# Deleting DataFrame: data_r24
# Deleting DataFrame: data_r25
# Deleting DataFrame: data_r26
# Deleting DataFrame: data_r27
# Deleting DataFrame: data_r28
# Deleting DataFrame: data_r29
# Deleting DataFrame: data_r30
# ...

# %%
print("Compelte")

# %% [markdown]
# ### bottom
