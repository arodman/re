# %% [markdown]
# ### 000 top <a id="title_page"></a

# %% [markdown]
# ### 000 packages <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %%
country_code="EMERGECW"

# %% [markdown]
# ### 000 heatmaps table <a id="title_page"></a

# %%
country_code="EMERGECW"
#### heatmaps
#### heatmaps
#### heatmaps
#### heatmaps

import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
horizon_00=120
print("monthly")
#nostr47
czk_m_tickers1 = ['s935pcx','n935pcx','n935pc',
                  'n935pcfb','n935phpc',
                  'h935pchl','h935pcss',
                  'h935pcj1','h935pcpx','h935pcrh',
                                    'n935pcfb','n935vcfy','n935vcf3',
                                    'h935elcr','n935elcr','n935ej',
                                    's935eler','s935elur','s935elpr',
                                    's935vcb','s935vcc','s935vb',
                                    's935d','w935d','t935d','n935d']
hv_tb_czk_000_001_m=Haver.data(czk_m_tickers1,country_code, dates=True)
print(hv_tb_czk_000_001_m)
czk_m_tickers2 = ['h935elpi','h935ecu','s935ngcy','s935ngcp','n935ngp2','n935ngap']
hv_tb_czk_000_002_m = Haver.data(czk_m_tickers2,country_code, dates=True)
print(hv_tb_czk_000_002_m)
hv_tb_czk_000_001_m = pd.concat([hv_tb_czk_000_001_m, hv_tb_czk_000_002_m], 
                                axis=1, join="outer")
hv_tb_czk_000_001_m = hv_tb_czk_000_001_m.fillna(method='bfill')
czk_m_tickers = czk_m_tickers1 + czk_m_tickers2
# Out:
# monthly
#             s935pcx  n935pcx  n935pc  n935pcfb  n935phpc  h935pchl  h935pcss  \
# 1991-01-31      NaN      NaN    28.4      43.2       NaN       NaN       NaN
# 1991-02-28      NaN      NaN    30.3      43.7       NaN       NaN       NaN
# 1991-03-31      NaN      NaN    31.4      42.6       NaN       NaN       NaN
# 1991-04-30      NaN      NaN    32.3      42.0       NaN       NaN       NaN
# 1991-05-31      NaN      NaN    32.9      41.4       NaN       NaN       NaN
# ...             ...      ...     ...       ...       ...       ...       ...
# 2024-09-30  135.499  138.251   151.8     146.7     152.2     100.1     105.2
# 2024-10-31  135.715  138.678   152.3     147.1     152.6     100.5     104.3
# 2024-11-30  135.916  138.747   152.4     147.7     152.7     100.7     103.7
# 2024-12-31  136.100  138.448   152.0     146.7     152.3     101.1     102.7
# 2025-01-31  136.520  140.026   154.0     151.3       NaN     101.6     105.2
#
#             h935pcj1  h935pcpx  h935pcrh  ...  s935eler  s935elur  s935elpr  \
# 1991-01-31       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1991-02-28       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1991-03-31       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1991-04-30       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1991-05-31       NaN       NaN       NaN  ...       NaN       NaN       NaN
# ...              ...       ...       ...  ...       ...       ...       ...
# 2024-09-30     107.7      97.5     112.5  ...      74.9       2.8      77.1
# 2024-10-31     108.3      94.8     113.7  ...      75.1       2.6      77.2
# 2024-11-30     108.4      96.4     115.0  ...      75.5       2.9      77.7
# 2024-12-31     108.2     100.2     114.2  ...      75.8       2.7      77.9
# 2025-01-31     106.0     102.3     110.1  ...       NaN       NaN       NaN
#
#             s935vcb  s935vcc  s935vb  s935d  w935d  t935d  n935d
# 1991-01-31      NaN      NaN     NaN    NaN    NaN    NaN    NaN
# 1991-02-28      NaN      NaN     NaN    NaN    NaN    NaN    NaN
# 1991-03-31      NaN      NaN     NaN    NaN    NaN    NaN    NaN
# 1991-04-30      NaN      NaN     NaN    NaN    NaN    NaN    NaN
# 1991-05-31      NaN      NaN     NaN    NaN    NaN    NaN    NaN
# ...             ...      ...     ...    ...    ...    ...    ...
# 2024-09-30      4.2    -12.3     8.3   99.7  103.3   99.0  104.1
# 2024-10-31      4.0     -9.8     7.4   99.3  105.2   99.0  107.0
# 2024-11-30      5.3     -9.0     8.9   97.5  105.7   99.0  106.6
# 2024-12-31      4.8    -10.0     8.5   99.0   92.4   98.9   89.8
# 2025-01-31      4.5    -13.0     8.9    NaN    NaN    NaN    NaN
#
# [409 rows x 25 columns]
#             h935elpi  h935ecu  s935ngcy  s935ngcp  n935ngp2  n935ngap
# 1995-09-30       NaN      NaN       NaN       NaN      2.31       NaN
# 1995-12-31       NaN      NaN       NaN       NaN      3.10       NaN
# 1996-03-31     68.68    60.77       NaN       NaN      3.59      1.50
# 1996-06-30     69.30    63.11       NaN       NaN      3.76      1.76
# 1996-09-30     69.68    64.43       NaN       NaN      3.74      1.88
# ...              ...      ...       ...       ...       ...       ...
# 2025-12-31       NaN      NaN       NaN       NaN     -0.42     -0.23
# 2026-03-31       NaN      NaN       NaN       NaN     -0.37     -0.33
# 2026-06-30       NaN      NaN       NaN       NaN     -0.36     -0.29
# 2026-09-30       NaN      NaN       NaN       NaN     -0.33     -0.22
# 2026-12-31       NaN      NaN       NaN       NaN     -0.31     -0.18
#
# [126 rows x 6 columns]

# %%
###### mopnthly prices
hv_tb_czk_000_001_m.rename(columns={'s935pcx':'prices_cpi_ex_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935pcx':'prices_cpi_ex_nsa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935pc':'prices_cpi_headline_nsa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935pcfb':'prices_cpi_food_nsa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935phpc':'prices_hcpi_nsa'}, inplace=True)
#hv_tb_czk_000_001_m.rename(columns={'n935shjt':'prices_house_price_index_nsa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'h935pchl':'prices_cpi_imputed_rentals_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'h935pcss':'prices_cpi_seasonal_goods_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'h935pcj1':'prices_cpi_goods_adm_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'h935pcpx':'prices_cpi_dom_heating_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'h935pcrh':'prices_cpi_package_holidays_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935pcfb':'prices_cpi_food_nonalcohol_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935vcfy':'prices_inf_expectations_1y'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935vcf3':'prices_inf_expectations_3y'}, inplace=True)


#### monthly employment
hv_tb_czk_000_001_m.rename(columns={'h935elcr':'employment_reg_unemployment_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935elcr':'employment_reg_unemployment_nsa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935ej':'employment_vacancies'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'s935eler':'employment_emp_rate_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'s935elur':'employment_ur_rate_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'s935elpr':'employment_lf_participation_sa'}, inplace=True)

###### monthly cycle
hv_tb_czk_000_001_m.rename(columns={'s935vcb':'cycle_composite_confidence_indicator'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'s935vcc':'cycle_consumer_confidence_indicator'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'s935vb':'cycle_business_confidence_indicator'}, inplace=True)

#### monthly industrila production 
hv_tb_czk_000_001_m.rename(columns={'s935d':'real_industrial_production_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'w935d':'real_industrial_production_wda'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'t935d':'real_industrial_production_trend'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935d':'real_industrial_production_nsa'}, inplace=True)




#### quarterly  productivity
hv_tb_czk_000_001_m.rename(columns={'h935elpi':'real_output_pep_sa'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'h935ecu':'real_ulc_sa'}, inplace=True)

#### quarterly gdp
hv_tb_czk_000_001_m.rename(columns={'s935ngcy':'real_gdp_flash_yy'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'s935ngcp':'real_gdp_flash_qq'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935ngp2':'real_output_gap_small_strucutral'}, inplace=True)
hv_tb_czk_000_001_m.rename(columns={'n935ngap':'real_output_gap_production'}, inplace=True)

# %%
list_c=  [
'prices_cpi_ex_sa',
'prices_cpi_ex_nsa',
'prices_cpi_headline_nsa',
'prices_cpi_food_nsa',
'prices_hcpi_nsa',
'prices_cpi_imputed_rentals_sa',
'prices_cpi_seasonal_goods_sa',
'prices_cpi_goods_adm_sa',
'prices_cpi_dom_heating_sa',
'prices_cpi_package_holidays_sa',
#'prices_cpi_food_nonalcohol_sa',
'prices_inf_expectations_1y',
'prices_inf_expectations_3y',

'employment_reg_unemployment_sa',
'employment_reg_unemployment_nsa',
'employment_vacancies',
'employment_emp_rate_sa',
'employment_ur_rate_sa',
'employment_lf_participation_sa',
'cycle_composite_confidence_indicator',
'cycle_consumer_confidence_indicator',
'cycle_business_confidence_indicator',
'real_industrial_production_sa',
'real_industrial_production_wda',
'real_industrial_production_trend',
'real_industrial_production_nsa',
'real_output_pep_sa',
'real_ulc_sa',
'real_gdp_flash_yy',
'real_gdp_flash_qq',
#'real_output_gap_small_strucutral',
#'real_output_gap_production'

    
]

#hv_tb_hu_000_001_m=hv_tb_hu_000_001_m.copy()
#hv_tb_hu_000_001_m=hv_tb_hu_000_001_m.tail(120)
hv_tb_czk_000_001_m = hv_tb_czk_000_001_m[list_c]
hv_tb_czk_000_001_m=hv_tb_czk_000_001_m.tail(60)

print(len(hv_tb_czk_000_001_m.columns.tolist()))
# Out:
# 29

# %%
#Financial: International International eop nsa
#Financial: Non improte weighted index avg
#Cycle: Norway Consumer Confidence next year Quarterly SA
n_time=45
#size figure
#wide
size1=32
#height
size2=size1/1.1
#heatmaps inside
font_size_h=10
number_vbs=29
#x size Label, axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
#axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_czk_000_001_m.copy()
df_row=df1.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names=['Variable']


num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])

    #print("end Loop")

for x in range(num_rows):
    #print(x)

    locals()[str(str("vmin_")+str(x))] = df_row.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = df_row.iloc[:,x].max()

    #print("end Loop")

print(vmin_0)
print(vmax_0)

#data = np.random.random((10,12))
#df1 = pd.DataFrame(data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)


sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})

sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
##sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r38, cmap=red_to_blue, annot=True, ax=axes[38], cbar=False, vmin=vmin_38, vmax=vmax_38, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r39, cmap=red_to_blue, annot=True, ax=axes[39], cbar=False, vmin=vmin_39, vmax=vmax_39, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})


n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=2)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), 
                                                          fontsize=x2_sizel,
                                                          rotation=0,
                                                          va="center")
    n = n + 1
    
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
fig.suptitle("czk Economic Dashboard", fontsize=title_s)
plt.figtext(0.5, 0.01, "czk Economic Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('czk_heatmap_001.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()
# Out:
# 110.205
# 136.52

# %% [markdown]
# ### 000 heatmaps birdeye <a id="title_page"></a

# %%
hv_tb_czk_001_001_m_g=hv_tb_czk_000_001_m.copy()
list_c=hv_tb_czk_001_001_m_g.columns.tolist()
print("start right here")
parameter1_o=6
parameter2_o=4
tail_n=102
tail_n2=48
linew=2
mks=0.5
print(" ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave ")
n=1
for y in list_c:
    print(y)
    #print("filtering time horizon")
    df1=hv_tb_czk_001_001_m_g.copy()
    df1=pd.DataFrame(df1[str(y)])
    #List_c=df1.columns.tolist()


    df1=df1.tail(90)
    g1=df1.copy()
    fig, ax = plt.subplots(figsize=((parameter1_o-1), (parameter2_o)))
    g1.plot(kind='line', ax=ax, y=str(y), 
         color="orange",
         linestyle='-', 
         linewidth= (linew+1),
         marker='o',
         markersize=mks)
    x_last = g1.index[-1]
    y_last = g1[str(y)].iloc[-1]
    #gl.index[-1] # Assuming the DataFrame index is date or sequential
    
    #Annotate the last value on the right of the plot Line
    #ax.annotate(f'{y_last:.2f}',
    #xy=(x_last, y_last),
    #xytext=(10, 0),
    #textcoords="offset points",
    #ha='left',
    #va="center",
    #color="orange",
    #size=17,
    #weight="bold")
    
    plt.style.use('default')
    #plt.ylabel(str(y_label), size-parameter3)
    #plt.xlabel(str(x_label), size-parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2=ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("hv_tb_czk_ov"+str(n)+".png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    #del List_c
    del fig
    del ax
    del ax2
    n=n+1
# Out:
# start right here
#  ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave
# prices_cpi_ex_sa
# prices_cpi_ex_nsa
# prices_cpi_headline_nsa
# prices_cpi_food_nsa
# prices_hcpi_nsa
# prices_cpi_imputed_rentals_sa
# prices_cpi_seasonal_goods_sa
# prices_cpi_goods_adm_sa
# prices_cpi_dom_heating_sa
# prices_cpi_package_holidays_sa
# prices_inf_expectations_1y
# prices_inf_expectations_3y
# employment_reg_unemployment_sa
# employment_reg_unemployment_nsa
# employment_vacancies
# employment_emp_rate_sa
# employment_ur_rate_sa
# employment_lf_participation_sa
# cycle_composite_confidence_indicator
# cycle_consumer_confidence_indicator
# cycle_business_confidence_indicator
# real_industrial_production_sa
# real_industrial_production_wda
# real_industrial_production_trend
# real_industrial_production_nsa
# real_output_pep_sa
# real_ulc_sa
# real_gdp_flash_yy
# real_gdp_flash_qq

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_czk_000_001_m
# Deleting DataFrame: hv_tb_czk_000_002_m
# Deleting DataFrame: df_row
# Deleting DataFrame: data_r0
# Deleting DataFrame: data_r1
# Deleting DataFrame: data_r2
# Deleting DataFrame: data_r3
# Deleting DataFrame: data_r4
# Deleting DataFrame: data_r5
# Deleting DataFrame: data_r6
# Deleting DataFrame: data_r7
# Deleting DataFrame: data_r8
# Deleting DataFrame: data_r9
# Deleting DataFrame: data_r10
# Deleting DataFrame: data_r11
# Deleting DataFrame: data_r12
# Deleting DataFrame: data_r13
# Deleting DataFrame: data_r14
# Deleting DataFrame: data_r15
# Deleting DataFrame: data_r16
# Deleting DataFrame: data_r17
# Deleting DataFrame: data_r18
# Deleting DataFrame: data_r19
# Deleting DataFrame: data_r20
# Deleting DataFrame: data_r21
# Deleting DataFrame: data_r22
# Deleting DataFrame: data_r23
# Deleting DataFrame: data_r24
# Deleting DataFrame: data_r25
# Deleting DataFrame: data_r26
# Deleting DataFrame: data_r27
# Deleting DataFrame: data_r28
# Deleting DataFrame: hv_tb_czk_001_001_m_g
# Environment cleaned!

# %% [markdown]
# ### bottom
