# %% [markdown]
# ### 000 top  <a id="title_page"></a

# %% [markdown]
# ### 000 packages  <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image


parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %%
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ### 001 heatmpa table <a id="title_page"></a

# %%
country_database = "EMERGE"
horizon_00=120

# ['emerge:1924Libd', 'emerge:n924du', 'emerge:n924elur', 'emerge:h924vlup']

# ['h924bd', 'h924d', 'h924du', 'h924trs']
print("monthly")

aui_m_tickers1 = ['h924trs', 'h924ibd', 
                  'n924elur', 'n924viup', 
                  'h924vcc',   'h924pfmi', 'h924pfxi', 
                  'h924ppc', 'h924pp', 'h924pcxg', 'h924pc',  
                  'n924rtar', 'n924xusv','n924fmr', 
                  'n924fp', 'n924fph', 'n924fltd', 'n924fc']

hv_tb_au_000_001_m = Haver.data(aui_m_tickers1, "EMERGE", dates=True)  # 'h924bd'
#print(hv_to_au_000_001_m)
aui_m_tickers2 = ["h924zddp", "h924zdnp", "h924zdhp","h924d", 
                  "n924du","n924frmg", "s924ngcp","n924ngcy", "n924nydk"]

hv_tb_au_000_002_m=Haver.data(aui_m_tickers2, "EMERGE", dates=True)
#print(hv_tb_au_000_002_m)
hv_tb_ch_001_001_m=pd.concat([hv_tb_au_000_001_m, hv_tb_au_000_002_m], axis=1, join="outer")
#hv_tb_ch_001_001_m.to_clipboard()
hv_tb_ch_001_001_m = hv_tb_ch_001_001_m.fillna (method='bfill')
ch_m_tickers=aui_m_tickers1+aui_m_tickers2
#hv_tb_ch_001_001_m.rename(columns={"s924ngcp": "Real: GDP QQ SA"}, inplace=True)
#hv_tb_ch_001_001_m.rename(columns={"n924ngcy": "Real: GDP YY SA"}, inplace=True)
#hv_tb_ch_001_001_m['n924nydk']= hv_tb_ch_001_001_m['n924nydk'].pct_change(periods=12,fill_method='bfill').multiply(100).round(1)
#hv_tb_ch_001_001_m.rename(columns={"n924nydk": "Real: Disposable Income residents YY SA"}, inplace=True)
#hv_tb_ch_001_001_m[ 'h924d']= hv_tb_ch_001_001_m['h924d'].pct_change(periods=12,fill_method='bfill').multiply(100).round(1)
#hv_tb_ch_001_001_m.rename(columns={"h924d": "Real: IP Value added sa"}, inplace=True)   
#hv_tb_ch_001_001_m.rename(columns={"n924du": "Real: Industrial Capacity Utilization"}, inplace=True)
#hv_tb_ch_001_001_m['h924trs']=hv_tb_ch_001_001_m['h924trs'].pct_change(periods=12,fill_method='bfill').multiply(100).round(1)
#hv_tb_ch_001_001_m.rename(columns={"h924trs": "Real: Retail Sales Monthly SA"}, inplace=True)
#hv_tb_ch_001_001_m['h924trs'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
#hv_tb_ch_001_001_m['h924ibd' ]= hv_tb_ch_001_001_m['h924ibd'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
#hv_tb_ch_001_001_m.rename(columns={"h924ibd": "Real: Balance Trade Goods Monthly SA"}, inplace=True)
#hv_tb_ch_001_001_m.rename(columns={"n924rtar": "Financial: China Official Interest rate"}, inplace=True)
#hv_tb_ch_001_001_m['n924xusv']= hv_tb_ch_001_001_m['n924xusv'].round(0)
#h##v_tb_ch_001_001_m.rename(columns={"n924xusv": "Financial: RMB Excahnge Rate"}, inplace=True)
#h#v_tb_ch_001_001_m['n924fmr']= hv_tb_ch_001_001_m['n924fmr'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
#hv_tb_ch_001_001_m.rename(columns={"n924fmr": "Financial: Monetary base monthly sa"}, inplace=True)     
#hv_tb_ch_001_001_m['n924fp']= hv_tb_ch_001_001_m['n924fp'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)   



# Rename columns
hv_tb_ch_001_001_m.rename(columns={"s924ngcp": "Real: GDP QQ SA"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"n924ngcy": "Real: GDP YY SA"}, inplace=True)
# Calculate year-over-year percentage change for Real: Disposable Income residents YY SA
hv_tb_ch_001_001_m['n924nydk'] = hv_tb_ch_001_001_m['n924nydk'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"n924nydk": "Real: Disposable Income residents YY SA"}, inplace=True)
# Calculate year-over-year percentage change for Real: IP Value added sa
hv_tb_ch_001_001_m['h924d'] = hv_tb_ch_001_001_m['h924d'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924d": "Real: IP Value added sa"}, inplace=True)
# Rename columns
hv_tb_ch_001_001_m.rename(columns={"n924du": "Real: Industrial Capacity Utilization"}, inplace=True)
# Calculate year-over-year percentage change for Real: Retail Sales Monthly SA
hv_tb_ch_001_001_m['h924trs'] = hv_tb_ch_001_001_m['h924trs'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924trs": "Real: Retail Sales Monthly SA"}, inplace=True)
# Calculate year-over-year percentage change for Real: Balance Trade Goods Monthly SA
hv_tb_ch_001_001_m['h924ibd'] = hv_tb_ch_001_001_m['h924ibd'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924ibd": "Real: Balance Trade Goods Monthly SA"}, inplace=True)
# Rename columns
hv_tb_ch_001_001_m.rename(columns={"n924rtar": "Financial: China Official Interest rate"}, inplace=True)
hv_tb_ch_001_001_m['n924xusv'] = hv_tb_ch_001_001_m['n924xusv'].round(0)
hv_tb_ch_001_001_m.rename(columns={"n924xusv": "Financial: RMB Excahnge Rate"}, inplace=True)

# Calculate year-over-year percentage change for Financial: Monetary base monthly sa
hv_tb_ch_001_001_m['n924fmr'] = hv_tb_ch_001_001_m['n924fmr'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"n924fmr": "Financial: Monetary base monthly sa"}, inplace=True)
# Calculate year-over-year percentage change for Financial: Deposits MFIs monthly nsa
hv_tb_ch_001_001_m['n924fp'] = hv_tb_ch_001_001_m['n924fp'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"n924fp": "Financial: Deposits MFIs monthly nsa"}, inplace=True)
# Calculate year-over-year percentage change for Financial: HH savings deposits monthly nsa
hv_tb_ch_001_001_m['n924fph'] = hv_tb_ch_001_001_m['n924fph'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"n924fph": "Financial: HH savings deposits monthly nsa"}, inplace=True)
# Round Financial: Loan to Deposit Ratio monthly nsa
hv_tb_ch_001_001_m['n924fltd'] = hv_tb_ch_001_001_m['n924fltd'].round(0)
hv_tb_ch_001_001_m.rename(columns={"n924fltd": "Financial: Loan to Deposit Ratio monthly nsa"}, inplace=True)

# Calculate year-over-year percentage change for Financial: Credit Monthly nsa
hv_tb_ch_001_001_m['n924fc'] = hv_tb_ch_001_001_m['n924fc'].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"n924fc": "Financial: Credit Monthly nsa"}, inplace=True)

# Round Financial: Domestic Economy Debt GDP quarterly sa, Nonfinancial corporate Debt GDP quarterly sa, Household Debt GDP quarterly sa, and External Debt GDP quarterly sa
hv_tb_ch_001_001_m['h924zddp'] = hv_tb_ch_001_001_m['h924zddp'].round(0)
hv_tb_ch_001_001_m['h924zdnp'] = hv_tb_ch_001_001_m['h924zdnp'].round(0)
hv_tb_ch_001_001_m['h924zdhp'] = hv_tb_ch_001_001_m['h924zdhp'].round(0)
hv_tb_ch_001_001_m['n924frmg'] = hv_tb_ch_001_001_m['n924frmg'].round(0)
# Rename columns
hv_tb_ch_001_001_m.rename(columns={"h924zddp": "Financial: Domestic Economy Debt GDP quarterly sa"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"h924zdnp": "Financial: Nonfinancial corporate Debt GDP quarterly sa"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"h924zdhp": "Financial: Household Debt GDP quarterly sa"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"n924frmg": "Financial: External Debt GDP quarterly sa"}, inplace=True)



# Rename columns
hv_tb_ch_001_001_m.rename(columns={"h924zddp": "Financial: Domestic Economy Debt GDP quarterly sa"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"h924zdnp": "Financial: Nonfinancial corporate Debt GDP quarterly sa"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"h924zdhp": "Financial: Household Debt GDP quarterly sa"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"n924frmg": "Financial: External Debt GDP quarterly sa"}, inplace=True)

# Calculate year-over-year percentage change for CPI
hv_tb_ch_001_001_m['h924pc'] = hv_tb_ch_001_001_m['h924pc'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924pc": "Prices: China CPI SA"}, inplace=True)

# Calculate year-over-year percentage change for Core CPI
hv_tb_ch_001_001_m['h924pcxg'] = hv_tb_ch_001_001_m['h924pcxg'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924pcxg": "Prices: China Core CPI SA"}, inplace=True)

# Calculate year-over-year percentage change for PPI
hv_tb_ch_001_001_m['h924pp'] = hv_tb_ch_001_001_m['h924pp'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924pp": "Prices: China PPI SA"}, inplace=True)

# Calculate year-over-year percentage change for PPI Consumer goods
hv_tb_ch_001_001_m['h924ppc'] = hv_tb_ch_001_001_m['h924ppc'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924ppc": "Prices: China PPI Consumer goods SA"}, inplace=True)

# Calculate year-over-year percentage change for Export price
hv_tb_ch_001_001_m['h924pfxi'] = hv_tb_ch_001_001_m['h924pfxi'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924pfxi": "Prices: China Export price SA"}, inplace=True)

# Calculate year-over-year percentage change for Import price
hv_tb_ch_001_001_m['h924pfmi'] = hv_tb_ch_001_001_m['h924pfmi'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_ch_001_001_m.rename(columns={"h924pfmi": "Prices: China Import price SA"}, inplace=True)

# Rename other columns
hv_tb_ch_001_001_m.rename(columns={"h924vcc": "Cycle: consumer confidence"}, inplace=True)
hv_tb_ch_001_001_m['n924viup'] = hv_tb_ch_001_001_m['n924viup'].round(8)
hv_tb_ch_001_001_m.rename(columns={"n924viup": "Cycle: News based policy uncertainty"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"n924elur": "Employment: Urban unemployment rate"}, inplace=True)

# Filter to the last 60 rows and copy to clipboard
hv_tb_ch_001_001_m = hv_tb_ch_001_001_m.tail(60)
#hv_tb_ch_001_001_m.to_clipboard()
# Out:
# monthly

# %%
hv_tb_ch_001_001_m=hv_tb_ch_001_001_m.tail(60)
hv_tb_ch_001_001_m.to_clipboard()

hv_tb_ch_001_001_m.index=hv_tb_ch_001_001_m.index.date

list_c=["Real: GDP QQ SA",
      "Real: GDP YY SA",
      "Real: Disposable Income residents YY SA",
      "Real: IP Value added sa",
      "Real: Industrial Capacity Utilization",
      "Real: Retail Sales Monthly SA",
      "Real: Balance Trade Goods Monthly SA",
      "Prices: China CPI SA",
      "Prices: China Core CPI SA",
      "Prices: China PPI SA",
      "Prices: China PPI Consumer goods SA",
      "Prices: China Export price SA",
      "Prices: China Import price SA",
      "Employment: Urban unemployment rate",
      "Financial: China Official Interest rate",
      "Financial: RMB Excahnge Rate",
      "Financial: Monetary base monthly sa",
      "Financial: Deposits MFIs monthly nsa",
      "Financial: HH savings deposits monthly nsa",
      "Financial: Loan to Deposit Ratio monthly nsa",
      "Financial: Credit Monthly nsa",
      "Financial: Domestic Economy Debt GDP quarterly sa",
      "Financial: Nonfinancial corporate Debt GDP quarterly sa",
      "Financial: Household Debt GDP quarterly sa",
      "Financial: External Debt GDP quarterly sa",
      "Cycle: consumer confidence",
      "Cycle: News based policy uncertainty",]

hv_tb_ch_001_001_m=hv_tb_ch_001_001_m[list_c]
hv_tb_ch_001_001_m_c=hv_tb_ch_001_001_m.copy()

hv_tb_ch_001_001_m_c=hv_tb_ch_001_001_m_c.tail(120)
hv_tb_ch_001_001_m=hv_tb_ch_001_001_m.tail(60)

# %%
n_time=45
#size figure
#wide
size1=32
#height
size2=size1/1.1
##heatmaps inside
font_size_h=10
number_vbs=27
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_ch_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names =['Variable']
num_rows = df1.shape[0]
for x in range(num_rows):
    locals()[str(str("data_r")+str(x))]= pd.DataFrame([df1.iloc[x]])

for x in range(num_rows):
    locals()[str(str("vmin_")+str(x))] = hv_tb_ch_001_001_m_c.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = hv_tb_ch_001_001_m_c.iloc[:,x].max()
print(vmin_0)
print(vmax_0)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})


sns.heatmap(data_r6,cmap=red_to_blue, annot=True, ax=axes [6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7,cmap=red_to_blue, annot=True, ax=axes [7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8,cmap=red_to_blue, annot=True, ax=axes [8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9,cmap=red_to_blue, annot=True, ax=axes [9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10,cmap=red_to_blue, annot=True, ax=axes [10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11,cmap=red_to_blue, annot=True, ax=axes [11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12,cmap=red_to_blue, annot=True, ax=axes [12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13,cmap=red_to_blue, annot=True, ax=axes [13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14,cmap=red_to_blue, annot=True, ax=axes [14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15,cmap=red_to_blue, annot=True, ax=axes [15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16,cmap=red_to_blue, annot=True, ax=axes [16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=reversed_red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=reversed_red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=reversed_red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=reversed_red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=reversed_red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=reversed_red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n = 0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=-90)
    n = (n + 1)
#axes[0].set_xticks([])
#axes[1].set_xticks([])
#axes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels(axis="x", which="both", length=0, labelrotation=45)
#.set_xticks([])
fig.suptitle("China Economic Dashboard ", fontsize=title_s)
plt.figtext(0.5, 0.01, "China Economic Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-0.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('china_heatmap_001.png', bbox_inches='tight', dpi=300)
plt.savefig('china_heatmap_001.jpg', bbox_inches='tight', dpi=300)
plt.show()
plt.close()
# Out:
# -10.5
# 12.8

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_au_000_001_m
# Deleting DataFrame: hv_tb_au_000_002_m
# Deleting DataFrame: hv_tb_ch_001_001_m
# Deleting DataFrame: hv_tb_ch_001_001_m_c
# Deleting DataFrame: df1
# Deleting DataFrame: data_r0
# Deleting DataFrame: data_r1
# Deleting DataFrame: data_r2
# Deleting DataFrame: data_r3
# Deleting DataFrame: data_r4
# Deleting DataFrame: data_r5
# Deleting DataFrame: data_r6
# Deleting DataFrame: data_r7
# Deleting DataFrame: data_r8
# Deleting DataFrame: data_r9
# Deleting DataFrame: data_r10
# Deleting DataFrame: data_r11
# Deleting DataFrame: data_r12
# Deleting DataFrame: data_r13
# Deleting DataFrame: data_r14
# Deleting DataFrame: data_r15
# Deleting DataFrame: data_r16
# Deleting DataFrame: data_r17
# Deleting DataFrame: data_r18
# Deleting DataFrame: data_r19
# Deleting DataFrame: data_r20
# Deleting DataFrame: data_r21
# Deleting DataFrame: data_r22
# Deleting DataFrame: data_r23
# Deleting DataFrame: data_r24
# Deleting DataFrame: data_r25
# ...

# %% [markdown]
# ### bottom
