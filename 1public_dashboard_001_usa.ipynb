# %%
### 001_top <a id="title_page"></a>
- [Top](#table_contents)

### packages

owner=""
import time
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6
parameter_w_seas=14
parameter_h_seas=13
million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

source_text="Haver"
source_text_f=30
source_text_c="gray"
source_text_a=0.5
source_text_r=30

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)




country_database = "USECON"

### 001_macrommoentum  <a id="title_page"></a>


###macrommoentum 
###macrommoentum 
###macrommoentum 
###macrommoentum 
###macrommoentum 
###macrommoentum 
###macrommoentum 

# Set the country database and data horizon
country_database = "USECON"
#'codesnotfound': ['usecon:cinfl', 'usecon:pmcxbaa'],

# Define tickers for the first dataset
#usai_m_tickers1 = ['ip', 'nrsxm', 'lp', 'laxepa', 'lanagrd', 'laprivd', 'pcuy', 'ypcuslife', 'cinfl', 'cinf5',
#                   'csent', 'ccin', 'pmcxbaa', 'napmc', 'nmfc', 'clevpcey', 'pce12']
#                   "pmcxbaa",
usai_m_tickers1 = ["ip", "nrsxm", "lp", "laxepa", "lanagrd", "laprivd", "pcuy",
                   "ypcuslfe", "cinf1", "cinf5","csent", "ccin","napmc", "nmfc", "clevpcey", "pce12"]

# Load data for the first dataset
hv_tb_usa_000_001_m = Haver.data(usai_m_tickers1, "USECON", dates=True)
#print(hv_tb_usa_000_001_m)
# Define tickers for the second dataset
usai_m_tickers2 = ['wgto', 'jcbm', 'jcxfebm']
hv_tb_usa_000_002_m = Haver.data(usai_m_tickers2, "USECON", dates=True)
# Print the second dataset
#print(hv_tb_usa_000_002_m)
# Combine the two datasets
hv_tb_usa_000_001_m = pd.concat([hv_tb_usa_000_001_m, 
                                 hv_tb_usa_000_002_m], axis=1, join="outer")
# Create a list of all tickers
usa_m_tickers = usai_m_tickers1 + usai_m_tickers2
#print(hv_tb_usa_000_001_m)
# Rename columns for clarity
hv_tb_usa_000_001_m.rename(columns={"ip": "Real: Industrial Production"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"nrsxm": "Real: Retail Sales excl Autos"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"wgto": "Employment: Wage Growth"}, inplace=True)
hv_tb_usa_000_001_m["lp"] = (hv_tb_usa_000_001_m["lp"] / 100)
hv_tb_usa_000_001_m.rename(columns={"lp": "Employment: Participation Rate"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"laxepa": "Employment: ADP Private Payroll"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"lanagrd": "Employment: NFP"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"laprivd": "Employment: NFP Private"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"pcuy": "Price: CPI Headline"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"ypcuslfe": "Price: CPI Core"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"jcbm": "Price: PCE Index"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"jcxfebm": "Price: PCE Core"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"clevpcey": "Price: FRB Clev PCE Median"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"pce12": "Price: FRB Dallas PCE Trimmed Mean"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"cinf1": "Price: Michigan Inflation next 1Y"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"cinf5": "Price: Michigan Inflation next 5Y"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"csent": "Cycle: Michigan Consumer Sentiment"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"ccin": "Cycle: CBoard Consumer Confidence"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"pmcxbaa": "Cycle: Chicago Business Index"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"napmc": "Cycle: ISM Manufacturing"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"nmfc": "Cycle: ISM Services"}, inplace=True)

# Sort the dataset by index in descending order
hv_tb_usa_000_001_m.sort_index(ascending=False, axis=1, inplace=True)
# Fill missing values with backfill method
#hv_tb_usa_000_001_m.fillna(method="bfill", inplace=True)
# Drop the last row of the dataset (optional)
# hv_tb_usa_000_001_m.drop(hv_tb_usa_000_001_m.tail(1).index, inplace=True)
## Print the final dataset
#print(hv_tb_usa_000_001_m)
## Real: Industrial Production
#hv_tb_usa_009_001_m.rename(columns={"ip": "Industrial Production SA"}, inplace=True)
# Real: Retail Sales
#hv_tb_usa_008_001_m.rename(columns={"nrsxm": "Retail Sales excl. Autos N/V SA"}, inplace=True)
# Employment: Wage growth
#hv_tb_usa_002_001_m.rename(columns={"wgto": "Huge Growth Overall: 3-Mo Mov Avg NSA %"}, inplace=True)
# Employment: Participation Rate
#hv_th_usa_002_001_m["lp"] = (hv_tb_usa_002_001_m["lp"] / 100)
#hv_tb_usa_002_001_m.rename(columns={"lp": "Civilian Participation Rate: 16 yr SA %"}, inplace=True)
# Employment: ADP Private Payroll
#hv_th_usa_002_003_m.rename(columns={"laxepa": "ADP Private Payroll SA"}, inplace=True)
# Employment: NFP Change SA
#hv_tb_usa_002_001_m.rename(columns={"lanagrd": "Change NFP SA"}, inplace=True)
# Inflation: Headline CPI
#hv_tb_usa_003_001_m.rename(columns={"pcuy": "CPI-U: ALL Items SA Y/Y"}, inplace=True)
#h_tb_usa_003_001_m.rename(columns={"ypcuslife": "CPI-U: Core SA Y/Y"}, inplace=True)
# Inflation: Core Inflation
#hv_tb_usa_004_001_m.rename(columns={"jcbm": "PCE Index SA Y/Y"}, inplace=True)
#hv_tb_usa_004_001_m.rename(columns={"jcxfebm": "PCE Core SA Y/Y"}, inplace=True)
# Inflation: Michigan Inflation Expectations
#hv_tb_usa_005_007_m.rename(columns={"cinf1": "Michigan Exp Inflation next 1Y"}, inplace=True)
# Cycle: Michigan Consumers
#hv_tb_usa_005_001_m.rename(columns={"csent": "Michigan: Consumer Sentiment NSA"}, inplace=True)
# Cycle: Consumer Board
#hv_th_usa_005_001_m.rename(columns={"ccin": "CBoard: Consumer Confidence SA"}, inplace=True)
# Cycle: Chicago Business Barometer
#hv_tb_usa_005_003_m.rename(columns={"pmcxbaa": "Chicago Business Barometer Index SA"}, inplace=True)
# Cycle: ISM manufacturing
#hv_tb_usa_005_002_m.rename(columns={"napmc": "ISM Mfg Composite Index SA"}, inplace=True)
# Cycle: ISM services
#hv_tb_usa_005_002_m.rename(columns={"nmfc": "ISM Serv Composite Index SA"}, inplace=True)

# Create a list of tickers
#sai_m_tickers = hv_tb_usa_000_001_m.columns
## Iterate through each ticker
#for x in range(len(usai_m_tickers)):
#    variable = str(usai_m_tickers[x])
#    print(variable)
#    # Calculate year-over-year (YoY) percentage change
#    hv_tb_usa_000_001_m[(str(variable) + str("_yy"))] = hv_tb_usa_000_001_m[variable].pct_change(12).multiply(100).round(3)#
#    # Calculate quarter-over-quarter (QoQ) percentage change
#    hv_tb_usa_000_001_m[(str(variable) + str("_qq"))] = hv_tb_usa_000_001_m[variable].pct_change(4).multiply(100).round(3)
#    # Calculate month-over-month (MoM) percentage change
#    hv_tb_usa_000_001_m[(str(variable) + str("_mm"))] = hv_tb_usa_000_001_m[variable].pct_change(1).multiply(100).round(3)




print("generating z score")
window_z10 = [3, 6, 12, 24, 36, 60, 100]
window_zl = window_z10
usai_m_tickers = hv_tb_usa_000_001_m.columns

for x in range(len(usai_m_tickers)):
    variable = str(usai_m_tickers[x])
    for y in range(len(window_zl)):
        window_z = window_zl[y]
        hv_tb_usa_000_001_m[(str(variable) + str("_zscore") + str(window_z))] = (zscore(hv_tb_usa_000_001_m[variable], 
                                                                                        window_z)).round(2)
        hv_tb_usa_000_001_m[(str(variable) + str("_zavg") + str(window_z))] = (zscore_avg(hv_tb_usa_000_001_m[variable], 
                                                                                          window_z)).round(2)

print("generating charts")
window_zl = window_z10

# window_zl=[12]
for x in range(len(window_zl)):
    print(x)
    window_z = window_zl[x]
    window_z_1 = str("zscore" + str(window_z))
    usai_m_tickers = ["Real: Industrial Production_zscore" + str(window_z),
                      "Real: Retail Sales excl Autos_zscore" + str(window_z),
                      "Employment: Wage Growth_zscore" + str(window_z),
                      "Employment: Participation Rate_zscore" + str(window_z),
                      "Employment: ADP Private Payroll_zscore" + str(window_z),
                      "Employment: NFP_zscore" + str(window_z),
                      "Employment: NFP Private_zscore" + str(window_z),
                      "Price: CPI Headline_zscore" + str(window_z),
                      "Price: CPI Core_zscore" + str(window_z),
                      "Price: PCE Index_zscore" + str(window_z),
                      "Price: PCE Core_zscore" + str(window_z),
                      "Price: FRB Clev PCE Median_zscore" + str(window_z),
                      "Price: FRB Dallas PCE Trimmed Mean_zscore" + str(window_z),
                      "Price: Michigan Inflation next 1Y_zscore" + str(window_z),
                      "Price: Michigan Inflation next 5Y_zscore" + str(window_z),
                      "Cycle: Michigan Consumer Sentiment_zscore" + str(window_z),
                      "Cycle: CBoard Consumer Confidence_zscore" + str(window_z),
                      #"Cycle: Chicago Business Index_zscore" + str(window_z),
                      "Cycle: ISM Manufacturing_zscore" + str(window_z),
                      "Cycle: ISM Services_zscore" + str(window_z)]
    usai_m_tickers_r = ["Real: Industrial Production_zscore" + str(window_z),
                     "Real: Retail Sales excl Autos_zscore" + str(window_z)]

    usai_m_tickers_e = ["Employment: Wage Growth_zscore" + str(window_z),
                         "Employment: Participation Rate_zscore" + str(window_z),
                         "Employment: ADP Private Payroll_zscore" + str(window_z),
                         "Employment: NFP_zscore" + str(window_z),
                         "Employment: NFP Private_zscore" + str(window_z)]
    
    usai_m_tickers_p = ["Price: CPI Headline_zscore" + str(window_z),
                         "Price: CPI Core_zscore" + str(window_z),
                         "Price: PCE Index_zscore" + str(window_z),
                         "Price: PCE Core_zscore" + str(window_z),
                         "Price: FRB Clev PCE Median_zscore" + str(window_z),
                         "Price: FRB Dallas PCE Trimmed Mean_zscore" + str(window_z),
                         "Price: Michigan Inflation next 1Y_zscore" + str(window_z),
                         "Price: Michigan Inflation next 5Y_zscore" + str(window_z)]
    
    usai_m_tickers_c = ["Cycle: Michigan Consumer Sentiment_zscore" + str(window_z),
                         "Cycle: CBoard Consumer Confidence_zscore" + str(window_z),
                         #"Cycle: Chicago Business Index_zscore" + str(window_z),
                         "Cycle: ISM Manufacturing_zscore" + str(window_z),
                         "Cycle: ISM Services_zscore" + str(window_z)]
    
    print("tickers updated")
    print(usai_m_tickers)
    
    hv_tb_usa_000_002_m = hv_tb_usa_000_001_m[usai_m_tickers]
    hv_tb_usa_000_002_m.sort_index(ascending=False,
                                   axis=1, inplace=True)
    hv_tb_usa_000_002_m = hv_tb_usa_000_002_m.tail(24)
    hv_tb_usa_000_002_m = hv_tb_usa_000_002_m.transpose()
    hv_tb_usa_000_002_m.index.names = ['Variable']
    #path_display = dashboard_eco\table_usa_000_002z"
    #path_display = str(path_display) + str(window_z) + ".csv"
    #hv_tb_usa_000_002_m.to_csv(path_display, index=True, header=True)   
    #####STACKED BARCHART
    hv_tb_usa_000_003_m = hv_tb_usa_000_001_m[usai_m_tickers]
    div = len(usai_m_tickers)
    div = div + 0
    hv_tb_usa_000_003_m = (hv_tb_usa_000_003_m / div)
    hv_tb_usa_000_003_m = hv_tb_usa_000_003_m.tail(120)
    #print(hv_tb_usa_000_003_m)
    ########## bar chart
    df1 = hv_tb_usa_000_003_m
    h1 = df1.copy()
    df1.index = df1.index.date
    fig, ax = plt.subplots(figsize=(parameter3_s, parameter4_s))
    #ax= df.plot(kind='bar', stacked=True, figsize=(10, 6))
    
    colors = ["orange", "orange", "blue", "blue", "blue", "blue",
              "yellow", "yellow", "yellow", "yellow", "yellow",
              "green", "green", "green", "green", "green"]
    
    h1.plot(kind='bar', stacked=True, ax=ax, color=colors)
    title_r = str('USA_MacroMomentum_z' + str(window_z))
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.title(str(title_r), size=parameter5)
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(title_r), size=parameter3)
    plt.legend(title='labels', bbox_to_anchor=(1.0, 1), loc='upper left')

    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    
    loc = plticker.MultipleLocator(base=4)  # This locator puts ticks at regular intervals
    ax.xaxis.set_major_locator(loc)

    #date_form = DateFormatter("%m-%Y")
    #ax.xaxis.set_major_formatter(date_form)
    #ax.xaxis.set_major_locator(mdates.YearLocator())
    #half_year_locator = mdates.MonthLocator(interval=1)
    #ax.xaxis.set_major_locator(half_year_locator)
    #ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
             ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    
    plt.savefig(str('USA_MacroMomentum_bar_z' + str(window_z) + ".png"), bbox_inches='tight')
    plt.savefig(str('USA_MacroMomentum_bar_z' + str(window_z) + ".jpg"), bbox_inches='tight')
    #plt.show()
    
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    
    del h1
    del df1
    del fig
    del ax
    del ax2



    #timeseries
    hv_tb_usa_000_003_m[str('USA_MacroMomentum_z'+str(window_z))] = hv_tb_usa_000_003_m[usai_m_tickers].mean(axis=1)
    hv_tb_usa_000_004_m=hv_tb_usa_000_003_m[str('USA_MacroMomentum_z'+str(window_z))]
    df1=hv_tb_usa_000_004_m.copy()
    g1=df1.copy()    
    title_r=str('USA_MacroMomentum_z'+str(window_z))
    fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z'+str(window_z))], color="darkorange",
            linewidth= l1, linestyle='-',marker='s', markersize=s2)
    plt.axhline(0, color="black", lw=1, linestyle ='dashed', alpha=0.75)                                               
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('USA_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 =ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,                                                                        
             ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    plt.savefig(str('USA_MacroMomentum_z'+str(window_z)+".png"), bbox_inches='tight')
    #plt.show()
    pit.close()
    pit.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    del fig
    del ax
    del ax2

    ###################tail 24
    df1=hv_tb_usa_000_004_m.tail(24)
    g1=df1.copy()    
    title_r=str('USA_MacroMomentum_z'+str(window_z))
    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    # Plot the data
    df1.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z'+str(window_z))], 
             color="darkorange", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    # Add horizontal line at 0
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    # Set plot style, labels, ticks, and title
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('USA_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    # Add a twin axis
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    # Add text
    plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", 
             alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    # Save the plot
    plt.savefig(str('USA_MacroMomentum_z'+str(window_z)+"z.png"), bbox_inches='tight')
    plt.savefig(str('USA_MacroMomentum_z'+str(window_z)+"z.jpg"), bbox_inches='tight')
    # Close the plot
    plt.close()
    # Clear the plot
    plt.close('all')
    plt.clf()
    plt.cla()
    
    # Delete variables
    del g1
    del df1
    del fig
    del ax
    del ax2
    
    # Calculate mean values for different tickers
    hv_tb_usa_000_003_m[str('USA_MacroMomentum_z_r_'+str(window_z))] = hv_tb_usa_000_003_m[usai_m_tickers_r].mean(axis=1)
    hv_tb_usa_000_003_m[str('USA_MacroMomentum_z_e_'+str(window_z))] = hv_tb_usa_000_003_m[usai_m_tickers_e].mean(axis=1)
    hv_tb_usa_000_003_m[str('USA_MacroMomentum_z_p_'+str(window_z))] = hv_tb_usa_000_003_m[usai_m_tickers_p].mean(axis=1)
    hv_tb_usa_000_003_m[str('USA_MacroMomentum_z_c_'+str(window_z))] = hv_tb_usa_000_003_m[usai_m_tickers_c].mean(axis=1)
    
    # Create a new DataFrame with the calculated means
    hv_tb_usa_000_005_m = hv_tb_usa_000_003_m[[str('USA_MacroMomentum_z_r_'+str(window_z)),
                                               str('USA_MacroMomentum_z_e_'+str(window_z)), 
                                               str('USA_MacroMomentum_z_p_'+str(window_z)), 
                                               str('USA_MacroMomentum_z_c_'+str(window_z))]]


    df2=hv_tb_usa_000_005_m.copy()
    g1=df2.copy()
    title_r=str("USA_MacroMomentum_z"+str(window_z))
    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    
    # Plot the data
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_r_'+str(window_z))], 
             color="orange", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_e_'+str(window_z))], 
             color="blue", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_p_'+str(window_z))], 
             color="green", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_c_'+str(window_z))], 
             color="yellow", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    
    # Add horizontal line at 0
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    
    # Set plot style, labels, ticks, and title
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('USA_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    # Add a twin axis
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    # Add text
    plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray",
             alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    # Save the plot
    plt.savefig(str('USA_MacroMomentum_zd'+str(window_z)+".png"), bbox_inches='tight')
    plt.savefig(str('USA_MacroMomentum_zd'+str(window_z)+".jpg"), bbox_inches='tight')
    # Show the plot
    #plt.show()
    # Close the plot
    plt.close()
    # Clear the plot
    plt.close('all')
    plt.clf()
    plt.cla()
    
    # Delete variables
    del df2
    del fig


    df2=hv_tb_usa_000_005_m.tail(24)
    g1=df2.copy()
    title_r=str("USA_MacroMomentum_z"+str(window_z))
    
    # Assuming you have the DataFrame df2 defined and the parameters window_z, parameter1_s, parameter2_s, parameter3, parameter4, parameter5, and owner defined
    
    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    
    # Plot the data
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_r_'+str(window_z))],
             color="orange", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_e_'+str(window_z))],
             color="blue", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_p_'+str(window_z))], 
             color="green", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    df2.plot(kind='line', ax=ax, y=[str('USA_MacroMomentum_z_c_'+str(window_z))], 
             color="yellow", linewidth=l1, linestyle='-', marker='s', markersize=s2)
    
    # Add horizontal line at 0
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    
    # Set plot style, labels, ticks, and title
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('USA_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    
    # Add a twin axis
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    
    # Add text
    plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray",
             alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
    
    # Save the plot
    plt.savefig(str('USA_MacroMomentum_zd'+str(window_z)+"z.png"), bbox_inches='tight')
    plt.savefig(str('USA_MacroMomentum_zd'+str(window_z)+"z.jpg"), bbox_inches='tight')
    # Show the plot
    #plt.show()
    
    # Close the plot
    plt.close()
    
    # Clear the plot
    plt.close('all')
    plt.clf()
    plt.cla()
    
    # Delete variables
    del df2
    del fig
    del ax
    del ax2

#usai_m_tickers_real=[
#"Real: Industrial Production_zscore"+str(window_z),
#"Real: Retail Sales exci Autos_zscore"+str(window_z),
#"Real: S&P Monthly GDP_zscore"+str(window_z)]###
##usai_m_tickers_employment =[
#"Employment: Wage Growth_zscore"+str(window_z),
#"Employment: Participation Rate_zscore"+str(window_z),
#"Employment: ADP Private Payroll_zscore"+str(window_z),#
#"Employment: NFP_zscore"+str(window_z),
#"Employment: NFP Private_zscore"+str(window_z)]
##usai_m_tickers_prices=[
#"Price: CPI Headline_zscore"+str(window_z),
#"Price: CPI Core_zscore"+str(window_z),
#"Price: PCE Index_zscore"+str(window_z),
#"Price: PCE Core_zscore"+str(window_z),
#"Price: FRB Clev PCE Median_zscore"+str(window_z),
#"Price: FRB Dallas PCE Trimmed Mean_zscore"+str(window_z),
#"Price: Michigan Inflation next 1Y_zscore"+str(window_z),
#"Price: Michigan Inflation next 5Y_zscore"+str(window_z)]
##usai_m_tickers_cycle=[
#"Cycle: Michigan Consumer Sentiment_zscore"+str(window_z),
#"Cycle: CBoard Consumer Confidence_zscore"+str(window_z),
#"Cycle: Chicago Business Index_zscore"+str(window_z),
#"Cycle: ISM Manufacturing_zscore"+str(window_z),
#"Cycle: ISM Services_zscore"+str(window_z)]


#Cycle: CBoard Consumer Confidence_zscore"+str(window_z),
#"Cycle: Chicago Business Index_zscore"+str(window_z),

#"Cycle: ISM Manufacturing_zscore"+str(window_z),
#"Cycle: ISM Services_zscore"+str(window_z)]
#US Eocnomics DADASHBOARD EMPLOYMENTS
#LABOR
#pmi
#LJJTPA@USECON JOLTS: Job Openings Rate: Total (EOP, SA, %)
#JOLTS Job Openings Rate SA %
#LJHTPA@USECON JOLTS: Hires Rate: Total (SA, %)
#LJQTPA@USECON JOLTS: Quits Rate: Total (SA, %)
#LJLTPA@USECON JOLTS: Layoffs and Discharges Rate: Total (SA, %)
#WGTN@USECON
#Wage Growth Tracker: Non-Smoothed Median Wage Growth (NSA, Y/Y %Chg)
#WGTO@USECON
#WGTVEUSECON
#Wage Growth Tracker: Weighted Overall: 3-MMA of Median Wage Grwth(NSA, Y/Y %Chg)
#Wage Growth Tracker: Overall: 3-Mo Mov Avg of Median Wage Growth (NSA, Y/Y %Chg)
#WGT97@USECON
#Wage Growth Tracker: 1997 Wghtd Overall: 3-MMA of Med Wage Grwth (NSA, Y/Y %Chg)
#WGT12@USECON Wage Growth Tracker: 12-Month Moving Avg of Median Wage Growth (NSA, Y/Y %Chg)
#NMFΕΙ ΕΜΠΟΥMENT INDEX NSA ISM SERVICES Employment NSA
#LP@USECON Civilian Participation Rate: 16 yr (SA, %)

#hv_uk1, rename(columns={ticker:name), inplace=True)
#LJJTPA@USECON JOLTS: Job Openings Rate: Total (EOP, SA, %)
#cpi_m_tickers = ['AUNIGI', 'AUNIGIC', 'AUNIGIT', 'AUNIGIY']

#comd_m_tickers
###employment
#['AUNPMAD, AUNPMRD", "AUNPMND', 'AUNPMMD', 'AUNPMBD', 'AUNPMSD"]
#empl_m_tickers = ['AUSELL', 'AUSELU', 'AUSELUR', 'AUSELPR', 'AUSELER']
#gdp[

### 001_employment data  <a id="title_page"></a>

horizon_tb_usa_002_001_m =24
#Loading tickers
horizon_1=24
country_database = "USECON"
jw_m_tickers = ['ffedtahe', 'LJJTPA', 'LJHTPA',
                'LJQTPA', 'LJLTPA',
                'WGTN', 'WGTO', 'WGTV',
                'WGT97', 'WGT12', 'LP']

hv_tb_usa_002_001_m = Haver.data(jw_m_tickers, 
                                 country_database, dates=True)
hv_tb_usa_002_001_m.rename(columns={"ffedtahe": "FED Target Rate Upper Limit"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"ljjtpa": "JOLTS Job Openings Rate SA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"ljhtpa": "JOLTS Hires Rate SA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"ljotpa": "JOLTS Quits Rate SA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"ljltpa": "JOLTS Layoffs Rate SA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"wgtn": "Wage Growth Non-Smoothed Median NSA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"wgto": "Wage Growth Overall: 3-Mo Mov Avg NSA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"wgtv": "Wage Growth Weighted Overall NSA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"wgt97": "Wage Growth 1997 Wightd Overall NSA %"}, inplace=True)
hv_tb_usa_002_001_m.rename(columns={"wgt12": "Wage Growth 12-Month Moving Avg NSA %"}, inplace=True)
hv_tb_usa_002_001_m["lp"] = (hv_tb_usa_002_001_m["lp"] / 100)
hv_tb_usa_002_001_m.rename(columns={"lp": "Civilian Participation Rate: 16 yr SA %"}, inplace=True)

# hv_tb_usa_002_001_m.rename(columns={"Lp": "Civilian Participation Rate: 16 yr SA %"}, inplace=True)
#hv_tb_usa_002_001_m_g_001=hv_tb_usa_002_001_m
#hv_database=hv_database.loc["2018-12-31":]
#hv_tb_usa_002_001_m_g_001=hv_tb_usa_002_001_m.copy()
#hv_tb_usa_002_001_m=hv_tb_usa_002_001_m.tail(horizon_tb_usa_002_001_m)
#hv_tb_usa_002_001_m = hv_tb_usa_002_001_m.transpose()
#hv_tb_usa_002_001_m.index.names = ['Variable']


hv_tb_usa_002_001_m_g = hv_tb_usa_002_001_m.copy()
hv_tb_usa_002_001_m_g_001 = hv_tb_usa_002_001_m.copy()

hv_tb_usa_002_001_m.index=hv_tb_usa_002_001_m.index.date
hv_tb_usa_002_001_m = hv_tb_usa_002_001_m.tail(horizon_tb)
hv_tb_usa_002_001_t1=hv_tb_usa_002_001_m.tail(horizon_tb)

hv_tb_usa_002_001_m_t = hv_tb_usa_002_001_m.transpose()
hv_tb_usa_002_001_m_t.index.names = ['Variable']

hv_tb_usa_002_001_t1_t = hv_tb_usa_002_001_t1.transpose()
hv_tb_usa_002_001_t1_t.index.names = ['Variable']



### 001_employment data table <a id="title_page"></a>


#####here*******
title_table="usa_employment_table"
df =hv_tb_usa_002_001_t1.copy()
df_transposed = hv_tb_usa_002_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_002_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_002_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_002_001_m_t_002.png')




### 001_employment data  graphs  <a id="title_page"></a>

#h#v_tb_usa_002_001_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_usa_002_001_m)

title_r="Wage Growth NSA"
y_label="Index %"
x_label=title_r
list_c=["Wage Growth Non-Smoothed Median NSA %",
        "Wage Growth Overall: 3-Mo Mov Avg NSA %",
        "Wage Growth Weighted Overall NSA %",
#        "Wage Growth 1997 Wghtd Overall NSA %",
        "Wage Growth 12-Month Moving Avg NSA %"]

df1=hv_tb_usa_002_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Wage Growth Non-Smoothed Median NSA %"], 
        color="darkgreen", linewidth= l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Wage Growth Overall: 3-Mo Mov Avg NSA %"], 
        color="darkblue", linewidth= l1, linestyle="-",marker= 'D',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Wage Growth Weighted Overall NSA %"], 
        color="darkred", linewidth= l1, linestyle="-",marker=">", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Wage Growth 1997 Wghtd Overall NSA %"], 
#        color="black", linewidth= 11, linestyle='-',marker='o', markersize=s2)

g1.plot(kind='line', ax=ax, y=["Wage Growth 12-Month Moving Avg NSA %"], 
        color="darkorange", linewidth= l1, linestyle='-',marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray',
         alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig


################

title_r="Wage Growth NSA"
y_label="Index %"
x_label=title_r
list_c=["Wage Growth Non-Smoothed Median NSA %",
        "Wage Growth Overall: 3-Mo Mov Avg NSA %",
        "Wage Growth Weighted Overall NSA %",
#        "Wage Growth 1997 Wghtd Overall NSA %",
        "Wage Growth 12-Month Moving Avg NSA %"]

df1=hv_tb_usa_002_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Wage Growth Non-Smoothed Median NSA %"], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Wage Growth Overall: 3-Mo Mov Avg NSA %"], 
        color="darkblue", linewidth= l1, linestyle="-",marker= 'D',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Wage Growth Weighted Overall NSA %"], 
        color="darkred", linewidth= l1, linestyle="-",marker=">", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Wage Growth 1997 Wghtd Overall NSA %"], 
#        color="black", linewidth= 11, linestyle='-',marker='o', markersize=s2)

g1.plot(kind='line', ax=ax, y=["Wage Growth 12-Month Moving Avg NSA %"], 
        color="darkorange", linewidth= l1, linestyle='-',marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray',
         alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig


#Laxepla Hospitality
#Laxepxa Other services

us_m_tickers = ['laxepa', 'laxepla', 'laxep2a', 'laxep8a', 
                'laxepga', 'laxepra', 'laxepca', 'laxepma', 
                'laxepsa','laxepta', 'laxepia','laxepfa',
                'laxeppa', 'laxepea','laxepla','laxepxa']
                #'lаxерха']


hv_tb_usa_002_003_m=Haver.data(us_m_tickers, 
                               country_database, 
                               dates=True)
for x in range(len(us_m_tickers)):
    #print(x)
    variable=str(us_m_tickers[x])
    #print(variable)
    hv_tb_usa_002_003_m[variable] = hv_tb_usa_002_003_m[variable].diff(1)
    #print(hv_tb_usa_002_003_m[variable])

hv_tb_usa_002_003_m.rename(columns={"laxepa": "ADP Private Payroll SA"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepla": "Priv Payroll Small bss SA"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxep2a": "Priv Payroll Medium bss SA"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxep8a": "Priv Payroll: Large bss SA"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepga": "Unemployed, 16 yr+ (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepra": "Civilians Unemployed: Job Losers (SA, Thous.)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepca": "Civilians Unemployed: Job Leavers (SA, Thous.)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepma": "Civilians Unemployed: Reentrants (SA, Thous.)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepsa": "Civilians Unemployed: New Entrants (SA, Thous.)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepta": "Change in Total Nonfarm Employment (SA, Thous.)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepia": "Work Part Time: All Industry (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepfa": "Work Part Time: All Industry (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxeppa": "Work Part Time: All Industry (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepea": "Work Part Time: All Industry (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepla": "Work Part Time: All Industry (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m.rename(columns={"laxepxa": "Work Part Time: All Industry (SA, Thous)"}, inplace=True)
hv_tb_usa_002_003_m_g_001=hv_tb_usa_002_003_m.copy()
hv_tb_usa_002_003_m=hv_tb_usa_002_003_m.tail(24)
hv_tb_usa_002_003_m =hv_tb_usa_002_003_m.transpose()
hv_tb_usa_002_003_m.index.names = ['Variable']
hv_tb_usa_002_003_m["Variable_"]=hv_tb_usa_002_003_m.index
#dashboard.to_clipboard()
#path_display = dashboard_eco\tb_usa_002_003_m.csv'
#rint(path_display)
#hv_tb_usa_002_003_m.to_csv (path_display, index True, header=True)
#print(hv_tb_usa_002_003_m)



title_r = "USA ADP Private Payroll SA"
y_label = "Change"
x_label = title_r
list_c = ["ADP Private Payroll SA", "Priv Payroll Small bss SA",
           "Priv Payroll Medium bss SA", "Priv Payroll: Large bss SA"]
df1 = hv_tb_usa_002_003_m_g_001[list_c]
df1 = df1.tail(36)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["ADP Private Payroll SA"], color="darkgreen", linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Priv Payroll Small bss SA"], color="darkblue", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Priv Payroll Medium bss SA"], color="darkred", linewidth=l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Priv Payroll: Large bss SA"], color="black", linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         transform=ax.transAxes)
plt.savefig("hv_tb_usa_002_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


###########


title_r = "USA ADP Private Payroll SA"
y_label = "Change"
x_label = title_r
list_c = ["ADP Private Payroll SA", "Priv Payroll Small bss SA",
           "Priv Payroll Medium bss SA", "Priv Payroll: Large bss SA"]
df1 = hv_tb_usa_002_003_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["ADP Private Payroll SA"], color="darkgreen", linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Priv Payroll Small bss SA"], color="darkblue", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Priv Payroll Medium bss SA"], color="darkred", linewidth=l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Priv Payroll: Large bss SA"], color="black", linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         transform=ax.transAxes)
plt.savefig("hv_tb_usa_002_003_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_nfp data  <a id="title_page"></a>

py_m_tickers = ['ffedtahe', 'lanagrd', 'lanagadx', 'lanagsd1', 'lanagsd2', 'lanagsd3',
                'lanagsr1', 'lanagsr2', 'lanagsr3']
hv_tb_usa_002_004_m=Haver.data(py_m_tickers, country_database, dates=True)        
hv_tb_usa_002_004_m.rename(columns={"ffedtahe": "FED Target Rate Upper Limit"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagrd": "Change NFP SA"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagadx": "Change NFP excluding strikes SA"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagsd1": "Change NFP 1st Est SA"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagsd2": "Change NFP 2nd Est SA"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagsd3": "Change NFP 3rd Est SA"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagsr1": "NFP Revision 2nd and 1st"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagsr2": "NFP Revision 3rd and 2nd"}, inplace=True)
hv_tb_usa_002_004_m.rename(columns={"lanagsr3": "NFP Revision 3rd and 1st"}, inplace=True)
#hv_tb_usa_002_004_m_g_001=hv_tb_usa_002_004_m.copy()
#hv_tb_usa_002_004_m=hv_tb_usa_002_004_m.tail(24)
#hv_tb_usa_002_004_m =hv_tb_usa_002_004_m.transpose()
#hv_tb_usa_002_004_m.index.names = ['Variable']
#hv_tb_usa_002_004_m["Variable_"]=hv_tb_usa_002_004_m.index
#dashboard.to_clipboard()
#path_display = Alan_data_sandbox\dashboard_eco\tb_usa_002_004_m.csv"
#print(path_display)
#h#v_tb_usa_002_004_m.to_csv (path_display, index True, header-True)
#print(hv_tb_usa_002_004_m)


hv_tb_usa_002_004_m_g = hv_tb_usa_002_004_m.copy()
hv_tb_usa_002_004_m_g_001 = hv_tb_usa_002_004_m.copy()

hv_tb_usa_002_004_m.index=hv_tb_usa_002_004_m.index.date
hv_tb_usa_002_004_m = hv_tb_usa_002_004_m.tail(horizon_tb)
hv_tb_usa_002_004_t1=hv_tb_usa_002_004_m.tail(horizon_tb)

hv_tb_usa_002_004_m_t = hv_tb_usa_002_004_m.transpose()
hv_tb_usa_002_004_m_t.index.names = ['Variable']

hv_tb_usa_002_004_t1_t = hv_tb_usa_002_004_t1.transpose()
hv_tb_usa_002_004_t1_t.index.names = ['Variable']

### 001_nfp data  table <a id="title_page"></a>


############################################################
######Table 1

#####here*******
title_table="usa_nfp_table"
df =hv_tb_usa_002_004_t1.copy()
df_transposed = hv_tb_usa_002_004_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_002_004_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_002_004_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_002_004_m_t_002.png')

### 001_nfp graphs  <a id="title_page"></a>

##############################################
title_r="USA NFP"
y_label="Change"
x_label=title_r
list_c=["Change NFP SA", "Change NFP excluding strikes SA"]
df1=hv_tb_usa_002_004_m_g_001.copy()
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
# Set the background to light gray
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area

#fig.patch.set_facecolor('#f0f0f0')  # Light gray background for the entire figure
#ax.set_facecolor('#e6e6e6')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["Change NFP SA"], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker="P",markersize=s2)
g1.plot(kind='line', ax=ax, y=["Change NFP excluding strikes SA"], 
        color="darkblue", 
        linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,  
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_004_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

##############################################

title_r="USA NFP"
y_label="Change"
x_label=title_r
list_c=['Change NFP 1st Est SA',
        'Change NFP 2nd Est SA',
        'Change NFP 3rd Est SA']
df1=hv_tb_usa_002_004_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s,parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["Change NFP 1st Est SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker="P",markersize=s2)
g1.plot(kind='line', ax=ax,y=["Change NFP 2nd Est SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker ='D',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Change NFP 3rd Est SA"], color="darkred", linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_004_m_g_002.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

##############################################

title_r="USA NFP"
y_label="Change"
x_label=title_r
list_c=['Change NFP 1st Est SA',
        'Change NFP 2nd Est SA',
        'Change NFP 3rd Est SA']
df1=hv_tb_usa_002_004_m_g_001[list_c]
#df1.index=date2num(df1.index)
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='bar', ax=ax, y=["Change NFP 1st Est SA"], width = 0.2, color="darkgreen", align="center")
g1.plot(kind='bar', ax=ax, y=["Change NFP 2nd Est SA"], width = 0.2, color="darkblue", align="center")
g1.plot(kind='bar', ax=ax, y=["Change NFP 3rd Est SA"], width = 0.2, color="darkred", align="center")
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, 
         color="gray", alpha=0.5,  ha='center',
         va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_004_m_g_003.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

##############################################

title_r="USA NFP Revisions"
y_label="Change"
x_label=title_r
list_c=["NFP Revision 2nd and 1st",
        "NFP Revision 3rd and 2nd",
        "NFP Revision 3rd and 1st"]
df1=hv_tb_usa_002_004_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["NFP Revision 2nd and 1st"], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["NFP Revision 3rd and 2nd"],
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["NFP Revision 3rd and 1st"],
        color="darkred", linewidth= l1, linestyle="-",
        marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color='gray', alpha=0.5,
         ha='center',va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_004_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

##############################################

title_r="USA NFP Revisions Final"
y_label="Change"
x_label=title_r
list_c=["NFP Revision 3rd and 1st"]
df1=hv_tb_usa_002_004_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax=plt.subplots (figsize= (parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["NFP Revision 3rd and 1st"], color="darkred", linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_004_m_g_005.png", bbox_inches="tight")

plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2









### nfp seasonality table 


##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['lanagr', 'lanagra', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"lanagr": "nfp_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"lanagra": "nfp_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=4)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_usa_002_004_m_g_006.png')


##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['lapriv', 'lapriva', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"lapriv": "nfp_private_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"lapriva": "nfp_private_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=4)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_usa_002_004_m_g_007.png')

##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['lagovt', 'lagovta', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"lagovt": "nfp_govt_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"lagovta": "nfp_govt_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=4)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_usa_002_004_m_g_008.png')





### 001_claims  <a id="title_page"></a>

#us_m_tickers = ['licm', 'licn']
#hv_tb_usa_002_005_m = Haver.data(us_m_tickers, country_database, dates=True)
##for x in range(len(us_m_tickers)):
#hv_tb_usa_002_005_m.rename(columns={"licm": "Initial Claims SA"}, inplace=True)
#hv_tb_usa_002_005_m.rename(columns={"licn": "Initial Claims NSA"}, inplace=True)
#hv_tb_usa_002_005_m["Initial Claims SA MAVG4"] = hv_tb_usa_002_005_m["Initial Claims SA"].rolling(4).mean()
#hv_tb_usa_002_005_m["Initial Claims SA MAVG12"] = hv_tb_usa_002_005_m["Initial Claims SA"].rolling(12).mean()



py_m_tickers = ['licm', 'licn', ]
hv_tb_usa_002_005_m=Haver.data(py_m_tickers, country_database, dates=True)        
hv_tb_usa_002_005_m.rename(columns={"licm": "Initial Claims SA"}, inplace=True)
hv_tb_usa_002_005_m.rename(columns={"licn": "Initial Claims NSA"}, inplace=True)

hv_tb_usa_002_005_m_g = hv_tb_usa_002_005_m.copy()
hv_tb_usa_002_005_m_g_001 = hv_tb_usa_002_005_m.copy()

hv_tb_usa_002_005_m.index=hv_tb_usa_002_005_m.index.date
hv_tb_usa_002_005_m = hv_tb_usa_002_005_m.tail(horizon_tb)
hv_tb_usa_002_005_t1=hv_tb_usa_002_005_m.tail(horizon_tb)

hv_tb_usa_002_005_m_t = hv_tb_usa_002_005_m.transpose()
hv_tb_usa_002_005_m_t.index.names = ['Variable']

hv_tb_usa_002_005_t1_t = hv_tb_usa_002_005_t1.transpose()
hv_tb_usa_002_005_t1_t.index.names = ['Variable']

title_r="Unemployment Claims"
y_label="Change"
x_label=title_r
list_c=["Initial Claims SA",
"Initial Claims NSA"]
df1=hv_tb_usa_002_005_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["Initial Claims SA"], color="darkgreen", linewidth=l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Initial Claims NSA"], color="darkblue", linewidth=l1, linestyle='-', marker="D", markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_005_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

del list_c
del fig

del ax
del ax2


title_r = "Unemployment Claims"
y_label = "Change"
x_label = title_r
list_c = ["Initial Claims SA", "Initial Claims NSA"]
df1 = hv_tb_usa_002_005_m_g_001[list_c]
df1 = df1.tail(42)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["Initial Claims SA"], color="darkgreen", linewidth=l1, linestyle='-', marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Initial Claims NSA"], color="darkblue", linewidth=l1, linestyle='-', marker='D', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5, 
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_005_m_g_001z.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2



### ----------------------------------------------------------------------------------------------------

### 001_Philllips Curve  <a id="title_page"></a>

###### Philllips Curve 

print("Philips Curve")
### cORE PCE VS UNEMPLTOEMTN
usi_m_tickers = ['jcxfebm','lr']
hv_tb_us_002_006_m = Haver.data(usi_m_tickers, "USECON", dates=True)
#hv_tb_us_002_006_m.index = hv_tb_us_002_006_m.index.floor('D')

usi_m_tickers = ['jcxfebm']
for x in range(len(usi_m_tickers)):
    variable = str(usi_m_tickers[x])
    hv_tb_us_002_006_m[variable] = hv_tb_us_002_006_m[variable].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(3)
    
hv_tb_us_002_006_m.rename(columns={'jcxfebm': 'US PCE Core yy sa Monthly'}, inplace=True)
hv_tb_us_002_006_m.rename(columns={'lr': 'US Unemployment Rate Monthly'}, inplace=True)
hv_tb_us_002_006_m['year'] = hv_tb_us_002_006_m.index.year
hv_tb_us_002_006_m = hv_tb_us_002_006_m.tail(240)

list_pc=hv_tb_us_002_006_m.columns.tolist()
print(hv_tb_us_002_006_m.tail(5))
x = hv_tb_us_002_006_m[list_pc[1]]
y = hv_tb_us_002_006_m[list_pc[0]]
t = hv_tb_us_002_006_m['year']
y_label = list_pc[0]
x_label = list_pc[1]
print(len(x))
print(len(y))




title_r="PHILLIPS CURVE CORE VS UNEMPLOYMENT"

df1=hv_tb_us_002_006_m.copy()
df1.index= df1.index.date

#df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[list_pc[1]],
            g1[list_pc[0]], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1[list_pc[1]],
         g1[list_pc[0]], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1[list_pc[1]].iloc[line], 
         g1[list_pc[0]].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_006_m_g_001.jpg", bbox_inches='tight')
plt.savefig("hv_tb_usa_002_006_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()


print("Philips Curve")
### cORE PCE VS UNEMPLTOEMTN
usi_m_tickers = ['jcxfebm','lr']
hv_tb_us_002_006_m = Haver.data(usi_m_tickers, "USECON", dates=True)
#hv_tb_us_002_006_m.index = hv_tb_us_002_006_m.index.floor('D')

usi_m_tickers = ['jcxfebm']
for x in range(len(usi_m_tickers)):
    variable = str(usi_m_tickers[x])
    hv_tb_us_002_006_m[variable] = hv_tb_us_002_006_m[variable].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(3)
    
hv_tb_us_002_006_m.rename(columns={'jcxfebm': 'US PCE Core yy sa Monthly'}, inplace=True)
hv_tb_us_002_006_m.rename(columns={'lr': 'US Unemployment Rate Monthly'}, inplace=True)
hv_tb_us_002_006_m['year'] = hv_tb_us_002_006_m.index.year
hv_tb_us_002_006_m = hv_tb_us_002_006_m.tail(240)

list_pc=hv_tb_us_002_006_m.columns.tolist()
print(hv_tb_us_002_006_m.tail(5))
x = hv_tb_us_002_006_m[list_pc[1]]
y = hv_tb_us_002_006_m[list_pc[0]]
t = hv_tb_us_002_006_m['year']
y_label = list_pc[0]
x_label = list_pc[1]
print(len(x))
print(len(y))


title_r="PHILLIPS CURVE CORE VS UNEMPLOYMENT"
df1=hv_tb_us_002_006_m.copy()
df1.index= df1.index.date

#df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[list_pc[1]],
            g1[list_pc[0]], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1[list_pc[1]],
         g1[list_pc[0]], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1[list_pc[1]].iloc[line], 
         g1[list_pc[0]].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_006_m_g_001.jpg", bbox_inches='tight')
plt.savefig("hv_tb_usa_002_006_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()



print("Philips Curve")
### cORE PCE VS UNEMPLTOEMTN
usi_m_tickers = ['lktpriva','lr']
hv_tb_us_002_006_m = Haver.data(usi_m_tickers, "USECON", dates=True)
#hv_tb_us_002_006_m.index = hv_tb_us_002_006_m.index.floor('D')

usi_m_tickers = ['lktpriva']
for x in range(len(usi_m_tickers)):
    variable = str(usi_m_tickers[x])
    hv_tb_us_002_006_m[variable] = hv_tb_us_002_006_m[variable].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(3)
    
hv_tb_us_002_006_m.rename(columns={'lktpriva': 'US AWE private yy sa Monthly'}, inplace=True)
hv_tb_us_002_006_m.rename(columns={'lr': 'US Unemployment Rate Monthly'}, inplace=True)
hv_tb_us_002_006_m['year'] = hv_tb_us_002_006_m.index.year
hv_tb_us_002_006_m = hv_tb_us_002_006_m.tail(50)

list_pc=hv_tb_us_002_006_m.columns.tolist()
print(hv_tb_us_002_006_m.tail(5))
x = hv_tb_us_002_006_m[list_pc[1]]
y = hv_tb_us_002_006_m[list_pc[0]]
t = hv_tb_us_002_006_m['year']
y_label = list_pc[0]
x_label = list_pc[1]
print(len(x))
print(len(y))


title_r="PHILLIPS CURVE WAGE VS UNEMPLOYMENT"
df1=hv_tb_us_002_006_m.copy()
df1.index= df1.index.date

#df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[list_pc[1]],
            g1[list_pc[0]], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1[list_pc[1]],
         g1[list_pc[0]], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1[list_pc[1]].iloc[line], 
         g1[list_pc[0]].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_002_006_m_g_002.jpg", bbox_inches='tight')
plt.savefig("hv_tb_usa_002_006_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()



### 001_cpi  <a id="title_page"></a>

country_database = "USECON"
us_m_tickers = ['PCUY', 'YPCUSLFE', 'YPCUFO', 'YPCUFH', 'YPCUFC', 'YPCUFM',
                'YPCUFD', 'YPCUFF', 'YPCUFONB', 'YPCUFHO', 'YPCUFA', 'YPCUSE',
                'YPCUSEC', 'UYHFHOF', 'YPCUTPM', 'YPCUTPMG', 'YPCUHFG', 'UYHFGE', 
                'UYHFGU', 'YPCUSCFE', 'YPCUA', 'YPCUTPV', 'YPCUTPU', 'YPCUMC', 'YPCUAB',
                'YPCUOT', 'YPCUSSLE', 'YPCUHS', 'YPCUHSRR', 'YPCUHSHA', 'YPCUMS', 'UYMSPP', 
                'UYMSHS', 'YPCUCST', 'YPCUTPR', 'UYTSI', 'UYTUA']
#uymssp
hv_tb_usa_003_001_m = Haver.data(us_m_tickers, country_database, dates=True)
print(hv_tb_usa_003_001_m)

hv_tb_usa_003_001_m.rename(columns={"pcuy": "CPI-U: All Items SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuslfe": "CPI-U: Core SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufo": "CPI-U: Food SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufh": "CPI-U: Food at Home SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufc": "CPI-U: Cereals and Bakery Products SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufm": "CPI-U: Meats, Poultry, Fish, and Eggs SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufd": "CPI-U: Dairy SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuff": "CPI-U: Fruits Vegetables SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufonb":"CPI-U: Nonalcoholic Beverages SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufho": "CPI-U: Other Food at Home SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcufa": "CPI-U: Food Away from Home SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuse": "CPI-U: Energy SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcusec": "CPI-U: Energy Commodities SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uyhfhof": "CPI-U: Fuel Oil SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcutpm": "CPI-U: Motor Fuel SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcutpmg": "CPI-U: Gasoline SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuhfg":"CPI-U: Energy Services SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uyhfge": "CPI-U: Electricity SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uyhfgu":"CPI-U: Gas Service SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuscfe": "CPI-U: Commodities Less Food and Energy Commodities SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcua": "CPI-U: Apparel SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcutpv": "CPI-U: New Vehicles SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcutpu": "CPI-U: Used Cars and Trucks SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcumc": "CPI-U: Medical Care Commodities SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuab": "CPI-U: Alcoholic Beverages SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuot": "CPI-U: Tobacco and Smoking Products SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcussle": "CPI-U: Services Less Energy Services SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuhs": "CPI-U: Shelter SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuhsrr": "CPI-U: Rent of Primary Residence SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcuhsha": "CPI-U: Owners Equivalent Rent of Residences SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcums": "CPI-U: Medical Care Services SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uymspp": "CPI-U: Physicians Services SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uymshs": "CPI-U: Hospital Services SA Y/Y"}, inplace=True)

hv_tb_usa_003_001_m.rename(columns={"ypcucst":"CPI-U: Transportation Services SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"ypcutpr": "CPI-U: Motor Vehicle Maintenance and Repair SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uytsi": "CPI-U: Motor Vehicle Insurance SA Y/Y"}, inplace=True)
hv_tb_usa_003_001_m.rename(columns={"uytua": "CPI-U: Airline Fare SA Y/Y"}, inplace=True)

hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Energy SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Energy Commodities SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Fuel Oil SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Motor Fuel SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Gasoline SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Energy Services SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Electricity SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Gas Service SA Y/Y', axis=1)
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.drop('CPI-U: Commodities Less Food and Energy Commodities SA Y/Y', axis=1)

#hv_tb_usa_003_001_m_g_001 = hv_tb_usa_003_001_m.copy()
#hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.tail(24)
#hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.transpose()
#hv_tb_usa_003_001_m.index.names = ['Variable']#
#hv_tb_usa_003_001_m["Variable_"] = hv_tb_usa_003_001_m.index
# dashboard.to_clipboard()


hv_tb_usa_003_001_m_g = hv_tb_usa_003_001_m.copy()
hv_tb_usa_003_001_m_g_001 = hv_tb_usa_003_001_m.copy()

hv_tb_usa_003_001_m.index=hv_tb_usa_003_001_m.index.date
hv_tb_usa_003_001_m = hv_tb_usa_003_001_m.tail(horizon_tb)
hv_tb_usa_003_001_t1=hv_tb_usa_003_001_m.tail(horizon_tb)

hv_tb_usa_003_001_m_t = hv_tb_usa_003_001_m.transpose()
hv_tb_usa_003_001_m_t.index.names = ['Variable']

hv_tb_usa_003_001_t1_t = hv_tb_usa_003_001_t1.transpose()
hv_tb_usa_003_001_t1_t.index.names = ['Variable']


### 001_cpi table <a id="title_page"></a>


############################################################
######Table 1

#####here*******
title_table="usa_cpi_table"
df =hv_tb_usa_003_001_t1.copy()
df_transposed = hv_tb_usa_003_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_003_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_003_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_003_001_m_t_002.png')


### 001_cpi  graphs <a id="title_page"></a>


# GRAPHS

#GRAPHS

#"CPI-U: ALL Items SA Y/Y",
#"CPI-U: Core SA Y/Y",

title_r0="USA"
label0="CPI-U: All Items SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line',ax=ax, y=[label0], color="darkblue", 
        linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle="-",marker="s", markersize=s2)
#
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center',
         rotation=30, transform=plt.gca().transAxes)

plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c

label="CPI-U: Core SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=[label], color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle-'-',#marker's', markersize=s2)#
plt.axhline(0, color="black", lw=1, linestyle ="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', 
         rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

labels="CPI-U: Food SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label0], color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle-'-',#marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_003.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

label0="CPI-U: Apparel SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label0], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',
#plt.axhline(0, color='black', lw=1, linestyle'dashed', alpha=0.75)marker='s', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

label10="CPI-U: New Vehicles SA Y/Y"
title_r=str(title_r0)+str(label10)
y_label="Index %"
x_label=title_r
list_c=[str(label10)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line',ax=ax,y=[label10], color="darkblue", linewidth= l1, 
        linestyle='-',        marker= 'D',markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle='-',marker='s', markersize=s2)#
plt.axhline (6, color="black", lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size= parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_005.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del df1
del list_c
del fig
del ax
del ax2

label10="CPI-U: Used Cars and Trucks SA Y/Y"
title_r=str(title_r0)+str(label10)
y_label="Index %"
x_label=title_r
list_c=[str(label10)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label10], color="darkblue", linewidth= l1, linestyle='-',
                                                        marker='D',markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth=11, linestyle-'-',
#                                                       marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_006.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

label10="CPI-U: Services Less Energy Services SA Y/Y"
title_r=str(title_r0)+str(label10)
y_label="Index %"
x_label=title_r
list_c=[str(label10)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=[label10], color="darkblue",
        linewidth=l1, linestyle='-', marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_007.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

label0="CPI-U: Shelter SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label0], color="darkblue", linewidth= 11, linestyle='-',
        marker='s', markersize=s2)
#g1.plot(kind='Line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth= 11, linestyle="-",
#        marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_008.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2

label0="CPI-U: Rent of Primary Residence SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=[label0], color="darkblue", linewidth= l1, linestyle='-', marker='s', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Nan Revolving Credit Outstanding Change SA"], color="darkred", linewidth= L1, linestyle='-',    marker='D',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray",
         alpha=0.5, ha='center', va='center', rotation=30, 
         transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_009.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

label0="CPI-U: Medical Care Services SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label0], color="darkblue", linewidth=l1, linestyle='-',
                                                         marker='D',markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',
plt.axhline(0, color='black', lw=1,linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_010.png", bbox_inches="tight")

plt.close()
plt.close('all')

plt.clf()
plt.cla()

del g1
del df1

del list_c
del fig

del ax
del ax2

label0 = "CPI-U: Transportation Services SA Y/Y"
title_r = str(title_r0) + str(label0)
y_label = "Index %"
x_label = title_r
list_c = [str(label0)]
df1 = hv_tb_usa_003_001_m_g_001[list_c]
df1 = df1.tail(48)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=[label0], color="darkblue",
        linewidth=l1, linestyle='-', marker='D', markersize=s2)
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray",
         alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_011.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

label0="CPI-U: Airline Fare SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_001_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label0], color="darkblue", linewidth= 11, linestyle='-',marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',
#marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')

plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_001_m_g_012.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

del fig
del ax
del ax2

### 001_cpi energy  <a id="title_page"></a>



us_m_tickers = ['YPCUSE', 'YPCUSEC', 'UYHFHOF', 
                'YPCUTPM', 'YPCUTPMG', 'YPCUHFG', 'UYHFGE', 'UYHFGU', 'YPCUSCFE']
hv_tb_usa_003_0011_m = Haver.data(us_m_tickers, country_database, dates=True)
hv_tb_usa_003_0011_m.rename(columns={"ypcuse": "CPI-U: Energy SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"ypcusec": "CPI-U: Energy Commodities SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"uyhfhof": "CPI-U: Fuel Oil SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"ypcutpm": "CPI-U: Motor Fuel SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"ypcutpmg": "CPI-U: Gasoline SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"ypcuhfg": "CPI-U: Energy Services SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"uyhfge": "CPI-U: Electricity SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"uyhfgu": "CPI-U: Gas Service SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m.rename(columns={"ypcuscfe": "CPI-U: Commodities Less Food and Energy Commodities SA Y/Y"}, inplace=True)
hv_tb_usa_003_0011_m_g_001 = hv_tb_usa_003_0011_m.copy()
hv_tb_usa_003_0011_m = hv_tb_usa_003_0011_m.tail(24)
hv_tb_usa_003_0011_m = hv_tb_usa_003_0011_m.transpose()
hv_tb_usa_003_0011_m.index.names = ['Variable']
hv_tb_usa_003_0011_m["Variable_"] = hv_tb_usa_003_0011_m.index
# dashboard.to_clipboard()

title_r0="USA"
label0="CPI-U: Energy SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_0011_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=[label0], color="darkblue",
        linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle'-',
#marker's", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center',va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_0011_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

del list_c
del fig

del ax
del ax2

label10="CPI-U: Energy Commodities SA Y/Y"
title_r=str(title_r0)+str(label10)
y_label="Index %"
x_label=title_r
list_c=[str(label10)]
df1=hv_tb_usa_003_0011_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label10], color="darkblue", linewidth= l1, linestyle="-",
        marker="D", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-",markers", markersize=s2)
#
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_0011_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

label10="CPI-U: Fuel Oil SA Y/Y"
title_r=str(title_r0)+str(label10)
y_label="Index %"
x_label=title_r
list_c=[str(label10)]
df1=hv_tb_usa_003_0011_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind="line", ax=ax,y=[label10], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-",marker='s', markersize=s2)
#
plt.axhline(0, color='black', lw=1,linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_0011_m_g_003.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

label0="CPI-U: Gasoline SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_0011_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize= (parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=[label0], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',marker='s', markersize=s2)
#
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_0011_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

del list_c
del fig

del ax
del ax2

label0="CPI-U: Energy Services SA Y/Y"
title_r=str(title_r0)+str(label0)
y_label="Index %"
x_label=title_r
list_c=[str(label0)]
df1=hv_tb_usa_003_0011_m_g_001[list_c]
df1=df1.tail(48)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=[label0], color="darkblue", 
        linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)

plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_003_0011_m_g_005.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2





### 001_pce yy  <a id="title_page"></a>

########### year
us_m_tickers = ['jcbm', 'jctgbm', 'jcdbm', 'jcnbm', 'jcsbm', 'jcxegm', 'jcxfebm', 'jcnfom', 'jcebm', 'jcmtm']
hv_tb_usa_004_001_m = Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_004_001_m)
#print(hv_tb_usa_004_001_m.columns)

for x in range(len(us_m_tickers)):
    variable = str(us_m_tickers[x])
    hv_tb_usa_004_001_m[variable] = hv_tb_usa_004_001_m[variable].pct_change(12).multiply(100).round(3)
    #print(hv_tb_usa_004_001_m[variable])

hv_tb_usa_004_001_m.rename(columns={"jcbm": "PCE Index SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jctgbm": "PCE Goods SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcdbm": "PCE Durable Goods SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcnbm": "PCE NonDurable Goods SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcsbm": "PCE Services SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcxegm": "PCE excl Goods Services SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcxfebm": "PCE Core SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcnfom": "PCE Food SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcebm": "PCE Energy Goods Services SA Y/Y"}, inplace=True)
hv_tb_usa_004_001_m.rename(columns={"jcmtm": "PCE Market Based SA Y/Y"}, inplace=True)
#df1 = hv_tb_usa_004_001_m_g_001 = hv_tb_usa_004_001_m
#hv_tb_usa_004_001_m = hv_tb_usa_004_001_m.tail(24)
#hv_tb_usa_004_001_m = hv_tb_usa_004_001_m.transpose()
##hv_tb_usa_004_001_m.index.names = ['Variable']
#hv_tb_usa_004_001_m["Variable_"] = hv_tb_usa_004_001_m.index
# dashboard.to_clipboard()
#print(hv_tb_usa_004_001_m)
# dashboard.to_clipboard()



hv_tb_usa_004_001_m_g = hv_tb_usa_004_001_m.copy()
hv_tb_usa_004_001_m_g_001 = hv_tb_usa_004_001_m.copy()

hv_tb_usa_004_001_m.index=hv_tb_usa_004_001_m.index.date
hv_tb_usa_004_001_m = hv_tb_usa_004_001_m.tail(horizon_tb)
hv_tb_usa_004_001_t1=hv_tb_usa_004_001_m.tail(horizon_tb)

hv_tb_usa_004_001_m_t = hv_tb_usa_004_001_m.transpose()
hv_tb_usa_004_001_m_t.index.names = ['Variable']

hv_tb_usa_004_001_t1_t = hv_tb_usa_004_001_t1.transpose()
hv_tb_usa_004_001_t1_t.index.names = ['Variable']

### 001_pce  yy table  <a id="title_page"></a>


############################################################
######Table 1

#####here*******
title_table="usa_pce_table"
df =hv_tb_usa_004_001_t1.copy()
df_transposed = hv_tb_usa_004_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>

plt.savefig("hv_tb_usa_004_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_004_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_004_001_m_t_002.png')


### 001_pce yy graph  <a id="title_page"></a>

print("step2")
title_r="PCE SA Y/Y"
y_label="Index %"

x_label=title_r
list_c=["PCE Index SA Y/Y",
         "PCE Goods SA Y/Y",
         "PCE Services SA Y/Y",
         "PCE Core SA Y/Y"]

df1=hv_tb_usa_004_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, 
                                parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["PCE Index SA Y/Y"], color="darkgreen", 
        linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["PCE Goods SA Y/Y"], color="darkblue", 
        linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Services SA Y/Y"], color="darkred",
        linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["PCE Core SA Y/Y"], color="black", 
        linewidth=l1, linestyle='',
        marker='D', markersize=s2)
#pit.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r = "PCE SA Y/Y"
y_label = "Index %"
x_label = title_r
list_c = [
    "PCE Index SA Y/Y",
    "PCE Goods SA Y/Y",
    "PCE Services SA Y/Y",
    "PCE Core SA Y/Y"]
df1 = hv_tb_usa_004_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Index SA Y/Y"], color="darkgreen", 
        linewidth=l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Goods SA Y/Y"], color="darkblue", 
        linewidth=l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Services SA Y/Y"], color="darkred", 
        linewidth=l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Core SA Y/Y"], color="black", 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_001_m_g_001Z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



title_r="PCE Core SA Y/Y"
y_label="Index %"
x_label=title_r
list_c=["PCE Core SA Y/Y"]
df1=hv_tb_usa_004_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["PCE Core SA Y/Y"], color="black", 
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
for x,y in zip(g1.index,g1 [title_r]):  
    label="{:.1f}".format(y)             
    plt.annotate(label, # this is the text
                 (x,y), #these are the coordinates to position the Label.                            
                 textcoords="offset points", # how to position the text
                 xytext=(0,18), # distance from text to points (x,y)
                 ha="center")

#pit.axhline(0, color="black", Lw=1, ha='center')"dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del list_c
del fig
del ax
del ax2


title_r="PCE Core SA Y/Y"
y_label="Index %"
x_label=title_r
list_c=["PCE Core SA Y/Y"]
df1=hv_tb_usa_004_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind="line", ax=ax,y=["PCE Core SA Y/Y"], color="black",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
for x,y in zip(g1.index,g1 [title_r]):
    label = "{:.1f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the Label
                 textcoords="offset points", # how to position the text
                 xytext=(0,18), # distance from text to points (x,y)
                 ha='center')
#plt.axhline (8, color='black', Lw=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
                                                           ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_001_m_g_002z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_pce mm  <a id="title_page"></a>

#monthly pce
us_m_tickers = ['jcbm', 'jctgbm', 'jcdbm', 'jcnbm', 'jcsbm', 'jcxegm', 'jcxfebm', 'jcnfom', 'jcebm', 'jcmtm']
hv_tb_usa_004_003_m=Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_004_003_m)
print(hv_tb_usa_004_003_m.columns)
for x in range(len(us_m_tickers)):
    print(x)
    variable=str(us_m_tickers[x])
    print(variable)
    hv_tb_usa_004_003_m[variable] = hv_tb_usa_004_003_m[variable].pct_change(1).multiply(100).round(3)
    print(hv_tb_usa_004_003_m[variable])

hv_tb_usa_004_003_m.rename(columns={"jcbm": "PCE Index SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jctgbm": "PCE Goods SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcdbm": "PCE Durable Goods SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcnbm": "PCE NonDurable Goods SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcsbm": "PCE Services SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcxegm": "PCE excl Goods & Services SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcxfebm": "PCE Core SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcnfom": "PCE Food SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcebm": "PCE Energy Goods Services SA M/M"}, inplace=True)
hv_tb_usa_004_003_m.rename(columns={"jcmtm": "PCE Market Based SA M/M"}, inplace=True)
#df1=hv_tb_usa_004_003_m_g_001=hv_tb_usa_004_003_m.copy()
#hv_tb_usa_004_003_m=hv_tb_usa_004_003_m.tail(24)
#hv_tb_usa_004_003_m=hv_tb_usa_004_003_m.transpose()
#hv_tb_usa_004_003_m.index.names = ['Variable']
#hv_tb_usa_004_003_m["Variable_"]=hv_tb_usa_004_003_m.index
#dashboard.to_clipboard()
#print(hv_tb_usa_004_003_m)
#print(hv_tb_usa_004_003_m)
#print("step2")


hv_tb_usa_004_003_m_g = hv_tb_usa_004_003_m.copy()
hv_tb_usa_004_003_m_g_001 = hv_tb_usa_004_003_m.copy()

hv_tb_usa_004_003_m.index=hv_tb_usa_004_003_m.index.date
hv_tb_usa_004_003_m = hv_tb_usa_004_003_m.tail(horizon_tb)
hv_tb_usa_004_003_t1=hv_tb_usa_004_003_m.tail(horizon_tb)

hv_tb_usa_004_003_m_t = hv_tb_usa_004_003_m.transpose()
hv_tb_usa_004_003_m_t.index.names = ['Variable']

hv_tb_usa_004_003_t1_t = hv_tb_usa_004_003_t1.transpose()
hv_tb_usa_004_003_t1_t.index.names = ['Variable']

### 001_pce mm  table <a id="title_page"></a>


############################################################
######Table 1

#####here*******
title_table="usa_pce_mm_table"
df =hv_tb_usa_004_003_t1.copy()
df_transposed = hv_tb_usa_004_003_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_004_003_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_004_003_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_004_003_m_t_002.png')


### 001_pce mm  graph <a id="title_page"></a>

title_r = "PCE SA M/M"
y_label = "Index %"
x_label = title_r
list_c = [
    "PCE Index SA M/M",
    "PCE Goods SA M/M",
    "PCE Services SA M/M",
    "PCE Core SA M/M"]
df1 = hv_tb_usa_004_003_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Index SA M/M"], color="darkgreen", 
        linewidth=l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Goods SA M/M"], color="darkblue", 
        linewidth=l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Services SA M/M"], color="darkred", 
        linewidth=l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Core SA M/M"], color="black", 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "PCE SA M/M"
y_label = "Index %"
x_label = title_r
list_c = ["PCE Index SA M/M",
          "PCE Goods SA M/M",
          "PCE Services SA M/M",
          "PCE Core SA M/M"]
df1 = hv_tb_usa_004_003_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Index SA M/M"], color="darkgreen", 
        linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Goods SA M/M"], color="darkblue", 
        linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Services SA M/M"], color="darkred",
        linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Core SA M/M"], color="black",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_003_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="PCE Core SA M/M"
y_label="Index %"
x_label=title_r
list_c=["PCE Core SA M/M"]
df1=hv_tb_usa_004_003_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Core SA M/M"], color="black",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
for x,y in zip(g1.index,g1 [title_r]):
    label="{:.1f}".format(y) 
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the Label
                 textcoords="offset points", # how to position the text
                 xytext=(0,18), # distance from text to points (x,y)
                 ha='center')
plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_003_m_g_002.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax

title_r="PCE Core SA M/M"
y_label="Index %"
x_label=title_r
list_c=["PCE Core SA M/M"]
df1=hv_tb_usa_004_003_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Core SA M/M"], 
        color="black", linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
for x,y in zip(g1.index,g1 [title_r]):
    label="{:.1f}".format(y) 
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the Label
                 textcoords="offset points", # how to position the text
                 xytext=(0,18), # distance from text to points (x,y)
                 ha='center')
plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_003_m_g_002z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax

### 001_inflation fed <a id="title_page"></a>

us_m_tickers = ['ph4', 'ph49116', 'pcuy', 'ypcuslfe', 'jcbm', 'jcxfebm', 'jcsxehm',
                'clevfedy', 'clevcpiy', 'pcedmcy', 'pcespcy', 'pcembcy', 'cinf1', 
                'cinf5', 'clevpcey', 'pce12', 'pcesfc', 'pcesfa', 'uigfd', 'uigpo',
                'acpisy', 'acpiscy', 'acpissy', 'acpiscsy']
hv_tb_usa_004_005_m = Haver.data(us_m_tickers, country_database, dates=True)
print(hv_tb_usa_004_005_m)
us_m_tickers = ['jcbm', 'jcxfebm', 'jcsxehm']
#print(hv_tb_usa_004_005_m)
#print(hv_tb_usa_004_005_m.columns)
for x in range(len(us_m_tickers)):
    #print(x)
    variable = str(us_m_tickers[x])
    #print(variable)
    hv_tb_usa_004_005_m[variable] = hv_tb_usa_004_005_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
    #print(hv_tb_usa_004_005_m[variable])

us_m_tickers = ['clevfedy', 'clevcpiy', 'clevpcey']
for x in range(len(us_m_tickers)):
    #print(x)
    variable = str(us_m_tickers[x])
    #print(variable)
    hv_tb_usa_004_005_m[variable] = hv_tb_usa_004_005_m[variable].round(3)
    #print(hv_tb_usa_004_005_m[variable])

hv_tb_usa_004_005_m.rename(columns={"ph4": "PPI Final demand NSA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"ph49116": "PPI Core NSA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pcuy": "Headline Inflation SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"ypcuslfe": "Core Inflation SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"jcbm": "PCE Headline SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"jcxfebm": "PCE Core SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"jcsxehm": "PCE Core Services ex h SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"clevfedy": "FRB Clev CPI Weigthed Median SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"clevcpiy": "FRB Clev CPI Trimmed Mean SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pcedmcy": "FRB SF PCE Core Demand driven SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pcespcy": "FRB SF PCE Core Supply driven SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pcembcy": "FRB SF PCE Core Ambiguous driven SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"cinf1": "Michigan Inflation expectations ly YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"cinf5": "Michigan Inflation expectations 5y YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"clevpcey": "FRB Clev PCE Median SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pce12": "FRB Dallas PCE Trimmed Mean SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pcesfc": "FRB SF PCE Core Cyclical SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"pcesfa": "FRB SF PCE Core Acyclical SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"uigfd": "FRB NY Underlying Inflation gauge fd SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"uigpo": "FRB NY Underlying Inflation gauge pd SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"acpisy": "FRB Atlanta CPI Sticky SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"acpiscy": "FRB Atlanta CPI Core Sticky SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"acpissy": "FRB Atlanta CPI Sticky excl h SA YY"}, inplace=True)
hv_tb_usa_004_005_m.rename(columns={"acpiscsy": "FRB Atlanta CPI Core Sticky excl h SA YY"}, inplace=True)
# hv_tb_usa_004_005_m.rename(columns={"acpify": "FRB Atlanta CPI Flexible SA YY"}, inplace=True)
# hv_tb_usa_004_005_m.rename(columns={"acpifcy": "FRB Atlanta CPI Core Flexible SA YY"}, inplace=True)
#hv_tb_usa_004_005_m_g_001 = hv_tb_usa_004_005_m.copy()
#hv_tb_usa_004_005_m = hv_tb_usa_004_005_m.tail(24)
#hv_tb_usa_004_005_m = hv_tb_usa_004_005_m.transpose()
#hv_tb_usa_004_005_m.index.names = ['Variable']
#hv_tb_usa_004_005_m["Variable_"] = hv_tb_usa_004_005_m.index


hv_tb_usa_004_005_m_g = hv_tb_usa_004_005_m.copy()
hv_tb_usa_004_005_m_g_001 = hv_tb_usa_004_005_m.copy()

hv_tb_usa_004_005_m.index=hv_tb_usa_004_005_m.index.date
hv_tb_usa_004_005_m = hv_tb_usa_004_005_m.tail(horizon_tb)
hv_tb_usa_004_005_t1=hv_tb_usa_004_005_m.tail(horizon_tb)

hv_tb_usa_004_005_m_t = hv_tb_usa_004_005_m.transpose()
hv_tb_usa_004_005_m_t.index.names = ['Variable']

hv_tb_usa_004_005_t1_t = hv_tb_usa_004_005_t1.transpose()
hv_tb_usa_004_005_t1_t.index.names = ['Variable']





### 001_inflation fed  graph <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_fed_inflation_table"
df =hv_tb_usa_004_005_t1.copy()
df_transposed = hv_tb_usa_004_005_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_004_005_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_004_005_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_004_005_m_t_002.png')


### 001_inflation fed  graph <a id="title_page"></a>

print("step2")
title_r = "PCE Core YY"
y_label = "Index %"
x_label = title_r
list_c = ["PCE Headline SA YY",
          "PCE Core SA YY",
          "PCE Core Services ex h SA YY",
          "FRB Clev PCE Median SA YY",
          "FRB Dallas PCE Trimmed Mean SA YY"]
df1 = hv_tb_usa_004_005_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind="line", ax=ax, y=["PCE Headline SA YY"], color="black", 
        linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind="line", ax=ax, y=["PCE Core SA YY"], color="darkblue",
        linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["PCE Core Services ex h SA YY"], color="darkred",
        linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["FRB Clev PCE Median SA YY"], color="darkgreen", 
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind="line", ax=ax, y=["FRB Dallas PCE Trimmed Mean SA YY"], color="brown",
        linewidth=l1, linestyle='-',
        marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "PCE Core YY"
y_label = "Index %"
x_label = title_r
list_c = [
    "PCE Headline SA YY",
    "PCE Core SA YY",
    "PCE Core Services ex h SA YY",
    "FRB Clev PCE Median SA YY",
    "FRB Dallas PCE Trimmed Mean SA YY"]
df1 = hv_tb_usa_004_005_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Headline SA YY"], color="black",
        linewidth=l1, linestyle='-', marker='', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Core SA YY"], color="darkblue", 
        linewidth=l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["PCE Core Services ex h SA YY"], color="darkred", 
        linewidth=l1, linestyle='-', marker='', markersize=s2)
g1.plot(kind='line', ax=ax, y=["FRB Clev PCE Median SA YY"], color="darkgreen", 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["FRB Dallas PCE Trimmed Mean SA YY"], color="brown",
        linewidth=l1, linestyle='-', marker='<', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", 
         alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

title_r="PCE Core YY"
y_label="Index %"
x_label=title_r
list_c=["PCE Core SA YY",
         "FRB SF PCE Core Demand driven SA YY",
         "FRB SF PCE Core Supply driven SA YY",
         "FRB SF PCE Core Ambiguous driven SA YY"]

df1=hv_tb_usa_004_005_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["PCE Core SA YY"], color="black", linewidth= 11, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["FRB SF PCE Core Demand driven SA YY"],
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Supply driven SA YY"], 
        color="darkred", linewidth= l1, linestyle="-",
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Ambiguous driven SA YY"],
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="PCE Core YY"
y_label="Index %"

x_label=title_r
list_c=["PCE Core SA YY",
        "FRB SF PCE Core Demand driven SA YY",
        "FRB SF PCE Core Supply driven SA YY",
        "FRB SF PCE Core Ambiguous driven SA YY"]
df1=hv_tb_usa_004_005_m_g_001[list_c]                
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["PCE Core SA YY"], 
        color="black", linewidth= l1, linestyle='',
        marker ='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Demand driven SA YY"], 
        color="darkblue", linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Supply driven SA YY"], 
        color="darkred", linewidth= l1, linestyle="-",
        marker=">",markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Ambiguous driven SA YY"],
        color="darkgreen", linewidth= l1, linestyle="-",
        marker='o',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del df1
del list_c
del fig
del ax
del ax2


title_r="PCE Core YY"
y_label="Index %"
x_label=title_r
list_c=["PCE Core SA YY",
        "FRB SF PCE Core Cyclical SA YY",
        "FRB SF PCE Core Acyclical SA YY"]
df1=hv_tb_usa_004_005_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Core SA YY"], color="black",
        linewidth= l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["FRB SF PCE Core Cyclical SA YY"],
        color="darkblue", linewidth= l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["FRB SF PCE Core Acyclical SA YY"], 
        color="darkred", linewidth= l1, linestyle='-', marker='s', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["FRB SF Ambiguous driven PCE Core SA YY"], color="black", linewidth= 11, linestyle='-', marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", 
         alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_003.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r="PCE Core YY"
y_label="Index %"

x_label=title_r
list_c=["PCE Core SA YY",
        "FRB SF PCE Core Cyclical SA YY",
        "FRB SF PCE Core Acyclical SA YY"]
df1=hv_tb_usa_004_005_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["PCE Core SA YY"], 
        color="black", linewidth= l1, linestyle='-',
        marker= 'P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Cyclical SA YY"],
        color="darkblue", linewidth= l1, linestyle='-',
        marker ='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB SF PCE Core Acyclical SA YY"], 
        color="darkred", linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
#g1.plot(kind='Line', ax-ax,y=["FRB SF Ambiguous driven PCE Core SA YY"], color="black", Linewidth= 11, Linestyle-'-',marker="o", markersize=s2)
#
plt.axhline(0, color="black", lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str (owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_003z.png", bbox_inches='tight')
pit.close()
pit.close('all')
pit.clf()
plt.cla()

del df1
del list_c
del fig
del ax
del ax2

title_r="PCE Core YY"
y_label="Index %"
x_label=title_r
list_c=["Core Inflation SA YY",
"FRB Atlanta CPI Core Sticky SA YY",
"FRB Atlanta CPI Core Sticky excl h SA YY"]
df1=hv_tb_usa_004_005_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["Core Inflation SA YY"], 
        color="black", linewidth= l1, linestyle='-',marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB Atlanta CPI Core Sticky SA YY"], 
        color="darkblue", linewidth= l1, linestyle='-',marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB Atlanta CPI Core Sticky excl h SA YY"], 
        color="darkred", linewidth= l1, linestyle="-",marker='D', markersize=s2)
#g1.plot(kind='line', ax=ах, у=["FRB Atlanta CPI Core Flexible SA YY"], color="darkgreen", Linewidth= L1, Linestyle='
plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r="PCE Core YY"
y_label="Index %"
x_label=title_r
list_c=["Core Inflation SA YY",
        "FRB Atlanta CPI Core Sticky SA YY",
        "FRB Atlanta CPI Core Sticky excl h SA YY"]
df1=hv_tb_usa_004_005_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["Core Inflation SA YY"],
        color="black", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax, y=["FRB Atlanta CPI Core Sticky SA YY"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FRB Atlanta CPI Core Sticky excl h SA YY"], 
        color="darkred", linewidth= l1, linestyle='-',
        marker='>',markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["FRB Atlanta CPI Core Flexible SA YY"], color="darkgreen", Linewidth= LI, Linestyle='-',
#                                                          marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_004_005_m_g_004z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2



### ----------------------------------------------------------------------------------------------------

### 001_consumer sentiment  <a id="title_page"></a>

us_m_tickers = ['ccin', 'ccipsn', 'ccien',
                'csent', 'ccond', 'cexp',]
hv_tb_usa_005_001_m = Haver.data(us_m_tickers, country_database, dates=True)
print(hv_tb_usa_005_001_m)
print(hv_tb_usa_005_001_m.columns)

#for x in range(len(us_m_tickers)):
#print(x)
#variable=str(us_m_tickers[x])
#print(variable)
#hv_tb_usa_005_001_m[variable]= hv_tb_usa_005_001_m[variable].pct_change(1).multiply(100).round(3)
#print(hv_tb_usa_005_001_m[variable])
hv_tb_usa_005_001_m.rename(columns={"ccin": "CBoard: Consumer Confidence SA"}, inplace=True)
hv_tb_usa_005_001_m.rename(columns={"ccipsn": "CBoard: Present Situation SA"}, inplace=True)
hv_tb_usa_005_001_m.rename(columns={"ccien": "CBoard: Consumer Expectations SA"}, inplace=True)
hv_tb_usa_005_001_m.rename(columns={"csent":"Michigan: Consumer Sentiment NSA"}, inplace=True)
hv_tb_usa_005_001_m.rename(columns={"ccond":"Michigan: Current Conditions NSA"}, inplace=True)
hv_tb_usa_005_001_m.rename(columns={"cexp": "Michigan: Consumer Expectations NSA"}, inplace=True)
#hv_tb_usa_005_001_m_g_001=hv_tb_usa_005_001_m.copy()
#hv_tb_usa_005_001_m=hv_tb_usa_005_001_m.tail(tail_0)
#hv_tb_usa_005_001_m = hv_tb_usa_005_001_m.transpose()
#hv_tb_usa_005_001_m.index.names = ['Variable']
#hv_tb_usa_005_001_m["Variable_"]=hv_tb_usa_005_001_m.index
#dashboard.to_clipboard()#
#print(hv_tb_usa_005_001_m)
##dashboard.to_clipboard()

hv_tb_usa_005_001_m_g = hv_tb_usa_005_001_m.copy()
hv_tb_usa_005_001_m_g_001 = hv_tb_usa_005_001_m.copy()

hv_tb_usa_005_001_m.index=hv_tb_usa_005_001_m.index.date
hv_tb_usa_005_001_m = hv_tb_usa_005_001_m.tail(horizon_tb)
hv_tb_usa_005_001_t1=hv_tb_usa_005_001_m.tail(horizon_tb)

hv_tb_usa_005_001_m_t = hv_tb_usa_005_001_m.transpose()
hv_tb_usa_005_001_m_t.index.names = ['Variable']

hv_tb_usa_005_001_t1_t = hv_tb_usa_005_001_t1.transpose()
hv_tb_usa_005_001_t1_t.index.names = ['Variable']

#print("step2")

### 001_consumer sentiment  table  <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_consumer_table"
df =hv_tb_usa_005_001_t1.copy()
df_transposed = hv_tb_usa_005_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_005_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_005_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_005_001_m_t_002.png')

### 001_consumer sentiment graph  <a id="title_page"></a>

title_r = "USA Michigan Consumer Sentiment"
y_label = "Index %"
x_label = title_r
list_c = ["Michigan: Consumer Sentiment NSA",
          "Michigan: Current Conditions NSA",
          "Michigan: Consumer Expectations NSA"]
df1=hv_tb_usa_005_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
print(g1.shape[0])
print(g1.shape[1])
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["Michigan: Consumer Sentiment NSA"], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Michigan: Current Conditions NSA"], color="darkblue", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Michigan: Consumer Expectations NSA"], color="darkred", linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "USA Michigan Consumer Sentiment"
y_label = "Index %"
x_label = title_r
list_c = ["Michigan: Consumer Sentiment NSA",
          "Michigan: Current Conditions NSA",
          "Michigan: Consumer Expectations NSA"]
df1=hv_tb_usa_005_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
print(g1.shape[0])
print(g1.shape[1])
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax, y=["Michigan: Consumer Sentiment NSA"], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Michigan: Current Conditions NSA"], color="darkblue", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Michigan: Consumer Expectations NSA"], color="darkred", linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_001_m_g_001Z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="USA CBOARD Consumer Confidence"
y_label="Index %"
x_label=title_r
list_c=["CBoard: Consumer Confidence SA",
        "CBoard: Present Situation SA",
        "CBoard: Consumer Expectations SA"]
df1=hv_tb_usa_005_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["CBoard: Consumer Confidence SA"], color="darkgreen", linewidth= 11, linestyle='-',
        marker ='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CBoard: Present Situation SA"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CBoard: Consumer Expectations SA"], color="darkred", linewidth= 11, linestyle='-',
        marker='>', markersize=s2)
#plt.axhline(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_001_mg_002.png", bbox_inches='tight')
pit.close()
pit.close('all')
pit.clf()
plt.cla()

del df1
del list_c
del fig
del ax
del ax2


title_r="USA CBOARD Consumer Confidence"
y_label="Index %"
x_label=title_r
list_c=["CBoard: Consumer Confidence SA",
"CBoard: Present Situation SA",
"CBoard: Consumer Expectations SA"]
df1=hv_tb_usa_005_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
fig.patch.set_facecolor('#f8f8f8')  # Very light gray for the entire figure
ax.set_facecolor('#f2f2f2')         # Slightly darker gray for the plotting area
g1.plot(kind='line', ax=ax,y=["CBoard: Consumer Confidence SA"], color="darkgreen", linewidth= 11, linestyle='-',
        marker ='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CBoard: Present Situation SA"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CBoard: Consumer Expectations SA"], color="darkred", linewidth= 11, linestyle='-',
        marker='>', markersize=s2)
#plt.axhline(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_001_mg_002z.png", bbox_inches='tight')
pit.close()
pit.close('all')
pit.clf()
plt.cla()

del df1
del list_c
del fig
del ax
del ax2

### 001_ism <a id="title_page"></a>

print("tickers")
us_m_tickers = ['ismc', 'napmc', 'napmni', 'napmoi', 'napmei', 'napmvdi', 'napmii', 'napmpi',
                'nmfc', 'nmfbaia', 'nmfnia', 'nmfeia', 'nmfvdi', 'nmfpia']
print("getting from api")
hv_tb_usa_005_002_m=Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_005_002_m)
#print(hv_tb_usa_005_002_m.columns)
#for x in range(len(us_m_tickers)):

#
print("renaming")
hv_tb_usa_005_002_m.rename(columns={"ismc": "ISM Composite Index SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"napmc": "ISM Mfg Composite Index SA"}, inplace=True)
hv_tb_usa_005_002_m.rename (columns={"napmni": "ISM Mfg New Orders SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"napmoi": "ISM Mfg Production SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"napmei": "ISM Mfg Employment SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"napmvdi": "ISM Mfg Deliveries SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"napmii": "ISM Mfg Inventories SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"napmpi": "ISM Mfg Prices NSA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"nmfc": "ISM Serv Composite Index SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"nmfbaia":"ISM Serv Bss Activity SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"nmfnia": "ISM Serv New Orders SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"nmfeia": "ISM Serv Employment SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"nmfvdi": "ISM Serv Deliveries SA"}, inplace=True)
hv_tb_usa_005_002_m.rename(columns={"nmfpia": "ISM Serv Prices SA"}, inplace=True)
#hv_tb_usa_005_002_m_g_001=hv_tb_usa_005_002_m.copy()
#hv_tb_usa_005_002_m=hv_tb_usa_005_002_m.tail(tail_0)
#hv_tb_usa_005_002_m = hv_tb_usa_005_002_m.transpose()
#hv_tb_usa_005_002_m.index.names = ['Variable']
#hv_tb_usa_005_002_m["Variable_"]=hv_tb_usa_005_002_m.index

hv_tb_usa_005_002_m_g = hv_tb_usa_005_002_m.copy()
hv_tb_usa_005_002_m_g_001 = hv_tb_usa_005_002_m.copy()

hv_tb_usa_005_002_m.index=hv_tb_usa_005_002_m.index.date
hv_tb_usa_005_002_m = hv_tb_usa_005_002_m.tail(horizon_tb)
hv_tb_usa_005_002_t1=hv_tb_usa_005_002_m.tail(horizon_tb)

hv_tb_usa_005_002_m_t = hv_tb_usa_005_002_m.transpose()
hv_tb_usa_005_002_m_t.index.names = ['Variable']

hv_tb_usa_005_002_t1_t = hv_tb_usa_005_002_t1.transpose()
hv_tb_usa_005_002_t1_t.index.names = ['Variable']


### 001_ism  table <a id="title_page"></a>


############################################################
######Table 1

#####here*******
title_table="usa_ism_table"
df =hv_tb_usa_005_002_t1.copy()
df_transposed = hv_tb_usa_005_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_005_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_005_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_005_002_m_t_002.png')


### 001_ism  graph <a id="title_page"></a>

#dashboard.to_clipboard()
#print(path_display)
#hv_tb_usa_005_002_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_usa_005_002_m)
print("step2")
##### Charts
title_r = "USA ISM Index"
y_label = "Index %"
x_label = title_r
list_c = ["ISM Mfg Composite Index SA", "ISM Serv Composite Index SA"]
df1 = hv_tb_usa_005_002_m_g_001[list_c]
df1 = df1.tail(tail_2)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax, y=["ISM Mfg Composite Index SA"], color="darkblue", linewidth=l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["ISM Serv Composite Index SA"], color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="USA ISM Index"
y_label="Index %"
x_label=title_r
list_c=["ISM Mfg Composite Index SA", 
        "ISM Serv Composite Index SA"]
df1=hv_tb_usa_005_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["ISM Mfg Composite Index SA"], color="darkblue", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["ISM Serv Composite Index SA"], color="darkred", linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
#plt.axhline(, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va="center", rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "USA ISM Manufacturing Index"
y_label = "Index %"
x_label = title_r
list_c = ["ISM Mfg Composite Index SA",
          "ISM Mfg Production SA",
          "ISM Mfg Employment SA",
          "ISM Mfg Prices NSA"]
df1 = hv_tb_usa_005_002_m_g_001[list_c]
df1 = df1.tail(tail_2)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["ISM Mfg Composite Index SA"], color="darkgreen", linewidth=l1, linestyle='', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["ISM Mfg Production SA"], color="darkblue", linewidth=l1, linestyle='', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["ISM Mfg Employment SA"], color="darkred", linewidth=l1, linestyle='', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["ISM Mfg Prices NSA"], color="black", linewidth=l1, linestyle='--', marker='^', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_002_m_g_002.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del ax
del ax2

title_r="USA ISM Manufacturing Index"
y_label="Index %"
x_label=title_r
list_c=["ISM Mfg Composite Index SA",
        "ISM Mfg Production SA",
        "ISM Mfg Employment SA",
        "ISM Mfg Prices NSA"]
df1=hv_tb_usa_005_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["ISM Mfg Composite Index SA"], color="darkgreen", linewidth= 11, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["ISM Mfg Production SA"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["ISM Mfg Employment SA"], color="darkred", linewidth= 11, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["ISM Mfg Prices NSA"], color="black", linewidth= 11, linestyle='-',
        marker='s', markersize=s2)
#plt.axhline(0, color="black", Lw=1, linestyle = 'dashed", alpha-0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
                                                        ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_002_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="USA ISM Service Index"
y_label="Index %"
x_label=title_r
list_c=["ISM Serv Composite Index SA",
        "ISM Serv Employment SA",
        "ISM Serv Prices SA"]
df1=hv_tb_usa_005_002_m_g_001[list_c]
df1=df1.tail(tail_2)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["ISM Serv Composite Index SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["ISM Serv Employment SA"], color="darkred", linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["ISM Serv Prices SA"], color="black",  linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_002_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2


title_r = "USA ISM Service Index"
y_label = "Index %"
x_label = title_r
list_c = ["ISM Serv Composite Index SA",
          "ISM Serv Employment SA",
          "ISM Serv Prices SA"]
df1 = hv_tb_usa_005_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["ISM Serv Composite Index SA"], color="darkgreen", linewidth=l1, linestyle='-', marker='.', markersize=s2)
g1.plot(kind="line", ax=ax, y=["ISM Serv Employment SA"], color="darkred", linewidth=l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["ISM Serv Prices SA"], color="black", linewidth=l1, linestyle='-', marker='s', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', 
         alpha=0.5, ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.text(0.5, 0.5, str(source_text), fontsize=source_text_f, color=source_text_c, alpha=source_text_a,  
         ha='center', va='center', rotation=source_text_r, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_005_002_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_consumer credit change <a id="title_page"></a>

print("tickers")
us_m_tickers = ['fot', 'for', 'fon']
print("getting from api")
hv_tb_usa_007_001_m = Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_007_001_m)
#print(hv_tb_usa_007_001_m.columns)
#for x in range(len(us_m_tickers)):
##print(x)
#                                print(variable)                                                                      variable=str(us_m_tickers[x])
#
#                               hv_th_usa_007_001_m[variable]= hv_tb_usa_007_001_m[variable].round(0)
#
#print(hv_tb_usa_007_001_m[variable])

print("renaming")
hv_tb_usa_007_001_m.rename(columns={"usecon_fot":"Consumer Credit Outstanding Change SA"}, inplace=True)
hv_tb_usa_007_001_m.rename(columns={"usecon_for": "Revolving Credit Outstanding Change SA"}, inplace=True)
hv_tb_usa_007_001_m.rename(columns={"usecon_fon": "Non Revolving Credit Outstanding Change SA"}, inplace=True)
#print(hv_tb_usa_007_001_m)
#hv_tb_usa_007_001_m_g_001=hv_tb_usa_007_001_m.copy()
#hv_tb_usa_007_001_m=hv_tb_usa_007_001_m.tail(tail_0)
#hv_tb_usa_007_001_m hv_tb_usa_007_001_m.transpose()
#hv_tb_usa_007_001_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_usa_007_001_m)
#dashboard.to_clipboard()

#print(path_display)
#hv_tb_usa_007_001_m.to_csv (path_display, index True, header=True)
#print(hv_tb_usa_007_001_m)
#print("step2")


hv_tb_usa_007_001_m_g = hv_tb_usa_007_001_m.copy()
hv_tb_usa_007_001_m_g_001 = hv_tb_usa_007_001_m.copy()

hv_tb_usa_007_001_m.index=hv_tb_usa_007_001_m.index.date
hv_tb_usa_007_001_m = hv_tb_usa_007_001_m.tail(horizon_tb)
hv_tb_usa_007_001_t1=hv_tb_usa_007_001_m.tail(horizon_tb)

hv_tb_usa_007_001_m_t = hv_tb_usa_007_001_m.transpose()
hv_tb_usa_007_001_m_t.index.names = ['Variable']

hv_tb_usa_007_001_t1_t = hv_tb_usa_007_001_t1.transpose()
hv_tb_usa_007_001_t1_t.index.names = ['Variable']


### 001_credit change  table  <a id="title_page"></a>


############################################################
######Table 1

#####here*******
title_table="usa_credit_table"
df =hv_tb_usa_007_001_t1.copy()
df_transposed = hv_tb_usa_007_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_007_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_007_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_007_001_m_t_002.png')


### 001_credit change   graph   <a id="title_page"></a>

title_r="USA Consumer Credit Change SA"
y_label="Index %"
x_label=title_r
list_c=["Revolving Credit Outstanding Change SA"]
df1=hv_tb_usa_007_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
#g1.plot(kind='Line', ax=ax, y=["Consumer Credit Outstanding Change SA"], color="darkgreen", Linewidth= 11, Linestyle='-'marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Revolving Credit Outstanding Change SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker= 'D',markersize=s2)

#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= (1, Linestyle="-",marker='s', markersize=s2)
#
#pit.axhline(0, color='black', Lw=1, Linestyle 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_007_001_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_ consumer credit outstandint g <a id="title_page"></a>

print("tickera")
us_m_tickers = ['fctr', 'fcrr','fcnr']

print("getting from api")
hv_tb_usa_007_002_m=Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_007_002_m)
#print(hv_tb_usa_007_002_m.columns)
#
#for x in range(len(us_m_tickers)):
#                               print(x)
#                               variable=str(us_m_tickers[x])
#                                print(variable)
#
#                               hv_tb_usa_007_001_m[variable]= hv_tb_usa_007_001_m[variable].diff(periods=1).round(0)
#                                print(hv_tb_usa_007_001_m[variable])

print("renaming")
hv_tb_usa_007_002_m.rename(columns={"fctr": "Consumer Credit Outstanding % SA"}, inplace=True)
hv_tb_usa_007_002_m.rename(columns={"fcrr": "Revolving Credit Outstanding % SA"}, inplace=True)
hv_tb_usa_007_002_m.rename(columns={"fcnr": "Non Revolving Credit Outstanding % SA"}, inplace=True)
#print(hv_tb_usa_007_002_m)
#hv_tb_usa_007_002_m_g_001=hv_tb_usa_007_002_m.copy()
#hv_tb_usa_007_002_m=hv_tb_usa_007_002_m.tail(tail_0)
#hv_tb_usa_007_002_m =hv_tb_usa_007_002_m.transpose()
#hv_tb_usa_007_002_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_usa_007_002_m)
#hv_tb_usa_007_002_m.to_csv (path_display, index True, header=True)
#print(hv_tb_usa_007_002_m)
#print("step2")


hv_tb_usa_007_002_m_g = hv_tb_usa_007_002_m.copy()
hv_tb_usa_007_002_m_g_001 = hv_tb_usa_007_002_m.copy()

hv_tb_usa_007_002_m.index=hv_tb_usa_007_002_m.index.date
hv_tb_usa_007_002_m = hv_tb_usa_007_002_m.tail(horizon_tb)
hv_tb_usa_007_002_t1=hv_tb_usa_007_002_m.tail(horizon_tb)

hv_tb_usa_007_002_m_t = hv_tb_usa_007_002_m.transpose()
hv_tb_usa_007_002_m_t.index.names = ['Variable']

hv_tb_usa_007_002_t1_t = hv_tb_usa_007_002_t1.transpose()
hv_tb_usa_007_002_t1_t.index.names = ['Variable']

### 001_ consumer credit outstanding table  <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_consumer_credit_outstanding"
df =hv_tb_usa_007_002_t1.copy()
df_transposed = hv_tb_usa_007_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_007_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_007_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_007_002_m_t_002.png')


### 001_ consumer credit outstanding graph <a id="title_page"></a>

title_r="USA Consumer Credit % SA"
y_label="Index %"
x_label=title_r
list_c=["Consumer Credit Outstanding % SA",
        "Revolving Credit Outstanding % SA",
        "Non Revolving Credit Outstanding % SA"]
df1=hv_tb_usa_007_002_m_g_001[list_c]
df1=df1.tail(36)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Consumer Credit Outstanding % SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind="line",ax=ax,y=["Revolving Credit Outstanding % SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker ='D',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding % SA"], color="darkred", linewidth= 11, linestyle='-',
         marker ='D',markersize=s2)
pit.axhline(0, color='black', lw=1,linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_007_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2





### ----------------------------------------------------------------------------------------------------





### 001_retail <a id="title_page"></a>

print("tickera")
us_m_tickers = ['nrs', 'nrsxm',]
print("getting from api")
hv_tb_usa_008_001_m=Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_008_001_m)
#print(hv_tb_usa_008_001_m.columns)
for x in range(len(us_m_tickers)):
     #print(x)
     variable=str(us_m_tickers[x])
     #print(variable)
     hv_tb_usa_008_001_m[variable]= hv_tb_usa_008_001_m[variable].pct_change(1).multiply(100).round(3)
     #print(hv_tb_usa_008_001_m[variable])
print("renaming")
hv_tb_usa_008_001_m.rename(columns={"nrs": "Retail Sales M/M SA"}, inplace=True)
hv_tb_usa_008_001_m.rename(columns={"nrsxm": "Retail Sales excl Autos M/M SA"}, inplace=True)
#prit(hv_tb_usa_008_001_m)
#hv_tb_usa_008_001_m_g_001=hv_tb_usa_008_001_m.copy()
#hv_tb_usa_008_001_m=hv_tb_usa_008_001_m.tail(tail_0)
#hv_tb_usa_008_001_m = hv_tb_usa_008_001_m.transpose()
#hv_tb_usa_008_001_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_usa_008_001_m)
#dashboard.to_clipboard()
#hv_tb_usa_008_001_m.to_csv (path_display, index True, header=True)
#print(hv_tb_usa_008_001_m)
#print("step2")

hv_tb_usa_008_001_m_g = hv_tb_usa_008_001_m.copy()
hv_tb_usa_008_001_m_g_001 = hv_tb_usa_008_001_m.copy()

hv_tb_usa_008_001_m.index=hv_tb_usa_008_001_m.index.date
hv_tb_usa_008_001_m = hv_tb_usa_008_001_m.tail(horizon_tb)
hv_tb_usa_008_001_t1=hv_tb_usa_008_001_m.tail(horizon_tb)

hv_tb_usa_008_001_m_t = hv_tb_usa_008_001_m.transpose()
hv_tb_usa_008_001_m_t.index.names = ['Variable']

hv_tb_usa_008_001_t1_t = hv_tb_usa_008_001_t1.transpose()
hv_tb_usa_008_001_t1_t.index.names = ['Variable']

### 001_retail   table  <a id="title_page"></a>

############################################################
######Table 1

#####here*******
title_table="usa_reatil_table"
df =hv_tb_usa_008_001_t1.copy()
df_transposed = hv_tb_usa_008_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_008_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_008_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_008_001_m_t_002.png')

### 001_retail   graph   <a id="title_page"></a>



title_r="USA Retail Sales M/M"
y_label="Index %"
x_label=title_r
list_c=["Retail Sales M/M SA", 
        "Retail Sales excl Autos M/M SA"]
df1=hv_tb_usa_008_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Retail Sales M/M SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Retail Sales excl Autos M/M SA"], color="darkblue", linewidth= l1,linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= (1, Linestyle="-",marker='s', markersize=s2)
#
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size =parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_008_001_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### retail sales seasonlailty table



##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['nrsn', 'nrs', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
#for x in range(len(uki_m_tickers)):
#    variable = str(uki_m_tickers[x])
#    hv_tb_uk_008_001_m[variable] = hv_tb_uk_008_001_m[variable].pct_change(12).multiply(100).round(3)

hv_tb_se_001_001_m.rename(columns={"nrsn": "retail_sales_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"nrs": "retail_sales_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_usa_008_002_m_g_001.png')

##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['nrsxmn', 'nrsxm', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
#for x in range(len(uki_m_tickers)):
#    variable = str(uki_m_tickers[x])
#    hv_tb_uk_008_001_m[variable] = hv_tb_uk_008_001_m[variable].pct_change(12).multiply(100).round(3)

hv_tb_se_001_001_m.rename(columns={"nrsxmn": "retail_sales_exm_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"nrsxm": "retail_sales_exm_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_usa_008_002_m_g_002.png')

### 001_ip <a id="title_page"></a>

#Industrial Production
print("tickera")

us_m_tickers = ['ip', 'ipfp', 'ip51', 'ip521', 'ip54', 'ip541', 'ip53']
print("getting from api")
hv_tb_usa_009_001_m=Haver.data(us_m_tickers, "USECON", dates=True)
print(hv_tb_usa_009_001_m)

print(hv_tb_usa_009_001_m.columns)
#for x in range(Len(us_m_tickers)):
#    print(x)
#    variable=str(us_m_tickers[x])
#    
#    print(variable)
#    hv_tb_usa_008_001_m[variable]= hv_tb_usa_008_001_m[variable].pct_change(1).multiply(100).round(3)

#                              print(hv_tb_usa_008_001_m[variable])

print("renaming")
hv_tb_usa_009_001_m.rename(columns={"ip":"Industrial Production SA"}, inplace=True)
hv_tb_usa_009_001_m.rename(columns={"ipfp": "IP Final Products SA"}, inplace=True)
hv_tb_usa_009_001_m.rename(columns={"ip51": "IP Consumers Goods SA"}, inplace=True)
hv_tb_usa_009_001_m.rename(columns={"ip521":"IP Business Equipment SA"}, inplace=True)
hv_tb_usa_009_001_m.rename(columns={"ip54": "IP Nonindustrial Supplies SA"}, inplace=True)
hv_tb_usa_009_001_m.rename(columns={"ip541": "IP Construction Supplies SA"}, inplace=True)
hv_tb_usa_009_001_m.rename(columns={"ip53": "IP Materials SA"}, inplace=True)
#print(hv_tb_usa_009_001_m)
#hv_tb_usa_009_001_m_g_001=hv_tb_usa_009_001_m
#hv_tb_usa_009_001_m=hv_tb_usa_009_001_m.tail(tail_0)
#hv_tb_usa_009_001_m = hv_tb_usa_009_001_m.transpose()
#h#v_tb_usa_009_001_m.index.names = ['Variable']
#h#v_tb_usa_009_001_m["Variable_"]=hv_tb_usa_009_001_m.index
#dashboard.to_clipboard()
#print(hv_tb_usa_009_001_m)
#print("step2")


hv_tb_usa_009_001_m_g = hv_tb_usa_009_001_m.copy()
hv_tb_usa_009_001_m_g_001 = hv_tb_usa_009_001_m.copy()

hv_tb_usa_009_001_m.index=hv_tb_usa_009_001_m.index.date
hv_tb_usa_009_001_m = hv_tb_usa_009_001_m.tail(horizon_tb)
hv_tb_usa_009_001_t1=hv_tb_usa_009_001_m.tail(horizon_tb)

hv_tb_usa_009_001_m_t = hv_tb_usa_009_001_m.transpose()
hv_tb_usa_009_001_m_t.index.names = ['Variable']

hv_tb_usa_009_001_t1_t = hv_tb_usa_009_001_t1.transpose()
hv_tb_usa_009_001_t1_t.index.names = ['Variable']

### 001_ip   table  <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_ip_table"
df =hv_tb_usa_009_001_t1.copy()
df_transposed = hv_tb_usa_009_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_009_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_009_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_009_001_m_t_002.png')




### 001_ip   graph  <a id="title_page"></a>

title_r="Industrial Production SA"
y_label="Index %"
x_label=title_r
list_c=["Industrial Production SA"]
df1=hv_tb_usa_009_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Industrial Production SA"], color="darkgreen", linewidth= 11, linestyle='-', marker='P', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Retail Sales excl Autos M/M SA"], color="darkblue", Linewidth= L1, Linestyle='-', marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-", marker='s', markersize=s2)
##plt.axhline (0, color="black', Lw=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), 
         fontsize=40, color='gray', alpha=0.5, 
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_009_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "Industrial Production SA"
y_label = "Index %"
x_label = title_r
list_c = ["Industrial Production SA"]
df1 = hv_tb_usa_009_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Industrial Production SA"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)
# g1.plot(kind="line", ax=ax, y=["Retail Sales exci Autos M/M SA"], color="darkblue", linewidth=L1, linestyle='-',
#         marker='P', markersize=s2)
# g1.plot(kind="line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=L1, linestyle="-",
#         marker='D', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_009_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



### ip seasonality table

##### COmplete seasonality analysis 
### first nsa then sa





### ----------------------------------------------------------------------------------------------------

### 001_fed regional <a id="title_page"></a>

###############################
#fed surveys
print("tickera")
us_m_tickers = ['dbacts', 'dsacts',
                'kcyci', 'kcsyn',
                'lmcia', 
                'emism', 'emgi',
                'boism', 'bocgx',
                'bnrgxs', 'rimcx']
print("getting from api")
hv_tb_usa_010_001_m=Haver.data(us_m_tickers, "SURVEYS", dates=True)
print(hv_tb_usa_010_001_m)
print(hv_tb_usa_010_001_m.columns)
print("renaming")
hv_tb_usa_010_001_m.rename(columns={"dbacts": "FED-Texas Mnfg yy sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"dsacts": "FED-Texas Serv yy sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"kcyci":"FED-Kansas Mnfg yy nsa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"kcsyn":"FED-Kansas Serv yy nsa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"lmcia": "FED-Kansas labor Imci nsa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"emism": "FED-NY Empire Mnfg adj sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"emgi": "FED-NY Empire Mnfg sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"boism": "FED-Phil Mnfg adj Current sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"bocgx": "FED-Phil Mnfg Current sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"bnrgxs": "FED-Phil Non Mnfg Region Current sa"}, inplace=True)
hv_tb_usa_010_001_m.rename(columns={"rimcx": "FED-Rich Mnfg Current sa"}, inplace=True)

hv_tb_usa_010_001_m["FED-NY Empire Mnfg adj sa"]=hv_tb_usa_010_001_m["FED-NY Empire Mnfg adj sa"]-50
hv_tb_usa_010_001_m["FED-Phil Mnfg adj Current sa"]=hv_tb_usa_010_001_m["FED-Phil Mnfg adj Current sa"]-50
hv_tb_usa_010_001_m["FED-Kansas Mnfg yy nsa"]=(hv_tb_usa_010_001_m["FED-Kansas Mnfg yy nsa"]/50)*25
hv_tb_usa_010_001_m["FED-Kansas Serv yy nsa"]=(hv_tb_usa_010_001_m["FED-Kansas Serv yy nsa"]/50)*25
#hv_tb_usa_010_001_m_g_001=hv_tb_usa_010_001_m.copy()
#hv_tb_usa_010_001_m=hv_tb_usa_010_001_m.tail(tail_0)
#hv_tb_usa_010_001_m = hv_tb_usa_010_001_m.transpose()
#hv_tb_usa_010_001_m.index.names = ['Variable']
#hv_tb_usa_010_001_m["Variable_"]=hv_tb_usa_010_001_m.index
#dashboard.to_clipboard()


hv_tb_usa_010_001_m_g = hv_tb_usa_010_001_m.copy()
hv_tb_usa_010_001_m_g_001 = hv_tb_usa_010_001_m.copy()

hv_tb_usa_010_001_m.index=hv_tb_usa_010_001_m.index.date
hv_tb_usa_010_001_m = hv_tb_usa_010_001_m.tail(horizon_tb)
hv_tb_usa_010_001_t1=hv_tb_usa_010_001_m.tail(horizon_tb)

hv_tb_usa_010_001_m_t = hv_tb_usa_010_001_m.transpose()
hv_tb_usa_010_001_m_t.index.names = ['Variable']

hv_tb_usa_010_001_t1_t = hv_tb_usa_010_001_t1.transpose()
hv_tb_usa_010_001_t1_t.index.names = ['Variable']


### 001_fed regional table <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_fed_regional_table"
df =hv_tb_usa_010_001_t1.copy()
df_transposed = hv_tb_usa_010_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_010_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_010_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_010_001_m_t_002.png')



### 001_fed regional regional <a id="title_page"></a>

title_r="USA FED SURVEYS Manufacturing"
y_label="Index %"

x_label=title_r
list_c=["FED-Texas Mnfg yy sa",
        "FED-Kansas Mnfg yy nsa",
        "FED-NY Empire Mnfg adj sa",
        "FED-Phil Mnfg adj Current sa",
        "FED-Rich Mnfg Current sa"]
df1=hv_tb_usa_010_001_m_g_001[list_c]
df1=df1.tail(36)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax, y=["FED-Texas Mnfg yy sa"], color="darkgreen", linewidth= l1, linestyle='-', marker='P', markersize=s2)
g1.plot(kind="line", ax=ax, y=["FED-Kansas Mnfg yy nsa"], color="darkblue", linewidth= l1, linestyle="-",marker='D', markersize=s2)
g1.plot(kind="line", ax=ax, y=["FED-NY Empire Mnfg adj sa"], color="darkred", linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind="line", ax=ax, y=["FED-Phil Mnfg adj Current sa"], color="black", linewidth= l1,  linestyle='-',marker='>',markersize=s2)
g1.plot(kind="line", ax=ax, y=["FED-Rich Mnfg Current sa"], color="darkorange", linewidth= l1, linestyle='-',marker='>', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_010_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="USA FED SURVEYS Services"
y_label="Index %"
x_label=title_r
list_c=["FED-Texas Serv yy sa",
        "FED-Kansas Serv yy nsa",
        "FED-Phil Non Mnfg Region Current sa"]
df1=hv_tb_usa_010_001_m_g_001[list_c]
df1=df1.tail(36)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["FED-Texas Serv yy sa"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FED-Kansas Serv yy nsa"], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FED-Phil Non Mnfg Region Current sa"], color="black", linewidth= l1, linestyle='-',
        marker='x', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_010_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

print("tickers")
us_m_tickers = ['dvnwos',
                'kcynxi',
                'emni',
                'bocnox',
                'rimnx']
print("getting from api")
hv_tb_usa_010_002_m=Haver.data(us_m_tickers, "SURVEYS", dates=True)
print(hv_tb_usa_010_002_m)
print(hv_tb_usa_010_002_m.columns)
print("renaming")
hv_tb_usa_010_002_m.rename(columns={"dvnwos": "FED-Texas Mnfg New Orders yy sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"kcynxi": "FED-Kansas Mnfg New orders yy nsa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"emni": "FED-NY Empire Mnfg New Orders sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"bocnox": "FED-Phil Mnfg New Orders sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"rimnx": "FED-Rich Mnfg Current New Orders sa"}, inplace=True)
hv_tb_usa_010_002_m["FED-NY Empire Mnfg New Orders adj sa"]=hv_tb_usa_010_002_m[ "FED-NY Empire Mnfg New Orders sa"]-50
hv_tb_usa_010_002_m["FED-Phil Mnfg New Orders adj sa"]=hv_tb_usa_010_002_m[ "FED-Phil Mnfg New Orders sa"]-50
hv_tb_usa_010_002_m["FED-Kansas Mnfg New orders adj nsa"]=(hv_tb_usa_010_002_m["FED-Kansas Mnfg New orders yy nsa"]/50)*25
hv_tb_usa_010_002_m_g_001=hv_tb_usa_010_002_m.copy()
hv_tb_usa_010_002_m=hv_tb_usa_010_002_m.tail(tail_0)
hv_tb_usa_010_002_m =hv_tb_usa_010_002_m.transpose()
hv_tb_usa_010_002_m.index.names = ['Variable']
hv_tb_usa_010_002_m["Variable_"]=hv_tb_usa_010_002_m.index




title_r="USA FED SURVEYS Manufacturing New Orders"
y_label="Index %"
x_label=title_r

list_c=["FED-Texas Mnfg New Orders yy sa",
        "FED-Kansas Mnfg New orders adj nsa",
        "FED-NY Empire Mnfg New Orders adj sa",
        "FED-Phil Mnfg New Orders adj sa",
        "FED-Rich Mnfg Current New Orders sa"]
df1=hv_tb_usa_010_002_m_g_001[list_c]
df1=df1.tail(36)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["FED-Texas Mnfg New Orders yy sa"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FED-Kansas Mnfg New orders adj nsa"], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["FED-NY Empire Mnfg New Orders adj sa"], color="darkred", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["FED-Phil Mnfg New Orders adj sa"], color="black", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=["FED-Rich Mnfg Current New Orders sa"], color="darkorange", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize= parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_010_002_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2



print("tickers")
us_m_tickers = ['dfcexps',
                'kc6cxna',
                'em6ci',
                'bofcex',
                'ri6cx']
print("getting from api")
hv_tb_usa_010_002_m=Haver.data(us_m_tickers, "SURVEYS", dates=True)
print(hv_tb_usa_010_002_m)
print(hv_tb_usa_010_002_m.columns)
print("renaming")
hv_tb_usa_010_002_m.rename(columns={"dfcexps": "FED-Texas Capex 6m sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"kc6cxna": "FED-Kansas Capex 6m sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"em6ci": "FED-NY Capex 6m sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"bofcex": "FED-Phil Capex 6m sa"}, inplace=True)
hv_tb_usa_010_002_m.rename(columns={"ri6cx": "FED-Richmond Capex 6m sa"}, inplace=True)
#hv_tb_usa_010_002_m["FED-NY Empire Mnfg New Orders adj sa"]=hv_tb_usa_010_002_m[ "FED-NY Empire Mnfg New Orders sa"]-50
#hv_tb_usa_010_002_m["FED-Phil Mnfg New Orders adj sa"]=hv_tb_usa_010_002_m[ "FED-Phil Mnfg New Orders sa"]-50
#hv_tb_usa_010_002_m["FED-Kansas Mnfg New orders adj nsa"]=(hv_tb_usa_010_002_m["FED-Kansas Mnfg New orders yy nsa"]/50)*25
hv_tb_usa_010_002_m_g_001=hv_tb_usa_010_002_m.copy()
hv_tb_usa_010_002_m=hv_tb_usa_010_002_m.tail(tail_0)
hv_tb_usa_010_002_m =hv_tb_usa_010_002_m.transpose()
hv_tb_usa_010_002_m.index.names = ['Variable']
hv_tb_usa_010_002_m["Variable_"]=hv_tb_usa_010_002_m.index


#hv_tb_usa_010_002_m.rename(columns={"dcexps": "FED-Texas Capex sa"}, inplace=True)
#hv_tb_usa_010_002_m.rename(columns={"kcycxni": "FED-Kansas Capex sa"}, inplace=True)

title_r="USA FED SURVEYS Capex 6 months"
y_label="Index %"
x_label=title_r

list_c=hv_tb_usa_010_002_m_g_001.columns.tolist()
df1=hv_tb_usa_010_002_m_g_001[list_c]
df1=df1.tail(36)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[list_c[0]], color="darkgreen", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[2]], color="darkred", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[3]], color="black", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[4]], color="darkorange", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize= parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_010_003_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2



### ----------------------------------------------------------------------------------------------------



### 001_sp monthly gdp  <a id="title_page"></a>

#MONHTHLY gdp
print("tickera")
us_m_tickers = ["mgdp"]
print("getting from api")
hv_tb_usa_011_001_m=Haver.data(us_m_tickers, "USECON", dates=True)
print(hv_tb_usa_011_001_m)
print(hv_tb_usa_011_001_m.columns)
for x in range(len(us_m_tickers)):
    variable=str(us_m_tickers [x])
    hv_tb_usa_011_001_m[variable]= hv_tb_usa_011_001_m[variable].pct_change(12).multiply(100).round(3)
print("renaming")
hv_tb_usa_011_001_m.rename(columns={"mgdp": "S&P US Monthly GDP SA"}, inplace=True)
#print(hv_tb_usa_011_001_m)
#hv_tb_usa_011_001_m_g_001=hv_tb_usa_011_001_m.copy()
##hv_tb_usa_011_001_m=hv_tb_usa_011_001_m.tail(tail_0)
#hv_tb_usa_011_001_m hv_tb_usa_011_001_m.transpose()
#hv_tb_usa_011_001_m.index.names = ['Variable']#
#hv_tb_usa_011_001_m["Variable_"]=hv_tb_usa_011_001_m.index
#dashboard.to_clipboard()



hv_tb_usa_011_001_m_g = hv_tb_usa_011_001_m.copy()
hv_tb_usa_011_001_m_g_001 = hv_tb_usa_011_001_m.copy()

hv_tb_usa_011_001_m.index=hv_tb_usa_011_001_m.index.date
hv_tb_usa_011_001_m = hv_tb_usa_011_001_m.tail(horizon_tb)
hv_tb_usa_011_001_t1=hv_tb_usa_011_001_m.tail(horizon_tb)

hv_tb_usa_011_001_m_t = hv_tb_usa_011_001_m.transpose()
hv_tb_usa_011_001_m_t.index.names = ['Variable']

hv_tb_usa_011_001_t1_t = hv_tb_usa_011_001_t1.transpose()
hv_tb_usa_011_001_t1_t.index.names = ['Variable']

### 001_sp monthly gdp table  <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_gdp_table"
df =hv_tb_usa_011_001_t1.copy()
df_transposed = hv_tb_usa_011_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_011_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_011_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_011_001_m_t_002.png')



### 001_sp monthly gdp graph <a id="title_page"></a>

title_r="S&P US Monthly GDP SA"
y_label="Index %"
x_label=title_r
list_c=["S&P US Monthly GDP SA"]
df1=hv_tb_usa_011_001_m_g_001[list_c]
df1=df1.tail(36)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["S&P US Monthly GDP SA"], color="darkgreen", 
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)

for x,y in zip(g1.index,g1[title_r]):
    label = "{:.1f}".format(y)
    #Label =f"({x}, {y})"##
    plt.annotate(label, # this is the text
                 (x,y), #these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,18), # distance from text to points (x,y)
                 ha='center')
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_011_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="S&P US Monthly GDP SA"
y_label="Index %"
x_label=title_r
list_c=["S&P US Monthly GDP SA"]
df1=hv_tb_usa_011_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["S&P US Monthly GDP SA"], color="darkgreen", 
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)

for x,y in zip(g1.index,g1[title_r]):
    label = "{:.1f}".format(y)
    #Label =f"({x}, {y})"##
    plt.annotate(label, # this is the text
                 (x,y), #these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,18), # distance from text to points (x,y)
                 ha='center')
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_011_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_ gdp  <a id="title_page"></a>

# Industrial Production
print("tickers")
us_m_tickers = ["pgdph", "pch", 
                "pctgh", "pcdh",
                "pcnh", "pcsh",
                "pih", "pfh",
                "pfnh", "pfnsh",
                "pfneh", "pfnph",
                "pfrh", "pxh", 
                "pxmh", "pxsh", 
                "pmh", "pmmh", 
                "pmsh", "pgh"]

print("getting from api")
hv_tb_usa_012_001_m = Haver.data(us_m_tickers, "USECON", dates=True)
print(hv_tb_usa_012_001_m)
print(hv_tb_usa_012_001_m.columns)

print("renaming")
hv_tb_usa_012_001_m.rename(columns={"pgdph": "Real Gross Domestic Product SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pch": "Personal Consumption Expenditure SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pctgh": "PCE Goods SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pcdh": "PCE Durable Goods SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pcnh": "PCE NonDurable Goods SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pcsh": "PCE Services SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pih": "Gross Private Domestic Investment SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pfh": "Private Fixed Investment SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pfnh": "Private Nonresidential Fixed Investment SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pfnsh": "Private Nonresidential Fixed Investment Structures SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pfneh": "Private Nonresidential Fixed Investment Equipment SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pfnph": "Private Nonresidential Fixed Investment Intellectual SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pfrh": "Private Residential Fixed Investment SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pxh": "Exports SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pxmh": "Exports Goods SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pxsh": "Exports Services SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pmh": "Imports SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pmmh": "Imports Goods SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pmsh": "Imports Services SAAR"}, inplace=True)
hv_tb_usa_012_001_m.rename(columns={"pgh": "Government Consumption Expenditure SAAR"}, inplace=True)


#hv_tb_usa_012_001_m_g_001 = hv_tb_usa_012_001_m.copy()
#hv_tb_usa_012_001_m = hv_tb_usa_012_001_m.tail(tail_0)
#hv_tb_usa_012_001_m = hv_tb_usa_012_001_m.transpose()
#hv_tb_usa_012_001_m.index.names = ['Variable']
#hv_tb_usa_012_001_m["Variable_"] = hv_tb_usa_012_001_m.index
##dashboard.to_clipboard()

#print(hv_tb_usa_012_001_m)
#dashboard.to_clipboard()


hv_tb_usa_012_001_m_g = hv_tb_usa_012_001_m.copy()
hv_tb_usa_012_001_m_g_001 = hv_tb_usa_012_001_m.copy()

hv_tb_usa_012_001_m.index=hv_tb_usa_012_001_m.index.date
hv_tb_usa_012_001_m = hv_tb_usa_012_001_m.tail(horizon_tb)
hv_tb_usa_012_001_t1=hv_tb_usa_012_001_m.tail(horizon_tb)

hv_tb_usa_012_001_m_t = hv_tb_usa_012_001_m.transpose()
hv_tb_usa_012_001_m_t.index.names = ['Variable']

hv_tb_usa_012_001_t1_t = hv_tb_usa_012_001_t1.transpose()
hv_tb_usa_012_001_t1_t.index.names = ['Variable']


### 001_ gdp  table <a id="title_page"></a>



############################################################
######Table 1

#####here*******
title_table="usa_gdp_table"
df =hv_tb_usa_012_001_t1.copy()
df_transposed = hv_tb_usa_012_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit


#### here >>>
plt.savefig("hv_tb_usa_012_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_usa_012_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_usa_012_001_m_t_002.png')




### 001_ gdp  graph <a id="title_page"></a>


print("step2")
title_r = "Real Gross Domestic Product SAAR"
y_label = "%"
x_label = title_r
list_c = [title_r]
df1 = hv_tb_usa_012_001_m_g_001[list_c]
df1 = df1.tail(tail_4)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[title_r], color="darkred", linewidth=11, linestyle='-',
        marker="D", markersize=s2)
# plt.axhline(0, color="black", Lw=1, Linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')

title_r = "Personal Consumption Expenditure SAAR"
y_label = "%"
x_label = title_r
list_c = [title_r]
df1 = hv_tb_usa_012_001_m_g_001[list_c]
df1 = df1.tail(tail_4)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[title_r], color="darkred", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="PCE Goods SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="darkred", linewidth= l1,  linestyle='-',
        marker="D", markersize=s2)
#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="PCE Services SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="darkred", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#plt.axhline(0, color='black', Lw=1, Linestyle = 'dashed", alpha-0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Gross Private Domestic Investment SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[title_r], color="darkred", linewidth=11, linestyle='-',
        marker='D', markersize=s2)
#plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_005.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Private Fixed Investment SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="darkred", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#pit.axhline(0, color='black', tw=1,Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_006.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "Private Nonresidential Fixed Investment SAAR"
y_label = "%"
x_label = title_r
list_c = [title_r]
df1 = hv_tb_usa_012_001_m_g_001[list_c]
df1 = df1.tail(tail_4)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[title_r], color="darkred", linewidth=11, linestyle='-',
        marker="D", markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_007.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Private Residential Fixed Investment SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="darkred", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
#plt.axhline(0, color='black', Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_009.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Exports SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="darkred", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=80.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
pit.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_010.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r="Exports Services SAAR"
y_label="%"
x_label=title_r
list_c=[title_r]
df1=hv_tb_usa_012_001_m_g_001[list_c]
df1=df1.tail(tail_4)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="darkred", linewidth= l1, linestyle='-',
        marker="D",markersize=s2)
#pit.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_012_001_m_g_012.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2







### ----------------------------------------------------------------------------------------------------

### 001_ heatmapc pce  <a id="title_page"></a>

print("Compelte")
####### heatmapc pce
####### heatmapc pce
####### heatmapc pce



country_database = "USECON"
horizon_00=120

us_m_tickers = ['ph4', 'ph49116', 'pcuy', 'ypcuslfe', 'jcbm', 'jcxfebm', 'jcsxehm', 'clevfedy', 'clevcpiy',
                'pcedmcy', 'pcespcy', 'pcembcy','cinf1', 'cinf5', 'clevpcey', 'pce12', 'pcesfc', 'pcesfa', 
                'uigfd', 'uigpo', 'acpisy', 'acpiscy', 'acpissy', 'acpiscsy']

hv_tb_usa_004_005_m=Haver.data(us_m_tickers, country_database, dates=True)
#print(hv_tb_usa_004_005_m)
#cinfl
us_m_tickers = ['jcbm', 'jcxfebm', 'jcsxehm']
#print(hv_tb_usa_004_005_m)
#print(hv_tb_usa_004_005_m.columns)
for x in range(len(us_m_tickers)):
    #print(x)
    variable=str(us_m_tickers [x])
    #print(variable)
    hv_tb_usa_004_005_m[variable] = hv_tb_usa_004_005_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
    #print(hv_tb_usa_004_005_m[variable])

us_m_tickers = [ "clevfedy", "clevcpiy", "clevpcey"]
for x in range(len(us_m_tickers)):
    #print(x)
    variable=str(us_m_tickers[x])
    #print(variable)
    hv_tb_usa_004_005_m[variable] = hv_tb_usa_004_005_m[variable].round(3)
    #print(hv_tb_usa_004_005_m[variable])

hv_tb_us_000_001_m=hv_tb_usa_004_005_m.copy()
hv_tb_us_000_001_m.rename(columns={"ph4": "PPI Final demand NSA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ph49116": "PPI Core NSA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcuy": "Headline Inflation SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ypcuslfe": "Core Inflation SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"jcbm": "PCE Headline SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"jcxfebm": "PCE Core SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"jcsxehm": "PCE Core Services ex h SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"clevfedy": "FRB Clev CPI Weigthed Median SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"clevcpiy": "FRB Clev CPI Trimmed Mean SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcedmcy": "FRB SF PCE Core Demand driven SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcespcy": "FRB SF PCE Core Supply driven SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcembcy": "FRB SF PCE Core Ambiguous driven SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"cinf1": "Michigan Inflation expectations ly YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"cinf5": "Michigan Inflation expectations 5y YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"clevpcey": "FRB Clev PCE Median SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pce12": "FRB Dallas PCE Trimmed Mean SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcesfc":"FRB SF PCE Core Cyclical SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcesfa":"FRB SF PCE Core Acyclical SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"uigfd": "FRB NY Underlying Inflation gauge fd SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"uigpo":"FRB NY Underlying Inflation gauge pd SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"acpisy": "FRB Atlanta CPI Sticky SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"acpiscy": "FRB Atlanta CPI Core Sticky SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"acpissy": "FRB Atlanta CPI Sticky exc1 h SA YY"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"acpiscsy": "FRB Atlanta CPI Core Sticky excl h SA YY"}, inplace=True)

#hv_tb_usa_004_005_m.rename(columns={"acpify": "FRB Atlanta CPI Flexible SA YY"), inplace=True)
#hv_tb_usa_004_005_m.rename(columns={"acpifcy": "FRB Atlanta CPI Core Flexible SA YY"), inplace=True)
hv_tb_us_000_001_m.index=hv_tb_us_000_001_m.index.date
list_c = ["Real: GDP Q0%",
          "Real: HH Spending WDA YY%",
          "Real: HH Spending Goods YY%",
         "Real: HH Spending Services YY%",
         "Real: Retail Turnover YY%",
         "Real: IP excl Const Y۷%",
         "Real: IP Mining YY%",
         "Real: IP Manufacturing YY%",
         "Real: Hours Worked YY%",
         "Real: Value Added per Hour YY%",
         "Employment: Unemployment Rate%",
         "Employment: Unemployment Rate% RM",
         "Employment: Underemployment Rate% RM",
         "Employment: Participation Rate%",
         "Employment: Employed FT K",
         "Employment: Employed PT K",
         "Employment: Wage Price YY%",
         "Employment: Wage Price Private YY%",
         "Employment: Wage Price Public YY%",
         "Employment: AWE YY%",
         "Employment: AWE Total YY%",
         "Employment: AWE Ordinary YY%",
         "Employment: Hours Worked FT YY%",
         "Employment: Hours Worked PT YY%"
         "Price: CPI All Groups NSA YY%",
         "Price: CPI Excluding Volatile NSA YY%",
         "Price: CPI Tradables NSA YY%",
         "Price: CPI Non Tradables NSA YY%",
         "Price: Monthly CPI Headline NSA YY%",
         "Price: Monthly CPI ex Vol NSA YY%",
        "Price: Monthly CPI Goods NSA YY%"
        "Price: Monthly CPI Services NSA YY%"
        "Price: Monthly CPI Tradeables NSA YY%"
        "Price: Monthly CPI nontradeables NSA YY%"
        "Cycle: Westpac Consumer Sentiment"
        "Cycle: Westpac Consumer Expectations"
        "Cycle: Westpac Current Condition Index SA"
        "Cycle: ANZ Monthly Consumer Confidence"
        "Cycle: RM Consumer Confidence"]




#hv_tb_au_000_001_m=hv_tb_au_000_001_m[list_c]
hv_tb_us_000_001_m_c=hv_tb_us_000_001_m.copy()
hv_tb_us_000_001_m_c=hv_tb_us_000_001_m_c.tail(120)
hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(60)

n_time=42
size1=26
size2=15
font_size_h=11
number_vbs=24
x_sizel=14
x2_sizel=x_sizel-4
xlabel_size=15
title_s=25
#size 1 width
#size 2 hegith

df1=hv_tb_us_000_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows =df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows): #print(x)
      locals() [str(str("vmin_")+str(x))] = hv_tb_us_000_001_m_c.iloc[:,x].min()
      locals()[str(str("vmax_")+str(x))] = hv_tb_us_000_001_m_c.iloc[:,x].max()
      #print("end Loop")

print(vmin_0)
print(vmax_0)
#data = np.random.random((10,12))
#df=pd.DataFrame (data)
red_to_blue= sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue =sns.color_palette("coolwarm")
reversed_red_to_blue=list(reversed (reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)
fig, axes= plt.subplots (number_vbs,1,  
                        figsize=(size1,size2), sharex=True)


                                 
sns.heatmap(data_r0,cmap=red_to_blue, annot =True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1,cmap=red_to_blue, annot =True, ax=axes [1], cbar=False, vmin=vmin_1, vmax=vmax_1,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2,cmap=red_to_blue, annot =True, ax=axes [2], cbar=False, vmin=vmin_2, vmax=vmax_2,fmt='g',
           annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3,cmap=red_to_blue, annot= True, ax=axes [3], cbar=False, vmin=vmin_3, vmax=vmax_3,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4,cmap=red_to_blue, annot=True, ax=axes [4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5,cmap=red_to_blue, annot=True, ax=axes [5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6,cmap=red_to_blue, annot=True, ax=axes [6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7,cmap=red_to_blue, annot=True, ax=axes [7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8,cmap=red_to_blue, annot=True, ax=axes [8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9,cmap=red_to_blue, annot=True, ax=axes [9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10,cmap=red_to_blue, annot=True, ax=axes [10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11,cmap=red_to_blue, annot=True, ax=axes [11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12,cmap=red_to_blue, annot=True, ax=axes [12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13,cmap=red_to_blue, annot=True, ax=axes [13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14,cmap=red_to_blue, annot=True, ax=axes [14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15,cmap=red_to_blue, annot=True, ax=axes [15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16,cmap=red_to_blue, annot=True, ax=axes [16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=reversed_red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=reversed_red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=reversed_red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=reversed_red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=reversed_red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=reversed_red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=reversed_red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals() [str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=98)
    n=n+1


axes[-1].tick_params(axis="x", which="both", length=0,labelrotation=45,labelsize=15, size=0)
# ... (other plot formatting)

plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('us_pce_heatmap_001.png', bbox_inches='tight', dpi=200)
plt.savefig('us_pce_heatmap_001_test.png', bbox_inches='tight', dpi=600)
plt.close()

### macro dashboard heatmap

hhi_m_tickers1 = ["mgdp", "nrsxm", "ip", "csent", "ccin", 
                  #"pmcxbaa", 
                  "napmc", "nmfc", "ffedtahe",
                  "pcuy", "ypcuslfe", "acpiscsy", "jcbm", "jcxfebm", "jcsxehm", "clevpcey", "pce12",
                  "wgto", "lp", "lr", "laxepa", "lanagrd", "laprivd", "cinf1", "cinf5",
                  "ljjtpa", "ljhtpa", "ljqtpa", "ljltpa", "licm", "lktpriva", "letpriva",
                  "vsmida", "vsmina", "fmv2", "farmb", "fcm10e"]
#['usecon:pmcxbaa'
# Real Gross Domestic Product SAAR
# Personal Consumption Expenditure SAAR
#"m112vpmg", "m112vpms"]
#ukuna
hv_tb_hh_000_001_m = Haver.data(hhi_m_tickers1, "USECON", dates=True)
#print(hv_tb_hh_000_001_m)
hhi_m_tickers2 = ["pgdph", "pch", "fodspx", "fofor"]
hv_tb_hh_000_002_m = Haver.data(hhi_m_tickers2, "USECON", dates=True)
print(hv_tb_hh_000_002_m)
hv_tb_hh_000_001_m = pd.concat([hv_tb_hh_000_001_m, hv_tb_hh_000_002_m], axis=1, join="outer")
#hv_tb_hh_000_001_m = pd.concat([hv_tb_hh_000_001_m, hv_tb_hh_000_002_m], axis-1, join="outer")
hh_m_tickers = hhi_m_tickers1 + hhi_m_tickers2
hv_tb_hh_000_001_m = hv_tb_hh_000_001_m.fillna(method="bfill")
hv_tb_hh_000_001_m["Real: S&P US Monthly GDP SA YY%"] = hv_tb_hh_000_001_m["mgdp"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_hh_000_001_m.rename(columns={"pgdph": "Real: Real Gross Domestic Product SAAR"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"pch": "Real: Personal Consumption Expenditure SAAR"}, inplace=True)
#v_tb_hh_000_001_m["Real: Monthly GDP Production SA YY%"] = hv_tb_hh_000_001_m["ecy44"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m["Real: Monthly GDP Services SA YY%"] = hv_tb_hh_000_001_m["ecyc4"].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
#
hv_tb_hh_000_001_m["Real: Retail Sales excl Autos SA YY%"] = hv_tb_hh_000_001_m["nrsxm"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_hh_000_001_m["Real: IP SA YY%"] = hv_tb_hh_000_001_m["ip"].pct_change(
    periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_hh_000_001_m["Real: IP SA YY%"]= hv_tb_hh_000_001_m["ip"].pct_change(periods=12,
                                                                           fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m.rename(columns=["usecon_fot": "Real: Consumer Credit Outstanding Change SA"), inplace=True)
#hv_tb_hh_000_001_m[ "Real: Halifax House Price SA YYW"]= hv_tb_hh_000_001_m["uhpaaps"].pct_change (periods-12,
#fill method="bfill).multiply(100).round(1)
#hv_tb_hh_000_001_m["Real: Rightmove House Price NSA YY%"]= hv_tb_hh_000_001_m["unrmin"].pct_change (periods=12,
#fill_method="bfill).multiply (100).round(1)
#hv_tb_hh_000_001_m["Employment: PAYE Median change SA"]= hv_tb_hh_000_001_m["ukseppm"].pct_change (periods=12,                                                          fill method="bfill").multiply (100).round(1)
hv_tb_hh_000_001_m.rename(columns={"wgto":"Employment: Wage Growth"}, inplace=True)
#hv_tb_hh_000_001_m["lp"]= (hv_tb_hh_000_001_m["Lp"]/100)
hv_tb_hh_000_001_m["lp"]= (hv_tb_hh_000_001_m["lp"].round(0))
hv_tb_hh_000_001_m.rename(columns={"lp": "Employment: Participation Rate"}, inplace =True)
hv_tb_hh_000_001_m.rename(columns={"lr": "Employment: Unemployment Rate"}, inplace=True)
hv_tb_hh_000_001_m["laxepa"]= (hv_tb_hh_000_001_m["laxepa"]/1000)
hv_tb_hh_000_001_m["laxepa"]= (hv_tb_hh_000_001_m["laxepa"].round(0))
hv_tb_hh_000_001_m.rename(columns={"laxepa": "Employment: ADP Private Payroll"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"lanagrd": "Employment: NFP"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"laprivd": "Employment: NFP Private"}, inplace=True)                           

hv_tb_hh_000_001_m["Employment: US AWE Private YY - Establishment Survey"]= hv_tb_hh_000_001_m["lktpriva"].pct_change(
    periods=12,fill_method='bfill').multiply(100).round(1)
hv_tb_hh_000_001_m["Employment: US AHE Private YY - Establishment Survey"]= hv_tb_hh_000_001_m["letpriva"].pct_change(
    periods=12,fill_method='bfill').multiply(108).round(1)
hv_tb_hh_000_001_m.rename(columns={"ljjtpa": "Employment: JOLTS Job Openings Rate SA %"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"ljhtpa": "Employment: JOLTS Hires Rate SA %"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"ljqtpa": "Employment: JOLTS Quits Rate SA %"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"ljltpa": "Employment: JOLTS Layoffs Rate SA %"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"licm": "Employment: Initial Claims SA"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"pcuy": "Price: Headline Inflation SA YY"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"ypcuslfe": "Price: Core Inflation SA YY"}, inplace=True)
hv_tb_hh_000_001_m["acpiscsy"]= (hv_tb_hh_000_001_m["acpiscsy"].round(1))
hv_tb_hh_000_001_m.rename(columns={"acpiscsy":"Price: FRB Atlanta CPI Core Sticky exc1 h SA YY"}, inplace=True)
#hv_tb_hh_000_001_m["jcbm"]= (hv_tb_hh_000_001_m["jcbm"].round(1))
hv_tb_hh_000_001_m["Price: PCE Headline SA YY"]= hv_tb_hh_000_001_m["jcbm"].pct_change(
    periods=12,fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m.rename(columns={"jcbm": "Price: PCE Headline SA YY"}, inplace=True)
hv_tb_hh_000_001_m["Price: PCE Core SA YY"] = hv_tb_hh_000_001_m["jcxfebm"].pct_change(
    periods=12,fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m["jcxfebm"]= (hv_tb_hh_000_001_m["jcxfebm"].round(1)) fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m.rename(columns={"jcxfebm": "Price: PCE Core SA YY), inplace=True)
hv_tb_hh_000_001_m["Price: PCE Core Services ex h SA YY"]= hv_tb_hh_000_001_m["jcsxehm"].pct_change(
    periods=12,fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m["jcsxehm"]= (hv_tb_hh_000_001_m["jcsxehm"].round(1))   fill_method='bfill').multiply(100).round(1)
#hv_tb_hh_000_001_m.rename(columns={"jcsxehm": "Price: PCE Core Services ex h SA YY"}, inplace=True)
hv_tb_hh_000_001_m["clevpcey"]= (hv_tb_hh_000_001_m["clevpcey"].round(1))
hv_tb_hh_000_001_m.rename(columns={"clevpcey":"Price: FRB Clev PCE Median SA YY"}, inplace=True)
hv_tb_hh_000_001_m["pce12"]= (hv_tb_hh_000_001_m["pce12"].round(1))
hv_tb_hh_000_001_m.rename(columns={"pce12": "Price: FRB Dallas PCE Trimmed Mean SA YY"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"cinf1": "Price: Michigan Inflation expectations 1y YY"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"cinf5": "Price: Michigan Inflation expectations 5y YY"}, inplace=True)
hv_tb_hh_000_001_m["napmc"] = hv_tb_hh_000_001_m["napmc"].round(0)
hv_tb_hh_000_001_m.rename(columns={"napmc": "Cycle: ISM Manufacturing"}, inplace=True)
hv_tb_hh_000_001_m["nmfc"] = hv_tb_hh_000_001_m["nmfc"].round(0)
hv_tb_hh_000_001_m.rename(columns={"nmfc": "Cycle: ISM Services"}, inplace=True)
hv_tb_hh_000_001_m["csent"] = hv_tb_hh_000_001_m["csent"].round(0)
hv_tb_hh_000_001_m.rename(columns={"csent": "Cycle: Michigan Consumer Sentiment"}, inplace=True)
hv_tb_hh_000_001_m["ccin"] = hv_tb_hh_000_001_m["ccin"].round(0)
hv_tb_hh_000_001_m.rename(columns={"ccin": "Cycle: CBoard Consumer Confidence"}, inplace=True)
#hv_tb_hh_000_001_m["pmcxbaa"] = hv_tb_hh_000_001_m["pmcxbaa"].round(0)
#hv_tb_hh_000_001_m.rename(columns={"pmcxbaa": "Cycle: Chicago Business Index"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"ffedtahe": "FED Target Rate Upper Limit"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fcm10e": "Financial: Nominal 10y Treasury eop"}, inplace=True)
hv_tb_hh_000_001_m["farmb"] = hv_tb_hh_000_001_m["farmb"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_hh_000_001_m.rename(columns={"farmb": "Financial: Monetary Base yy nsa"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fmv2": "Financial: velocity of money gdp m2"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"vsmida": "Financial: visa discretionary spending index"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"vsmina": "Financial: visa nondiscretionary spending index"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fodspx": "Financial: household debt service ratio quarterly"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fofor": "Financial: household obligation ratio quarterly"}, inplace=True)


hv_tb_hh_000_001_m.index = hv_tb_hh_000_001_m.index.date
list_c = ["Real: S&P US Monthly GDP SA YY%", 
          "Real: Real Gross Domestic Product SAAR",
          "Real: Personal Consumption Expenditure SAAR",
          "Real: Retail Sales excl Autos SA YY%",
          "Real: IP SA YY%", 
          "Employment: Wage Growth",
          "Employment: Participation Rate", 
          "Employment: Unemployment Rate", 
         "Employment: NFP",
         "Employment: NFP Private",
         "Employment: US AWE Private YY - Establishment Survey",
         "Employment: US AHE Private YY - Establishment Survey",
         "Employment: JOLTS Job Openings Rate SA %",
         "Employment: JOLTS Hires Rate SA %",
         "Employment: JOLTS Quits Rate SA %",
         "Employment: JOLTS Layoffs Rate SA %",
         "Employment: Initial Claims SA",
         "Price: Headline Inflation SA YY",
         "Price: Core Inflation SA YY",
         "Price: FRB Atlanta CPI Core Sticky exc1 h SA YY",
         "Price: PCE Headline SA YY",
         "Price: PCE Core SA YY",
         "Price: PCE Core Services ex h SA YY",
         "Price: FRB Clev PCE Median SA YY",
         "Price: FRB Dallas PCE Trimmed Mean SA YY",
         "Price: Michigan Inflation expectations 1y YY",
         "Price: Michigan Inflation expectations 5y YY",
         "Cycle: ISM Manufacturing",
         "Cycle: ISM Services",
         "Cycle: Michigan Consumer Sentiment",
         "Cycle: CBoard Consumer Confidence",
         #"Cycle: Chicago Business Index",
         "FED Target Rate Upper Limit",
         "Financial: Nominal 10y Treasury eop",
         "Financial: Monetary Base yy nsa",
         "Financial: velocity of money gdp m2",
         "Financial: visa discretionary spending index",
         "Financial: visa nondiscretionary spending index",
         "Financial: household debt service ratio quarterly",]
        # "Financial: household obligation ratio quarterly",]


list_xc=["Real: Monthly GDP SA YY%",
    "Real: Monthly GDP Production SA YY%",
    "Real: Monthly GDP Services SA YY%",
    "Real: Retail excl Fuel SA YY%",
    "Real: IP SA YY%",
    "Real: DMP Realized Sales Growth NSA",
    "Real: DMP Expected Sales Growth NSA",
    "Real: Halifax House Price SA YY%",
    "Real: Rightmove House Price NSA YY%",
    "Employment: LFS Unemployment Rate SA",
    "Employment: LFS Eco Active",
    "Employment: PAYE Employment Change SA",
    "Employment: PAYE Median change SA",
    "Employment: Adzuna Job Advertisements YY%",
    "Employment: AWE Whole Economy Regular Pay YY%",
    "Employment: AWE Private Sector Regular Pay YY%",
    "Employment: AWE Public Sector Regular Pay YY%",
    "Employment: DMP Realized Employment Growth NSA",
    "Employment: DMP Expected Employment Growth NSA",
    "Employment: DMP Realized Wage Growth NSA",
    "Employment: DMP Expected Wage Growth NSA",
    "Price: CPI Headline NSA YY%",
    "Price: CPI Core NSA YY%",
         "Price: CPI Goods NSA YY%"
        "Price: CPI Services NSA YY%"
        "Price: DMP CPI Expected 1Y ahead NSA",
        "Price: DMP CPI Expected 3Y ahead NSA",
        "Price: DMP Realized Price Growth NSA"
        "Price: DMP Expected Price Growth NSA",
        "Cycle: PMI Manufacturing SA",
        "Cycle: PMI Services SA",
        "Cycle: Lloyds Overall Bs Confidence NSA",
        "Cycle: GFK Consumer Confidence Barometer"]



hv_tb_hh_000_001_m=hv_tb_hh_000_001_m[list_c]
hv_tb_hh_000_001_m_c=hv_tb_hh_000_001_m.copy()
hv_tb_hh_000_001_m_c=hv_tb_hh_000_001_m_c.tail(120)
hv_tb_hh_000_001_m=hv_tb_hh_000_001_m.tail(60)
#print(hv_tb_hh_000_001_m.tail(5))
time.sleep(10)

#hv_tb_hh_000_001_m.to_clipboard()

### macro dashbaord heatmpa graph

#size I width
#size z negith
n_time = 50
size1 = 30
size2 = 20
font_size_h = 11
number_vbs = 38
x_size1 = 13
x2_size1 = x_size1 - 1
xlabel_size = 20
title_s = 25
hspace_n=-1
df1 = hv_tb_hh_000_001_m.copy()
#df1.index=df1.index.date
df1 = df1.tail(n_time)
df1 = df1.transpose()
df1.index.names = ["Variable"]
#print(df1)
time.sleep(5)

#print(df1.tail(1))
#df1.to_clipboard()

num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")
time.sleep(5)
for x in range(num_rows):
    #print(x)
    locals()[str(str("vmin_")+str(x))] = hv_tb_hh_000_001_m_c.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = hv_tb_hh_000_001_m_c.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)
#data = np.random.random((10,12))
#df = pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)
#size 1 width
#size 2 height
print(number_vbs)
print(f" number variables {number_vbs}")
time.sleep(5)

#print(data_r0)
#print(data_r1)
#print(data_r2)



fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1,
                                  size2),
                         sharex=True,)
time.sleep(5)
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
time.sleep(1)
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
time.sleep(5)
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
time.sleep(5)
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
time.sleep(5)
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels (ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels (ax.get_xticklabels(), rotation=90)
    n=(n+1)
time.sleep(5)
#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])

axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels (axis="x", which="both", Length=0, Labelrotation=45)
#.set_xticks([])
fig.suptitle("USA Economic Dashboard - Monthly", fontsize=title_s)
plt.figtext(0.5,0.01, "USA Economic Dashboard - Monthly", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=hspace_n)
plt.tight_layout(rect=[0,0.03,1,0.971])
#plt.savefig('ussaa_heatmap_001.png', bbox_inches='tight', dpi=600)
#plt.savefig('ussaa_heatmap_001_test.png', bbox_inches='tight', dpi=600)
plt.savefig('us_heatmap_001.png', bbox_inches='tight', dpi=600)
#plt.savefig('us_heatmap_001_0002.png', bbox_inches='tight', dpi=600)
plt.savefig('us_heatmap_001.jpg', bbox_inches='tight', dpi=600)
#plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()
print("Complete")







#df1.to_clipboard()

#'Employment: US AWE Private YY - Establishment Survey',
#'Employment: US AHE Private YY - Establishment Survey', 
#'Employment: JOLTS Quits Rate SA %', 
#'Cycle: Chicago Business Index'] not in index"

##### PCE simulation 
##### PCE simulation 
##### PCE simulation 

### 001_PCE simulation   <a id="title_page"></a>

print("Compelte")
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
country_database = "USECON"
horizon_00=120
#'pculfet'
us_m_tickers = ['pcu', 'pcuslfe', 'jcbm', 'jcxfebm', 'jcsxehm']
hv_tb_usa_009_009_m=Haver.data(us_m_tickers, country_database, dates=True)
print(hv_tb_usa_009_009_m)
hv_tb_usa_009_009_m.rename(columns={"pcu": "CPI Headline"}, inplace=True)
hv_tb_usa_009_009_m.rename(columns={"pcuslfe":"CPI Core"}, inplace=True)
hv_tb_usa_009_009_m.rename(columns={"pcuslfe":"CPI Core"}, inplace=True)
hv_tb_usa_009_009_m.rename(columns={"jcbm":"PCE Headline"}, inplace=True)
hv_tb_usa_009_009_m.rename(columns={"jcxfebm":"PCE Core"}, inplace=True)
hv_tb_usa_009_009_m.rename(columns={"jcsxehm":"PCE Core SxH"}, inplace=True)
#hv_tb_us_000_001_w.rename(columns={"pculfet": "US Core CPI 3M3M rolling Annualized"), inplace=True)
usi_m_tickers=hv_tb_usa_009_009_m.columns.tolist()
hv_tb_us_000_001_m=hv_tb_usa_009_009_m.copy()
#print(hv_tb_eu_000_001_m)

for x in range(len(usi_m_tickers)):
    variable=str(usi_m_tickers[x])
    variable0=variable +" YY"
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[ (str(variable))]
    hv_tb_us_000_001_m[str(variable0)]= hv_tb_us_000_001_m[variable0].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)
    #hv_tb_us_000_001_m[(str(variable)+"_mavg6M")]= hv_tb_us_000_001_m[variable].rolling(6).mean().round(3)
    del variable0
    
    variable0= variable +" 6M Ann"
    #print(variable)
    #print(hv_tb_us_800_001_m[variable])
    hv_tb_us_000_001_m[str(variable0)]=hv_tb_us_000_001_m[str(variable)]
    #hv_tb_us_000_001_m[(str(variable))]= hv_th_us_000_001_m[variable].rolling(3).mean()
    hv_tb_us_000_001_m[(str(variable0))]= hv_tb_us_000_001_m[variable0].pct_change (periods=6, fill_method='bfill')+1
    hv_tb_us_000_001_m[str(variable0)] =hv_tb_us_000_001_m[ (str(variable0))].apply(lambda x: x**2)
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[ (str(variable0))]-1
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[(str(variable0))].multiply(108).round(2)

    variable0 = variable + " 3M Ann"
    #print(variable)
    #print(hv_tb_us_800_001_m[variable])
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[(str(variable))]
    #hv_tb_us_000_001_m[(str(variable))]= hv_tb_us_000_001_m[variable].rolling(3).mean()
    hv_tb_us_000_001_m[(str(variable0))]= hv_tb_us_000_001_m[variable0].pct_change(periods=3, fill_method="bfill")+1
    hv_tb_us_000_001_m[(str(variable0))] = hv_tb_us_000_001_m[ (str(variable0))].apply(lambda x: x**4)
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[(str(variable0))]-1
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[ (str(variable0))].multiply(100).round(2)
    del variable0

    variable0 = variable + " MM"
    hv_tb_us_000_001_m[(str(variable0))]=hv_tb_us_000_001_m[(str(variable))]
    hv_tb_us_000_001_m[(str(variable0))]= hv_tb_us_000_001_m[variable0].pct_change(periods=1, fill_method="bfill").multiply(100).round(2)
    #hv_tb_us_000_001_m[(str(variable)+"_mavg6M")]=hv_tb_us_000_001_m[variable].rolling(6).mean().round(3)
    del variable0

print(hv_tb_us_000_001_m)
hv_tb_us_000_001_m=hv_tb_us_000_001_m.iloc[:,5:]
hv_tb_us_000_001_m.insert(0, 'Index', hv_tb_us_000_001_m.index)
#hv_tb_us_000_001_m[ 'Index']=hv_th_us_000_001_m['Index" [.date()
hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(18)
#hv_th_hh_800_e01_m=hv_tb_hh_000_001_m[List_c]
#hv th_hh_900_001_m_c=hv_th_hh_008_001_m.copy()
#hv_tb_hh_800_001_w_c=hv_tb_hh_000_001_w_c.tail (120)
#hv_tb_hh_000_001_m=hv_tb_hh_008_001_m.tail (60)

df = hv_tb_us_000_001_m.copy()
fig = go.Figure(data=[go.Table(header=dict(values=list(df.columns)),
                                    cells=dict(values=df.transpose().values.tolist()))])

fig.update_layout(autosize=False,
                  width=1688,
                  height=750)
fig.write_image('us_pce_heatmap_003.png')
fig.write_image('us_pce_heatmap_003.jpg')
fig.write_image('us_pce_heatmap_003_test.jpg')

### pce core simulation 


from dateutil.relativedelta import relativedelta
# pip install kaleido
# us_m_tickers = ['pcu', 'pcusife',
#                'jcbm', 'jcxfebm', 'jcsxehm']
us_m_tickers = ['jcxfebm']

hv_tb_us_009_009_m = Haver.data(us_m_tickers, country_database, dates=True)
# hv_tb_us_009_009_m.rename(columns={"pcu": "CPI Headline"}, inplace=True)
# hv_tb_us_009_009_m.rename(columns={"pcusife": "CPI Core"}, inplace=True)
# hv_tb_us_009_009_m.rename(columns={"pcusife": "CPI Core"}, inplace=True)
# hv_tb_us_009_009_m.rename(columns={"jcbm": "PCE HeadLine"}, inplace=True)
hv_tb_us_009_009_m.rename(columns={"jcxfebm": "PCE Core"}, inplace=True)
# hv_tb_us_009_009_m.rename(columns={"jcsxehm":"PCE Core SXH"}, inplace=True)
# hv_th_us_000_001_m.rename(columns={"pculfet": "US Core CPI 3M3M rolling Annualized"}, inplace=True)

us_m_tickers = hv_tb_us_009_009_m.columns.tolist()
hv_tb_us_000_001_m = hv_tb_us_009_009_m.copy()
max_index0 = hv_tb_us_000_001_m.index.max()
print(max_index0)
hv_tb_us_000_001_m["PCE Core diff"] = hv_tb_us_000_001_m["PCE Core"].diff()
variable = "PCE Core diff"
hv_tb_us_000_001_m[str(variable) + "_1mean"] = hv_tb_us_000_001_m[variable].rolling(window=1).mean()
hv_tb_us_000_001_m[str(variable) + "_2mean"] = hv_tb_us_000_001_m[variable].rolling(window=2).mean()
hv_tb_us_000_001_m[str(variable) + "_3mean"] = hv_tb_us_000_001_m[variable].rolling(window=3).mean()
hv_tb_us_000_001_m[str(variable) + "_4mean"] = hv_tb_us_000_001_m[variable].rolling(window=4).mean()
hv_tb_us_000_001_m[str(variable) + "_5mean"] = hv_tb_us_000_001_m[variable].rolling(window=5).mean()
hv_tb_us_000_001_m[str(variable) + "_6mean"] = hv_tb_us_000_001_m[variable].rolling(window=6).mean()
delta_input=18
hv_tb_us_000_001_m = (hv_tb_us_000_001_m.reindex(pd.date_range(hv_tb_us_000_001_m.index.min(),
                                                               hv_tb_us_000_001_m.index.max() + relativedelta(months= delta_input),
                                                               freq="M"), method="ffill"))
hv_tb_us_000_001_m["PCE Core0"]=hv_tb_us_000_001_m["PCE Core"]
hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(48)
hv_tb_us_000_001_m["PCE Core"]= np.where(hv_tb_us_000_001_m.index> max_index0,np.nan,hv_tb_us_000_001_m["PCE Core"])
hv_tb_us_000_001_m["PCE Core"]=hv_tb_us_000_001_m["PCE Core"].fillna(method='ffill', limit=1)
hv_tb_us_000_001_m["PCE Core"]=hv_tb_us_000_001_m["PCE Core"].fillna(0)
hv_tb_us_000_001_m["PCE Core0"]= np.where(hv_tb_us_000_001_m.index > max_index0,0,hv_tb_us_000_001_m["PCE Core0"])

hv_tb_us_000_001_m["PCE Core yy"]= hv_tb_us_000_001_m["PCE Core0"].pct_change(periods=12, fill_method='bfill').multiply(100).round(2)
hv_tb_us_000_001_m["PCE Core yy"]= np.where(hv_tb_us_000_001_m.index> max_index0,0,hv_tb_us_000_001_m["PCE Core yy"])


hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = hv_tb_us_000_001_m[str("PCE Core")] + hv_tb_us_000_001_m[str(variable)+"_1mean"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_1mean_s"])
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_1mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_1mean_s_cs"] + hv_tb_us_000_001_m["PCE Core0"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_1mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = hv_tb_us_000_001_m[str("PCE Core")] + hv_tb_us_000_001_m[str(variable)+"_2mean"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_2mean_s"])
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_2mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_2mean_s_cs"] + hv_tb_us_000_001_m["PCE Core0"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_2mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = hv_tb_us_000_001_m[str("PCE Core")] + hv_tb_us_000_001_m[str(variable)+"_3mean"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_3mean_s"])
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_3mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_3mean_s_cs"] + hv_tb_us_000_001_m["PCE Core0"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_3mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_4mean_s"] = hv_tb_us_000_001_m[str("PCE Core")] + hv_tb_us_000_001_m[str(variable)+"_4mean"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_4mean_s"])
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_4mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_4mean_s_cs"] + hv_tb_us_000_001_m["PCE Core0"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_4mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_5mean_s"]=hv_tb_us_000_001_m[str("PCE Core")] + hv_tb_us_000_001_m[str(variable)+"_5mean"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0, 0,hv_tb_us_000_001_m[str(variable)+"_5mean_s"])
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable) + "_5mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable) + "_5mean_s_cs"]+hv_tb_us_000_001_m["PCE Core0"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s_yy"]= hv_tb_us_000_001_m[str(variable) + "_5mean_s_cs"].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_6mean_s"]=hv_tb_us_000_001_m[str("PCE Core")]+hv_tb_us_000_001_m[str(variable)+"_6mean"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0,0,hv_tb_us_000_001_m[str(variable)+"_6mean_s"])
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]+hv_tb_us_000_001_m["PCE Core0"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)

#whv_tb_us_880_001_m["Cum_sum"]=np.where(hv_tb_us_000_001_m.index>=max_indexe, hv_tb_us_800_001_m["Cum_sum"],0)
#hv_tb_us_000_081_m["PCE Core" J=hv_tb_us_000_001_m["PCE Core").cumsum()

hv_tb_us_000_001_m=hv_tb_us_000_001_m[["PCE Core yy",
                                       "PCE Core diff_1mean_s_yy",
                                       "PCE Core diff_2mean_s_yy",
                                       "PCE Core diff_3mean_s_yy",
                                       "PCE Core diff_4mean_s_yy",
                                       "PCE Core diff_5mean_s_yy",
                                       "PCE Core diff_6mean_s_yy"]]

hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(24)
hv_tb_us_000_001_m.insert(0, 'Index',hv_tb_us_000_001_m.index)


df=hv_tb_us_000_001_m.copy()
fig=go.Figure(data=[go.Table(header=dict(values=list(df.columns)), 
                             cells=dict(values=df.transpose().values.tolist()))])

fig.update_layout(autosize=False, width=1600, height=750,)
fig.write_image('us_pce_heatmap_004.png')     
fig.write_image('us_pce_heatmap_004.jpg')                                                                    
fig.write_image('us_pce_heatmap_004_test.jpg')      
print("Complete")

title_r="PCE CORE Simulation YY"
y_label = "Index %"
x_label = title_r
list_c=[ "PCE Core yy",
        "PCE Core diff_1mean_s_yy",
        "PCE Core diff_2mean_s_yy",
        "PCE Core diff_3mean_s_yy", 
        "PCE Core diff_4mean_s_yy",
        "PCE Core diff_5mean_s_yy",
        "PCE Core diff_6mean_s_yy"]

df1=hv_tb_us_000_001_m[list_c]
g1=df1.copy()
g1["PCE Core yy"]= np.where(g1.index > max_index0, np.nan, g1["PCE Core yy"])

fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=str(list_c[0]), color="black", linewidth= l0, linestyle='-')
g1.plot(kind='line', ax=ax,y=str(list_c[1]), color="blue", linewidth= l1, linestyle='-',
        marker="o", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[2]), color="green", linewidth= l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[3]), color="orange", linewidth= l1, linestyle='--',
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[4]), color="red", linewidth= l1, linestyle='-',
        marker="^", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[5]), color="yellow", linewidth= l1, linestyle='-',
        marker="x", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[6]), color="brown", linewidth= l1, linestyle="--",
        marker="<", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.axvline(max_index0, color='black', lw=1, linestyle='dashed', alpha=0.75)

for x, y in zip(g1.index, g1[str(list_c[0])]):
    label = f"{y:.2f}"
    # label = f"({x}, {y})"
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 17),  # distance from text to points (x, y)
                 ha='center',
                 fontsize=11)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner), fontsize=48, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)

plt.savefig("pce_core_simulation_yy.jpg", bbox_inches='tight')
plt.savefig("pce_core_simulation_yy.png", bbox_inches='tight')
plt.savefig("pce_core_simulation_yy_test.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()

del g1
del df1
del list_c
del fig
del ax
del ax2







### pce core  ex housing simulation  

us_m_tickers = ['jcsxehm']
hv_tb_usa_009_009_m = Haver.data(us_m_tickers, country_database, dates=True)

# hv_tb_usa_009_009_m.rename(columns={"pcu": "CPI Headline"}, inplace=True)
# hv_tb_usa_889_809_m.rename(columns={"pcusLfe": "CPI Core"}, inplace=True)
# hv_tb_usa_009_009_m.rename(columns=("pousife": "CPI Core"), inplace=True)
# hv_tb_usa_009_009_m.rename(columns={"jcbm": "PCE Headline"}, inplace=True)
# hv_tb_usa_009_009_m.rename(columns={"jcxfebm":"PCE Core"}, inplace=True)
# hv_tb_us_000_001_m.rename(columns={"pculfet": "US Core CPI 3M3M rolling Annualized"}, inplace=True)

hv_tb_usa_009_009_m.rename(columns={"jcsxehm":"PCE Core SxH"}, inplace=True)
usi_m_tickers = hv_tb_usa_009_009_m.columns.tolist()
hv_tb_us_000_001_m = hv_tb_usa_009_009_m.copy()
max_index0 = hv_tb_us_000_001_m.index.max()
hv_tb_us_000_001_m["PCE Core SxH diff"] = hv_tb_us_000_001_m["PCE Core SxH"].diff()
variable = "PCE Core SxH diff"
hv_tb_us_000_001_m[str(variable) + "_1mean"] = hv_tb_us_000_001_m[variable].rolling(window=1).mean()
hv_tb_us_000_001_m[str(variable) + "_2mean"] = hv_tb_us_000_001_m[variable].rolling(window=2).mean()
hv_tb_us_000_001_m[str(variable) + "_3mean"] = hv_tb_us_000_001_m[variable].rolling(window=3).mean()
hv_tb_us_000_001_m[str(variable) + "_4mean"] = hv_tb_us_000_001_m[variable].rolling(window=4).mean()
hv_tb_us_000_001_m[str(variable) + "_5mean"] = hv_tb_us_000_001_m[variable].rolling(window=5).mean()
hv_tb_us_000_001_m[str(variable) + "_6mean"] = hv_tb_us_000_001_m[variable].rolling(window=6).mean()
delta_input = 18


#####


##########
hv_tb_us_000_001_m = (hv_tb_us_000_001_m.reindex(pd.date_range(hv_tb_us_000_001_m.index.min(), 
                                                               hv_tb_us_000_001_m.index.max() + relativedelta(months=delta_input), 
                                                               freq='M'), method='ffill'))
hv_tb_us_000_001_m["PCE Core SxH0"] = hv_tb_us_000_001_m["PCE Core SxH"]
hv_tb_us_000_001_m = hv_tb_us_000_001_m.tail(48)
hv_tb_us_000_001_m["PCE Core SxH"] = np.where(hv_tb_us_000_001_m.index > max_index0, np.nan, hv_tb_us_000_001_m["PCE Core SxH"])
hv_tb_us_000_001_m["PCE Core SxH"] = hv_tb_us_000_001_m["PCE Core SxH"].fillna(method="ffill", limit=1)
hv_tb_us_000_001_m["PCE Core SxH"] = hv_tb_us_000_001_m["PCE Core SxH"].fillna(0)
hv_tb_us_000_001_m["PCE Core SxH0"] = np.where(hv_tb_us_000_001_m.index > max_index0, 0, hv_tb_us_000_001_m["PCE Core SxH0"])

hv_tb_us_000_001_m["PCE Core SxH yy"] = hv_tb_us_000_001_m["PCE Core SxH0"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)
hv_tb_us_000_001_m["PCE Core SxH yy"] = np.where(hv_tb_us_000_001_m.index > max_index0, 0, hv_tb_us_000_001_m["PCE Core SxH yy"])

print(variable)
#print(hv_tb_us_000_001_m[str(variable) + "_1mean"])
hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = hv_tb_us_000_001_m[str("PCE Core SxH")] + hv_tb_us_000_001_m[str(variable) + "_1mean"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_1mean_s"])
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_1mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] + hv_tb_us_000_001_m["PCE Core SxH0"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)
                                                                                                                
hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = hv_tb_us_000_001_m[str("PCE Core SxH")] + hv_tb_us_000_001_m[str(variable)+"_2mean"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_2mean_s"])
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_2mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] + hv_tb_us_000_001_m["PCE Core SxH0"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)

hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = hv_tb_us_000_001_m[str("PCE Core SxH")] + hv_tb_us_000_001_m[str(variable)+"_3mean"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_3mean_s"])
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_3mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] + hv_tb_us_000_001_m["PCE Core SxH0"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)

hv_tb_us_000_001_m[str(variable)+"_4mean_s"] = hv_tb_us_000_001_m[str("PCE Core SxH")] + hv_tb_us_000_001_m[str(variable)+"_4mean"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0,0, hv_tb_us_000_001_m[str(variable)+"_4mean_s"])
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_4mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] = hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] + hv_tb_us_000_001_m["PCE Core SxH0"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s_yy"] = hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_5mean_s"]=hv_tb_us_000_001_m[str("PCE Core SxH")]+hv_tb_us_000_001_m[str(variable)+"_5mean"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0, 0,hv_tb_us_000_001_m[str(variable)+"_5mean_s"])
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_5mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]+hv_tb_us_000_001_m["PCE Core SxH0"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)

hv_tb_us_000_001_m[str(variable)+"_6mean_s"]=hv_tb_us_000_001_m[str("PCE Core SxH")]+hv_tb_us_000_001_m[str(variable)+"_6mean"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0,0,hv_tb_us_000_001_m[str(variable)+"_6mean_s"])
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]+hv_tb_us_000_001_m["PCE Core SxH0"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)


#hv_tb_us_000_001_m["Cum_sum"]=np.where(hv_tb_us_000_001_m.index>=max_indexe, hv_tb_us_000_001_m["Cum_sum"], 0)
#hv_tb_us_000_001_m["PCE Core"]=hv_tb_us_000_001_m["PCE Core"].cumsum()

hv_tb_us_000_001_m=hv_tb_us_000_001_m[['PCE Core SxH yy',
                                       'PCE Core SxH diff_1mean_s_yy', 
                                       'PCE Core SxH diff_2mean_s_yy', 
                                       'PCE Core SxH diff_3mean_s_yy', 
                                       'PCE Core SxH diff_4mean_s_yy', 
                                       'PCE Core SxH diff_5mean_s_yy', 
                                       'PCE Core SxH diff_6mean_s_yy']]

hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(24)
hv_tb_us_000_001_m.insert(0, 'Index', hv_tb_us_000_001_m.index)
#hv_tb_us_000_001_m.to_clipboard()
#print(hv_tb_us_000_001_m)
df=hv_tb_us_000_001_m.copy()
fig=go.Figure(data=[go.Table(header=dict(values=list(df.columns)), cells=dict(values=df.transpose().values.tolist()))])
fig.update_layout(autosize=False, width=1500, height=750)
fig.write_image('us_pce_heatmap_005.jpg')
fig.write_image('us_pce_heatmap_005.png')
fig.write_image('us_pce_heatmap_005_test.png')


print("COmplete")



title_r="PCE CORE SxH Simulation YY"
y_label = "Index %"
x_label = title_r
list_c=[ "PCE Core SxH yy",
        "PCE Core SxH diff_1mean_s_yy",
        "PCE Core SxH diff_2mean_s_yy",
        "PCE Core SxH diff_3mean_s_yy", 
        "PCE Core SxH diff_4mean_s_yy",
        "PCE Core SxH diff_5mean_s_yy",
        "PCE Core SxH diff_6mean_s_yy"]

df1=hv_tb_us_000_001_m[list_c]
g1=df1.copy()
g1['PCE Core SxH yy'] = np.where(g1.index > max_index0, np.nan, g1['PCE Core SxH yy'])
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=str(list_c[0]), color="black", linewidth= l0, linestyle='-')
g1.plot(kind='line', ax=ax,y=str(list_c[1]), color="blue", linewidth= l1, linestyle='-',
        marker="o", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[2]), color="green", linewidth= l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[3]), color="orange", linewidth= l1, linestyle='--',
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[4]), color="red", linewidth= l1, linestyle='-',
        marker="^", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[5]), color="yellow", linewidth= l1, linestyle='-',
        marker="x", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[6]), color="brown", linewidth= l1, linestyle="--",
        marker="<", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.axvline(max_index0, color='black', lw=1, linestyle='dashed', alpha=0.75)

for x, y in zip(g1.index, g1[str(list_c[0])]):
    label = "{:.2f}".format(y)
    # Label =f"((x), (y))"
    # Label =f"((x), (y))"

    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(8, 17),  # distance from text to points (x, y)
                 ha="center",
                 fontsize=11)

plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("pce_core_sxh_simulation_yy.jpg", bbox_inches='tight')
plt.savefig("pce_core_sxh_simulation_yy.png", bbox_inches='tight')

plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2







### CPI core simulation  

us_m_tickers = [ 'pcuslfe']

hv_tb_us_009_009_m = Haver.data(us_m_tickers, country_database, dates=True)
# hv_tb_usa_009_009_m.rename(columns={"pcu": "CPI Headline"}, inplace=True)
# hv_tb_usa_009_009_m.rename(columns={"pcuslfe": "CPI Core"}, inplace=True)
hv_tb_us_009_009_m.rename(columns={"pcuslfe": "CPI Core"}, inplace=True)
# hv_tb_usa_009_009_m.rename(columns={"jcbm": "PCE Headline"}, inplace=True)
# hv_tb_usa_009_009_m.rename(columns={"jcxfebm": "PCE Core"}, inplace=True)
# hv_tb_usa_009_009_m.rename(columns={"jcsxehm": "PCE Core SxH"}, inplace=True)
# hv_tb_us_000_001_m.rename(columns={"pculfet": "US Core CPI 3M3M rolling Annualized"}, inplace=True)
print(hv_tb_us_009_009_m.head())

us_m_tickers = hv_tb_us_009_009_m.columns.tolist()
hv_tb_us_000_001_m = hv_tb_us_009_009_m.copy()
max_index0 = hv_tb_us_000_001_m.index.max()
print(max_index0)
print(hv_tb_us_000_001_m)
hv_tb_us_000_001_m["CPI Core diff"] = hv_tb_us_000_001_m["CPI Core"].diff()
variable = "CPI Core diff"
hv_tb_us_000_001_m[str(variable) + "_1mean"] = hv_tb_us_000_001_m[variable].rolling(window=1).mean()
hv_tb_us_000_001_m[str(variable) + "_2mean"] = hv_tb_us_000_001_m[variable].rolling(window=2).mean()
hv_tb_us_000_001_m[str(variable) + "_3mean"] = hv_tb_us_000_001_m[variable].rolling(window=3).mean()
hv_tb_us_000_001_m[str(variable) + "_4mean"] = hv_tb_us_000_001_m[variable].rolling(window=4).mean()
hv_tb_us_000_001_m[str(variable) + "_5mean"] = hv_tb_us_000_001_m[variable].rolling(window=5).mean()
hv_tb_us_000_001_m[str(variable) + "_6mean"] = hv_tb_us_000_001_m[variable].rolling(window=6).mean()
delta_input=18
hv_tb_us_000_001_m = (hv_tb_us_000_001_m.reindex(pd.date_range(hv_tb_us_000_001_m.index.min(),
                                                               hv_tb_us_000_001_m.index.max() + relativedelta(months= delta_input),
                                                               freq="M"), method="ffill"))
hv_tb_us_000_001_m["CPI Core0"]=hv_tb_us_000_001_m["CPI Core"]
hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(48)
hv_tb_us_000_001_m["CPI Core"]= np.where(hv_tb_us_000_001_m.index> max_index0,np.nan,hv_tb_us_000_001_m["CPI Core"])
hv_tb_us_000_001_m["CPI Core"]=hv_tb_us_000_001_m["CPI Core"].fillna(method='ffill', limit=1)
hv_tb_us_000_001_m["CPI Core"]=hv_tb_us_000_001_m["CPI Core"].fillna(0)
hv_tb_us_000_001_m["CPI Core0"]= np.where(hv_tb_us_000_001_m.index > max_index0,0,hv_tb_us_000_001_m["CPI Core0"])

hv_tb_us_000_001_m["CPI Core yy"]= hv_tb_us_000_001_m["CPI Core0"].pct_change(periods=12, fill_method='bfill').multiply(100).round(2)
hv_tb_us_000_001_m["CPI Core yy"]= np.where(hv_tb_us_000_001_m.index> max_index0,0,hv_tb_us_000_001_m["CPI Core yy"])


hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = hv_tb_us_000_001_m[str("CPI Core")] + hv_tb_us_000_001_m[str(variable)+"_1mean"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_1mean_s"])
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_1mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_1mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_1mean_s_cs"] + hv_tb_us_000_001_m["CPI Core0"]
hv_tb_us_000_001_m[str(variable)+"_1mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_1mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = hv_tb_us_000_001_m[str("CPI Core")] + hv_tb_us_000_001_m[str(variable)+"_2mean"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_2mean_s"])
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_2mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_2mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_2mean_s_cs"] + hv_tb_us_000_001_m["CPI Core0"]
hv_tb_us_000_001_m[str(variable)+"_2mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_2mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = hv_tb_us_000_001_m[str("CPI Core")] + hv_tb_us_000_001_m[str(variable)+"_3mean"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_3mean_s"])
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_3mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_3mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_3mean_s_cs"] + hv_tb_us_000_001_m["CPI Core0"]
hv_tb_us_000_001_m[str(variable)+"_3mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_3mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_4mean_s"] = hv_tb_us_000_001_m[str("CPI Core")] + hv_tb_us_000_001_m[str(variable)+"_4mean"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s"] = np.where(hv_tb_us_000_001_m.index <= max_index0, 0, hv_tb_us_000_001_m[str(variable)+"_4mean_s"])
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_4mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_4mean_s_cs"] = hv_tb_us_000_001_m[str(variable) + "_4mean_s_cs"] + hv_tb_us_000_001_m["CPI Core0"]
hv_tb_us_000_001_m[str(variable)+"_4mean_s_yy"] = hv_tb_us_000_001_m[str(variable) + "_4mean_s_cs"].pct_change(periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_5mean_s"]=hv_tb_us_000_001_m[str("CPI Core")] + hv_tb_us_000_001_m[str(variable)+"_5mean"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0, 0,hv_tb_us_000_001_m[str(variable)+"_5mean_s"])
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable) + "_5mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_5mean_s_cs"]=hv_tb_us_000_001_m[str(variable) + "_5mean_s_cs"]+hv_tb_us_000_001_m["CPI Core0"]
hv_tb_us_000_001_m[str(variable)+"_5mean_s_yy"]= hv_tb_us_000_001_m[str(variable) + "_5mean_s_cs"].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)


hv_tb_us_000_001_m[str(variable)+"_6mean_s"]=hv_tb_us_000_001_m[str("CPI Core")]+hv_tb_us_000_001_m[str(variable)+"_6mean"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s"]= np.where(hv_tb_us_000_001_m.index <= max_index0,0,hv_tb_us_000_001_m[str(variable)+"_6mean_s"])
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s"].cumsum()
hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]=hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"]+hv_tb_us_000_001_m["CPI Core0"]
hv_tb_us_000_001_m[str(variable)+"_6mean_s_yy"]= hv_tb_us_000_001_m[str(variable)+"_6mean_s_cs"].pct_change (periods=12, fill_method="bfill").multiply(100).round(2)

#whv_tb_us_880_001_m["Cum_sum"]=np.where(hv_tb_us_000_001_m.index>=max_indexe, hv_tb_us_800_001_m["Cum_sum"],0)
#hv_tb_us_000_081_m["CPI Core" J=hv_tb_us_000_001_m["CPI Core").cumsum()

hv_tb_us_000_001_m=hv_tb_us_000_001_m[["CPI Core yy",
                                       "CPI Core diff_1mean_s_yy",
                                       "CPI Core diff_2mean_s_yy",
                                       "CPI Core diff_3mean_s_yy",
                                       "CPI Core diff_4mean_s_yy",
                                       "CPI Core diff_5mean_s_yy",
                                       "CPI Core diff_6mean_s_yy"]]

hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(24)
hv_tb_us_000_001_m.insert(0, 'Index',hv_tb_us_000_001_m.index)


df=hv_tb_us_000_001_m.copy()
fig=go.Figure(data=[go.Table(header=dict(values=list(df.columns)), 
                             cells=dict(values=df.transpose().values.tolist()))])
fig.update_layout(autosize=False, width=1600, height=750,)
fig.write_image('us_pce_heatmap_006.png')        
fig.write_image('us_pce_heatmap_006.jpg')                                                                    
fig.write_image('us_pce_heatmap_006_test.jpg')      
print("Complete")









title_r="CPI Core Simulation YY"
y_label="Index"

x_label=title_r
list_c=['CPI Core yy',
        'CPI Core diff_1mean_s_yy',
        'CPI Core diff_2mean_s_yy',
        'CPI Core diff_3mean_s_yy',
        'CPI Core diff_4mean_s_yy',
        'CPI Core diff_5mean_s_yy',
        'CPI Core diff_6mean_s_yy']

df1=hv_tb_us_000_001_m[list_c]
g1=df1.copy()
g1['CPI Core yy']= np.where(g1.index > max_index0, np.nan, g1['CPI Core yy'])
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=str(list_c[0]), color="black", linewidth= l0, linestyle='-')
g1.plot(kind='line', ax=ax,y=str(list_c[1]), color="blue", linewidth= l1, linestyle='-',
        marker="o", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[2]), color="green", linewidth= l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[3]), color="orange", linewidth= l1, linestyle='--',
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[4]), color="red", linewidth= l1, linestyle='-',
        marker="^", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[5]), color="yellow", linewidth= l1, linestyle='-',
        marker="x", markersize=s2)
g1.plot(kind='line', ax=ax,y=str(list_c[6]), color="brown", linewidth= l1, linestyle="--",
        marker="<", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.axvline(max_index0, color='black', lw=1, linestyle='dashed', alpha=0.75)
for x,y in zip(g1.index, g1[str(list_c[0])]):
    label = "{:.2f}".format(y)
    # Label =f"({x}, {y})"

    # This is the text
    plt.annotate(label,
                 # these are the coordinates to position the label
                 (x,y),
                 # these are the offsets to position the text
                 textcoords="offset points",
                 xytext=(8,17), # distance from text to points (x,y)
                 ha='center',
                 fontsize=11)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("cpi_core_simulation_yy.jpg", bbox_inches='tight')
plt.savefig("cpi_core_simulation_yy.png", bbox_inches='tight')
plt.savefig("cpi_core_simulation_yy_test.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### table simlulation 

import plotly.graph_objects as go
us_m_tickers = ['jcxfebm']
df = Haver.data(us_m_tickers, country_database, dates=True)
df.rename(columns={"jcxfebm":"Close"}, inplace=True)
import pandas as pd
import numpy as np

# Sample DataFrame creation
#dates = pd.date_range(start='2014-01-01', end='2023-12-31', freq='M')
#data = np.random.randn(len(dates))
#df = pd.DataFrame(data, index=dates, columns=['Close'])

# Calculate historical year-on-year returns
last_index = df.index.max()
print(last_index)
given_date = pd.to_datetime(last_index)

next_end_of_month = given_date + pd.offsets.MonthEnd(1)
print(next_end_of_month)

# Calculate the next end of month 3 months after
three_months_later_end_of_month = given_date + pd.offsets.MonthEnd(3)
print("Given Date:", given_date)
print("Next End of Month:", next_end_of_month)
print("End of Month 3 Months After:", three_months_later_end_of_month)

# Define future dates and growth rates for the scenarios
future_dates = pd.date_range(start=next_end_of_month,
                             end=three_months_later_end_of_month, freq='M')

growth_scenario_1 = [0.1/100, 0.1/100, 0.1/100]
growth_scenario_2 = [0.1/100, 0.1/100, 0.2/100]
growth_scenario_3 = [0.1/100, 0.1/100, 0.3/100]
growth_scenario_4 = [0.1/100, 0.1/100, 0.4/100]
growth_scenario_5 = [0.1/100, 0.2/100, 0.1/100]
growth_scenario_6 = [0.1/100, 0.2/100, 0.2/100]
growth_scenario_7 = [0.1/100, 0.2/100, 0.3/100]
growth_scenario_8 = [0.1/100, 0.2/100, 0.4/100]
growth_scenario_9 = [0.1/100, 0.3/100, 0.1/100]
growth_scenario_10 = [0.1/100, 0.3/100, 0.2/100]
growth_scenario_11 = [0.1/100, 0.3/100, 0.3/100]
growth_scenario_12 = [0.1/100, 0.3/100, 0.4/100]
growth_scenario_13 = [0.1/100, 0.4/100, 0.2/100]
growth_scenario_14 = [0.1/100, 0.4/100, 0.1/100]
growth_scenario_15 = [0.1/100, 0.4/100, 0.3/100]
growth_scenario_16 = [0.1/100, 0.4/100, 0.4/100]


growth_scenario_17 = [0.2/100, 0.1/100, 0.1/100]
growth_scenario_18 = [0.2/100, 0.1/100, 0.2/100]
growth_scenario_19 = [0.2/100, 0.1/100, 0.3/100]
growth_scenario_20 = [0.2/100, 0.1/100, 0.4/100]
growth_scenario_21 = [0.2/100, 0.2/100, 0.1/100]
growth_scenario_22 = [0.2/100, 0.2/100, 0.2/100]
growth_scenario_23 = [0.2/100, 0.2/100, 0.3/100]
growth_scenario_24 = [0.2/100, 0.2/100, 0.4/100]
growth_scenario_25 = [0.2/100, 0.3/100, 0.1/100]
growth_scenario_26 = [0.2/100, 0.3/100, 0.2/100]
growth_scenario_27 = [0.2/100, 0.3/100, 0.3/100]
growth_scenario_28 = [0.2/100, 0.3/100, 0.4/100]
growth_scenario_29 = [0.2/100, 0.4/100, 0.1/100]
growth_scenario_30 = [0.2/100, 0.4/100, 0.2/100]
growth_scenario_31 = [0.2/100, 0.4/100, 0.3/100]
growth_scenario_32 = [0.2/100, 0.4/100, 0.4/100]


growth_scenario_33 = [0.3/100, 0.1/100, 0.1/100]
growth_scenario_34 = [0.3/100, 0.1/100, 0.2/100]
growth_scenario_35 = [0.3/100, 0.1/100, 0.3/100]
growth_scenario_36 = [0.3/100, 0.1/100, 0.4/100]
growth_scenario_37 = [0.3/100, 0.2/100, 0.1/100]
growth_scenario_38 = [0.3/100, 0.2/100, 0.2/100]
growth_scenario_39 = [0.3/100, 0.2/100, 0.3/100]
growth_scenario_40 = [0.3/100, 0.2/100, 0.4/100]
growth_scenario_41 = [0.3/100, 0.3/100, 0.1/100]
growth_scenario_42 = [0.3/100, 0.3/100, 0.2/100]
growth_scenario_43 = [0.3/100, 0.3/100, 0.3/100]
growth_scenario_44 = [0.3/100, 0.3/100, 0.4/100]
growth_scenario_45 = [0.3/100, 0.4/100, 0.1/100]
growth_scenario_46 = [0.3/100, 0.4/100, 0.2/100]
growth_scenario_47 = [0.3/100, 0.4/100, 0.3/100]
growth_scenario_48 = [0.3/100, 0.4/100, 0.4/100]


growth_scenario_49 = [0.4/100, 0.1/100, 0.1/100]
growth_scenario_50 = [0.4/100, 0.1/100, 0.2/100]
growth_scenario_51 = [0.4/100, 0.1/100, 0.3/100]
growth_scenario_52 = [0.4/100, 0.1/100, 0.4/100]
growth_scenario_53 = [0.4/100, 0.2/100, 0.1/100]
growth_scenario_54 = [0.4/100, 0.2/100, 0.2/100]
growth_scenario_55 = [0.4/100, 0.2/100, 0.3/100]
growth_scenario_56 = [0.4/100, 0.2/100, 0.4/100]
growth_scenario_57 = [0.4/100, 0.3/100, 0.1/100]
growth_scenario_58 = [0.4/100, 0.3/100, 0.2/100]
growth_scenario_59 = [0.4/100, 0.3/100, 0.3/100]
growth_scenario_60 = [0.4/100, 0.3/100, 0.4/100]
growth_scenario_61 = [0.4/100, 0.4/100, 0.1/100]
growth_scenario_62 = [0.4/100, 0.4/100, 0.2/100]
growth_scenario_63 = [0.4/100, 0.4/100, 0.3/100]
growth_scenario_64 = [0.4/100, 0.4/100, 0.4/100]




import pandas as pd
import numpy as np

# Assuming 'df' is the Dataframe with monthly 'Close' prices ending in December 2023
# dates = pd.date_range(start='2014-01-01', end='2023-12-31', freq='M')

# df = pd.DataFrame({'Close': np.random.rand(len(dates)) * 100}, index=dates)

# Calculate historical year-on-year returns
df['Historical_YoY'] = df['Close'].pct_change(12)

# Define scenarios
scenarios = [
    ###1-4
    {"name": "0.1_0.1_0.1", "growth_rates": [0.1, 0.1, 0.1]},
    {"name": "0.1_0.1_0.2", "growth_rates": [0.1, 0.1, 0.2]},
    {"name": "0.1_0.1_0.3", "growth_rates": [0.1, 0.1, 0.3]},
    {"name": "0.1_0.1_0.4", "growth_rates": [0.1, 0.1, 0.4]},
    ##5-8
    {"name": "0.1_0.2_0.1", "growth_rates": [0.1, 0.2, 0.1]},
    {"name": "0.1_0.2_0.2", "growth_rates": [0.1, 0.2, 0.2]},
    {"name": "0.1_0.2_0.3", "growth_rates": [0.1, 0.2, 0.3]},
    {"name": "0.1_0.2_0.4", "growth_rates": [0.1, 0.2, 0.4]},
    ##9--12
    {"name": "0.1_0.3_0.1", "growth_rates": [0.1, 0.3, 0.1]},
    {"name": "0.1_0.3_0.2", "growth_rates": [0.1, 0.3, 0.2]},
    {"name": "0.1_0.3_0.3", "growth_rates": [0.1, 0.3, 0.3]},
    {"name": "0.1_0.3_0.4", "growth_rates": [0.1, 0.3, 0.4]},
    ##12--16
    {"name": "0.1_0.4_0.1", "growth_rates": [0.1, 0.4, 0.1]},
    {"name": "0.1_0.4_0.2", "growth_rates": [0.1, 0.4, 0.2]},
    {"name": "0.1_0.4_0.3", "growth_rates": [0.1, 0.4, 0.3]},
    {"name": "0.1_0.4_0.4", "growth_rates": [0.1, 0.4, 0.4]},
    ###########
    {"name": "0.2_0.1_0.1", "growth_rates": [0.2, 0.1, 0.1]},
    {"name": "0.2_0.1_0.2", "growth_rates": [0.2, 0.1, 0.2]},
    {"name": "0.2_0.1_0.3", "growth_rates": [0.2, 0.1, 0.3]},
    {"name": "0.2_0.1_0.4", "growth_rates": [0.2, 0.1, 0.4]},
    
    {"name": "0.2_0.2_0.1", "growth_rates": [0.2, 0.2, 0.1]},
    {"name": "0.2_0.2_0.2", "growth_rates": [0.2, 0.2, 0.2]},
    {"name": "0.2_0.2_0.3", "growth_rates": [0.2, 0.2, 0.3]},
    {"name": "0.2_0.2_0.4", "growth_rates": [0.2, 0.2, 0.4]},
    
    {"name": "0.2_0.3_0.1", "growth_rates": [0.2, 0.3, 0.1]},
    {"name": "0.2_0.3_0.2", "growth_rates": [0.2, 0.3, 0.2]},
    {"name": "0.2_0.3_0.3", "growth_rates": [0.2, 0.3, 0.3]},
    {"name": "0.2_0.3_0.4", "growth_rates": [0.2, 0.3, 0.4]},

    {"name": "0.2_0.4_0.1", "growth_rates": [0.2, 0.4, 0.1]},
    {"name": "0.2_0.4_0.2", "growth_rates": [0.2, 0.4, 0.2]},
    {"name": "0.2_0.4_0.3", "growth_rates": [0.2, 0.4, 0.3]},
    {"name": "0.2_0.4_0.4", "growth_rates": [0.2, 0.4, 0.4]},

    ###########
    {"name": "0.3_0.1_0.1", "growth_rates": [0.3, 0.1, 0.1]},
    {"name": "0.3_0.1_0.2", "growth_rates": [0.3, 0.1, 0.2]},
    {"name": "0.3_0.1_0.3", "growth_rates": [0.3, 0.1, 0.3]},
    {"name": "0.3_0.1_0.4", "growth_rates": [0.3, 0.1, 0.4]},

    {"name": "0.3_0.2_0.1", "growth_rates": [0.3, 0.2, 0.1]},
    {"name": "0.3_0.2_0.2", "growth_rates": [0.3, 0.2, 0.2]},
    {"name": "0.3_0.2_0.3", "growth_rates": [0.3, 0.2, 0.3]},
    {"name": "0.3_0.2_0.4", "growth_rates": [0.3, 0.2, 0.4]},
    
    {"name": "0.3_0.3_0.1", "growth_rates": [0.3, 0.3, 0.1]},
    {"name": "0.3_0.3_0.2", "growth_rates": [0.3, 0.3, 0.2]},
    {"name": "0.3_0.3_0.3", "growth_rates": [0.3, 0.3, 0.3]},
    {"name": "0.3_0.3_0.4", "growth_rates": [0.3, 0.3, 0.4]},

    {"name": "0.3_0.4_0.1", "growth_rates": [0.3, 0.4, 0.1]},
    {"name": "0.3_0.4_0.2", "growth_rates": [0.3, 0.4, 0.2]},
    {"name": "0.3_0.4_0.3", "growth_rates": [0.3, 0.4, 0.3]},
    {"name": "0.3_0.4_0.4", "growth_rates": [0.3, 0.4, 0.4]},

    ###########
    {"name": "0.4_0.1_0.1", "growth_rates": [0.4, 0.1, 0.1]},
    {"name": "0.4_0.1_0.2", "growth_rates": [0.4, 0.1, 0.2]},
    {"name": "0.4_0.1_0.3", "growth_rates": [0.4, 0.1, 0.3]},
    {"name": "0.4_0.1_0.4", "growth_rates": [0.4, 0.1, 0.4]},

    {"name": "0.4_0.2_0.1", "growth_rates": [0.4, 0.2, 0.1]},
    {"name": "0.4_0.2_0.2", "growth_rates": [0.4, 0.2, 0.2]},
    {"name": "0.4_0.2_0.3", "growth_rates": [0.4, 0.2, 0.3]},
    {"name": "0.4_0.2_0.4", "growth_rates": [0.4, 0.2, 0.4]},
    
    {"name": "0.4_0.3_0.1", "growth_rates": [0.4, 0.3, 0.1]},
    {"name": "0.4_0.3_0.2", "growth_rates": [0.4, 0.3, 0.2]},
    {"name": "0.4_0.3_0.3", "growth_rates": [0.4, 0.3, 0.3]},
    {"name": "0.4_0.3_0.4", "growth_rates": [0.4, 0.3, 0.4]},

    {"name": "0.4_0.4_0.1", "growth_rates": [0.4, 0.4, 0.1]},
    {"name": "0.4_0.4_0.2", "growth_rates": [0.4, 0.4, 0.2]},
    {"name": "0.4_0.4_0.3", "growth_rates": [0.4, 0.4, 0.3]},
    {"name": "0.4_0.4_0.4", "growth_rates": [0.4, 0.4, 0.4]},
]



print(next_end_of_month)
print(three_months_later_end_of_month)

# Future dates
future_dates = pd.date_range(start=next_end_of_month, end=three_months_later_end_of_month, freq='M')

# Placeholder for aggregated simulation results
aggregated_simulations = pd.DataFrame(index=df.index.union(future_dates))

# Process each scenario
for scenario in scenarios:
    last_close = df.iloc[-1]['Close']
    simulated_closes = [last_close]

    # Simulate future 'Close' prices and calculate YoY returns
    for growth_rate in scenario['growth_rates']:
        new_close = simulated_closes[-1] * (1 + growth_rate / 100)
        simulated_closes.append(new_close)

    # Append simulated 'Close' prices for future months
    df_simulated = pd.DataFrame({'Close': simulated_closes[1:]}, index=future_dates)
    df_extended = pd.concat([df[['Close']], df_simulated])

    # Calculate YoY returns including the simulated months
    df_extended['Simulated_YoY'] = df_extended['Close'].pct_change(12)
    column_name = f"YoY_{scenario['name']}"
    aggregated_simulations[column_name] = df_extended['Simulated_YoY']

# Now, aggregated_simulations includes all the simulated YoY returns.
# Let's fill NaN values for continuity in the original time series part.
aggregated_simulations.fillna(method='ffill', inplace=True)

# Display the DataFrame including the new simulated month rows
print(aggregated_simulations.tail(15))
aggregated_simulations = aggregated_simulations.tail(6)
aggregated_simulations.index = aggregated_simulations.index.date
aggregated_simulations = aggregated_simulations.multiply(100).round(3)
aggregated_simulations = aggregated_simulations.T
aggregated_simulations = aggregated_simulations.reset_index()
aggregated_simulations.rename(columns={'index': 'Scenario'}, inplace=True)

print(aggregated_simulations)
df = aggregated_simulations.copy()
fig = go.Figure(data=[go.Table(
    header=dict(
        values=list(df.columns),
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise'
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=12)  # Increase cell font size here
    )
)])

fig.update_layout(autosize=False,
                  width=900,
                  height=1550,
                  title="Core PCE Year on Year Simulation")  # Add title here
fig.write_image('us_corepce_table_sim.png')
fig.write_image('us_corepce_table_sim.jpg')





### ------------------------------------------------------------------------------------------------------------

### yield curve rates vs economics viaralbes

#hisotircal   time series and then scatterplot  


#10y rates, 5 y ratses, 2y rates 1 y rates
#historical rates versus unemplymente
#historical rates versus gdp
#historicar rates versus fx
#historical rates verus payrols
##histoircal rates versus inflation core pce
#histoircal ip
#ism
#consumer sensitmentes

us_m_tickers = ['mgdp',
                'ip','ismc','napmc','nmfc',
                'jcbm','jctgbm','jcsbm','jcxfebm','lr']

hv_tb_usa_000_001_m = Haver.data(us_m_tickers, country_database, dates=True)

us_m_tickers = ['mgdp',
                'ip',
                'jcbm','jctgbm','jcsbm','jcxfebm']

for x in range(len(us_m_tickers)):
    variable=str(us_m_tickers [x])
    hv_tb_usa_000_001_m[variable]= hv_tb_usa_000_001_m[variable].pct_change(12).multiply(100).round(3)
print("renaming")

hv_tb_usa_000_001_m.rename(columns={"mgdp": "monthly_gdp_sa_s&p"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"ip":"industrial_production_sa"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"ismc": "ism_composite_sa"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"napmc": "ism_manufacturing_sa"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"nmfc": "ism_services_sa"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"jcbm": "pce_index"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"jctgbm": "pce_goods_sa"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"jcsbm": "pce_services_sa"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={'jcxfebm': 'pce_core_sa'}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={'lr': 'ur_monthly'}, inplace=True)

eco_df=hv_tb_usa_000_001_m.copy()
list_eco=eco_df.columns.tolist()

us_m_tickers = ['r111m1y',
                'r111m2y', 
                'r111m5y', 
                'r111ma',
                ]
print("getting from api")
hv_tb_usa_000_001_m=Haver.data(us_m_tickers, "USECON", dates=True)

print("renaming")
hv_tb_usa_000_001_m.rename(columns={"r111m1y": "treasury_1y_avg"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"r111m2y": "treasury_2y_avg"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"r111m5y": "treasury_5y_avg"}, inplace=True)
hv_tb_usa_000_001_m.rename(columns={"r111ma":  "treasury_10y_avg"}, inplace=True)
rates_df=hv_tb_usa_000_001_m.copy()
list_rates=rates_df.columns.tolist()

list_rates1=["treasury_2y_avg","treasury_10y_avg"]



### time series

loop_parameters = [
    ( 1,500),
    (2,252),
    ( 3,125),
    ( 4,66),]

list_tail = [(12*20),(12*10)]



# Loop over each time window
#for number, time_y in loop_parameters:
n=0
for x_vb in list_eco:
    print(x_vb)
    eco_df001=eco_df[[x_vb]]
    rates_df000=rates_df.copy()
    df000 = pd.concat([eco_df001, rates_df000], axis=1, join="outer")
    print(df000.columns.tolist())
    #df000=df000.tail(12*20)
    title_r=f"{x_vb}"
    #y_label="Index %"
    #x_label=title_r
    list_c=df000.columns.tolist()
    
    for tail_n in list_tail:
        df1=df000.copy()
        df1=df1.tail(tail_n)
        g1=df1.copy()
        fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))  # Create figure
    
        # Define different blue shades for the right y-axis lines
        colors = ["black", "mediumblue", "dodgerblue", "steelblue", "cornflowerblue", "deepskyblue"]
        
        # Plot the first line on the LEFT y-axis (dark green)
        g1.plot(kind='line', ax=ax, y=list_c[0], color="darkgreen", linewidth=l1+2, linestyle='-',
                marker='D', markersize=0, label=str(list_c[0]))  # Left Y-axis
        
        # Create a second y-axis for the remaining lines
        ax2 = ax.twinx()  
        
        # Plot the rest of the lines on the RIGHT y-axis using different shades of blue
        for i, col in enumerate(list_c[1:]):  # Iterate over remaining columns
            color = colors[i % len(colors)]  # Cycle through blue tones
            g1.plot(kind='line', ax=ax2, y=col, color=color, linewidth=l1, linestyle='-',
                    marker='D', markersize=0, alpha=0.8, label=str(col))  # Right Y-axis
        
        # Formatting and Labels
        ax.set_ylabel(f"{x_vb} (Left Axis)", size=parameter3, color="darkgreen")  # Left y-axis label
        ax2.set_ylabel("Rates (Right Axis)", size=parameter3, color="darkblue")  # Right y-axis label
        ax.set_xlabel("x_label", size=parameter3)
        ax.tick_params(labelsize=parameter4)
        ax2.tick_params(labelsize=parameter4)
        
        # Independent y-axis scales (no forced alignment)
        # ax2.set_ylim(ax.get_ylim())  # Removed to allow different scales
        
        # Grid, Title, and Additional Formatting
        plt.title(str(title_r), size=parameter5)
        #plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
        plt.grid(axis='both', alpha=0.3)
        
        # Watermark or Text Overlay
        plt.text(0.15, 0.15, str(owner), fontsize=40, color="gray", alpha=0.5,
                 ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
        
        # Save and Cleanup
        filename = f"hv_tb_usa_020_001_m_g_0{n:02d}.png"
        # Save and Cleanup
        plt.savefig(filename, bbox_inches="tight")    
        plt.close('all')
        plt.clf()
        plt.cla()
        
        del g1, fig, ax, ax2
        n += 1


## Scagtterplot  



## Scagtterplot  

# Loop over each time window
#for number, time_y in loop_parameters:
n=0
for x_vb in list_eco:
    print(x_vb)
    eco_df001=eco_df[[x_vb]]

    for y_vb in list_rates1:
        print(y_vb)
        rates_df000=rates_df[[y_vb]]   
        rates_df000=rates_df.copy()

        title_r = f" {x_vb} v. {y_vb}"
        
        df000 = pd.concat([eco_df001, rates_df000], axis=1, join="outer")
        print(df000.columns.tolist())
        df00_sp=df000.copy()
        df00_sp = df00_sp.tail(12*10)       
        df00_sp['year'] = df00_sp.index.year
        x = df00_sp[x_vb]
        y = df00_sp[y_vb]
        t = df00_sp['year']
        y_label = y_vb
        x_label = x_vb
        print(len(x))
        print(len(y))
        
        df00_sp.index= df00_sp.index.date
        g1=df00_sp.copy()
        fig,ax = plt.subplots(figsize=(8,8))
        plt.scatter(g1[x_vb], 
                    g1[y_vb],                
                    c=g1.year,
                    s=75,
                    cmap="brg", zorder=2)
        plt.plot(g1[x_vb], g1[y_vb], color="lightgray", alpha=0.3, zorder=1)
        
        #add annotations in every 3 data points with a Loop
        for line in range(0, g1.shape[0], 6):
            plt.annotate(
                g1.index[line],
                (g1[x_vb].iloc[line],
                 g1[y_vb].iloc[line]
                 ),
                va="top",
                ha='right',
                size=7)
        x0 = x.iloc[range(len(x)-1)].values
        x1 = x.iloc[range(1,len(x))].values
        y0 = y.iloc[range(len(y)-1)].values
        y1 = y.iloc[range(1,len(y))].values
        xpos = (x0+x1)/2
        ypos = (y0+y1)/2
        xdir = x1-x0
        ydir = y1-y0
        plt.style.use('default')
        plt.ylabel(str(y_label), size=15)
        plt.xlabel(str(x_label), size=15)
        plt.tick_params(labelsize=10)
        plt.title(str(title_r), size=15)
        plt.grid(axis='both', alpha=.5)
        ax2 = ax.twinx()
        ax2.set_ylim(ax.get_ylim())
        filename = f"hv_tb_usa_021_001_m_g_0{n:02d}.png"
        plt.savefig(filename, bbox_inches='tight')
        #plt.savefig(str("hv_tb_ycus_002_001_m_g_00"+str(time_n)+str(".png")), bbox_inches='tight')
        # Close the figure to free memory
        plt.close()
        plt.close()
        plt.close('all')
        plt.clf()
        plt.cla()
        n=n+1



### heatmap 



# Real Gross Domestic Product SAAR
# Personal Consumption Expenditure SAAR

# "ml12vpnq", "ml12vpms"
# ukvna
hhi_m_tickers1=["mgdp","nrsxm","ip","csent","ccin","napmc","nmfc","ffedtahe",
                "pcuy","ypcuslfe","acpiscsy","jcbm","jcxfebm","jcsxehm","clevpcey","pce12",
                "wgto","lp","lr","laxepa","lanagrd","laprivd","cinf1","cinf5",
                "ljjtpa","ljhtpa","ljqtpa","ljltpa","licm","lktpriva","letpriva",
                "vsmida","vsmina","fmv2","farmb","fcm10e"]
hv_tb_hh_000_001_m = Haver.data(hhi_m_tickers1, "USECON", dates=True)
#print(hv_tb_hh_000_001_m)
hhi_m_tickers2 = ["pgdph", "pch", "fodspx", "fofor"]
hv_tb_hh_000_002_m = Haver.data(hhi_m_tickers2, "USECON", dates=True)
#print(hv_tb_hh_000_002_m)
hv_tb_hh_000_001_m = pd.concat([hv_tb_hh_000_001_m, hv_tb_hh_000_002_m], axis=1, join="outer")
# hv_tb_hh_000_001_m = pd.concat([hv_tb_hh_000_001_m, hv_tb_hh_000_002_m], axis=1, join="outer")
hh_m_tickers = hhi_m_tickers1 + hhi_m_tickers2
hv_tb_hh_000_001_m = hv_tb_hh_000_001_m.fillna(method="bfill")

hv_tb_hh_000_001_m["Real: S&P US Monthly GDP SA YY%"] = hv_tb_hh_000_001_m["mgdp"].pct_change(periods=12,
                                                                                              fill_method="bfill").multiply(100).round(1)

hv_tb_hh_000_001_m.rename(columns={"pgdph": "Real: Real Gross Domestic Product SAAR"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"pch": "Real: Personal Consumption Expenditure SAAR"}, inplace=True)
hv_tb_hh_000_001_m["Real: Retail Sales excl Autos SA YY%"] = hv_tb_hh_000_001_m["nrsxm"].pct_change(periods=12,
                                                                                                    fill_method="bfill").multiply(100).round(1)
hv_tb_hh_000_001_m["Real: IP SA YY%"] = hv_tb_hh_000_001_m["ip"].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)

# Wage Growth
hv_tb_hh_000_001_m.rename(columns={"wgto": "Employment: Wage Growth"}, inplace=True)
hv_tb_hh_000_001_m["lp"] = hv_tb_hh_000_001_m["lp"].round(1)
hv_tb_hh_000_001_m.rename(columns={"lp": "Employment: Participation Rate"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"lr": "Employment: Unemployment Rate"}, inplace=True)
# Additional Employment metrics
hv_tb_hh_000_001_m["laxepa"] = hv_tb_hh_000_001_m["laxepa"] / 1000
hv_tb_hh_000_001_m["laxepa"] = hv_tb_hh_000_001_m["laxepa"].round(2)

# Rename ADP Payroll and NFP metrics
hv_tb_hh_000_001_m.rename(columns={"laxepa": "Employment: ADP Private Payroll"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"lanagrd": "Employment: NFP"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"laprivd": "Employment: NFP Private"}, inplace=True)

# Calculate and rename AWE Private and AHE Private metrics
hv_tb_hh_000_001_m["Employment: US AWE Private YY - Establishment Survey"] = hv_tb_hh_000_001_m["lktpriva"].pct_change(
    periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_hh_000_001_m["Employment: US AHE Private YY - Establishment Survey"] = hv_tb_hh_000_001_m["letpriva"].pct_change(
    periods=12, fill_method="bfill").multiply(100).round(1)

# Rename columns for JOLTS data
hv_tb_hh_000_001_m.rename(columns={
    "ljjtpa": "Employment: JOLTS Job Openings Rate SA %",
    "ljhtpa": "Employment: JOLTS Hires Rate SA %",
    "ljqtpa": "Employment: JOLTS Quits Rate SA %",
    "ljltpa": "Employment: JOLTS Layoffs Rate SA %",
    "licm": "Employment: Initial Claims SA"
}, inplace=True)

# Rename and process Price-related columns
hv_tb_hh_000_001_m.rename(columns={"pcuy": "Price: Headline Inflation SA YY"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"ypcuslfe": "Price: Core Inflation SA YY"}, inplace=True)

# Process and rename FRB Atlanta CPI metric
hv_tb_hh_000_001_m["acpiscsy"] = hv_tb_hh_000_001_m["acpiscsy"].round(1)
hv_tb_hh_000_001_m.rename(columns={"acpiscsy": "Price: FRB Atlanta CPI Core Sticky excl h SA YY"}, inplace=True)

# Process and rename PCE Headline metrics
hv_tb_hh_000_001_m["Price: PCE Headline SA YY"] = hv_tb_hh_000_001_m["jcbm"].pct_change(
    periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_hh_000_001_m.rename(columns={"jcbm": "Price: PCE Headline SA YY"}, inplace=True)

# Process and rename PCE Core metrics
hv_tb_hh_000_001_m["Price: PCE Core SA YY"] = hv_tb_hh_000_001_m["jcxfebm"].pct_change(
    periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_hh_000_001_m.rename(columns={"jcxfebm": "Price: PCE Core SA YY"}, inplace=True)

# Process and rename PCE Core Services
hv_tb_hh_000_001_m["Price: PCE Core Services ex h SA YY"] = hv_tb_hh_000_001_m["jcsxehm"].pct_change(
    periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_hh_000_001_m.rename(columns={"jcsxehm": "Price: PCE Core Services ex h SA YY"}, inplace=True)

# Process and rename Cleveland and Dallas PCE metrics
hv_tb_hh_000_001_m["clevpcey"] = hv_tb_hh_000_001_m["clevpcey"].round(1)
hv_tb_hh_000_001_m.rename(columns={"clevpcey": "Price: FRB Clev PCE Median SA YY"}, inplace=True)
hv_tb_hh_000_001_m["pce12"] = hv_tb_hh_000_001_m["pce12"].round(1)
hv_tb_hh_000_001_m.rename(columns={"pce12": "Price: FRB Dallas PCE Trimmed Mean SA YY"}, inplace=True)

# Michigan Inflation Expectations
hv_tb_hh_000_001_m.rename(columns={"cinf1": "Price: Michigan Inflation Expectations 1y YY"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"cinf5": "Price: Michigan Inflation Expectations 5y YY"}, inplace=True)

# ISM Manufacturing and Services
hv_tb_hh_000_001_m["napmc"] = hv_tb_hh_000_001_m["napmc"].round(1)
hv_tb_hh_000_001_m.rename(columns={"napmc": "Cycle: ISM Manufacturing"}, inplace=True)
hv_tb_hh_000_001_m["nmfc"] = hv_tb_hh_000_001_m["nmfc"].round(1)
hv_tb_hh_000_001_m.rename(columns={"nmfc": "Cycle: ISM Services"}, inplace=True)

# Michigan Consumer Sentiment and Conference Board Confidence
hv_tb_hh_000_001_m["csent"] = hv_tb_hh_000_001_m["csent"].round(1)
hv_tb_hh_000_001_m.rename(columns={"csent": "Cycle: Michigan Consumer Sentiment"}, inplace=True)
hv_tb_hh_000_001_m["ccin"] = hv_tb_hh_000_001_m["ccin"].round(1)
hv_tb_hh_000_001_m.rename(columns={"ccin": "Cycle: CBoard Consumer Confidence"}, inplace=True)

# Chicago Business Index
#hv_tb_hh_000_001_m["pmcxbaa"] = hv_tb_hh_000_001_m["pmcxbaa"].round(1)
#hv_tb_hh_000_001_m.rename(columns={"pmcxbaa": "Cycle: Chicago Business Index"}, inplace=True)

# Rename columns for Federal Reserve and financial data
hv_tb_hh_000_001_m.rename(columns={"ffedtahe": "FED Target Rate Upper Limit"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fcm10e": "Financial: Nominal 10y Treasury eop"}, inplace=True)
hv_tb_hh_000_001_m["farmb"] = hv_tb_hh_000_001_m["farmb"].pct_change(
    periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_hh_000_001_m.rename(columns={"farmb": "Financial: Monetary Base yy nsa"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fmv2": "Financial: Velocity of Money GDP m2"}, inplace=True)

# Visa discretionary and nondiscretionary spending indexes
hv_tb_hh_000_001_m.rename(columns={"vsmida": "Financial: Visa discretionary spending index"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"vsmina": "Financial: Visa nondiscretionary spending index"}, inplace=True)

# Household financial ratios
hv_tb_hh_000_001_m.rename(columns={"fodspx": "Financial: Household debt service ratio quarterly"}, inplace=True)
hv_tb_hh_000_001_m.rename(columns={"fofor": "Financial: Household obligation ratio quarterly"}, inplace=True)


#KeyError: "['Employment: JOLTS Quits Rate SA %',
#'Employment: Initial Claims SA', 
#'Price: Headline Inflation SA YY%', 
#'Price: Core Inflation SA YY%',
#'Price: FRB Atlanta CPI Core Sticky excl h SA YY%',
#'Price: PCE Headline SA YY%', 'Price: PCE Core SA YY%', 
#'Price: PCE Core Services ex h SA YY%', 'Price: FRB Clev PCE Median SA YY%', 
##'Price: FRB Dallas PCE Trimmed Mean SA YY%', 
#'Price: Michigan Inflation Expectations 1y YY%', 
#'Price: Michigan Inflation Expectations 5y YY%', 
#'Cycle: Chicago Business Index',
#'Financial: Visa discretionary spending index'] not in index"



#hv_tb_hh_000_001_m.index = hv_tb_hh_000_001_m.index.date
list_c = [
    "Real: S&P US Monthly GDP SA YY%",
    "Real: Real Gross Domestic Product SAAR",
    "Real: Personal Consumption Expenditure SAAR",
    "Real: Retail Sales excl Autos SA YY%",
    "Real: IP SA YY%",
    "Employment: Wage Growth",
    "Employment: Participation Rate",
    "Employment: Unemployment Rate",
    "Employment: NFP Private",
    "Employment: US AWE Private YY - Establishment Survey",
    "Employment: US AHE Private YY - Establishment Survey",
    "Employment: JOLTS Job Openings Rate SA %",
    "Employment: JOLTS Hires Rate SA %",
    "Employment: JOLTS Quits Rate SA %",
    "Employment: JOLTS Layoffs Rate SA %",
    "Employment: Initial Claims SA",
    "Price: Headline Inflation SA YY",
    "Price: Core Inflation SA YY",
    "Price: FRB Atlanta CPI Core Sticky excl h SA YY",
    "Price: PCE Headline SA YY",
    "Price: PCE Core SA YY",
    "Price: PCE Core Services ex h SA YY",
    "Price: FRB Clev PCE Median SA YY",
    "Price: FRB Dallas PCE Trimmed Mean SA YY",
    "Price: Michigan Inflation Expectations 1y YY",
    "Price: Michigan Inflation Expectations 5y YY",
    "Cycle: ISM Manufacturing",
    "Cycle: ISM Services",
    "Cycle: Michigan Consumer Sentiment",
    "Cycle: CBoard Consumer Confidence",
    #"Cycle: Chicago Business Index",
    "FED Target Rate Upper Limit",
    "Financial: Nominal 10y Treasury eop",
    "Financial: Monetary Base yy nsa",
    "Financial: Velocity of Money GDP m2",
    "Financial: Visa discretionary spending index",
    "Financial: Visa nondiscretionary spending index",
    "Financial: Household debt service ratio quarterly",
    "Financial: Household obligation ratio quarterly"
]
list_xc = [
    "Real: IP SA YY%",
    "Real: DMP Realized Sales Growth NSA",
    "Real: DMP Expected Sales Growth NSA",
    "Real: Halifax House Price SA YY%",
    "Real: Rightmove House Price NSA YY%",
    "Employment: LFS Unemployment Rate SA",
    "Employment: LFS Eco Active",
    "Employment: PAYE Employment Change SA",
    "Employment: PAYE Median change SA",
    "Employment: Adzuna Job Advertisements YY%",
    "Employment: AWE Whole Economy Regular Pay YY%",
    "Employment: AWE Private Sector Regular Pay YY%",
    "Employment: AWE Public Sector Regular Pay YY%",
    "Employment: DMP Realized Employment Growth NSA",
    "Employment: DMP Expected Employment Growth NSA",
    "Employment: DMP Realized Wage Growth NSA",
    "Employment: DMP Expected Wage Growth NSA",
    "Price: CPI Headline NSA YY%",
    "Price: CPI Core NSA YY%",
    "Price: CPI Goods NSA YY%",
    "Price: CPI Services NSA YY%",
    "DMP CPI Expected 1Y ahead NSA",
    "DMP CPI Expected 3Y ahead NSA",
    "DMP Realized Price Growth NSA",
    "DMP Expected Price Growth NSA",
    "Cycle: PMI Manufacturing SA",
    "Cycle: PMI Services SA",
    "Cycle: Lloyds Overall Bs Confidence NSA",
    "Cycle: GFK Consumer Confidence Barometer"
]



# Configuration
hv_tb_hh_000_001_m = hv_tb_hh_000_001_m[list_c]
hv_tb_hh_000_001_m_c = hv_tb_hh_000_001_m.copy()
hv_tb_hh_000_001_m_c = hv_tb_hh_000_001_m_c.tail(120)
hv_tb_hh_000_001_m = hv_tb_hh_000_001_m.tail(60)

# Size settings
n_time = 42
size1 = 26
size2 = 19
font_size_h = 10
number_vbs=40
x_size1=12
x2_size1=x_size1-4
xlabel_size = 20
title_s = 25

# Data preparation
df1 = hv_tb_hh_000_001_m.copy()
df1 = df1.tail(n_time)
df1 = df1.transpose()
df1.index.names = ['Variable']

# Iterate through rows to process data
num_rows = df1.shape[0]
for x in range(num_rows):
    locals()[f"data_r{x}"] = pd.DataFrame([df1.iloc[x]])

# Calculate min and max for each column
for x in range(num_rows):
    locals()[f"vmin_{x}"] = hv_tb_hh_000_001_m_c.iloc[:, x].min()
    locals()[f"vmax_{x}"] = hv_tb_hh_000_001_m_c.iloc[:, x].max()

# Print example values
print(vmin_0)
print(vmax_0)

# Visualization setup
# Example for random data
# data = np.random.random((10, 12))
# df = pd.DataFrame(data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))

# Uncomment for color palette visualization
# sns.color_palette("coolwarm", as_cmap=True)



# Heatmap visualizations with subplots
fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)

# Plot heatmaps for each data subset
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})

sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})


# Additional heatmap plotting
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r38, cmap=red_to_blue, annot=True, ax=axes[38], cbar=False, vmin=vmin_38, vmax=vmax_38, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r39, cmap=red_to_blue, annot=True, ax=axes[39], cbar=False, vmin=vmin_39, vmax=vmax_39, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})

# Adjusting tick labels
n = 0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_size1, rotation=0)
    locals()[f"axes_t{n}"] = ax.twinx()
    locals()[f"axes_t{n}"].set_yticklabels(ax.get_yticklabels(), fontsize=x2_size1, rotation=0, va="center")
    n += 1

# Final adjustments
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45)

# Add title and save figure
fig.suptitle("USA Economic Dashboard", fontsize=title_s)
plt.figtext(0.5, 0.02, "USA Economic Dashboard", fontsize=15, ha="center")
plt.subplots_adjust(hspace=1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('us_heatmap_001.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()






### 001_fomc Forecasts   <a id="title_page"></a>

######Forecasts
######Forecasts
######Forecasts
######Forecasts
######Forecasts

usi_m_tickers = ['ffrmd', 'ffrmt', 'ffrlt', 'ffrht', 'ffrlr', 'ffrhr']
hv_tb_us_000_001_m=Haver.data(usi_m_tickers, "usecon", dates=True)
print(hv_tb_us_000_001_m)
hv_tb_us_000_001_m.rename(columns={"ffrmd": "FOMC Appropriate FFR Median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt": "FOMC Appropriate FFR Central Tendency Mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrlt": "FOMC Appropriate FFR Central Tendency Low"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrht": "FOMC Appropriate FFR Central Tendency High"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrlr": "FOMC Appropriate FFR Range Low"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrhr": "FOMC Appropriate FFR Range High"}, inplace=True)
df = hv_tb_us_000_001_m.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")


#hv_tb_us_000_001_m_g_001=hv_tb_us_000_001_m
#print(hv_tb_us_000_001_m)
#hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(48)
df = df.transpose()
df.index.names = ['Variable']
#print(hv_tb_us_000_001_m)
#df = df.transpose()
df["Index"] = df.index
#df["Index"] = df.index
column_to_move = "Index"
# Reorder columns
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
print(df)


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=15),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ),
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=False,
                  width=1400,
                  height=500,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_fed_forecast.png')



### fed forecast evolaiution 

usi_m_tickers1 = ["gdpmd244","gdpmd243","gdpmd242","gdpmd241",
               "gdpmd234","gdpmd233","gdpmd232","gdpmd231",
               "gdpmd224","gdpmd223","gdpmd222","gdpmd221",
               "gdpmd214","gdpmd213","gdpmd212","gdpmd211",
               "gdpmd204","gdpmd203",
               "pcemd244","pcemd243","pcemd242","pcemd241",
               "pcemd234","pcemd233","pcemd232","pcemd231",
               "pcemd224","pcemd223","pcemd222","pcemd221",
               "pcemd214","pcemd213","pcemd212","pcemd211",
               "pcemd204","pcemd203",
               "pcxmd244","pcxmd243","pcxmd242","pcxmd241",
               "pcxmd234","pcxmd233","pcxmd232","pcxmd231",
               "pcxmd224","pcxmd223","pcxmd222","pcxmd221",
               "pcxmd214","pcxmd213","pcxmd212","pcxmd211",
               "pcxmd204","pcxmd203",
               "lrmd244","lrmd243","lrmd242","lrmd241",
               "lrmd234","lrmd233","lrmd232","lrmd231",
               "lrmd224","lrmd223","lrmd222","lrmd221",
               "lrmd214","lrmd213","lrmd212","lrmd211",
               "lrmd204","lrmd203",
               "ffrmd244","ffrmd243","ffrmd242","ffrmd241",
               "ffrmd234","ffrmd233","ffrmd232","ffrmd231",
               "ffrmd224","ffrmd223","ffrmd222","ffrmd221",
               "ffrmd214","ffrmd213","ffrmd212","ffrmd211",
               "ffrmd204","ffrmd203"]

usi_m_tickers2 =["gdpmt244","gdpmt243","gdpmt242","gdpmt241",
               "gdpmt234","gdpmt233","gdpmt232","gdpmt231",
               "gdpmt224","gdpmt223","gdpmt222","gdpmt221",
               "gdpmt214","gdpmt213","gdpmt212","gdpmt211",
               "gdpmt204","gdpmt203",
               "pcemt244","pcemt243","pcemt242","pcemt241",
               "pcemt234","pcemt233","pcemt232","pcemt231",
               "pcemt224","pcemt223","pcemt222","pcemt221",
               "pcemt214","pcemt213","pcemt212","pcemt211",
               "pcemt204","pcemt203",
               "pcxmt244","pcxmt243","pcxmt242","pcxmt241",
               "pcxmt234","pcxmt233","pcxmt232","pcxmt231",
               "pcxmt224","pcxmt223","pcxmt222","pcxmt221",
               "pcxmt214","pcxmt213","pcxmt212","pcxmt211",
               "pcxmt204","pcxmt203",
               "lrmt244","lrmt243","lrmt242","lrmt241",
               "lrmt234","lrmt233","lrmt232","lrmt231",
               "lrmt224","lrmt223","lrmt222","lrmt221",
               "lrmt214","lrmt213","lrmt212","lrmt211",
               "lrmt204","lrmt203",
               "ffrmt244","ffrmt243","ffrmt242","ffrmt241",
               "ffrmt234","ffrmt233","ffrmt232","ffrmt231",
               "ffrmt224","ffrmt223","ffrmt222","ffrmt221",
               "ffrmt214","ffrmt213","ffrmt212","ffrmt211",
               "ffrmt204","ffrmt203"]


usi_m_tickers=usi_m_tickers1+usi_m_tickers2
hv_tb_us_000_001_m=Haver.data(usi_m_tickers, "SURVEYS", dates=True)
print(hv_tb_us_000_001_m)

#hv_tb_us_000_001_m.to_clipboard()

hv_tb_us_000_001_m.rename(columns={"gdpmd244": "fomc_2024Q4_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd243": "fomc_2024Q3_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd242": "fomc_2024Q2_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd241": "fomc_2024Q1_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd234": "fomc_2023Q4_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd233": "fomc_2023Q3_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd232": "fomc_2023Q2_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd231": "fomc_2023Q1_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd224": "fomc_2022Q4_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd223": "fomc_2022Q3_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd222": "fomc_2022Q2_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd221": "fomc_2022Q1_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd214": "fomc_2021Q4_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd213": "fomc_2021Q3_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd212": "fomc_2021Q2_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd211": "fomc_2021Q1_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd204": "fomc_2020Q4_gdp_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmd203": "fomc_2020Q3_gdp_median"}, inplace=True)
##############
hv_tb_us_000_001_m.rename(columns={"pcemd244": "fomc_2024Q4_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd243": "fomc_2024Q3_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd242": "fomc_2024Q2_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd241": "fomc_2024Q1_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd234": "fomc_2023Q4_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd233": "fomc_2023Q3_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd232": "fomc_2023Q2_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd231": "fomc_2023Q1_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd224": "fomc_2022Q4_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd223": "fomc_2022Q3_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd222": "fomc_2022Q2_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd221": "fomc_2022Q1_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd214": "fomc_2021Q4_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd213": "fomc_2021Q3_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd212": "fomc_2021Q2_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd211": "fomc_2021Q1_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd204": "fomc_2020Q4_pce_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemd203": "fomc_2020Q3_pce_median"},  inplace=True)
##############                          
hv_tb_us_000_001_m.rename(columns={"pcxmd244": "fomc_2024Q4_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd243": "fomc_2024Q3_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd242": "fomc_2024Q2_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd241": "fomc_2024Q1_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd234": "fomc_2023Q4_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd233": "fomc_2023Q3_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd232": "fomc_2023Q2_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd231": "fomc_2023Q1_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd224": "fomc_2022Q4_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd223": "fomc_2022Q3_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd222": "fomc_2022Q2_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd221": "fomc_2022Q1_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd214": "fomc_2021Q4_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd213": "fomc_2021Q3_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd212": "fomc_2021Q2_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd211": "fomc_2021Q1_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd204": "fomc_2020Q4_pcecore_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmd203": "fomc_2020Q3_pcecore_median"},  inplace=True)

##############
hv_tb_us_000_001_m.rename(columns={"lrmd244": "fomc_2024Q4_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd243": "fomc_2024Q3_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd242": "fomc_2024Q2_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd241": "fomc_2024Q1_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd234": "fomc_2023Q4_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd233": "fomc_2023Q3_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd232": "fomc_2023Q2_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd231": "fomc_2023Q1_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd224": "fomc_2022Q4_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd223": "fomc_2022Q3_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd222": "fomc_2022Q2_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd221": "fomc_2022Q1_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd214": "fomc_2021Q4_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd213": "fomc_2021Q3_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd212": "fomc_2021Q2_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd211": "fomc_2021Q1_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd204": "fomc_2020Q4_ur_median"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmd203": "fomc_2020Q3_ur_median"}, inplace=True)

##############            
hv_tb_us_000_001_m.rename(columns={"ffrmd244": "fomc_2024Q4_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd243": "fomc_2024Q3_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd242": "fomc_2024Q2_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd241": "fomc_2024Q1_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd234": "fomc_2023Q4_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd233": "fomc_2023Q3_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd232": "fomc_2023Q2_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd231": "fomc_2023Q1_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd224": "fomc_2022Q4_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd223": "fomc_2022Q3_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd222": "fomc_2022Q2_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd221": "fomc_2022Q1_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd214": "fomc_2021Q4_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd213": "fomc_2021Q3_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd212": "fomc_2021Q2_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd211": "fomc_2021Q1_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd204": "fomc_2020Q4_rate_median"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmd203": "fomc_2020Q3_rate_median"},  inplace=True)


##############                                

hv_tb_us_000_001_m.rename(columns={"gdpmt244": "fomc_2024Q4_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt243": "fomc_2024Q3_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt242": "fomc_2024Q2_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt241": "fomc_2024Q1_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt234": "fomc_2023Q4_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt233": "fomc_2023Q3_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt232": "fomc_2023Q2_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt231": "fomc_2023Q1_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt224": "fomc_2022Q4_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt223": "fomc_2022Q3_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt222": "fomc_2022Q2_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt221": "fomc_2022Q1_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt214": "fomc_2021Q4_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt213": "fomc_2021Q3_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt212": "fomc_2021Q2_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt211": "fomc_2021Q1_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt204": "fomc_2020Q4_gdp_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"gdpmt203": "fomc_2020Q3_gdp_ct_mean"}, inplace=True)
##############

hv_tb_us_000_001_m.rename(columns={"pcemt244": "fomc_2024Q4_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt243": "fomc_2024Q3_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt242": "fomc_2024Q2_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt241": "fomc_2024Q1_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt234": "fomc_2023Q4_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt233": "fomc_2023Q3_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt232": "fomc_2023Q2_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt231": "fomc_2023Q1_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt224": "fomc_2022Q4_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt223": "fomc_2022Q3_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt222": "fomc_2022Q2_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt221": "fomc_2022Q1_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt214": "fomc_2021Q4_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt213": "fomc_2021Q3_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt212": "fomc_2021Q2_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt211": "fomc_2021Q1_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt204": "fomc_2020Q4_pce_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcemt203": "fomc_2020Q3_pce_ct_mean"},  inplace=True)


##############

hv_tb_us_000_001_m.rename(columns={"pcxmt244": "fomc_2024Q4_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt243": "fomc_2024Q3_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt242": "fomc_2024Q2_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt241": "fomc_2024Q1_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt234": "fomc_2023Q4_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt233": "fomc_2023Q3_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt232": "fomc_2023Q2_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt231": "fomc_2023Q1_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt224": "fomc_2022Q4_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt223": "fomc_2022Q3_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt222": "fomc_2022Q2_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt221": "fomc_2022Q1_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt214": "fomc_2021Q4_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt213": "fomc_2021Q3_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt212": "fomc_2021Q2_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt211": "fomc_2021Q1_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt204": "fomc_2020Q4_pcecore_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"pcxmt203": "fomc_2020Q3_pcecore_ct_mean"},  inplace=True)


##############

hv_tb_us_000_001_m.rename(columns={"lrmt244": "fomc_2024Q4_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt243": "fomc_2024Q3_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt242": "fomc_2024Q2_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt241": "fomc_2024Q1_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt234": "fomc_2023Q4_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt233": "fomc_2023Q3_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt232": "fomc_2023Q2_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt231": "fomc_2023Q1_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt224": "fomc_2022Q4_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt223": "fomc_2022Q3_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt222": "fomc_2022Q2_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt221": "fomc_2022Q1_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt214": "fomc_2021Q4_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt213": "fomc_2021Q3_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt212": "fomc_2021Q2_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt211": "fomc_2021Q1_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt204": "fomc_2020Q4_ur_ct_mean"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"lrmt203": "fomc_2020Q3_ur_ct_mean"}, inplace=True)


##############                         

hv_tb_us_000_001_m.rename(columns={"ffrmt244": "fomc_2024Q4_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt243": "fomc_2024Q3_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt242": "fomc_2024Q2_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt241": "fomc_2024Q1_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt234": "fomc_2023Q4_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt233": "fomc_2023Q3_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt232": "fomc_2023Q2_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt231": "fomc_2023Q1_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt224": "fomc_2022Q4_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt223": "fomc_2022Q3_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt222": "fomc_2022Q2_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt221": "fomc_2022Q1_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt214": "fomc_2021Q4_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt213": "fomc_2021Q3_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt212": "fomc_2021Q2_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt211": "fomc_2021Q1_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt204": "fomc_2020Q4_rate_ct_mean"},  inplace=True)
hv_tb_us_000_001_m.rename(columns={"ffrmt203": "fomc_2020Q3_rate_ct_mean"},  inplace=True)

hv_tb_us_000_001_m.to_clipboard()

hv_tb_us_000_001_m2=hv_tb_us_000_001_m.copy()
hv_tb_us_000_001_m2 = hv_tb_us_000_001_m2.apply(lambda col: col.dropna().reset_index(drop=True))
hv_tb_us_000_001_m2g=hv_tb_us_000_001_m2.copy()

hv_tb_us_000_001_m2.to_clipboard()
hv_tb_us_000_001_m2 = hv_tb_us_000_001_m2.T
hv_tb_us_000_001_m2 = hv_tb_us_000_001_m2.reset_index()

hv_tb_us_000_001_m2["year"] = hv_tb_us_000_001_m2["index"].str.extract(r"fomc_(\d{4})Q\d")
hv_tb_us_000_001_m2["quarter"] = hv_tb_us_000_001_m2["index"].str.extract(r"Q(\d)")
hv_tb_us_000_001_m2["variable"] = hv_tb_us_000_001_m2["index"].apply(
    lambda x: "GDP" if "gdp" in x else
              "Rate" if "rate" in x else
              "UR" if "ur" in x else
              "PCE Core" if "pcecore" in x else
              "PCE" if "pce" in x else "Other"
)
hv_tb_us_000_001_m2["forecast_type"] = hv_tb_us_000_001_m2["index"].apply(
    lambda x: "Median" if "median" in x else "CT Mean" if "ct_mean" in x else "Other"
)

hv_tb_us_000_001_m2.rename(columns={0: "year_0"},  inplace=True)
hv_tb_us_000_001_m2.rename(columns={1: "year_1"},  inplace=True)
hv_tb_us_000_001_m2.rename(columns={2: "year_2"},  inplace=True)
hv_tb_us_000_001_m2.rename(columns={3: "year_3"},  inplace=True)


hv_tb_us_000_001_m2["long_term"] = hv_tb_us_000_001_m2.apply(
    lambda row: row["year_3"] if row["quarter"] in [3, 4] else row["year_2"], axis=1)

hv_tb_us_000_001_m2["long_term"]  = hv_tb_us_000_001_m2["long_term"] + (np.random.uniform(low=-0.02, high=0.02, size=len(hv_tb_us_000_001_m2)))

hv_tb_us_000_001_m2["label"]=hv_tb_us_000_001_m2["year"]+"Q"+hv_tb_us_000_001_m2["quarter"]
hv_tb_us_000_001_m2=hv_tb_us_000_001_m2[hv_tb_us_000_001_m2.forecast_type=="Median"]


print(hv_tb_us_000_001_m2.columns.tolist())

# Create a pivot table with "year" in the columns section
df_pivot_table = hv_tb_us_000_001_m2.pivot_table(index="label", columns="variable", values="long_term",aggfunc="mean")
df_pivot_table=df_pivot_table.tail(12)
print(df_pivot_table)
df_pivot_table001=df_pivot_table[["Rate","GDP"]]
df_pivot_table002=df_pivot_table[["Rate","UR"]]
df_pivot_table003=df_pivot_table[["GDP","UR"]]
df_pivot_table004=df_pivot_table[["Rate","PCE Core"]]
df_pivot_table005=df_pivot_table[["GDP","PCE Core"]]

### scatterplot plot fed sep

n=1


pivot_df = [
    ("df_pivot_table001","Rate","GDP"),
    ("df_pivot_table002","Rate","UR"),
    ("df_pivot_table003","GDP","UR"),
    ("df_pivot_table004","Rate","PCE Core"),
    ("df_pivot_table005","GDP","PCE Core")]

for df_pv, x_vb,y_vb  in pivot_df:   
    df00_sp= locals().get(df_pv)
    x = df00_sp[x_vb]
    y = df00_sp[y_vb]
    #t = df00_sp['year']
    y_label = y_vb
    x_label = x_vb    
    title_r=f" Fed SEP Long term \n X: {x_label} vs. Y: {y_vb}"
    g1=df00_sp.copy()
    fig,ax = plt.subplots(figsize=(8,8))
    plt.scatter(g1[x_vb], 
                g1[y_vb],                
                #c=g1.year,
                s=100,cmap="brg", zorder=2)
    plt.plot(g1[x_vb], g1[y_vb], color="lightgray", alpha=0.65, zorder=1)

    #add annotations in every 3 data points with a Loop
    for line in range(0, g1.shape[0], 1):
        plt.annotate( g1.index[line],(g1[x_vb].iloc[line], g1[y_vb].iloc[line] ),
            va="top", ha='right',  size=8)
    x0 = x.iloc[range(len(x)-1)].values
    x1 = x.iloc[range(1,len(x))].values
    y0 = y.iloc[range(len(y)-1)].values
    y1 = y.iloc[range(1,len(y))].values
    xpos = (x0+x1)/2
    ypos = (y0+y1)/2
    xdir = x1-x0
    ydir = y1-y0
    plt.style.use('default')
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.tick_params(labelsize=10)
    plt.title(str(title_r), size=20)
    plt.grid(axis='both', alpha=.75)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    filename = f"hv_tb_fed_forecast_g_002_0{n:02d}.png"
    plt.savefig(filename, bbox_inches='tight')
    #plt.savefig(str("hv_tb_ycus_002_001_m_g_00"+str(time_n)+str(".png")), bbox_inches='tight')
    # Close the figure to free memory
    plt.close()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    n=n+1

### historical grpah fed sep

hv_tb_us_000_001_m3=hv_tb_us_000_001_m.copy()
#print(hv_tb_us_000_001_m3)

list_g = ["_gdp_median","_pcecore_median","_pce_median","_ur_median","_rate_median"]
n=1
for vb  in list_g:   
    df_filtered = hv_tb_us_000_001_m3.filter(like=str(vb))
    #print(f"shape {df_filtered.shape[1]}")
    # Generate colors dynamically
    num_cols = df_filtered.shape[1]
    colors = [plt.cm.Blues(0.9 - (i * 0.6 / max(num_cols - 1, 1))) for i in range(num_cols)]

    title_r = f"Historical_forecast_{vb}"
    y_label = "%"
    x_label = "Year"

    # Plot the line graph
    fig, ax = plt.subplots(figsize=(10, 6))
    
    for i, col in enumerate(df_filtered.columns):  # Iterate over filtered columns
        ax.plot(df_filtered.index, df_filtered[col], label=col, color=colors[i], linewidth=2)

    # Add labels, title, and grid
    ax.set_ylabel(y_label, fontsize=12)
    ax.set_xlabel(x_label, fontsize=12)
    ax.set_title(title_r, fontsize=14)
    ax.grid(axis='both', alpha=0.3)

    # Add legend
    ax.legend(title="Forecasts", loc="upper left", bbox_to_anchor=(-0.30, 1), fontsize=8, frameon=True)


    # Twin axis to match limits
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())

    # Save figure
    filename = f"hv_tb_fed_forecast_g_001_0{n:02d}.png"
    plt.savefig(filename, bbox_inches='tight')
    plt.close()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    n=n+1




    



    

# Filter DataFrame to only consider columns that contain "rate_ct_median"













#hv_tb_us_000_001_m2.to_clipboard()


### FInnacial balance


####### FInnacial balance


#Series 1: sa(S111ZCPP@G10) 
#  S111ZCPP@G10   [US: Private Sector Capital Balance as % of GDP(%)]
#Series 2: sa(S111ZCGP@G10) 
#  S111ZCGP@G10   [US: General Government Capital Balance as % of GDP (%)]
#Series 3: (-1 * sa(S111ZCWP@G10)) 
##  -1
#  S111ZCWP@G10   [US: Rest of the World Capital Balance as % of GDP (%)]


usi_m_tickers = ['s111zcpp', 's111zcgp',]
hv_tb_us_000_001_m=Haver.data(usi_m_tickers, "G10", dates=True)
print(hv_tb_us_000_001_m)
hv_tb_us_000_001_m.rename(columns={"s111zcpp": "US Private Sector Capital Balance"}, inplace=True)
hv_tb_us_000_001_m.rename(columns={"s111zcgp": "US General Govt Capital Balance"}, inplace=True)
hv_tb_usa_010_001_m_g_001=hv_tb_us_000_001_m.copy()
hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(120)

list_c=hv_tb_usa_010_001_m_g_001.columns.tolist()
title_r=""
y_label="Index %"

x_label=title_r
df1=hv_tb_usa_010_001_m_g_001.copy()
df1=df1.tail(36)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax, y=[list_c[0]], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[1]], color="darkblue", linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_013_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



#here to jump





### ----------------------------------------------------------------------------------------------------

### FED SCORE

#Comparable unit for comparison
#A 1% change in inflation may have different economic significance than a 1% change in unemployment. 
#We retrieve historical data, then let one standard deviation represent one unit for scoring purposes.
#Note that the past scores will thus be represented ex-post, which is to say, influenced by recent data.

#The dual mandate is not required to be explicitly stated numerically by the Federal Reserve, so we assign 
#explicit target values for unemployment and inflation (those frequently mentioned in Congressional testimonies
#and used as benchmarks by the market). These targets can be finely reset below so that the Fed performance can be re-evaluated.

#Sidenote: "The natural rate of unemployment [NAIRU, non-accelerating inflation rate of unemployment] is the 
#rate of unemployment arising from all sources except fluctuations in aggregate demand. Estimates of potential 
#GDP are based on the long-term natural rate. The short-term natural rate is used to gauge the amount of current 
#and projected slack in labor markets." See https://research.stlouisfed.org/fred2/series/NROU and Appendix 1 for details.

#  Set DUAL MANDATE, assumed throughout this notebook:
unem_target = 5.0
infl_target = 2.0

#  The Fed varies the targets over time, 
#  sometimes only implicitly. So for example,
#  there may be disagreement among Board members
#  regarding NAIRU -- but we set it to what
#  seems to be the prevalent market assumption.

#hv_tb_us_002_006_m.rename(columns={'jcxfebm': 'US PCE Core yy sa Monthly'}, inplace=True)
#hv_tb_us_002_006_m.rename(columns={'lr': 'US Unemployment Rate Monthly'}, inplace=True)
#hv_tb_us_002_006_m['year'] = hv_tb_us_002_006_m.index.year
#hv_tb_us_002_006_m = hv_tb_us_002_006_m.tail(240)

#Unemployment rate
date_000="1960-01-01"
hv_tb_fed_m_1=Haver.data("lr", "USECON", dates=True)
print(hv_tb_fed_m_1.index.min())
hv_tb_fed_m_1.rename(columns={'lr': 'unemployment'}, inplace=True)
hv_tb_fed_m_1 = hv_tb_fed_m_1[hv_tb_fed_m_1.index >date_000]
#unem = get( m4unemp )
#           m4 implies monthly frequency.
# #  Starts 1948-01-01, uncomment to view:
# stats( unem )
#  Standard deviation for unemployment rate:
unem_std = hv_tb_fed_m_1["unemployment"].std()
unem_std
#Y    1.638152
#  Uncomment to plot raw unemployment rate:
#  plot( unem )
#  Score unemployment as standard deviations from target: 
unem_score = ( (hv_tb_fed_m_1["unemployment"] - unem_target) / unem_std )
print(unem_score.shape[0])
#print(unem_score.shape[1])

#Inflation
#  Use synthetic inflation
#  which averages CPI and PCE for both headline and core versions:
hv_tb_fed_m_2=Haver.data("jcxfebm", "usecon", dates=True)
print(hv_tb_fed_m_2)
print(hv_tb_fed_m_2.index.min())
hv_tb_fed_m_2.rename(columns={'jcxfebm': 'pcec'}, inplace=True)
hv_tb_fed_m_2["pcec"] = hv_tb_fed_m_2["pcec"].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
hv_tb_fed_m_2
hv_tb_fed_m_2 = hv_tb_fed_m_2[hv_tb_fed_m_2.index >date_000]
infl_std = hv_tb_fed_m_2["pcec"].std()
infl_std
#Y    2.458588
infl_score = ( (hv_tb_fed_m_2["pcec"] - infl_target) / infl_std )
print(infl_score.shape[0])
#print(infl_score.shape[1])







#. Let u be the unemployment score and i the inflation score. (Note: we follow the Python/engineering convention by letting j be the imaginary number 
scores = [unem_score, infl_score, infl_score, infl_score]
scores = pd.DataFrame({"z_unem": unem_score,"z_infl": infl_score, "z": infl_score,"z_norm": infl_score})
print(scores)
#  Third and fouth columns are dummy placeholders to be replaced later.
scores.columns = ['z_unem', 'z_infl', 'z', 'z_norm']
#  Fill in THIRD column z as complex number per our discussion:
scores.z = scores.z_unem + (scores.z_infl * 1j)
#  The imaginary number in itself in Python is represented as 1j, 
#  since j may be a variable elsewhere.
scores.z_norm = abs( scores.z ) 
print(scores.tail())
print("---------------------------------------------------------------------------------------------")
print("step2")
title_r = "z_norm"
y_label = "%"
x_label = title_r
list_c = ["z_norm"]
df1 = scores.copy()
#df1 = df1.tail(tail_4)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[title_r], color="darkred", linewidth=2, linestyle='-',
        marker="D", markersize=0)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(0.5, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(1, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(2, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(3, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_015_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')

#In this scatter plot: z_unem is shown along the x-axis, z_infl along the y-axis, such that the color heat map
#depicts chronological movement from blue to green to red.
#The coordinate (0, 0) represents our Fed dual mandate, so it is easy to see deviations from target. 
#Geometrically a point's distance from the origin is what we have computed as fed_score (= z_norm, in the complex plane).

df006=scores.copy()
df006 = df006[df006.index >"2015-01-01"]
x_vb="z_unem"
y_vb="z_infl"

title_r = "Scatterplot z scores"
df00_sp=df006.copy()
df00_sp=df00_sp[[y_vb,x_vb]]
df00_sp['year'] = df00_sp.index.year
x = df00_sp[x_vb]
y = df00_sp[y_vb]
t = df00_sp['year']
y_label = y_vb
x_label = x_vb
print(len(x))
print(len(y))
df00_sp.index= df00_sp.index.date
g1=df00_sp.copy()
fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[x_vb], 
            g1[y_vb],
            c=g1.year,
            s=5,
            cmap="brg", zorder=2)
plt.plot(g1[x_vb],g1[y_vb],  
         zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 12):
    plt.annotate(
        g1.index[line],
        (g1[x_vb].iloc[line],g1[y_vb].iloc[line]),
        va="top",
        ha='right',
        size=6)
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axvline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_usa_015_001_m_g_003.png", bbox_inches='tight')
# Close the figure to free memory
plt.close()
plt.close()
plt.close('all')
plt.clf()
plt.cla()






#Unemployment rate
date_000="1980-01-01"
hv_tb_fed_m_1=Haver.data("lr", "USECON", dates=True)
print(hv_tb_fed_m_1.index.min())
hv_tb_fed_m_1.rename(columns={'lr': 'unemployment'}, inplace=True)
hv_tb_fed_m_1 = hv_tb_fed_m_1[hv_tb_fed_m_1.index >date_000]
#unem = get( m4unemp )
#           m4 implies monthly frequency.
# #  Starts 1948-01-01, uncomment to view:
# stats( unem )
#  Standard deviation for unemployment rate:
unem_std = hv_tb_fed_m_1["unemployment"].std()
unem_std
#Y    1.638152
#  Uncomment to plot raw unemployment rate:
#  plot( unem )
#  Score unemployment as standard deviations from target: 
unem_score = ( (hv_tb_fed_m_1["unemployment"] - unem_target) / unem_std )
print(unem_score.shape[0])
#print(unem_score.shape[1])

#Inflation
#  Use synthetic inflation
#  which averages CPI and PCE for both headline and core versions:
hv_tb_fed_m_2=Haver.data("jcxfebm", "usecon", dates=True)
print(hv_tb_fed_m_2)
print(hv_tb_fed_m_2.index.min())
hv_tb_fed_m_2.rename(columns={'jcxfebm': 'pcec'}, inplace=True)
hv_tb_fed_m_2["pcec"] = hv_tb_fed_m_2["pcec"].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
hv_tb_fed_m_2
hv_tb_fed_m_2 = hv_tb_fed_m_2[hv_tb_fed_m_2.index >date_000]
infl_std = hv_tb_fed_m_2["pcec"].std()
infl_std
#Y    2.458588
infl_score = ( (hv_tb_fed_m_2["pcec"] - infl_target) / infl_std )
print(infl_score.shape[0])
#print(infl_score.shape[1])




#. Let u be the unemployment score and i the inflation score. (Note: we follow the Python/engineering convention by letting j be the imaginary number 
scores = [unem_score, infl_score, infl_score, infl_score]
scores = pd.DataFrame({"z_unem": unem_score,"z_infl": infl_score, "z": infl_score,"z_norm": infl_score})
print(scores)
#  Third and fouth columns are dummy placeholders to be replaced later.
scores.columns = ['z_unem', 'z_infl', 'z', 'z_norm']
#  Fill in THIRD column z as complex number per our discussion:
scores.z = scores.z_unem + (scores.z_infl * 1j)
#  The imaginary number in itself in Python is represented as 1j, 
#  since j may be a variable elsewhere.
scores.z_norm = abs( scores.z ) 
print(scores.tail())
print("---------------------------------------------------------------------------------------------")
print("step2")
title_r = "z_norm"
y_label = "%"
x_label = title_r
list_c = ["z_norm"]
df1 = scores.copy()
#df1 = df1.tail(tail_4)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[title_r], color="darkred", linewidth=2, linestyle='-',
        marker="D", markersize=0)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(0.5, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(1, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(2, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axhline(3, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner), fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_usa_015_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')

#In this scatter plot: z_unem is shown along the x-axis, z_infl along the y-axis, such that the color heat map
#depicts chronological movement from blue to green to red.
#The coordinate (0, 0) represents our Fed dual mandate, so it is easy to see deviations from target. 
#Geometrically a point's distance from the origin is what we have computed as fed_score (= z_norm, in the complex plane).

df006=scores.copy()
df006 = df006[df006.index >"2015-01-01"]
x_vb="z_unem"
y_vb="z_infl"

title_r = "Scatterplot z scores"
df00_sp=df006.copy()
df00_sp=df00_sp[[y_vb,x_vb]]
df00_sp['year'] = df00_sp.index.year
x = df00_sp[x_vb]
y = df00_sp[y_vb]
t = df00_sp['year']
y_label = y_vb
x_label = x_vb
print(len(x))
print(len(y))
df00_sp.index= df00_sp.index.date
g1=df00_sp.copy()
fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[x_vb], 
            g1[y_vb],
            c=g1.year,
            s=5,
            cmap="brg", zorder=2)
plt.plot(g1[x_vb],g1[y_vb],  
         zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 12):
    plt.annotate(
        g1.index[line],
        (g1[x_vb].iloc[line],g1[y_vb].iloc[line]),
        va="top",
        ha='right',
        size=6)
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.axvline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_usa_015_002_m_g_003.png", bbox_inches='tight')
# Close the figure to free memory
plt.close()
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#https://github.com/rsvp/fecon235/blob/master/nb/fred-infl-unem-fed.ipynb











































#














### cleaning

import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()





### bottom <a id="bottom"></a>

- [Top](#table_contents)
