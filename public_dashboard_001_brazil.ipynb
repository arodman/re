# %% [markdown]
# ### 000 top  <a id="title_page"></a

# %% [markdown]
# ### 000 packages  <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %% [markdown]
# ### 001 brazil ifnlation  <a id="title_page"></a

# %%
country_database ="EMERGELA"

# %%
country_database ="EMERGELA"
bcb_m_tickers = ["n223ip", "n223ipfb", "n223ipw", "n2231pg", "n223ipa", "n223ipt",
                 "n223ipl", "n223ipm", "n223ipo", "n223ipr", "n223ipe", "n223ipc",
                 "s223ip", "s223ipfb", "s223ipw", "s223ipg", "s223ipa", "s223ipt", 
                 "s223ipl", "s223ipm", "s223ipo", "s223ipr", "s223ipe", "s223ipc",
                 "h223pca", "c223pca", "h223pcx", "c223pcx", "h223pcts", "c223pcts",
                 "h223pctn", "c223pctn", "h223pcxd", "n223pcxd"]
hv_tb_bra_001_001_m=Haver.data(bcb_m_tickers, country_database, dates=True)
print(hv_tb_bra_001_001_m)


for x in range(len(bcb_m_tickers)):
    variable=str(bcb_m_tickers[x])
    hv_tb_bra_001_001_m[variable]= hv_tb_bra_001_001_m[variable].pct_change(12).multiply(100).round(1)


hv_tb_bra_001_001_m.rename(columns={"h223pca": "ipca extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pca": "ipca extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcx": "ipca core extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcx": "ipca core extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcts": "ipca core trim smoothed extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcts": "ipca core trim smoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pctn": "ipca core trim nonsmoothed extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pctn": "ipca core trim nonsmoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcxd": "ipca core doublew sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223pcxd": "ipca core doublew nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ip": "ipca sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipfb": "ipca food beverage sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipw": "ipca dwellings sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipg": "ipca housing goods sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipa": "ipca clothing sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipt": "ipca transport sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipl": "ipca personal care sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipm": "ipca health services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipo": "ipca personal services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipr": "ipca recreational services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipe": "ipca education sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipc": "ipca communications sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ip": "ipca nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipfb": "ipca food beverage nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipw": "ipca dwellings nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipg": "ipca housing goods nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipa": "ipca clothing nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipt": "ipca transport nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipl": "ipca personal care nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipm": "ipca health services nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipo": "ipca personal services nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipr": "ipca recreational services nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipe": "ipca education nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipc": "ipca communications nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n2231p": "ipca 15 nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcn": "inpc sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c2231pcnb": "inpc nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n2231p8c": "sao paulo nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223pp": "sao paulo nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pp": "sao paulo sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pg1": "igp 10 nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pgm": "igp m nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pgd": "igp di nsa"}, inplace=True)


#bcb_list = hv_tb_bra_001_001_m.columns.tolist()
#for x in range(len(bcb_list)):
#    variable = str(bcb_list[x])
#    hv_tb_bra_001_001_m[variable] = hv_tb_bra_001_001_m[variable].pct_change(12).multiply(100).round(1)

hv_tb_bra_001_001_m = hv_tb_bra_001_001_m.tail(240)
hv_tb_bra_001_001_m_g = hv_tb_bra_001_001_m.copy()


#bcb_m_tickers = ["n223pidi",]
#hv_tb_ba_001_001_m = Hover.data(bcb_m_tickers, country_database, dates=True)
#for x in range(len(bcb_m_tickers)):
#    variable = str(bcb_m_tickers[x])
#    hv_tb_ba_001_001_m[variable] = hv_tb_ba_001_001_m[variable].pct_change(12).multiply(100).round(1)
# Out:
#              n223ip  n223ipfb  n223ipw  n2231pg  n223ipa  n223ipt  n223ipl  \
# 1990-01-31      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 1990-02-28      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 1990-03-31      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 1990-04-30      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 1990-05-31      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...       ...      ...      ...      ...      ...      ...
# 2024-09-30  162.342   178.811  162.722  139.887  149.689  161.345  177.485
# 2024-10-31  163.251   180.706  165.147  140.461  150.242  160.732  178.159
# 2024-11-30  163.888   183.507  162.620  140.615  150.062  162.162  178.052
# 2024-12-31  164.740   185.672  161.709  139.884  151.773  163.249  178.729
# 2025-01-31  165.003   187.455  156.729  140.891  151.560  165.371  179.980
#
# ...

# %% [markdown]
# ### inflation graph

# %%
df1 = hv_tb_bra_001_001_m_g.copy()
df1 = df1.tail(48)
for i in range(19):
    print(i)
    ai = f"{i:02}"
    print(ai)
    g1 = df1.copy()
    list_c = g1.columns.tolist()
    title_r = str(list_c[i])
    y_label = "Growth %"
    x_label = title_r
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax, y=list_c[i], color="darkred", linewidth=11, linestyle='-',
            marker='D', markersize=(s3-1))

    for x, y in zip(g1.index, g1[list_c[i]]):
        label = "{:.1f}".format(y)
        plt.annotate(label,  # this is the text
                     (x, y),  # these are the coordinates to position the Label
                     textcoords="offset points",  # how to position the text
                     xytext=(0, 15),  # distance from text to points (x, y)
                     size=7,
                     ha='center',
                     weight='bold')
    
    for series_name in list_c[i:(i+1)]:
        last_y_value = g1[series_name][-1]
        # print(last_y_value)
        plt.annotate(f'{series_name} \n ({last_y_value})',
                     xy=(g1.index.max(), last_y_value),
                     xytext=(20, -25),
                     textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
    
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=-parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()   
    ax2.set_ylim(ax.get_ylim())

    x_position = 0.5  # Adjust this value
    y_position = 0.5  # Adjust this value to place the text inside the plot
    
    plt.text(0.05, 0.5, "[BCB]",
             fontsize=12, transform=plt.gca().transAxes,
             bbox=dict(facecolor='white', alpha=0.5))  # Adding the text box
    
    plt.text(0.5, 0.5, "BRAZIL",
             fontsize=40, color="gray", alpha=0.5,
             ha='center', va='center', rotation=30,
             transform=plt.gca().transAxes)
    
    plt.text(0.15, 0.15, str(owner),
             fontsize=15, color="gray", alpha=0.5,
             ha='center', va='center', rotation=30,
             transform=plt.gca().transAxes)
    
    plt.savefig(str("hv_tb_bra_001_001_m_g_0" + str(ai) + ".png"), bbox_inches='tight')
    plt.savefig(str("hv_tb_bra_001_001_m_g_0" + str(ai) + "_bu.png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
# Out:
# 0
# 00
# 1
# 01
# 2
# 02
# 3
# 03
# 4
# 04
# 5
# 05
# 6
# 06
# 7
# 07
# 8
# 08
# 9
# 09
# 10
# 10
# 11
# 11
# 12
# 12
# 13
# 13
# 14
# 14
# 15
# 15
# 16
# 16
# 17
# 17
# 18
# 18

# %% [markdown]
# ### 001 brazil ifnlation  sa <a id="title_page"></a

# %%
country_database = "EMERGELA"
horizon_00=120

bcb_m_tickers = ["n223ip", "n223ipfb", "n223ipw", "n223ipg", "n223ipa", 
                 "n223ipt", "n223ipl", "n223ipm", "n223ipo", "n223ipr", "n223ipe", "n223ipc",
                 "s223ip", "s223ipfb", "s223ipw", "s223ipg", "s223ipa", 
                 "s223ipt", "s223ipl","s223ipm", "s223ipo", "s223ipr", "s223ipe", "s223ipc",
                 "h223pca", "c223pca", "h223pcx", "c223pcx", "h223pcts", 
                 "c223pcts", "h223pctn", "c223pctn", "h223pcxd", "n223pcxd"]
hv_tb_bra_001_001_m=Haver.data(bcb_m_tickers, country_database, dates=True)

#print(hv_tb_ba_001_001_m)
#print(hv_tb_ch_001_001_m)
#print(chf_m_tickers.columns)

for x in range(len(bcb_m_tickers)):
     #print(x)
     variable=str(bcb_m_tickers [x])
     #print(variable)
     hv_tb_bra_001_001_m[variable]= hv_tb_bra_001_001_m[variable].pct_change (12).multiply(100).round(1)
     #print(chf_m_tickers [variable])

hv_tb_bra_001_001_m.rename(columns={"h223pca": "ipca extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pca": "ipca extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcx": "ipca core extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcx": "ipca core extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcts": "ipca core trim smoothed extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcts": "ipca core trim smoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pctn":"ipca core trim nonsmoothed extended sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pctn":"ipca core trim nonsmoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223pcxd": "ipca core doublew sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223pcxd": "ipca core doublew nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ip": "ipca sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipfb": "ipca food beverage sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipw":"ipca dwellings sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipg": "ipca housing goods sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipa": "ipca clothing sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipt":"ipca transport sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipl": "ipca personal care sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipm": "ipca health services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipo": "ipca personal services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipr": "ipca recreational services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipe": "ipca education sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ipc": "ipca communications sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ip": "ipca nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n2231pfb": "ipca food beverage nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n2231pw": "ipca dwellings nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n2231pg": "ipca housing goods nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipe": "ipca clothing nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipt": "ipca transport nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipl": "ipca personal care nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipm": "ipca health services nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipo": "ipca personal services nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipr": "ipca recreational services nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipe": "ipca education nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ipc": "ipca communications nsa"}, inplace=True)


hv_tb_bra_001_001_m=hv_tb_bra_001_001_m.tail(240)

# %%
print(hv_tb_bra_001_001_m.columns.tolist())
#hv_tb_bra_001_001_m=hv_tb_bra_001_001_m[list_c]
#hv_tb_bra_001_001_m=hv_tb_bra_001_001_m[list_c]
hv_tb_bra_001_001_m_c=hv_tb_bra_001_001_m.copy()
hv_tb_bra_001_001_m_c=hv_tb_bra_001_001_m_c.tail(120)
#hv_tb_bra_001_001_m=hv_tb_bra_001_001_m.tail(60)
#"["Financial: International International eop nsa',
#'Financial: Nok improte weighted index avg',
#'Cycle: Norway Consumer Confidence next year Quarterly SA']
n_time=45
#size figure
#wide
size1=32
#height
size2=size1/1.1
##heatmaps inside
font_size_h=12
number_vbs=34
#x size Label axis
x_size1=17
#axis 2 Label
x2_size1=x_size1-5
xlabel_size=20
### axes-1 Loel sie dates
axes_1label=12
title_s=32
df1=hv_tb_bra_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows = df1.shape[0]

for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")
# Assuming you have a DataFrame named df1
num_rows = df1.shape[0]
for x in range(num_rows):
    locals()["data_r" + str(x)] = pd.DataFrame([df1.iloc[x]])

for x in range(num_rows):
    locals()["vmin_" + str(x)] = df1.iloc[:, x].min()
    locals()["vmax_" + str(x)] = df1.iloc[:, x].max()

print(vmin_0)
print(vmax_0)
# Example usage with random data
# data = np.random.random((10, 12))
# df = pd.DataFrame(data)
#df = pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)
#size 1 width
#size 2 height
print(number_vbs)
fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)                               
sns.heatmap(data_r0,cmap=red_to_blue, annot =True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1,cmap=red_to_blue, annot =True, ax=axes [1], cbar=False, vmin=vmin_1, vmax=vmax_1,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2,cmap=red_to_blue, annot =True, ax=axes [2], cbar=False, vmin=vmin_2, vmax=vmax_2,fmt='g',
           annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3,cmap=red_to_blue, annot= True, ax=axes [3], cbar=False, vmin=vmin_3, vmax=vmax_3,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4,cmap=red_to_blue, annot=True, ax=axes [4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5,cmap=red_to_blue, annot=True, ax=axes [5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6,cmap=red_to_blue, annot=True, ax=axes [6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7,cmap=red_to_blue, annot=True, ax=axes [7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8,cmap=red_to_blue, annot=True, ax=axes [8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9,cmap=red_to_blue, annot=True, ax=axes [9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10,cmap=red_to_blue, annot=True, ax=axes [10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11,cmap=red_to_blue, annot=True, ax=axes [11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12,cmap=red_to_blue, annot=True, ax=axes [12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13,cmap=red_to_blue, annot=True, ax=axes [13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14,cmap=red_to_blue, annot=True, ax=axes [14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15,cmap=red_to_blue, annot=True, ax=axes [15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16,cmap=red_to_blue, annot=True, ax=axes [16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=reversed_red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=reversed_red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=reversed_red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=reversed_red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=reversed_red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=reversed_red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_size1, rotation=0)
    locals() [str(str("axes_t")+str(n))]= ax.twinx()
    locals() [str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_size1, rotation=0,va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n=(n+1)

#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels (axis="x", which="both", Length=0, Labelrotation=45)
#.set_xticks([])
fig.suptitle("BRAZIL Inflation Dashboard ", fontsize=title_s)
plt.figtext(0.5,0.01, "BRAZIL Inflation Dashboard ", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout (rect=[0,0.03,1,0.97])
plt.savefig('brazil_heatmap_001.jpg', bbox_inches='tight', dpi=300)
plt.savefig('brazil_heatmap_001.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()
# Out:
# ['ipca nsa', 'n223ipfb', 'n223ipw', 'n223ipg', 'n223ipa', 'ipca transport nsa', 'ipca personal care nsa', 'ipca health services nsa', 'ipca personal services nsa', 'ipca recreational services nsa', 'ipca clothing nsa', 'ipca communications nsa', 'ipca sa', 'ipca food beverage sa', 'ipca dwellings sa', 'ipca housing goods sa', 'ipca clothing sa', 'ipca transport sa', 'ipca personal care sa', 'ipca health services sa', 'ipca personal services sa', 'ipca recreational services sa', 'ipca education sa', 'ipca communications sa', 'ipca extended sa', 'ipca extended nsa', 'ipca core extended sa', 'ipca core extended nsa', 'ipca core trim smoothed extended sa', 'ipca core trim smoothed extended nsa', 'ipca core trim nonsmoothed extended sa', 'ipca core trim nonsmoothed extended nsa', 'ipca core doublew sa', 'ipca core doublew nsa']
# -1.1
# 14.9
# 34

# %% [markdown]
# ### 001 brazil eco heatmpa  sa <a id="title_page"></a

# %%
# BRAZIL Economic Dashboard 
# BRAZIL Economic Dashboard 
# BRAZIL Economic Dashboard 

country_database = "EMERGELA"
horizon_00=120
bcb_m_tickers = ["n223elur", "n223eler", "n223rd","c223ro","n223xusv","s223gvv",
                 "s223giv", "s223ginv", "s223gsv", "s223nfim", "s223gvi",
                 "s223d", "n223er", "n223erpw",
                 "s223sran", "s223srn", "s223srav", "s223srv", "c223pca", "c223pcx", "c223pcts", "c223pctn", "n223pcxd",
                 "n2231p", "n223pp", "c223pg1", "c223pgm","c223pgd", "s223vccf", "h223vcc", "h223vcc"]
#"c223ro", "n223xusv","n223rd", "c223го",]
#    "s223gvv", "s223giv", "s223ginv", "s223gsv", "s223nfim", "s223gvi",]
#    ",]
#    "s223sran", "s223srn", "s223srav", "s223srv", "c223pca", "c223pcx", "c223pcts", "c223pctn", "n223pcxd",
#    "n2231p", "n223pp", "c223pg1", "c223pgm","c223pgd", "s223vccf", "h223vcc", "h223vcc"]

hv_tb_bra_001_001_m=Haver.data(bcb_m_tickers, country_database, dates=True)
# print(hv_tb_bra_001_001_m)
bcb_m_tickers1=["s223gvv", "s223giv", "s223ginv", "s223gsv", "s223nfim", "s223gvi",
    "s223d", "n223er", "n223erpw",
    "s223sran", "s223srn", "s223srav", "s223srv", "s223vccf", "h223vcc", "h223vcc",]
for x in range(len(bcb_m_tickers1)):
    variable=str(bcb_m_tickers1[x])
    hv_tb_bra_001_001_m[variable]= hv_tb_bra_001_001_m[variable].pct_change(12).multiply(100).round(1)


##monthyl
hv_tb_bra_001_001_m.rename(columns={"n223elur": "Employment: unemployment rate 3mmavg"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223eler": "Employment: employment rate 3mmavg"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223rd": "Financial: selic rate target rate eop"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223ro": "Financial: overnight rate over selic"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223xusv": "Financial: brlusd mid"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223gvv": "Real: fgv real gdp market price sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223giv": "Real: fgv real value added basic prices sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223ginv": "Real: fgv real value added industry sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223gsv": "Real: fgv real value added services sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223nfim": "Real: ipea gross fixed capital formation sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223gvi": "Real: brazil economic activity indicator ibc br sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223d": "Real: industrial production sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223er": "Real: real avg monthly earning"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223erpw": "Real: real avg monthly earning private sector contract"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223ervg": "Real: real avg monthly earning public sector"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223sran": "Real: retail trade extended nominal value sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223srn": "Real: retail trade headline nominal value sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223srav": "Real: retail trade extended volume sales sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223srv": "Real: retail trade headline volume sales sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pca": "Price: ipca extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcx": "Price: ipca core extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcts": "Price: ipca core trim smoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pctn":"Price: ipca core trim nonsmoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223pcxd": "Price: ipca core doublew nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223sran": "Real: retail trade extended nominal value sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223srn": "Real: retail trade headline nominal value sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223srav": "Real: retail trade extended volume sales sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223srv": "Real: retail trade headline volume sales sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pca": "Price: ipca extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcx": "Price: ipca core extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pcts": "Price: ipca core trim smoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pctn": "Price: ipca core trim nonsmoothed extended nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223pcxd": "Price: ipca core doublew nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n2231p": "Price: ipca 15 nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c2231pcnb": "Price: inpc nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"n223pp": "Price: sao paulo nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pg1": "Price: igp 10 nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pgm": "Price: igp m nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"c223pgd": "Price: igp di nsa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"s223vccf": "Cycle: consumer confidence index fgv sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223vcc": "Cycle: consumer confidence index fecomercio sa"}, inplace=True)
hv_tb_bra_001_001_m.rename(columns={"h223vcc": "Cycle: economic policy uncertainty news based nsa"}, inplace=True)


print(len(hv_tb_bra_001_001_m.columns.tolist()))
print(hv_tb_bra_001_001_m.shape[0])
print(hv_tb_bra_001_001_m.shape[1])
#hv_tb_mex_001_001_m.to_clipboard()
hv_tb_bra_001_001_m=hv_tb_bra_001_001_m.tail(200)
#M008_dashboard_eco_mexico
# Out:
# 30
# 464
# 30

# %%
n_time=45
#size figure
#wide
size1=32
#height
size2=size1/1.1
##heatmaps inside
font_size_h=10
number_vbs=34
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_bra_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals() [str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):                                                       
    locals()[str(str("vmin_")+str(x))] = df1.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = df1.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)
#size 1 width
#size 2 height
print(number_vbs)
fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)        

sns.heatmap(data_r0,cmap=red_to_blue, annot =True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1,cmap=red_to_blue, annot =True, ax=axes [1], cbar=False, vmin=vmin_1, vmax=vmax_1,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2,cmap=red_to_blue, annot =True, ax=axes [2], cbar=False, vmin=vmin_2, vmax=vmax_2,fmt='g',
           annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3,cmap=red_to_blue, annot= True, ax=axes [3], cbar=False, vmin=vmin_3, vmax=vmax_3,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4,cmap=red_to_blue, annot=True, ax=axes [4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5,cmap=red_to_blue, annot=True, ax=axes [5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6,cmap=red_to_blue, annot=True, ax=axes [6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7,cmap=red_to_blue, annot=True, ax=axes [7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8,cmap=red_to_blue, annot=True, ax=axes [8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9,cmap=red_to_blue, annot=True, ax=axes [9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10,cmap=red_to_blue, annot=True, ax=axes [10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11,cmap=red_to_blue, annot=True, ax=axes [11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12,cmap=red_to_blue, annot=True, ax=axes [12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13,cmap=red_to_blue, annot=True, ax=axes [13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14,cmap=red_to_blue, annot=True, ax=axes [14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15,cmap=red_to_blue, annot=True, ax=axes [15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16,cmap=red_to_blue, annot=True, ax=axes [16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size":font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=reversed_red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=reversed_red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=reversed_red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=reversed_red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=reversed_red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=reversed_red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals() [str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0,va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n=(n+1)
#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15,size=0)
#axes[-1].set_xticklabels (axis="x", which="both", length=0, Labelrotation=45)
#.set_xticks([])
fig.suptitle("BRAZIL Economic Dashboard ", fontsize=title_s)
plt.figtext(0.5,0.01, "BRAZIL Economic Dashboard ", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('brazil_heatmap_002.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()
# Out:
# -189.4
# 5769.98
# 34

# %% [markdown]
# ### 001 brazil eco heatmap bird eye   sa

# %%
hv_tb_bra_001_001_m_g=hv_tb_bra_001_001_m.copy()
list_c=hv_tb_bra_001_001_m_g.columns.tolist()
print("start right here")
parameter1_o=6
parameter2_o=4
tail_n=102
tail_n2=48
linew=2
mks=0.5
print(" ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave ")
n=1
for y in list_c:
    print(y)
    #print("filtering time horizon")
    df1=hv_tb_bra_001_001_m_g.copy()
    df1=pd.DataFrame(df1[str(y)])
    #List_c=df1.columns.tolist()


    df1=df1.tail(90)
    g1=df1.copy()
    fig, ax = plt.subplots(figsize=((parameter1_o-1), (parameter2_o)))
    g1.plot(kind='line', ax=ax, y=str(y), 
         color="orange",
         linestyle='-', 
         linewidth= (linew+1),
         marker='o',
         markersize=mks)
    x_last = g1.index[-1]
    y_last = g1[str(y)].iloc[-1]
    #gl.index[-1] # Assuming the DataFrame index is date or sequential
    
    #Annotate the last value on the right of the plot Line
    ax.annotate(f'{y_last:.2f}',
    xy=(x_last, y_last),
    xytext=(10, 0),
    textcoords="offset points",
    ha='left',
    va="center",
    color="orange",
    size=17,
    weight="bold")
    
    plt.style.use('default')
    #plt.ylabel(str(y_label), size-parameter3)
    #plt.xlabel(str(x_label), size-parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2=ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("hv_tb_bra_ov"+str(n)+".png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    #del List_c
    del fig
    del ax
    del ax2
    n=n+1
# Out:
# start right here
#  ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave
# Employment: unemployment rate 3mmavg
# Employment: employment rate 3mmavg
# Financial: selic rate target rate eop
# Financial: overnight rate over selic
# Financial: brlusd mid
# Real: fgv real gdp market price sa
# Real: fgv real value added basic prices sa
# Real: fgv real value added industry sa
# Real: fgv real value added services sa
# Real: ipea gross fixed capital formation sa
# Real: brazil economic activity indicator ibc br sa
# Real: industrial production sa
# Real: real avg monthly earning
# Real: real avg monthly earning private sector contract
# Real: retail trade extended nominal value sa
# Real: retail trade headline nominal value sa
# Real: retail trade extended volume sales sa
# Real: retail trade headline volume sales sa
# Price: ipca extended nsa
# Price: ipca core extended nsa
# Price: ipca core trim smoothed extended nsa
# ...

# %%
#####Forecasts

# %% [markdown]
# ### 001 brazil focus forecast   sa

# %%
country_database = "EMERGELA"
bri_m_tickers1 =["i223ipm","i223ica","i223ipl","i223ips","i223ipi","i223ipa","i223ipd",
                 "i223tpm","i223tca","i223tpl","i223tps","i223tpi","i223tpa","i223tpd",
                 "i223ipme","i223icae","i223iple","i223ipse","i223ipie","i223ipae","i223ipde",
                 "i223tpme","i223tcae","i223tple","i223tpse","i223tpie","i223tpae","i223tpde"]
hv_tb_br_000_001_m = Haver.data(bri_m_tickers1, country_database, dates=True)
print(hv_tb_br_000_001_m)
table_F=hv_tb_br_000_001_m.copy()
table_F=table_F.tail(12)
table_F=table_F.round(2)
#hv_tb_uk_002_005_m_g_001 = hv_tb_uk_002_005_m.copy()
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.tail(horizon_1)
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.transpose()
#hv_tb_uk_002_005_m.index.names = ['Variable']
#hv_tb_uk_002_005_m['Variable_'] = hv_tb_uk_002_005_m.index
## dashboard.to_clipboard()
#print(hv_tb_uk_002_005_m)

table_F.rename(columns={"i223ipm": "Focus: inf 12m IGPM last30d avg"}, inplace=True)
table_F.rename(columns={"i223ica": "Focus: inf 12m IPCA last30d avg"}, inplace=True)
table_F.rename(columns={"i223ipl": "Focus: inf 12m IPCA free last30d avg"}, inplace=True)
table_F.rename(columns={"i223ips": "Focus: inf 12m IPCA services last30d avg"}, inplace=True)
table_F.rename(columns={"i223ipi": "Focus: inf 12m IPCA goods last30d avg"}, inplace=True)
table_F.rename(columns={"i223ipa": "Focus: inf 12m IPCA foodhome last30d avg"}, inplace=True)
table_F.rename(columns={"i223ipd": "Focus: inf 12m IPCA regulated last30d avg"}, inplace=True)

table_F.rename(columns={"i223tpm": "Focus: inf 12m IGPM last5d avg"}, inplace=True)
table_F.rename(columns={"i223tca": "Focus: inf 12m IPCA last5d avg"}, inplace=True)
table_F.rename(columns={"i223tpl": "Focus: inf 12m IPCA free last5d avg"}, inplace=True)
table_F.rename(columns={"i223tps": "Focus: inf 12m IPCA services last5d avg"}, inplace=True)
table_F.rename(columns={"i223tpi": "Focus: inf 12m IPCA goods last5d avg"}, inplace=True)
table_F.rename(columns={"i223tpa": "Focus: inf 12m IPCA foodhome last5d avg"}, inplace=True)
table_F.rename(columns={"i223tpd": "Focus: inf 12m IPCA regulated last5d avg"}, inplace=True)

table_F.rename(columns={"i223ipme": "Focus: inf 12m IGPM last30d eop"}, inplace=True)
table_F.rename(columns={"i223icae": "Focus: inf 12m IPCA last30d eop"}, inplace=True)
table_F.rename(columns={"i223iple": "Focus: inf 12m IPCA free last30d eop"}, inplace=True)
table_F.rename(columns={"i223ipse": "Focus: inf 12m IPCA services last30d eop"}, inplace=True)
table_F.rename(columns={"i223ipie": "Focus: inf 12m IPCA goods last30d eop"}, inplace=True)
table_F.rename(columns={"i223ipae": "Focus: inf 12m IPCA foodhome last30d eop"}, inplace=True)
table_F.rename(columns={"i223ipde": "Focus: inf 12m IPCA regulated last30d eop"}, inplace=True)

table_F.rename(columns={"i223tpme": "Focus: inf 12m IGPM last5d eop"}, inplace=True)
table_F.rename(columns={"i223tcae": "Focus: inf 12m IPCA last5d eop"}, inplace=True)
table_F.rename(columns={"i223tple": "Focus: inf 12m IPCA free last5d eop"}, inplace=True)
table_F.rename(columns={"i223tpse": "Focus: inf 12m IPCA services last5d eop"}, inplace=True)
table_F.rename(columns={"i223tpie": "Focus: inf 12m IPCA goods last5d eop"}, inplace=True)
table_F.rename(columns={"i223tpae": "Focus: inf 12m IPCA foodhome last5d eop"}, inplace=True)
table_F.rename(columns={"i223tpde": "Focus: inf 12m IPCA regulated last5d eop"}, inplace=True)


df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=800,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_br_forecast_001.png')
# Out:
#             i223ipm  i223ica  i223ipl  i223ips  i223ipi  i223ipa  i223ipd  \
# 2001-11-30   7.8300   5.5153      NaN      NaN      NaN      NaN      NaN
# 2001-12-31   7.0285   5.2640      NaN      NaN      NaN      NaN      NaN
# 2002-01-31   5.9482   4.7232      NaN      NaN      NaN      NaN      NaN
# 2002-02-28   6.0868   4.6911      NaN      NaN      NaN      NaN      NaN
# 2002-03-31   6.1795   4.7935      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# 2024-09-30   4.1171   4.0135   4.0954   4.8596   3.0579   4.3352   3.4359
# 2024-10-31   4.3403   4.0766   4.2723   4.9035   2.9606   5.2031   3.0727
# 2024-11-30   4.4624   4.2305   4.7699   5.1786   3.0561   6.4857   2.6630
# 2024-12-31   4.8754   4.7350   5.1805   5.4888   3.5178   6.8788   3.4598
# 2025-01-31   4.8967   5.1725   5.4212   5.7703   3.8659   6.7740   4.4782
#
#             i223tpm  i223tca  i223tpl  ...  i223ipie  i223ipae  i223ipde  \
# ...

# %% [markdown]
# ### brazil focus1  forecast table

# %%
#table_F_m_g = table_F_m.copy()
#table_F_m_g_001 = table_F_m.copy()

#table_F_m.index=table_F_m.index.date
#table_F_m = table_F_m.tail(horizon_tb)
#table_F_t1=table_F_m.tail(horizon_tb)#

#table_F_m_t = table_F_m.transpose()
#table_F_m_t.index.names = ['Variable']
#
#table_F_t1_t = table_F_t1.transpose()
#table_F_t1_t.index.names = ['Variable']
#############################################################
######Table 1

# %% [markdown]
# ### brazil focus ipca forecast2  table

# %%
country_database = "EMERGELA"
bri_m_tickers1 =["i223ica","i223tca","i223icae","i223tcae",]
hv_tb_br_000_001_m = Haver.data(bri_m_tickers1, country_database, dates=True)
table_F=hv_tb_br_000_001_m.copy()
table_F=table_F.tail(12)
table_F=table_F.round(2)
#hv_tb_uk_002_005_m_g_001 = hv_tb_uk_002_005_m.copy()
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.tail(horizon_1)
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.transpose()
#hv_tb_uk_002_005_m.index.names = ['Variable']
#hv_tb_uk_002_005_m['Variable_'] = hv_tb_uk_002_005_m.index
## dashboard.to_clipboard()
#print(hv_tb_uk_002_005_m)


table_F.rename(columns={"i223ica": "Focus: inf 12m IPCA last30d avg"}, inplace=True)
table_F.rename(columns={"i223tca": "Focus: inf 12m IPCA last5d avg"}, inplace=True)
table_F.rename(columns={"i223icae": "Focus: inf 12m IPCA last30d eop"}, inplace=True)
table_F.rename(columns={"i223tcae": "Focus: inf 12m IPCA last5d eop"}, inplace=True)



df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=800,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_br_forecast_002.png')

# %%
### brazil ipca evolving

# %%
country_database = "EMERGELA"
bri_m_tickers1 =["q223c24m","q223c24e","u223c24m","u223c24e",
                        "q223c25m","q223c25e","u223c25m","u223c25e",
                        "q223c26m","q223c26e","u223c26m","u223c26e",
                        "q223c27m","q223c27e","u223c27m","u223c27e"]
hv_tb_br_000_001_m = Haver.data(bri_m_tickers1, country_database, dates=True)
table_F=hv_tb_br_000_001_m.copy()
table_F=table_F.tail(12)
table_F=table_F.round(2)



table_F.rename(columns={"q223c24m": "Focus: 2024 IPCA median last 5d avg"}, inplace=True)
table_F.rename(columns={"q223c24e": "Focus: 2024 IPCA median last 5d eop"}, inplace=True)
table_F.rename(columns={"u223c24m": "Focus: 2024 IPCA median last 30d avg"}, inplace=True)
table_F.rename(columns={"u223c24e": "Focus: 2024 IPCA median last 30d eop"}, inplace=True)

table_F.rename(columns={"q223c25m": "Focus: 2025 IPCA median last 5d avg"}, inplace=True)
table_F.rename(columns={"q223c25e": "Focus: 2025 IPCA median last 5d eop"}, inplace=True)
table_F.rename(columns={"u223c25m": "Focus: 2025 IPCA median last 30d avg"}, inplace=True)
table_F.rename(columns={"u223c25e": "Focus: 2025 IPCA median last 30d eop"}, inplace=True)

table_F.rename(columns={"q223c26m": "Focus: 2026 IPCA median last 5d avg"}, inplace=True)
table_F.rename(columns={"q223c26e": "Focus: 2026 IPCA median last 5d eop"}, inplace=True)
table_F.rename(columns={"u223c26m": "Focus: 2026 IPCA median last 30d avg"}, inplace=True)
table_F.rename(columns={"u223c26e": "Focus: 2026 IPCA median last 30d eop"}, inplace=True)

table_F.rename(columns={"q223c27m": "Focus: 2027 IPCA median last 5d avg"}, inplace=True)
table_F.rename(columns={"q223c27e": "Focus: 2027 IPCA median last 5d eop"}, inplace=True)
table_F.rename(columns={"u223c27m": "Focus: 2027 IPCA median last 30d avg"}, inplace=True)
table_F.rename(columns={"u223c27e": "Focus: 2027 IPCA median last 30d eop"}, inplace=True)



df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=800,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_br_forecast_003.png')

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_bra_001_001_m
# Deleting DataFrame: hv_tb_bra_001_001_m_g
# Deleting DataFrame: hv_tb_bra_001_001_m_c
# Deleting DataFrame: data_r0
# Deleting DataFrame: data_r1
# Deleting DataFrame: data_r2
# Deleting DataFrame: data_r3
# Deleting DataFrame: data_r4
# Deleting DataFrame: data_r5
# Deleting DataFrame: data_r6
# Deleting DataFrame: data_r7
# Deleting DataFrame: data_r8
# Deleting DataFrame: data_r9
# Deleting DataFrame: data_r10
# Deleting DataFrame: data_r11
# Deleting DataFrame: data_r12
# Deleting DataFrame: data_r13
# Deleting DataFrame: data_r14
# Deleting DataFrame: data_r15
# Deleting DataFrame: data_r16
# Deleting DataFrame: data_r17
# Deleting DataFrame: data_r18
# Deleting DataFrame: data_r19
# Deleting DataFrame: data_r20
# Deleting DataFrame: data_r21
# Deleting DataFrame: data_r22
# Deleting DataFrame: data_r23
# Deleting DataFrame: data_r24
# Deleting DataFrame: data_r25
# Deleting DataFrame: data_r26
# Deleting DataFrame: data_r27
# ...

# %%
print("Comeplte")
# Out:
# Comeplte

# %% [markdown]
# ### 001 bottom
