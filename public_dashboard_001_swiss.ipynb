# %% [markdown]
# ### 000 top  <a id="title_page"></a

# %% [markdown]
# ### 000 packages  <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap


parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %% [markdown]
# ### 001 swiss inflation expectations <a id="title_page"></a

# %%
#chnvies #switzerland inflation expectations 6-12 months
#chnviel #switzerland inflation expectations 3-5 years
country_database = ["ALPMED"]
chf_m_tickers = ['chnvies', 'chnviel']
hv_tb_ch_001_001_m = Haver.data(chf_m_tickers, country_database, dates=True)
hv_tb_ch_001_001_m.rename(columns={"chnvies":"Swiss Inflation Expectations 6-12m survey"}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={"chnviel":"Swiss Inflation Expectations 3-5y survey"}, inplace=True)
#hv_tb_ch_001_001_m_g=hv_tb_ch_001_001_m.copy()
#hv_tb_ch_001_001_m = hv_tb_ch_001_001_m.transpose()
#hv_tb_ch_001_001_m.index.names = ['Variable']


hv_tb_ch_001_001_m_g = hv_tb_ch_001_001_m.copy()
hv_tb_ch_001_001_m_g_001 = hv_tb_ch_001_001_m.copy()

hv_tb_ch_001_001_m.index=hv_tb_ch_001_001_m.index.date
hv_tb_ch_001_001_m = hv_tb_ch_001_001_m.tail(horizon_tb)
hv_tb_ch_001_001_t1=hv_tb_ch_001_001_m.tail(horizon_tb)

hv_tb_ch_001_001_m_t = hv_tb_ch_001_001_m.transpose()
hv_tb_ch_001_001_m_t.index.names = ['Variable']

hv_tb_ch_001_001_t1_t = hv_tb_ch_001_001_t1.transpose()
hv_tb_ch_001_001_t1_t.index.names = ['Variable']
############################################################

# %% [markdown]
# ### 001 swiss inflation expectations table

# %%
######Table 1

#####here*******
title_table="swiss_inflation_expectations"
df =hv_tb_ch_001_001_t1.copy()
df_transposed = hv_tb_ch_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_chf_001_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_ch_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_chf_001_001_m_t_002.png')

# %% [markdown]
# ### 001 swiss inflation expectations graphs

# %%
#print("step2")
df1 = hv_tb_ch_001_001_m_g.copy()
df1 = df1.tail(24)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
y_label = "Growth %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="darkgreen", linewidth=11, linestyle='-', marker='o', markersize=13)
for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha='center')

for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name}: {last_y_value}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, '[Swiss]', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor="white", alpha=0.85))  # Adding the text box
plt.text(0.5, 0.5, 'SNB', fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_chf_001_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')

# %%
df1 = hv_tb_ch_001_001_m_g.copy()
df1 = df1.tail(24)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[1])
y_label = "Growth %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=l1, linestyle='-', marker='o', markersize=13)
for x, y in zip(g1.index, g1[list_c[1]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha='center')

for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name}: {last_y_value}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, '[Swiss]', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor="white", alpha=0.85))  # Adding the text box
plt.text(0.5, 0.5, 'SNB', fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_chf_001_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')

# %%
#Quarterly
#Swiss national bank conditional forecasts, Forecasts based on assumption SNB policy rate remains unchanged over next 3 years
#chpco
country_database=["ALPMED"]
chf_m_tickers = ['chpcq',]
hv_tb_ch_001_001_m = Haver.data(chf_m_tickers, country_database, dates=True)
#print(hv_tb_ch_001_001_m)
#print(chftichers.columns)
hv_tb_ch_001_001_m.rename(columns={"chpcq":"SNB Headline Inflation Conditional forecast Quarterly"}, inplace=True)
#hv_tb_ch_001_001_m = hv_tb_ch_001_001_m.tail(horizon_tb)
hv_tb_ch_001_001_m_g=hv_tb_ch_001_001_m.copy()
hv_tb_ch_001_001_m=hv_tb_ch_001_001_m.transpose()
hv_tb_ch_001_001_m.index.names = ["Variable"]
df1=hv_tb_ch_001_001_m_g.copy()
df1=df1.tail(24)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r = str(list_c[0])
y_label = "Growth"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="black", linewidth=11, linestyle='-', marker='o', markersize=3)

for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0,18),  # distance from text to points (x, y)
                 size=7,
                 ha='center')

for series_name in list_c[0:13]:
    last_y_value = g1[series_name][-1]
    # print(Last_y_value)
    plt.annotate(f" {series_name} {last_y_value}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=3)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, 'Forecast based on assumption SNB policy rate remains unchanged over next 3y', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'SNB', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_chf_001_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#det gi
#del df1
del list_c
del fig
del ax
del ax2

# %% [markdown]
# ### 001 swiss inflation nsa <a id="title_page"></a

# %%
#Montchy
#Cpi headline nsa Switzerland
#chnoc
#Core inflation 1 is CPI excluding fresh and seasonal products, energy
#and fuel.
#CHINPCOR1
#ore inflation 2 is CPI excluding fresh and seasonal products, energy,
#fuel and products with administered prices.
#CHNPCOR2
#GOODS INFLATION NSA
#CHNPCI SITZERLAN cpi goods
#services nsa
#chnpcst services
#Dosmestic good services
#chnocgsd
#Foreign goods services
#chnpcgsf
country_database = 'ALPMED'
chf_m_tickers = ['chnpc', 'chnpcor1', 
                 'chnpcor2', 'chnpci',
                 'chnpcst', 'chnpcgsd',
                 'chnpcgsf']
hv_tb_ch_001_001_m = Haver.data(chf_m_tickers, country_database, dates=True)
#print(chf_m_tickers.columns)
for x in range(len(chf_m_tickers)):
    variable = str(chf_m_tickers[x])
    #print(variable)
    hv_tb_ch_001_001_m[variable] = hv_tb_ch_001_001_m[variable].pct_change(12).multiply(100).round(1)
    #print(chf_m_tickers[variable])

hv_tb_ch_001_001_m.rename(columns={'chnpc': 'Swiss Headline Inflation CPI NSA'}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={'chnpcor1': 'Swiss Core1 Inflation NSA'}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={'chnpcor2': 'Swiss Core2 Inflation NSA'}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={'chnpci': 'Swiss Goods Inflation NSA'}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={'chnpcst': 'Swiss Services Inflation NSA'}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={'chnpcgsd': 'Swiss Domestic GS NSA'}, inplace=True)
hv_tb_ch_001_001_m.rename(columns={'chnpcgsf': 'Swiss Foreign GS NSA'}, inplace=True)

#hv_tb_ch_001_001_m=hv_tb_ch_001_001_m.tail(horizon_tb)
#hv_tb_ch_001_001_m_g=hv_tb_ch_001_001_m.copy()
#hv_tb_ch_001_001_m=hv_tb_ch_001_001_m.transpose()
#hv_tb_ch_001_001_m.index.names=['Variable']
#dashboard.to_clipboard()
#dashboard.to_clipboard()

#print(path_display)
#hv_tb_ch_001_001_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_ou_006_001_m)
#print("step2")


hv_tb_ch_001_001_m_g = hv_tb_ch_001_001_m.copy()
hv_tb_ch_001_001_m_g_001 = hv_tb_ch_001_001_m.copy()

hv_tb_ch_001_001_m.index=hv_tb_ch_001_001_m.index.date
hv_tb_ch_001_001_m = hv_tb_ch_001_001_m.tail(horizon_tb)
hv_tb_ch_001_001_t1=hv_tb_ch_001_001_m.tail(horizon_tb)

hv_tb_ch_001_001_m_t = hv_tb_ch_001_001_m.transpose()
hv_tb_ch_001_001_m_t.index.names = ['Variable']

hv_tb_ch_001_001_t1_t = hv_tb_ch_001_001_t1.transpose()
hv_tb_ch_001_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001 swiss inflation 001 003 table

# %%
############################################################
######Table 1

#####here*******
title_table="swiss_inflation_yy_table"
df =hv_tb_ch_001_001_t1.copy()
df_transposed = hv_tb_ch_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_chf_001_003_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_ch_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_chf_001_003_m_t_002.png')

# %% [markdown]
# ### 001 swiss inflation 001 003 graphgs

# %%
df1=hv_tb_ch_001_001_m_g.copy()
df1=df1.tail(36)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[0])
y_label="Growth %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind="line", ax=ax, y=list_c[0], color="darkgreen", linewidth=1.1, linestyle="-")
for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(8, 18),  # distance from text to points (x,y)
                 ha='center')

for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f"{series_name} : {last_y_value}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, '[Swiss]', 
         fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor="white", alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'SNB', 
         fontsize=40, color="gray", alpha=0.5,
         ha='center', va='center',
         rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_chf_001_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# det gi
# det dfi
del list_c
del fig
del ax
del ax2

# %%
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[1])
y_label = "Growth %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=1, linestyle='',
        marker="o", markersize=3)
for x, y in zip(g1.index, g1[list_c[1]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha='center')
for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f"{series_name} {last_y_value}", 
                 xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), 
                 textcoords="offset points", 
                 arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 8.5  # Adjust this value to place the text inside the plot

#plt.text(0.1, 8.5, 'CPI excluding fresh and seasonal products, energy and fuel', fontsize=12, transform=plt.gca().transAxes,
#         bbox=dict(facecolor='white', 
#                   alpha=0.5)) # Adding the text box

plt.text(0.5, 0.5, 'SNB', 
         fontsize=40, 
         color="gray", alpha=0.5,
         ha='center', va='center',
         rotation=30, transform=plt.gca().transAxes)

plt.savefig("hv_tb_chf_001_003_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# del gl
# del df1
del list_c
del fig
del ax
del ax2

# %%
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[1])
y_label = "Growth %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[2], color="darkgreen", linewidth=l1, linestyle="-", marker="o", markersize=3)
# Annotate the last y-value
for x, y in zip(g1.index, g1[list_c[2]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(8, 18),  # distance from text to points (x, y)
                 size=6,
                 ha='center')

# Annotate the last y-value of each series
for series_name in list_c[2:3]:
    last_y_value = g1[series_name].iloc[-1]
    plt.annotate(f'({series_name}) ({last_y_value})', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))

# Add a horizontal line at y=0
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
# Set the plot style
plt.style.use("default")
# Set the labels and title
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
# Add grid lines
plt.grid(axis='both', alpha=.3)
# Add a twin x-axis
ax2 = ax.twinx()
# Set the y-limits of the twin axis
ax2.set_ylim(ax.get_ylim())
# Adjust the position of the text box
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot

# Add a text box to the plot
plt.text(0.1, 0.5, 'CPI excluding fresh and seasonal products, energy, fuel and products with administered prices', 
         fontsize=12, transform=plt.gca().transAxes, bbox=dict(facecolor="white", alpha=0.5)) # Adding the text box
plt.text(0.5, 0.5, 'SNB', 
         fontsize=40, 
         color="gray",
         alpha=0.5,
         ha='center', va='center',
         rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_chf_001_003_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#del gi
#del of1
del list_c
del fig
del ax
del ax2

# %%
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[3])
y_label = "Growth"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[3], color="darkgreen", linewidth=11, linestyle="-",
        marker='o', markersize=s3)
for x, y in zip(g1.index, g1[list_c[3]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),   # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha='center')
for series_name in list_c[3:4]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f"{series_name} ({last_y_value})", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), 
                 textcoords="offset points", 
                 arrowprops=dict(facecolor="black", arrowstyle='->'))
plt.axhline(0, color='black', lw=1, 
            linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, 'Swiss', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor="white", alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'SNB', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)

plt.savefig("hv_tb_chf_001_003_m_g_004.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()

plt.cla()

# del df
# del dfl

del list_c
del fig
del ax
del ax2

# %%
### 001 swiss inflation forecasts <a id="title_page"></a

# %%
#forecassts

# %%
#Swiss National Bank Conditional Inflation Forecasts [1] 
#Forecasts are based on the assumption that the 
#SNB Policy Rate (shown inside the parentheses) 
#remains unchanged over the next 3 years 
#Year-over-Year Percent Change

# %%
country_database = "ALPMED"
uki_m_tickers1 = ['chpcq',]
hv_tb_uk_000_001_m = Haver.data(uki_m_tickers1, country_database, dates=True)



uk_m_tickers=uki_m_tickers1
print(hv_tb_uk_000_001_m)
table_F=hv_tb_uk_000_001_m.copy()






table_F.rename(columns={"chpcq": "SNB-F Inflation constant rate"}, inplace=True)


df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=800,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_chf_forecast_001.png')
# Out:
#             chpcq
# 2024-12-31    0.7
# 2025-03-31    0.3
# 2025-06-30    0.2
# 2025-09-30    0.3
# 2025-12-31    0.5
# 2026-03-31    0.8
# 2026-06-30    0.8
# 2026-09-30    0.8
# 2026-12-31    0.7
# 2027-03-31    0.7
# 2027-06-30    0.7
# 2027-09-30    0.7

# %% [markdown]
# ### cleaning

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_ch_001_001_m
# Deleting DataFrame: hv_tb_ch_001_001_m_g
# Deleting DataFrame: hv_tb_ch_001_001_m_g_001
# Deleting DataFrame: hv_tb_ch_001_001_t1
# Deleting DataFrame: hv_tb_ch_001_001_m_t
# Deleting DataFrame: hv_tb_ch_001_001_t1_t
# Deleting DataFrame: df
# Deleting DataFrame: df_transposed
# Deleting DataFrame: df1
# Deleting DataFrame: g1
# Deleting DataFrame: hv_tb_uk_000_001_m
# Deleting DataFrame: table_F
# Environment cleaned!

# %% [markdown]
# ### bottom
